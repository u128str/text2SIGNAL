# %% [markdown]
# # Get and Extract Signals from Signavio sources: API calls to workspaces and load from saved JSON files
# This notebook provides a collection of cells where we extract Signals from several workspaces by means of Signavio API backend calls.
# You would need Signavio credentials - check if you can access:
#
# https://editor.signavio.com/g/statics/pi/areas
#
# Create *.env* file
# ```js
# MY_SIGNAVIO_PASSWORD=*****
# MY_SIGNAVIO_NAME=alexey.streltsov@sap.com
# ```

# %% [markdown]
# # Credentials / API  initialization

# %%
import sys
sys.path.append("./")
print(sys.path)
# Out:
# ['/Users/d071211/projects/signavio/text2SIGNAL/notebooks', '/Users/d071211/.pyenv/versions/3.11.6/lib/python311.zip', '/Users/d071211/.pyenv/versions/3.11.6/lib/python3.11', '/Users/d071211/.pyenv/versions/3.11.6/lib/python3.11/lib-dynload', '', '/Users/d071211/Library/Caches/pypoetry/virtualenvs/text2signal-_sxAEIlr-py3.11/lib/python3.11/site-packages', '/Users/d071211/projects/signavio/text2SIGNAL', './']

# %%
from text2signal.authenticator import initialize_signavio_client, WORKSPACES

auth_clients = {}

for workspace_name, workspace_id in WORKSPACES.items():
    auth_clients[workspace_name] = initialize_signavio_client(workspace_id)

# %%
! echo $MY_SIGNAVIO_NAME
# Out:
# darko.velkoski@sap.com

# %% [markdown]
# ## Example how to run manually -constructed SIGNALS against workspace DB:

# %%
workspace_name = "Solutions Demo Workspace"
signavio_client = auth_clients[workspace_name]

for process in signavio_client.pi.subjects():
    print(process.id, process.name)
    schema = signavio_client.signal.schema(process.id)
    columns = [field.column_name for field in schema.fields]
    print(columns)
# Out:
# sl-itc-dashboard-test-1 000_DEMO✨ - Dashboards ITC ECC & S4H (DO NOT CHANGE)
# ['case_id', 'event_name', 'end_time', 'Invoice_u0020_Posting_u0020_Gross_u0020_Amount', 'Event_u0020_Created_u0020_By_u0020_User_u0020_Id', 'Event_u0020_Created_u0020_By_u0020_User_u0020_Type', 'Change_u0020_Old_u0020_Value', 'Change_u0020_New_u0020_Value', 'Changed_u0020_Table', 'Changed_u0020_Field', 'Changed_u0020_Object_u0020_Id', 'Change_u0020_Type', 'Change_u0020_Number', 'Invoice_u0020_Line_u0020_Item', 'Accounting_u0020_Document_u0020_Segment_u0020_Primary_u0020_Key', 'Invoice_u0020_Due_u0020_Date', 'Transaction_u0020_Code', 'Reverse_u0020_Document_u0020_Number', 'Reverse_u0020_Document_u0020_Fiscal_u0020_Year', 'Reversal_u0020_Indicator', 'Document_u0020_Currency', 'Amount_u0020_in_u0020_Document_u0020_Currency', 'Converted_u0020_USD_u0020_Amount', 'Amount_u0020_Eligible_u0020_for_u0020_Cash_u0020_Discount_u0020_in_u0020_Document_u0020_Currency', 'Converted_u0020_USD_u0020_Amount_u0020_Eligible_u0020_for_u0020_Cash_u0020_Discount', 'Cash_u0020_Discount_u0020_Amount_u0020_in_u0020_Document_u0020_Currency', 'Converted_u0020_USD_u0020_Cash_u0020_Discount_u0020_Amount', 'Net_u0020_Payment_u0020_Amount', 'Converted_u0020_USD_u0020_Net_u0020_Payment_u0020_Amount', 'SD_u0020_Cancelled_u0020_Doc', 'SD_u0020_Credit_u0020_Control_u0020_Area', 'SD_u0020_Customer_u0020_Number', 'SD_u0020_Distribution_u0020_Channel', 'SD_u0020_Number', 'SD_u0020_Type', 'SD_u0020_Organization', 'SD_u0020_Organization_u0020_Text', 'SD_u0020_Preceding_u0020_Doc', 'SD_u0020_Subsequent_u0020_Doc', 'Inv_u002e__u0020_Fiscal_u0020_Year', 'Inv_u002e__u0020_Document_u0020_Type', 'Inv_u002e__u0020_Amount_u0020_in_u0020_Local_u0020_Currency', 'Inv_u002e__u0020_Amount_u0020_in_u0020_Document_u0020_Currency', 'Inv_u002e__u0020_Converted_u0020_USD_u0020_Amount', 'Inv_u002e__u0020_Amount_u0020_in_u0020_Second_u0020_Local_u0020_Currency', 'Inv_u002e__u0020_Original_u0020_Reduction_u0020_Amount_u0020_in_u0020_Local_u0020_Currency', 'Inv_u002e__u0020_Amount_u0020_Eligible_u0020_for_u0020_Cash_u0020_Discount_u0020_in_u0020_Document_u0020_Currency', 'Inv_u002e__u0020_Converted_u0020_USD_u0020_Amount_u0020_Eligible_u0020_for_u0020_Cash_u0020_Discount', 'Inv_u002e__u0020_Client', 'Inv_u002e__u0020_Company_u0020_Code', 'Inv_u002e__u0020_Company_u0020_Code_u0020_Text', 'Inv_u002e__u0020_Accounting_u0020_Document_u0020_Number', 'Inv_u002e__u0020_Document_u0020_Type_u0020_Text', 'Inv_u002e__u0020_Date', 'Inv_u002e__u0020_Posting_u0020_Document_u0020_Date', 'Inv_u002e__u0020_Accounting_u0020_Document_u0020_Date', 'Inv_u002e__u0020_Creation_u0020_User', 'Inv_u002e__u0020_Creation_u0020_User_u0020_Type', 'Inv_u002e__u0020_Transaction_u0020_Code', 'Inv_u002e__u0020_Currency_u0020_Key', 'Inv_u002e__u0020_Currency_u0020_Key_u0020_of_u0020_Second_u0020_Local_u0020_Currency', 'Inv_u002e__u0020_Currency_u0020_Key_u0020_for_u0020_the_u0020_Group_u0020_Currency', 'Inv_u002e__u0020_Exchange_u0020_rate', 'Inv_u002e__u0020_Exchange_u0020_Rate_u0020_Type', 'Inv_u002e__u0020_Group_u0020_Currency_u0020_Exchange_u0020_Rate', 'Inv_u002e__u0020_Document_u0020_Status', 'Inv_u002e__u0020_Reference_u0020_Transaction', 'Inv_u002e__u0020_Reference_u0020_Key', 'Inv_u002e__u0020_Local_u0020_Currency', 'Inv_u002e__u0020_Reversal_u0020_Indicator', 'Inv_u002e__u0020_Parking_u0020_Date', 'Inv_u002e__u0020_Parking_u0020_User', 'Last_u0020_Inv_u002e__u0020_Number_u0020_of_u0020_Line_u0020_Item_u0020_Within_u0020_Accounting_u0020_Document', 'Last_u0020_Inv_u002e__u0020_Item_u0020_Clearing_u0020_Date', 'Last_u0020_Inv_u002e__u0020_Item_u0020_Clearing_u0020_Entry_u0020_Date', 'Last_u0020_Inv_u002e__u0020_Item_u0020_Document_u0020_Number_u0020_of_u0020_the_u0020_Clearing_u0020_Document', 'Last_u0020_Inv_u002e__u0020_Item_u0020_Posting_u0020_Key', 'Last_u0020_Inv_u002e__u0020_Item_u0020_Account_u0020_Type', 'Last_u0020_Inv_u002e__u0020_Item_u0020_Special_u0020_G_u002f_L_u0020_Indicator', 'Last_u0020_Inv_u002e__u0020_Item_u0020_Special_u0020_G_u002f_L_u0020_Transaction_u0020_Type', 'Last_u0020_Inv_u002e__u0020_I ...
# 00demo---sap-s4h-itp-dashboar-1 000_DEMO✨ - Dashboards ITP ECC & S4H (DO NOT CHANGE)
# ['case_id', 'event_name', 'end_time', 'Event_u0020_Created_u0020_By_u0020_User_u0020_Id', 'Event_u0020_Created_u0020_By_u0020_User_u0020_Type', 'Invoice_u0020_Line_u0020_Item', 'Accounting_u0020_Document_u0020_Segment_u0020_Primary_u0020_Key', 'Document_u0020_Currency', 'Amount_u0020_in_u0020_Document_u0020_Currency', 'Converted_u0020_USD_u0020_Amount', 'Amount_u0020_Eligible_u0020_for_u0020_Cash_u0020_Discount_u0020_in_u0020_Document_u0020_Currency', 'Converted_u0020_USD_u0020_Amount_u0020_Eligible_u0020_for_u0020_Cash_u0020_Discount', 'Cash_u0020_Discount_u0020_Amount_u0020_in_u0020_Document_u0020_Currency', 'Converted_u0020_USD_u0020_Cash_u0020_Discount_u0020_Amount', 'Invoice_u0020_Due_u0020_Date', 'Change_u0020_Old_u0020_Value', 'Change_u0020_New_u0020_Value', 'Changed_u0020_Table', 'Changed_u0020_Field', 'Changed_u0020_Object_u0020_Id', 'Change_u0020_Type', 'Change_u0020_Number', 'Transaction_u0020_Code', 'Reverse_u0020_Document_u0020_Number', 'Reverse_u0020_Document_u0020_Fiscal_u0020_Year', 'Reversal_u0020_Indicator', 'PO_u0020_Number', 'GR_u0020_Document_u0020_ID', 'GR_u0020_Document_u0020_Item', 'GR_u0020_Document_u0020_Year', 'Invoice_u0020_Receipt_u0020_ID', 'Invoice_u0020_Receipt_u0020_Item', 'Invoice_u0020_Receipt_u0020_Year', 'GR_u0020_Document_u0020_Date', 'GR_u0020_Document_u0020_Posting_u0020_Date', 'GR_u0020_Quantity', 'GR_u0020_Debit_u002f_Credit_u0020_Indicator', 'GR_u0020_Reference_u0020_Material_u0020_Document_u0020_ID', 'GR_u0020_Reference_u0020_Material_u0020_Document_u0020_Item', 'GR_u0020_Reference_u0020_Material_u0020_Document_u0020_Year', 'GR_u0020_Reference_u0020_PO_u0020_Document_u0020_ID', 'GR_u0020_Reference_u0020_PO_u0020_Document_u0020_Item', 'PO_u0020_Item_u0020_Number', 'Inv_u002e__u0020_Client', 'Inv_u002e__u0020_Company_u0020_Code', 'Inv_u002e__u0020_Company_u0020_Code_u0020_Text', 'Inv_u002e__u0020_Accounting_u0020_Document_u0020_Number', 'Last_u0020_Inv_u002e__u0020_Item_u0020_Cash_u0020_Discount_u0020_Due_u0020_Date_u0020_2', 'Last_u0020_Inv_u002e__u0020_Item_u0020_Payment_u0020_Method', 'Last_u0020_Inv_u002e__u0020_Item_u0020_Payment_u0020_Block_u0020_Key', 'Last_u0020_Inv_u002e__u0020_Item_u0020_Fixed_u0020_Payment_u0020_Terms', 'Last_u0020_Inv_u002e__u0020_Item_u0020_Dunning_u0020_Area', 'Last_u0020_Inv_u002e__u0020_Item_u0020_Dunned_u0020_On', 'Last_u0020_Inv_u002e__u0020_Item_u0020_Dunning_u0020_key', 'Last_u0020_Inv_u002e__u0020_Item_u0020_Total_u0020_Quantity', 'Last_u0020_Inv_u002e__u0020_Item_u0020_Number_u0020_of_u0020_the_u0020_Relevant_u0020_Invoice', 'Last_u0020_Inv_u002e__u0020_Item_u0020_Fiscal_u0020_Year_u0020_of_u0020_the_u0020_Relevant_u0020_Invoice', 'Last_u0020_Inv_u002e__u0020_Item_u0020_Line_u0020_Item_u0020_of_u0020_the_u0020_Relevant_u0020_Invoice', 'Last_u0020_Inv_u002e__u0020_Item_u0020_Follow_u002d_On_u0020_Document_u0020_Type', 'Last_u0020_Inv_u002e__u0020_Item_u0020_Dunning_u0020_Level', 'Last_u0020_Inv_u002e__u0020_Item_u0020_Dunning_u0020_Block', 'Last_u0020_Inv_u002e__u0020_Item_u0020_Account_u0020_Type_u0020_Text', 'Last_u0020_Inv_u002e__u0020_Item_u0020_Debit_u002f_Credit_u0020_Indicator_u0020_Text', 'Last_u0020_Inv_u002e__u0020_Item_u0020_Tax_u0020_Type_u0020_Text', 'Last_u0020_Inv_u002e__u0020_Item_u0020_Vendor_u0020_Master_u0020_Payment_u0020_Terms', 'Last_u0020_Inv_u002e__u0020_Item_u0020_Vendor_u0020_Master_u0020_CD_u0020_1', 'Inv_u002e__u0020_Fiscal_u0020_Year', 'Inv_u002e__u0020_Document_u0020_Type', 'Inv_u002e__u0020_Document_u0020_Type_u0020_Text', 'Inv_u002e__u0020_Date', 'Inv_u002e__u0020_Posting_u0020_Document_u0020_Date', 'Inv_u002e__u0020_Accounting_u0020_Document_u0020_Date', 'Inv_u002e__u0020_Creation_u0020_User', 'Inv_u002e__u0020_Creation_u0020_User_u0020_Type', 'Inv_u002e__u0020_Transaction_u0020_Code', 'Inv_u002e__u0020_Currency_u0020_Key', 'Inv_u002e__u0020_Currency_u0020_Key_u0020_of_u0020_Second_u0020_Local_u0020_Currency', 'Inv_u002e__u0020_Currency_u0020_Key_u0020_of_u0020_Third_u0020_Local_u0020_Currency', 'Inv_u002e__u0020_Cu ...
# 00demo---sap-s4h-otc-dashboar-1 000_DEMO✨ - Dashboards OTC ECC & S4H (DO NOT CHANGE)
# ['case_id', 'event_name', 'end_time', 'InvoiceId', 'InvoiceAccountingDocumentId', 'InvoicePostingDebitCreditIndicator', 'InvoiceAccountingClearingDate', 'InvoiceDueDate', 'InvoiceDocumentType', 'EventCreatedByUserId', 'EventCreatedByUserType', 'NumberOfLineItems', 'InvoicePostingGrossAmount', 'ChangeNewValue', 'ChangedTable', 'ChangedField', 'ChangedObjectId', 'ChangedObjectClass', 'ChangeType', 'ChangeNumber', 'UniqueEventId', 'ARUniqueKey', 'InvoiceAccountingDocumentDate', 'InvoiceAccountingDocumentPostingDate', 'InvoicedQuantity', 'InvoicedNetAmount', 'InvoiceNetAmountCurrConverted', 'InvoiceGrossAmount', 'InvoiceGrossAmountCurrConverted', 'InvoiceGrossCashDiscountAmount', 'InvoiceGrossCashDiscountAmountCurrConverted', 'InvoiceUnplannedDeliveryCosts', 'InvoiceAccountingDocumentDebitCreditIndicator', 'InvoiceClearingDocumentId', 'InvoiceClearingDocumentDebitCreditIndicator', 'InvoiceQuantity', 'InvoiceNetAmount', 'InvoiceGrossAmountPaid', 'InvoiceGrossAmountPaidCurrConverted', 'DeliveryId', 'DeliveryWarehouse', 'DeliveryQuantityDelivered', 'DeliveryGoodsMovementOnTime', 'LastInvoiceId', 'LastInvoiceAccountingDocumentId', 'InvoicePaymentTerms', 'InvoiceCashDiscountDays1', 'InvoiceCashDiscountDays2', 'InvoiceNetPaymentTermsPeriod', 'InvoiceCashDiscountDate1', 'InvoiceCashDiscountDate2', 'InvoiceCashDiscountPercentage1', 'InvoiceCashDiscountPercentage2', 'InvoiceItemTotalGrossCashDiscountAmount', 'InvoiceItemTotalGrossCashDiscountAmountCurrConverted', 'InvoiceItemTotalNetAmount', 'InvoiceItemTotalGrossAmount', 'InvoiceItemTotalNetAmountCurrConverted', 'InvoiceItemTotalGrossAmountCurrConverted', 'InvoiceItemTotalGrossAmountPaid', 'InvoiceItemTotalGrossAmountPaidCurrConverted', 'InvoiceItemTotalQuantity', 'InvoiceTotalUnplannedDeliveryCosts', 'InvoiceTransactionCode', 'InvoiceCurrency', 'InvoiceCompanyCode', 'LastInvoiceDocumentType', 'LastInvoiceCreateUserType', 'InvoiceDunningBlock', 'InvoiceDunningLevel', 'InvoiceDunningArea', 'InvoiceLastDunnedOn', 'LastDeliveryId', 'LastDeliveryItemId', 'DeliveryCategory', 'DeliveryType', 'DeliveryItemCategory', 'DeliveryTotalQuantityDelivered', 'LastDeliveryWarehouse', 'DeliveryShippingType', 'DeliveryPlannedPickingDate', 'DeliveryPlannedDeliveryDate', 'LastDeliveryGoodsMovementOnTime', 'SalesDocId', 'SalesDocItemId', 'SalesDocItemName', 'SalesDocItemQuantityOrdered', 'SalesDocItemQuantityConfirmed', 'SalesDocItemMaterialNumber', 'SalesDocItemCategory', 'SalesDocItemNetValue', 'SalesDocItemMaterial', 'SalesDocItemMaterialGroup', 'SalesDocItemPlant', 'SalesDocType', 'SalesDocSalesOffice', 'SalesDocSalesOrganization', 'SalesDocCustomerCountry', 'SalesDocCustomerCompany', 'SalesDocTradingPartner', 'SalesDocReworked', 'SalesDocPrecedingDocumentType', 'SalesDocLastConfirmedDeliveryDate', 'SalesDocPlannedShipmentDate', 'SalesDocPlannedMaterialAvailabilityDate', 'SalesDocItemRejectionReason', 'SalesDocOrderReason', 'SalesDocDeliveryBlockReason', 'SalesDocBillingBlockReason', 'SalesDocDistributionChannel', 'SalesDocDivision']
# sademo-dashboardss4h-p2p-proc-1 000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)
# ['case_id', 'event_id', 'event_name', 'start_time', 'end_time', 'Change_u0020_New_u0020_Value', 'Change_u0020_Old_u0020_Value', 'Change_u0020_Type', 'Changed_u0020_Field', 'Changed_u0020_Object_u0020_Id', 'Changed_u0020_Table', 'Event_u0020_Created_u0020_By_u0020_User_u0020_Id', 'Event_u0020_Created_u0020_By_u0020_User_u0020_Type', 'Event_u0020_Transaction_u0020_Code', 'FI_u0020_Invoice_u0020_Company_u0020_Code', 'FI_u0020_Invoice_u0020_Document_u0020_Date', 'FI_u0020_Invoice_u0020_Document_u0020_Type', 'FI_u0020_Invoice_u0020_Document_u0020_Type_u0020_Text', 'FI_u0020_Invoice_u0020_Fiscal_u0020_Year', 'FI_u0020_Invoice_u0020_ID', 'FI_u0020_Invoice_u0020_Item_u0020_Amount_u0020_for_u0020_G_u002f_L', 'FI_u0020_Invoice_u0020_Item_u0020_Cash_u0020_Discount_u0020_1_u0020_Due_u0020_Date', 'FI_u0020_Invoice_u0020_Item_u0020_Cash_u0020_Discount_u0020_2_u0020_Due_u0020_Date', 'FI_u0020_Invoice_u0020_Item_u0020_Cash_u0020_Discount_u0020_Days_u0020_1', 'FI_u0020_Invoice_u0020_Item_u0020_Cash_u0020_Discount_u0020_Days_u0020_2', 'FI_u0020_Invoice_u0020_Item_u0020_Cash_u0020_Discount_u0020_Percentage_u0020_1', 'FI_u0020_Invoice_u0020_Item_u0020_Cash_u0020_Discount_u0020_Percentage_u0020_2', 'FI_u0020_Invoice_u0020_Item_u0020_Clearing_u0020_Date', 'FI_u0020_Invoice_u0020_Item_u0020_Clearing_u0020_Doc_u002e__u0020_ID', 'FI_u0020_Invoice_u0020_Item_u0020_Clearing_u0020_Entry_u0020_Date', 'FI_u0020_Invoice_u0020_Item_u0020_Due_u0020_Date', 'FI_u0020_Invoice_u0020_Item_u0020_Dunning_u0020_Block', 'FI_u0020_Invoice_u0020_Item_u0020_Dunning_u0020_Date', 'FI_u0020_Invoice_u0020_Item_u0020_Dunning_u0020_Key', 'FI_u0020_Invoice_u0020_Item_u0020_Dunning_u0020_Level', 'FI_u0020_Invoice_u0020_Item_u0020_Fiscal_u0020_Year_u0020_Clearing_u0020_Doc_u002e_', 'FI_u0020_Invoice_u0020_Item_u0020_G_u002f_L_u0020_Account_u0020_Number', 'FI_u0020_Invoice_u0020_Item_u0020_Gross_u0020_Amount_u0020_Document_u0020_Curr_u002e_', 'FI_u0020_Invoice_u0020_Item_u0020_Gross_u0020_Amount_u0020_Local_u0020_Curr_u002e_', 'FI_u0020_Invoice_u0020_Item_u0020_Gross_u0020_Amount_u0020_in_u0020_USD', 'FI_u0020_Invoice_u0020_Item_u0020_Net_u0020_Payment_u0020_Days', 'FI_u0020_Invoice_u0020_Item_u0020_Profit_u0020_Center', 'FI_u0020_Invoice_u0020_Item_u0020_Quantity', 'FI_u0020_Invoice_u0020_Item_u0020_Terms_u0020_of_u0020_Payment_u0020_Key', 'FI_u0020_Invoice_u0020_Line_u0020_Item', 'FI_u0020_Invoice_u0020_Parking_u0020_Date', 'FI_u0020_Invoice_u0020_Posting_u0020_Date', 'FI_u0020_Invoice_u0020_Posting_u0020_Period', 'FI_u0020_Invoice_u0020_Receipt_u0020_Date', 'GR_u0020_Debit_u002f_Credit_u0020_Indicator', 'GR_u0020_Document_u0020_Date', 'GR_u0020_Document_u0020_ID', 'GR_u0020_Document_u0020_Item', 'GR_u0020_Document_u0020_Posting_u0020_Date', 'GR_u0020_Document_u0020_Year', 'GR_u0020_Quantity', 'GR_u0020_Reference_u0020_Material_u0020_Document_u0020_ID', 'GR_u0020_Reference_u0020_Material_u0020_Document_u0020_Item', 'GR_u0020_Reference_u0020_Material_u0020_Document_u0020_Year', 'GR_u0020_Reference_u0020_PO_u0020_Document_u0020_ID', 'GR_u0020_Reference_u0020_PO_u0020_Document_u0020_Item', 'PO_u0020_Item_u0020_Invoiced_u0020_Net_u0020_Amount_u0020_Document_u0020_Curr_u002e_', 'PO_u0020_Item_u0020_Invoiced_u0020_Net_u0020_Amount_u0020_Local_u0020_Curr_u002e_', 'PO_u0020_Item_u0020_Invoiced_u0020_Quantity', 'Quality_u0020_Inspection_u0020_Lot_u0020_ID', 'Quality_u0020_Inspection_u0020_Scheduled_u0020_End_u0020_Date', 'Quality_u0020_Inspection_u0020_Scheduled_u0020_Start_u0020_Date', 'Quality_u0020_Inspection_u0020_UD_u0020_Valuation', 'Contract_u0020_Company_u0020_Code', 'Contract_u0020_Company_u0020_Code_u0020_Text', 'Contract_u0020_Id', 'Contract_u0020_Item', 'Contract_u0020_Item_u0020_Net_u0020_Order_u0020_Value', 'Contract_u0020_Item_u0020_Net_u0020_Order_u0020_Value_u0020_in_u0020_USD', 'Contract_u0020_Item_u0020_Net_u0020_Price', 'Contract_u0020_Purchase_u0020_Group', 'Contract_u0020_Purchase_u0020_Organization', 'Contract_u0020_Released_u0020_Quantity', 'Contract_u0020_Status' ...
# lg-00demo---ato-sap-s4-hana-d-1 00_DEMO - Acquire-to-Onboard for  SAP ECC & S/4 HANA (DO NOT CHANGE)
# ['case_id', 'event_id', 'event_name', 'start_time', 'end_time', 'APUniqueKey', 'Asset_u0020_Number', 'Asset_u0020_SubNumber', 'Asset_u0020_Transaction_u0020_Type', 'Change_u0020_New_u0020_Value', 'Change_u0020_Old_u0020_Value', 'Change_u0020_Type', 'Changed_u0020_Field', 'Changed_u0020_Object_u0020_Id', 'Changed_u0020_Table', 'Event_u0020_Created_u0020_By_u0020_User_u0020_Id', 'Event_u0020_Created_u0020_By_u0020_User_u0020_Type', 'Event_u0020_Transaction_u0020_Code', 'FI_u0020_Invoice_u0020_Company_u0020_Code', 'FI_u0020_Invoice_u0020_Document_u0020_Date', 'FI_u0020_Invoice_u0020_Document_u0020_Type', 'FI_u0020_Invoice_u0020_Document_u0020_Type_u0020_Text', 'FI_u0020_Invoice_u0020_Fiscal_u0020_Year', 'FI_u0020_Invoice_u0020_ID', 'FI_u0020_Invoice_u0020_Item_u0020_Amount_u0020_for_u0020_G_u002f_L', 'FI_u0020_Invoice_u0020_Item_u0020_Cash_u0020_Discount_u0020_1_u0020_Due_u0020_Date', 'FI_u0020_Invoice_u0020_Item_u0020_Cash_u0020_Discount_u0020_2_u0020_Due_u0020_Date', 'FI_u0020_Invoice_u0020_Item_u0020_Cash_u0020_Discount_u0020_Days_u0020_1', 'FI_u0020_Invoice_u0020_Item_u0020_Cash_u0020_Discount_u0020_Days_u0020_2', 'FI_u0020_Invoice_u0020_Item_u0020_Cash_u0020_Discount_u0020_Percentage_u0020_1', 'FI_u0020_Invoice_u0020_Item_u0020_Cash_u0020_Discount_u0020_Percentage_u0020_2', 'FI_u0020_Invoice_u0020_Item_u0020_Due_u0020_Date', 'FI_u0020_Invoice_u0020_Item_u0020_Dunning_u0020_Block', 'FI_u0020_Invoice_u0020_Item_u0020_Dunning_u0020_Date', 'FI_u0020_Invoice_u0020_Item_u0020_Dunning_u0020_Key', 'FI_u0020_Invoice_u0020_Item_u0020_Dunning_u0020_Level', 'FI_u0020_Invoice_u0020_Item_u0020_G_u002f_L_u0020_Account_u0020_Number', 'FI_u0020_Invoice_u0020_Item_u0020_Gross_u0020_Amount_u0020_Document_u0020_Curr_u002e_', 'FI_u0020_Invoice_u0020_Item_u0020_Gross_u0020_Amount_u0020_Local_u0020_Curr_u002e_', 'FI_u0020_Invoice_u0020_Item_u0020_Gross_u0020_Amount_u0020_in_u0020_USD', 'FI_u0020_Invoice_u0020_Item_u0020_Net_u0020_Payment_u0020_Days', 'FI_u0020_Invoice_u0020_Item_u0020_Profit_u0020_Center', 'FI_u0020_Invoice_u0020_Item_u0020_Quantity', 'FI_u0020_Invoice_u0020_Item_u0020_Terms_u0020_of_u0020_Payment_u0020_Key', 'FI_u0020_Invoice_u0020_Line_u0020_Item', 'FI_u0020_Invoice_u0020_Parking_u0020_Date', 'FI_u0020_Invoice_u0020_Posting_u0020_Date', 'FI_u0020_Invoice_u0020_Posting_u0020_Period', 'FI_u0020_Invoice_u0020_Receipt_u0020_Date', 'GR_u0020_Debit_u002f_Credit_u0020_Indicator', 'GR_u0020_Document_u0020_Date', 'GR_u0020_Document_u0020_ID', 'GR_u0020_Document_u0020_Item', 'GR_u0020_Document_u0020_Posting_u0020_Date', 'GR_u0020_Document_u0020_Year', 'GR_u0020_Quantity', 'GR_u0020_Reference_u0020_Material_u0020_Document_u0020_ID', 'GR_u0020_Reference_u0020_Material_u0020_Document_u0020_Item', 'GR_u0020_Reference_u0020_Material_u0020_Document_u0020_Year', 'GR_u0020_Reference_u0020_PO_u0020_Document_u0020_ID', 'GR_u0020_Reference_u0020_PO_u0020_Document_u0020_Item', 'PO_u0020_Item_u0020_Invoiced_u0020_Net_u0020_Amount_u0020_Document_u0020_Curr_u002e_', 'PO_u0020_Item_u0020_Invoiced_u0020_Net_u0020_Amount_u0020_Local_u0020_Curr_u002e_', 'PO_u0020_Item_u0020_Invoiced_u0020_Net_u0020_Amount_u0020_in_u0020_USD', 'PO_u0020_Item_u0020_Invoiced_u0020_Quantity', 'Asset_u0020_Class_u0020_Description', 'Asset_u0020_Class_u0020_Type', 'Asset_u0020_Company', 'Asset_u0020_Company_u0020_Name', 'Asset_u0020_Quantity', 'Asset_u0020_Value', 'Asset_u0020_Value_u0020_in_u0020_USD', 'First_u0020_PR_u0020_Category', 'First_u0020_PR_u0020_Company_u0020_Code', 'First_u0020_PR_u0020_Company_u0020_Name', 'First_u0020_PR_u0020_Contract', 'First_u0020_PR_u0020_Created_u0020_Date', 'First_u0020_PR_u0020_Creation_u0020_Indicator', 'First_u0020_PR_u0020_Desired_u0020_Vendor', 'First_u0020_PR_u0020_Expected_u0020_Delivery_u0020_Date', 'First_u0020_PR_u0020_Id', 'First_u0020_PR_u0020_Item_u0020_Category', 'First_u0020_PR_u0020_Material', 'First_u0020_PR_u0020_Material_u0020_Group', 'First_u0020_PR_u0020_Measure_u0020_Units', 'First_u0020_PR_u0020_Plant', 'First_u0020_PR_ ...
# attract-to-acquire-talent---s-1 00_DEMO - Attract-to-Acquire-Talent for SuccessFactors
# ['case_id', 'event_id', 'event_name', 'start_time', 'end_time', 'Job_u0020_Offer_u0020_Approval_u0020_Order_u0020_Number', 'Assessment_u0020_Rating_u0020_Scale_u0020_Name', 'Business_u0020_Unit', 'Candidate_u0020_ID', 'Candidate_u0020_Progress', 'Cost_u0020_Center', 'Country_u002f_Region', 'Data_u0020_Source', 'Department', 'Division', 'HR_u0020_Professional', 'HR_u0020_Staffing_u0020_Coordinator', 'Hire_u0020_Source', 'Is_u0020_Candidate_u0020_External', 'Job_u0020_Grade', 'Job_u0020_Requisition_u0020_ID', 'Job_u0020_Requisition_u0020_Number_u0020_of_u0020_Openings', 'Job_u0020_Requisition_u0020_Status', 'Job_u0020_Role', 'Legal_u0020_Entity', 'Location', 'Numbe_u0020_of_u0020_Openings', 'Openings_u0020_Filled', 'Position_u0020_Number', 'Recruiter', 'Requisition_u0020_Created', 'Requisition_u0020_Status', 'Requisition_u0020_Template_u0020_Name', 'Requisition_u0020_Template_u0020_Type']
# 00demo---ato-sap-s4-hana-do-n-4 00_DEMO - Inspect-to-Quality for SAP S/4 HANA (DO NOT CHANGE)
# ['case_id', 'event_name', 'end_time', 'event_u0020_created_u0020_by_u0020_user_u0020_type', 'ud_u0020_code', 'ud_u0020_text', 'changenewvalue', 'inspectionlot', 'material', 'material_u0020_text', 'material_u0020_group', 'material_u0020_type', 'material_u0020_group_u0020_text', 'batch', 'plant', 'plant_u0020_text', 'origin', 'origin_u0020_text', 'type', 'type_u0020_text', 'usage_u0020_decision_u0020_code', 'usage_u0020_decision_u0020_text', 'planned_u0020_inspection_u0020_start_u0020_date', 'planned_u0020_inspection_u0020_end_u0020_date', 'production_u0020_scheduler', 'production_u0020_scheduler_u0020_text', 'recurring_u0020_inspection_u0020_interval']
# demo---itc-sap-s4-hana-do-not-1 00_DEMO - Invoice-to-Cash for SAP S/4 HANA (DO NOT CHANGE)
# ['case_id', 'event_id', 'event_name', 'start_time', 'end_time', 'Accounting_u0020_Document_u0020_Segment_u0020_Primary_u0020_Key', 'Amount_u0020_Eligible_u0020_for_u0020_Cash_u0020_Discount_u0020_in_u0020_Document_u0020_Currency', 'Amount_u0020_in_u0020_Document_u0020_Currency', 'Cash_u0020_Discount_u0020_Amount_u0020_in_u0020_Document_u0020_Currency', 'Change_u0020_New_u0020_Value', 'Change_u0020_Old_u0020_Value', 'Change_u0020_Type', 'Changed_u0020_Field', 'Changed_u0020_Object_u0020_Id', 'Changed_u0020_Table', 'Converted_u0020_USD_u0020_Amount', 'Converted_u0020_USD_u0020_Amount_u0020_Eligible_u0020_for_u0020_Cash_u0020_Discount', 'Converted_u0020_USD_u0020_Cash_u0020_Discount_u0020_Amount', 'Converted_u0020_USD_u0020_Net_u0020_Payment_u0020_Amount', 'Document_u0020_Currency', 'Event_u0020_Created_u0020_By_u0020_User_u0020_Id', 'Event_u0020_Created_u0020_By_u0020_User_u0020_Type', 'Invoice_u0020_Due_u0020_Date', 'Invoice_u0020_Line_u0020_Item', 'Invoice_u0020_Posting_u0020_Gross_u0020_Amount', 'Net_u0020_Payment_u0020_Amount', 'Reversal_u0020_Indicator', 'Reverse_u0020_Document_u0020_Fiscal_u0020_Year', 'Reverse_u0020_Document_u0020_Number', 'Transaction_u0020_Code', 'Inv_u002e__u0020_Accounting_u0020_Document_u0020_Date', 'Inv_u002e__u0020_Accounting_u0020_Document_u0020_Number', 'Inv_u002e__u0020_Amount_u0020_Eligible_u0020_for_u0020_Cash_u0020_Discount_u0020_in_u0020_Document_u0020_Currency', 'Inv_u002e__u0020_Amount_u0020_in_u0020_Document_u0020_Currency', 'Inv_u002e__u0020_Amount_u0020_in_u0020_Local_u0020_Currency', 'Inv_u002e__u0020_Amount_u0020_in_u0020_Second_u0020_Local_u0020_Currency', 'Inv_u002e__u0020_Cash_u0020_Discount_u0020_Amount_u0020_in_u0020_Document_u0020_Currency', 'Inv_u002e__u0020_Cash_u0020_Discount_u0020_Amount_u0020_in_u0020_Local_u0020_Currency', 'Inv_u002e__u0020_Client', 'Inv_u002e__u0020_Company_u0020_Code', 'Inv_u002e__u0020_Company_u0020_Code_u0020_Text', 'Inv_u002e__u0020_Converted_u0020_USD_u0020_Amount', 'Inv_u002e__u0020_Converted_u0020_USD_u0020_Amount_u0020_Eligible_u0020_for_u0020_Cash_u0020_Discount', 'Inv_u002e__u0020_Converted_u0020_USD_u0020_Cash_u0020_Discount_u0020_Amount', 'Inv_u002e__u0020_Creation_u0020_User', 'Inv_u002e__u0020_Creation_u0020_User_u0020_Type', 'Inv_u002e__u0020_Currency_u0020_Key', 'Inv_u002e__u0020_Currency_u0020_Key_u0020_for_u0020_the_u0020_Group_u0020_Currency', 'Inv_u002e__u0020_Currency_u0020_Key_u0020_of_u0020_Second_u0020_Local_u0020_Currency', 'Inv_u002e__u0020_Date', 'Inv_u002e__u0020_Document_u0020_Status', 'Inv_u002e__u0020_Document_u0020_Type', 'Inv_u002e__u0020_Document_u0020_Type_u0020_Text', 'Inv_u002e__u0020_Exchange_u0020_Rate_u0020_Type', 'Inv_u002e__u0020_Exchange_u0020_rate', 'Inv_u002e__u0020_Fiscal_u0020_Year', 'Inv_u002e__u0020_Group_u0020_Currency_u0020_Exchange_u0020_Rate', 'Inv_u002e__u0020_Local_u0020_Currency', 'Inv_u002e__u0020_Original_u0020_Reduction_u0020_Amount_u0020_in_u0020_Local_u0020_Currency', 'Inv_u002e__u0020_Parking_u0020_Date', 'Inv_u002e__u0020_Parking_u0020_User', 'Inv_u002e__u0020_Posting_u0020_Document_u0020_Date', 'Inv_u002e__u0020_Reference_u0020_Key', 'Inv_u002e__u0020_Reference_u0020_Transaction', 'Inv_u002e__u0020_Reversal_u0020_Indicator', 'Inv_u002e__u0020_Transaction_u0020_Code', 'Last_u0020_Inv_u002e__u0020_Item_u0020_Account_u0020_Type', 'Last_u0020_Inv_u002e__u0020_Item_u0020_Account_u0020_Type_u0020_Text', 'Last_u0020_Inv_u002e__u0020_Item_u0020_Assignment_u0020_Number', 'Last_u0020_Inv_u002e__u0020_Item_u0020_Baseline_u0020_Date', 'Last_u0020_Inv_u002e__u0020_Item_u0020_Billing_u0020_Document', 'Last_u0020_Inv_u002e__u0020_Item_u0020_Business_u0020_Area', 'Last_u0020_Inv_u002e__u0020_Item_u0020_Cash_u0020_Discount_u0020_Days_u0020_1', 'Last_u0020_Inv_u002e__u0020_Item_u0020_Cash_u0020_Discount_u0020_Days_u0020_2', 'Last_u0020_Inv_u002e__u0020_Item_u0020_Cash_u0020_Discount_u0020_Due_u0020_Date_u0020_1', 'Last_u0020_Inv_u002e__u0020_Item_u0020_Cash_u0020_Discount_u0020_Due_u0020_Date_u0020_2', 'Last_u ...
# 00demo---itp-sap-s4-hana-1 00_DEMO - Invoice-to-Pay for SAP S/4 HANA (DO NOT CHANGE)
# ['case_id', 'event_id', 'event_name', 'start_time', 'end_time', 'Accounting_u0020_Document_u0020_Segment_u0020_Primary_u0020_Key', 'Amount_u0020_Eligible_u0020_for_u0020_Cash_u0020_Discount_u0020_in_u0020_Document_u0020_Currency', 'Amount_u0020_in_u0020_Document_u0020_Currency', 'Cash_u0020_Discount_u0020_Amount_u0020_in_u0020_Document_u0020_Currency', 'Change_u0020_New_u0020_Value', 'Change_u0020_Old_u0020_Value', 'Change_u0020_Type', 'Changed_u0020_Field', 'Changed_u0020_Object_u0020_Id', 'Changed_u0020_Table', 'Converted_u0020_USD_u0020_Amount', 'Converted_u0020_USD_u0020_Amount_u0020_Eligible_u0020_for_u0020_Cash_u0020_Discount', 'Converted_u0020_USD_u0020_Cash_u0020_Discount_u0020_Amount', 'Converted_u0020_USD_u0020_Net_u0020_Payment_u0020_Amount', 'Documet_u0020_Currency', 'Event_u0020_Created_u0020_By_u0020_User_u0020_Id', 'Event_u0020_Created_u0020_By_u0020_User_u0020_Type', 'GR_u0020_Debit_u002f_Credit_u0020_Indicator', 'GR_u0020_Document_u0020_Date', 'GR_u0020_Document_u0020_ID', 'GR_u0020_Document_u0020_Item', 'GR_u0020_Document_u0020_Posting_u0020_Date', 'GR_u0020_Document_u0020_Year', 'GR_u0020_Quantity', 'GR_u0020_Reference_u0020_Material_u0020_Document_u0020_ID', 'GR_u0020_Reference_u0020_Material_u0020_Document_u0020_Item', 'GR_u0020_Reference_u0020_Material_u0020_Document_u0020_Year', 'GR_u0020_Reference_u0020_PO_u0020_Document_u0020_ID', 'GR_u0020_Reference_u0020_PO_u0020_Document_u0020_Item', 'Invoice_u0020_Due_u0020_Date', 'Invoice_u0020_Line_u0020_Item', 'Invoice_u0020_Receipt_u0020_ID', 'Invoice_u0020_Receipt_u0020_Item', 'Invoice_u0020_Receipt_u0020_Year', 'Net_u0020_Payment_u0020_Amount', 'PO_u0020_Number', 'Quality_u0020_Inspection_u0020_Lot_u0020_ID', 'Quality_u0020_Inspection_u0020_Scheduled_u0020_End_u0020_Date', 'Quality_u0020_Inspection_u0020_Scheduled_u0020_Start_u0020_Date', 'Quality_u0020_Inspection_u0020_UD_u0020_Valuation', 'Reversal_u0020_Indicator', 'Reverse_u0020_Document_u0020_Fiscal_u0020_Year', 'Reverse_u0020_Document_u0020_Number', 'Transaction_u0020_Code', 'Inv_u002e__u0020_Accounting_u0020_Document_u0020_Date', 'Inv_u002e__u0020_Accounting_u0020_Document_u0020_Number', 'Inv_u002e__u0020_Amount_u0020_Eligible_u0020_for_u0020_Cash_u0020_Discount_u0020_in_u0020_Document_u0020_Currency', 'Inv_u002e__u0020_Amount_u0020_in_u0020_Document_u0020_Currency', 'Inv_u002e__u0020_Amount_u0020_in_u0020_Local_u0020_Currency', 'Inv_u002e__u0020_Amount_u0020_in_u0020_Second_u0020_Local_u0020_Currency', 'Inv_u002e__u0020_Amount_u0020_in_u0020_Third_u0020_Local_u0020_Currency', 'Inv_u002e__u0020_Cash_u0020_Discount_u0020_Amount_u0020_in_u0020_Document_u0020_Currency', 'Inv_u002e__u0020_Cash_u0020_Discount_u0020_Amount_u0020_in_u0020_Local_u0020_Currency', 'Inv_u002e__u0020_Client', 'Inv_u002e__u0020_Company_u0020_Code', 'Inv_u002e__u0020_Company_u0020_Code_u0020_Text', 'Inv_u002e__u0020_Converted_u0020_USD_u0020_Amount', 'Inv_u002e__u0020_Converted_u0020_USD_u0020_Amount_u0020_Eligible_u0020_for_u0020_Cash_u0020_Discount', 'Inv_u002e__u0020_Converted_u0020_USD_u0020_Cash_u0020_Discount_u0020_Amount', 'Inv_u002e__u0020_Creation_u0020_User', 'Inv_u002e__u0020_Creation_u0020_User_u0020_Type', 'Inv_u002e__u0020_Currency_u0020_Key', 'Inv_u002e__u0020_Currency_u0020_Key_u0020_for_u0020_the_u0020_Group_u0020_Currency', 'Inv_u002e__u0020_Currency_u0020_Key_u0020_of_u0020_Second_u0020_Local_u0020_Currency', 'Inv_u002e__u0020_Currency_u0020_Key_u0020_of_u0020_Third_u0020_Local_u0020_Currency', 'Inv_u002e__u0020_Date', 'Inv_u002e__u0020_Document_u0020_Status', 'Inv_u002e__u0020_Document_u0020_Type', 'Inv_u002e__u0020_Document_u0020_Type_u0020_Text', 'Inv_u002e__u0020_Exchange_u0020_Rate_u0020_Type', 'Inv_u002e__u0020_Exchange_u0020_rate', 'Inv_u002e__u0020_Fiscal_u0020_Year', 'Inv_u002e__u0020_Group_u0020_Currency_u0020_Exchange_u0020_Rate', 'Inv_u002e__u0020_Local_u0020_Currency', 'Inv_u002e__u0020_Original_u0020_Reduction_u0020_Amount_u0020_in_u0020_Local_u0020_Currency', 'Inv_u002e__u0020_Posting_u0020_Document ...
# 00demo-jira-issue-to-resoluti-1 00_DEMO Issue-to-Resolution for Jira
# ['case_id', 'event_id', 'event_name', 'start_time', 'end_time', 'Breach_u0020_Time', 'Breached', 'Cycle_u0020_Type', 'Elapsed_u0020_Time_u0020__u0028_seconds_u0029_', 'Field_u0020_Name', 'Goal_u0020_Duration_u0020__u0028_Date_u0020_based_u0020_intial_u0020_unix_u0029_', 'Goal_u0020_Duration_u0020__u0028_seconds_u0029_', 'New_u0020_Status', 'New_u0020_Value', 'Old_u0020_Status', 'Old_u0020_Value', 'Paused', 'Remaining_u0020_Time_u0020__u0028_seconds_u0029_', 'SLA_u0020_Name', 'Start_u0020_Time', 'Stop_u0020_Time', 'Within_u0020_Calendar_u0020_Hours', 'Actual_u0020_End_u0020_Date', 'Actual_u0020_Start_u0020_Date', 'Affected_u0020_Hardware', 'Change_u0020_Reason', 'Change_u0020_Risk', 'Change_u0020_Type', 'Creator', 'Current_u0020_Assignee', 'Current_u0020_Impact', 'Current_u0020_Priority', 'Current_u0020_Reporter', 'Current_u0020_Severity', 'Current_u0020_Status', 'Current_u0020_Status_u0020_Category', 'Current_u0020_Team', 'Current_u0020_Urgency', 'Customer_u0020_Comment_u0020_Count', 'Employee_u0020_Comment_u0020_Count', 'Environment', 'Extraction_u0020_Date', 'First_u0020_Employee_u0020_Comment_u0020_Date', 'First_u0020_Response_u0020_Date', 'First_u0020_Waiting_u0020_for_u0020_Customer_u0020_Date', 'Investigation_u0020_Reason', 'Inward_u0020_Issue_u0020_Links_u0020_Count', 'Issue_u0020_Created_u0020_Date', 'Issue_u0020_Due_u0020_Date', 'Issue_u0020_Key', 'Issue_u0020_Last_u0020_Viewed_u0020_Date', 'Issue_u0020_Resolution_u0020_Date', 'Issue_u0020_Type', 'Issue_u0020_Updated_u0020_Date', 'Labels', 'Major_u0020_Incident', 'Operational_u0020_Categorization', 'Originial_u0020_Estimate_u0020__u0028_seconds_u0029_', 'Outward_u0020_Issue_u0020_Links_u0020_Count', 'Pending_u0020_Reason', 'Planned_u0020_End_u0020_Date', 'Planned_u0020_Start_u0020_Date', 'Product_u0020_Categorization', 'Project', 'Remaining_u0020_Estimate_u0020__u0028_seconds_u0029_', 'Request_u0020_Language', 'Request_u0020_Type', 'Resolution', 'SLA_u0020_Count_u0020_Breaches', 'SLA_u0020_Count_u0020_Completed', 'SLA_u0020_Count_u0020_Ongoing', 'SLA_u0020_Count_u0020_Paused', 'SLA_u0020_Definition_u0020_Count', 'Satisfaction', 'Satisfaction_u0020_Date', 'Summary', 'Target_u0020_End_u0020_Date', 'Target_u0020_Start_u0020_Date', 'URL', 'Work_u0020_Category']
# s4-plan-to-fulfill-1 00_DEMO - Make-to-Stock for SAP S/4 HANA (DO NOT CHANGE)
# ['case_id', 'event_id', 'event_name', 'start_time', 'end_time', 'Event_u0020_Created_u0020_By_u0020_User_u0020_Id', 'Event_u0020_Created_u0020_By_u0020_User_u0020_Type', 'GI_u002f_GR_u0020_Quantity', 'Movement_u0020_Type', 'Object_u0020_Status', 'Status_u0020_Text_u0020_Short', 'TCODE', 'Tcode', 'Actual_u0020_Delivery_u0020_Date', 'Actual_u0020_Finish_u0020_Date', 'Actual_u0020_Release_u0020_Date', 'Actual_u0020_Start_u0020_Date', 'Base_u0020_Quantity', 'Base_u0020_Unit_u0020_of_u0020_Measure', 'Basic_u0020_Finish_u0020_Date', 'Basic_u0020_Start_u0020_Date', 'Business_u0020_Area', 'Client', 'Company_u0020_Code', 'Company_u0020_Name', 'Confirmed_u0020_Finish_u0020_Date', 'Controlling_u0020_Area', 'Controlling_u0020_Area_u0020_Name', 'Creation_u0020_Date', 'Deletion_u0020_Flag', 'Delivery_u0020_Completed', 'Division', 'Division_u0020_Text', 'Functional_u0020_Area', 'GR_u0020_Processing_u0020_Time', 'Location', 'MRP_u0020_Controller', 'Manufacturing_u0020_Plant', 'Manufacturing_u0020_Plant_u0020_Name', 'Material_u0020_Group', 'Material_u0020_Group_u0020_Text', 'Material_u0020_ID', 'Material_u0020_Text', 'Material_u0020_Type', 'Material_u0020_Type_u0020_Text', 'Planned_u0020_Order_u0020_Actual_u0020_Delivery_u0020_Date', 'Planned_u0020_Order_u0020_Basic_u0020_Finish_u0020_Date', 'Planned_u0020_Order_u0020_Number', 'Planned_u0020_Order_u0020_Opening_u0020_Date', 'Planned_u0020_Order_u0020_Start_u0020_Date', 'Planned_u0020_Release_u0020_Date', 'Plant', 'Plant_u0020_Name', 'Process_u0020_Order_u0020_Id', 'Process_u0020_Order_u0020_Type', 'Produced_u0020_Delivered_u0020_Quantity', 'Production_u0020_Scheduler', 'Production_u0020_Scheduler_u0020_Profile', 'Profit_u0020_Center', 'Routing_u0020_Number', 'ScenarioType', 'Scheduled_u0020_Finish_u0020_Date', 'Scheduled_u0020_Release_u0020_Date', 'Scheduled_u0020_Start_u0020_Date', 'Scrap_u0020_Quantity', 'Special_u0020_Procurement_u0020_Type', 'Technical_u0020_Completion_u0020_Date', 'Total_u0020_Order_u0020_Quantity', 'Total_u0020_Scrap_u0020_Quantity', 'Type']
# 00demo---manage-personal-empl-2 00_DEMO - Manage-Personal-Employee-Information for SAP SuccessFactors Employee Central (DO NOT CHANGE)
# ['case_id', 'event_id', 'event_name', 'start_time', 'end_time', 'role', 'step', 'Business_u0020_Unit', 'Comments', 'Country_u0020_of_u0020_Company', 'Created_u0020_By', 'Created_u0020_Date', 'Department', 'Effective_u0020_Date', 'Employee_u0020_Class', 'Employee_u0020_Id', 'Employee_u0020_Status', 'Employment_u0020_Start_u0020_Date', 'Employment_u0020_Type', 'Hiring_u0020_Date', 'Is_u0020_External_u0020_Employee', 'Last_u0020_Modified_u0020_Date', 'Legal_u0020_Entity', 'Location', 'Manager_u0020_Id', 'Request_u0020_Type', 'Workflow_u0020_Created_u0020_By', 'Workflow_u0020_Created_u0020_Date', 'Workflow_u0020_Id', 'Workflow_u0020_Last_u0020_Modified_u0020_Date', 'Workflow_u0020_Status']
# 00testewmoutbound-1 00_DEMO - Manage Warehouse and Inventory (Outbound) in SAP EWM (DO NOT CHANGE)
# ['case_id', 'event_name', 'end_time', 'Event_u0020_Created_u0020_by_u0020_User_u0020_Type', 'LE_u0020_Outbound_u0020_Delivery_u0020_Number', 'EWM_u0020_Outbound_u0020_Delivery_u0020_Number', 'Status_u0020_Type', 'WT_u0020_Process_u0020_Type', 'WT_u0020_Process_u0020_Type_u0020_Description', 'WT_u0020_Activity_u0020_Type', 'WT_u0020_Activity_u0020_Type_u0020_Description', 'SO_u0020_Item_u0020_Document_u0020_Number', 'SO_u0020_Item_u0020_Number', 'SO_u0020_Item_u0020_Material_u0020_Number', 'SO_u0020_Item_u0020_Material_u0020_Description', 'SO_u0020_Item_u0020_Material_u0020_Group', 'SO_u0020_Item_u0020_Material_u0020_Group_u0020_Description', 'SO_u0020_Item_u0020_Net_u0020_Value_u0020_in_u0020_Document_u0020_Currency', 'SO_u0020_Item_u0020_Net_u0020_Price_u0020_in_u0020_Document_u0020_Currency', 'SO_u0020_Item_u0020_Document_u0020_Currency', 'SO_u0020_Item_u0020_Quantity_u0020_Ordered', 'SO_u0020_Item_u0020_Quantity_u0020_Confirmed', 'SO_u0020_Item_u0020_Sales_u0020_Unit', 'LE_u0020_Delivery_u0020_Number', 'LE_u0020_Delivery_u0020_Type', 'LE_u0020_Loading_u0020_Date', 'LE_u0020_Picking_u0020_Date', 'ODO_u0020_Document_u0020_Number', 'ODO_u0020_Incoterms_u0020_1', 'ODO_u0020_Incoterms_u0020_2', 'ODO_u0020_Creation_u0020_Time', 'ODO_u0020_Route', 'ODO_u0020_Item_u0020_Category', 'ODO_u0020_Item_u0020_Staging_u0020_Area', 'ODO_u0020_Item_u0020_Delivery_u0020_Priority', 'ODO_u0020_Item_u0020_Shipping_u0020_Condition', 'ODO_u0020_Item_u0020_Quantity', 'ODO_u0020_Item_u0020_Unit_u0020_of_u0020_Measure', 'ODO_u0020_Item_u0020_Warehouse_u0020_Number', 'ODO_u0020_Item_u0020_Warehouse_u0020_Door', 'ODO_u0020_Item_u0020_Warehouse_u0020_Process_u0020_Type', 'EWM_u0020_Item_u0020_Delivery_u0020_Number', 'EWM_u0020_Item_u0020_Delivery_u0020_Category', 'EWM_u0020_Item_u0020_Number', 'EWM_u0020_Item_u0020_Category', 'EWM_u0020_Item_u0020_Generated_u0020_Manually', 'GI_u0020_Unit_u0020_of_u0020_Measure', 'Total_u0020_GI_u0020_Quantity', 'Number_u0020_of_u0020_WTs']
# bs-sap-is-u-m2c-demo-1 00_DEMO - Meter-to-Cash for SAP IS-U and S/4HANA (DO NOT CHANGE)
# ['case_id', 'event_id', 'event_name', 'start_time', 'end_time', 'BillingDocCancelReason', 'BillingDocId', 'BillingDocValidationName', 'ChangeNewValue', 'ChangeType', 'ChangedField', 'ChangedObjectId', 'ChangedTable', 'DunningCounter', 'DunningId', 'DunningInterestRate', 'DunningTotalAmount', 'EventCreatedByUserId', 'EventCreatedByUserType', 'InvoiceAmount', 'InvoiceCancelReason', 'InvoiceCurrency', 'InvoiceId', 'InvoicePaymentDueDate', 'MeterReadingDataValue', 'PaymentTotalAmount', 'BusinessPartner', 'CompanyCode', 'ContractAccountNo', 'LastBillingDocDivision', 'LastBillingDocDocumentType', 'LastBillingDocId', 'LastBillingDocPortion', 'LastDunningCounter', 'LastDunningId', 'LastDunningInterestRate', 'LastDunningTotalAmount', 'LastInvoiceAmount', 'LastInvoiceBillingKeyDate', 'LastInvoiceCurrency', 'LastInvoiceId', 'LastInvoicePaymentDueDate', 'LastPaymentReason', 'LastPaymentTotalAmount', 'MeterReadingInstallation', 'MeterReadingMeterReader', 'MeterReadingNote', 'MeterReadingOrderDevice', 'MeterReadingOrderId', 'MeterReadingOrderReason', 'MeterReadingPerformedAsPlanned', 'MeterReadingRegister', 'MeterReadingScheduledBillingDate', 'MeterReadingScheduledReadingDate', 'MeterReadingTypeActual', 'MeterReadingTypePlanned', 'MeterReadingUnit', 'MeterReadingUnitDetails']
# sl-dmc-20231009---4-original--1 00_DEMO_Operate Manufacturing in SAP Digital Manufacturing (DO NOT CHANGE)
# ['case_id', 'event_name', 'end_time', 'sfc_u0020_assembly_u0020_operation_u0020_activity', 'sfc_u0020_assembly_u0020_quantity', 'routing_u0020_version', 'routing_u0020_step_u0020_description', 'sfc', 'work_u0020_center', 'resource', 'routing', 'routing_u0020_step', 'sfc_u0020_initial_u0020_quantity', 'sfc_u0020_received_u0020_quantity', 'sfc_u0020_scrapped_u0020_quantity', 'sfc_u0020_build_u0020_quantity', 'sfc_u0020_routing_u0020_type', 'nonconformance_u0020_code', 'nonconformance_u0020_state', 'quantity', 'rework_u0020_activity', 'order_u0020_scrapped_u0020_quantity', 'plant', 'order_u0020_material', 'order_u0020_batch', 'customer_u0020_order', 'order_u0020_type', 'order_u0020_bom', 'order_u0020_bom_u0020_version', 'order_u0020_routing', 'order_u0020_quantity_u0020_ordered', 'order_u0020_received_u0020_quantity', 'order_u0020_released_u0020_quantity', 'order_u0020_build_u0020_quantity', 'unitofmeasure', 'order_u0020_planned_u0020_routing_u0020_type', 'order_u0020_actual_u0020_routing_u0020_type', 'order_u0020_production_u0020_version', 'order_u0020_storage_u0020_location', 'order_u0020_priority', 'order_u0020_release_u0020_status', 'order_u0020_inspection_u0020_lot_u0020_number', 'order_u0020_planned_u0020_bom', 'order_u0020_production_u0020_unit_u0020_of_u0020_measure', 'order_u0020_planned_u0020_material', 'order_u0020_execution_u0020_status', 'order_u0020_scheduled_u0020_completion', 'order_u0020_planned_u0020_completion', 'order_u0020_actual_u0020_completion', 'order_u0020_scheduled_u0020_start', 'order_u0020_actual_u0020_start', 'order_u0020_planned_u0020_start']
# sol-1734sapeccplantmaintenanc-1 00_DEMO - Operate-to-Maintain/Plant_Maintenance for SAP ECC
# ['case_id', 'event_id', 'event_name', 'start_time', 'end_time', 'Change_u0020_New_u0020_Value', 'Change_u0020_Old_u0020_Value', 'Change_u0020_Type', 'Changed_u0020_Field', 'Changed_u0020_Object_u0020_Id', 'Changed_u0020_Table', 'Event_u0020_Created_u0020_By_u0020_User_u0020_Id', 'Event_u0020_Created_u0020_By_u0020_User_u0020_Type', 'Event_u0020_QN_u0020_Catalog_u0020_Type_u0020__u002d__u0020_Coding', 'Event_u0020_QN_u0020_Code_u0020_Group_u0020__u002d__u0020_Coding', 'Event_u0020_QN_u0020_Coding', 'Event_u0020_QN_u0020_ID', 'Event_u0020_QN_u0020_Notification_u0020_Type', 'Event_u0020_QN_u0020_Priority', 'Event_u0020_QN_u0020_Priority_u0020_Type', 'Event_u0020_QN_u0020_Required_u0020_End_u0020_Time', 'Event_u0020_QN_u0020_Required_u0020_Start_u0020_Time', 'Event_u0020_Transaction_u0020_Code', 'MO_u0020_System_u0020_Status', 'Last_u0020_QN_u0020_Item_u0020_Cause', 'Last_u0020_QN_u0020_Item_u0020_Cause_u0020_Code_u0020_Group', 'Last_u0020_QN_u0020_Item_u0020_Cause_u0020_Text', 'Last_u0020_QN_u0020_Item_u0020_Damage', 'Last_u0020_QN_u0020_Item_u0020_Damage_u0020_Code_u0020_Group', 'Last_u0020_QN_u0020_Item_u0020_Damage_u0020_Text', 'Last_u0020_QN_u0020_Item_u0020_ID', 'Last_u0020_QN_u0020_Item_u0020_Object_u0020_Code_u0020_Group', 'Last_u0020_QN_u0020_Item_u0020_Object_u0020_Part', 'Last_u0020_QN_u0020_Item_u0020_Object_u0020_Part_u0020_Text', 'MO_u0020_Actual_u0020_Start_u0020_Date', 'MO_u0020_Assembly_u0020_Number', 'MO_u0020_Assembly_u0020_Text', 'MO_u0020_Basic_u0020_Finish_u0020_Date', 'MO_u0020_Basic_u0020_Start_u0020_Date', 'MO_u0020_Business_u0020_Area', 'MO_u0020_Business_u0020_Area_u0020_Text', 'MO_u0020_Category', 'MO_u0020_Client', 'MO_u0020_Company_u0020_Code', 'MO_u0020_Company_u0020_Name', 'MO_u0020_Confirmed_u0020_Order_u0020_Finish_u0020_Date', 'MO_u0020_Creation_u0020_Date', 'MO_u0020_Deletion_u0020_Flag', 'MO_u0020_Equipment_u0020_Name', 'MO_u0020_Equipment_u0020_Number', 'MO_u0020_Functional_u0020_Location', 'MO_u0020_Functional_u0020_Location_u0020_Label', 'MO_u0020_Functional_u0020_Location_u0020_Text', 'MO_u0020_ID', 'MO_u0020_Location_u0020_and_u0020_account_u0020_assignment_u0020_for_u0020_technical_u0020_object', 'MO_u0020_Main_u0020_Work_u0020_Center', 'MO_u0020_Maintenance_u0020_Activity_u0020_Type', 'MO_u0020_Maintenance_u0020_Activity_u0020_Type_u0020_Text', 'MO_u0020_Maintenance_u0020_Item', 'MO_u0020_Maintenance_u0020_Plan', 'MO_u0020_Maintenance_u0020_Plant', 'MO_u0020_Maintenance_u0020_Plant_u0020_Name', 'MO_u0020_Maintenance_u0020_Processing_u0020_Phase', 'MO_u0020_Material_u0020_Number', 'MO_u0020_Material_u0020_Text', 'MO_u0020_Object_u0020_Number', 'MO_u0020_Order_u0020_Type', 'MO_u0020_Order_u0020_Type_u0020_Text', 'MO_u0020_Planner_u0020_Group', 'MO_u0020_Planner_u0020_Group_u0020_Name', 'MO_u0020_Planning_u0020_Indicator', 'MO_u0020_Planning_u0020_Plant', 'MO_u0020_Planning_u0020_Plant_u0020_Name', 'MO_u0020_Plant', 'MO_u0020_Plant_u0020_Name', 'MO_u0020_Priority', 'MO_u0020_Priority_u0020_Text', 'MO_u0020_Priority_u0020_Type', 'MO_u0020_Priority_u0020_Type_u0020_Text', 'MO_u0020_Profit_u0020_Center', 'MO_u0020_Routing_u0020_number_u0020_of_u0020_operations', 'MO_u0020_Scheduled_u0020_Finish_u0020_Date', 'MO_u0020_Scheduled_u0020_Start_u0020_Date', 'MO_u0020_System_u0020_Condition', 'MO_u0020_System_u0020_Condition_u0020_Text', 'MO_u0020_WBS_u0020_element', 'QN_u0020_Breakdown_u0020_Duration', 'QN_u0020_Breakdown_u0020_Indicator', 'QN_u0020_Catalog_u0020_Type_u0020__u002d__u0020_Coding', 'QN_u0020_Client', 'QN_u0020_Code_u0020_Group_u0020__u002d__u0020_Coding', 'QN_u0020_Coding', 'QN_u0020_Completion_u0020_Date', 'QN_u0020_Creation_u0020_Date', 'QN_u0020_Delete_u0020_Data_u0020_Record', 'QN_u0020_End_u0020_of_u0020_Malfunction', 'QN_u0020_Equipment_u0020_Name', 'QN_u0020_Equipment_u0020_Number', 'QN_u0020_ID', 'QN_u0020_Location_u0020_and_u0020_account_u0020_assignment_u0020_for_u0020_technical_u0020_object', 'QN_u0020_Maintenance_u0020_Order_u0020_ID', 'QN_u0020_Maintenance_u0020_Planning_ ...
# 00demo---otc-sap-ecc-v2-do-no-1 00_DEMO - OTC SAP ECC V2 (DO NOT CHANGE)
# ['case_id', 'event_id', 'event_name', 'start_time', 'end_time', 'ChangeNewValue', 'ChangeType', 'ChangedField', 'ChangedObjectClass', 'ChangedObjectId', 'ChangedTable', 'DeliveryGoodsMovementOnTime', 'DeliveryId', 'DeliveryQuantityDelivered', 'DeliveryWarehouse', 'EventCreatedByUserId', 'EventCreatedByUserType', 'InvoiceAccountingClearingDate', 'InvoiceAccountingDocumentDate', 'InvoiceAccountingDocumentDebitCreditIndicator', 'InvoiceAccountingDocumentId', 'InvoiceAccountingDocumentPostingDate', 'InvoiceClearingDocumentDebitCreditIndicator', 'InvoiceClearingDocumentId', 'InvoiceDocumentType', 'InvoiceDueDate', 'InvoiceGrossAmount', 'InvoiceGrossAmountCurrConverted', 'InvoiceGrossAmountPaid', 'InvoiceGrossAmountPaidCurrConverted', 'InvoiceGrossCashDiscountAmount', 'InvoiceGrossCashDiscountAmountCurrConverted', 'InvoiceId', 'InvoiceNetAmount', 'InvoiceNetAmountCurrConverted', 'InvoicePostingDebitCreditIndicator', 'InvoicePostingGrossAmount', 'InvoiceQuantity', 'InvoiceUnplannedDeliveryCosts', 'NumberOfLineItems', 'UniqueEventId', 'DeliveryCategory', 'DeliveryItemCategory', 'DeliveryPlannedDeliveryDate', 'DeliveryPlannedPickingDate', 'DeliveryShippingType', 'DeliveryTotalQuantityDelivered', 'DeliveryType', 'InvoiceCashDiscountDate1', 'InvoiceCashDiscountDate2', 'InvoiceCashDiscountDays1', 'InvoiceCashDiscountDays2', 'InvoiceCashDiscountPercentage1', 'InvoiceCashDiscountPercentage2', 'InvoiceCompanyCode', 'InvoiceCurrency', 'InvoiceDunningArea', 'InvoiceDunningBlock', 'InvoiceDunningLevel', 'InvoiceItemTotalGrossAmount', 'InvoiceItemTotalGrossAmountCurrConverted', 'InvoiceItemTotalGrossAmountPaid', 'InvoiceItemTotalGrossAmountPaidCurrConverted', 'InvoiceItemTotalGrossCashDiscountAmount', 'InvoiceItemTotalGrossCashDiscountAmountCurrConverted', 'InvoiceItemTotalNetAmount', 'InvoiceItemTotalNetAmountCurrConverted', 'InvoiceItemTotalQuantity', 'InvoiceLastDunnedOn', 'InvoiceNetPaymentTermsPeriod', 'InvoicePaymentTerms', 'InvoiceTotalUnplannedDeliveryCosts', 'InvoiceTransactionCode', 'LastDeliveryGoodsMovementOnTime', 'LastDeliveryId', 'LastDeliveryItemId', 'LastDeliveryWarehouse', 'LastInvoiceAccountingDocumentId', 'LastInvoiceCreateUserType', 'LastInvoiceDocumentType', 'LastInvoiceId', 'SalesDocBillingBlockReason', 'SalesDocCustomerCompany', 'SalesDocCustomerCountry', 'SalesDocDeliveryBlockReason', 'SalesDocId', 'SalesDocItemCategory', 'SalesDocItemId', 'SalesDocItemMaterial', 'SalesDocItemMaterialGroup', 'SalesDocItemMaterialNumber', 'SalesDocItemName', 'SalesDocItemNetValue', 'SalesDocItemPlant', 'SalesDocItemQuantityConfirmed', 'SalesDocItemQuantityOrdered', 'SalesDocItemRejectionReason', 'SalesDocLastConfirmedDeliveryDate', 'SalesDocOrderReason', 'SalesDocPlannedMaterialAvailabilityDate', 'SalesDocPlannedShipmentDate', 'SalesDocPrecedingDocumentType', 'SalesDocReworked', 'SalesDocSalesOffice', 'SalesDocSalesOrganization', 'SalesDocTradingPartner', 'SalesDocType']
# 00demo---otc-sap-s4-hana-v2-d-1 00_DEMO - OTC SAP S/4 HANA (DO NOT CHANGE)
# ...
# hs-163-demo-1 0_demo_accelerators_generic (PTP S4H, changes allowed)
# ['case_id', 'event_id', 'event_name', 'start_time', 'end_time', 'Change_u0020_New_u0020_Value', 'Change_u0020_Old_u0020_Value', 'Change_u0020_Type', 'Changed_u0020_Field', 'Changed_u0020_Object_u0020_Id', 'Changed_u0020_Table', 'Event_u0020_Created_u0020_By_u0020_User_u0020_Id', 'Event_u0020_Created_u0020_By_u0020_User_u0020_Type', 'Event_u0020_Transaction_u0020_Code', 'FI_u0020_Invoice_u0020_Company_u0020_Code', 'FI_u0020_Invoice_u0020_Document_u0020_Date', 'FI_u0020_Invoice_u0020_Document_u0020_Type', 'FI_u0020_Invoice_u0020_Document_u0020_Type_u0020_Text', 'FI_u0020_Invoice_u0020_Fiscal_u0020_Year', 'FI_u0020_Invoice_u0020_ID', 'FI_u0020_Invoice_u0020_Item_u0020_Amount_u0020_for_u0020_G_u002f_L', 'FI_u0020_Invoice_u0020_Item_u0020_Cash_u0020_Discount_u0020_1_u0020_Due_u0020_Date', 'FI_u0020_Invoice_u0020_Item_u0020_Cash_u0020_Discount_u0020_2_u0020_Due_u0020_Date', 'FI_u0020_Invoice_u0020_Item_u0020_Cash_u0020_Discount_u0020_Days_u0020_1', 'FI_u0020_Invoice_u0020_Item_u0020_Cash_u0020_Discount_u0020_Days_u0020_2', 'FI_u0020_Invoice_u0020_Item_u0020_Cash_u0020_Discount_u0020_Percentage_u0020_1', 'FI_u0020_Invoice_u0020_Item_u0020_Cash_u0020_Discount_u0020_Percentage_u0020_2', 'FI_u0020_Invoice_u0020_Item_u0020_Clearing_u0020_Date', 'FI_u0020_Invoice_u0020_Item_u0020_Clearing_u0020_Doc_u002e__u0020_ID', 'FI_u0020_Invoice_u0020_Item_u0020_Clearing_u0020_Entry_u0020_Date', 'FI_u0020_Invoice_u0020_Item_u0020_Due_u0020_Date', 'FI_u0020_Invoice_u0020_Item_u0020_Dunning_u0020_Block', 'FI_u0020_Invoice_u0020_Item_u0020_Dunning_u0020_Date', 'FI_u0020_Invoice_u0020_Item_u0020_Dunning_u0020_Key', 'FI_u0020_Invoice_u0020_Item_u0020_Dunning_u0020_Level', 'FI_u0020_Invoice_u0020_Item_u0020_Fiscal_u0020_Year_u0020_Clearing_u0020_Doc_u002e_', 'FI_u0020_Invoice_u0020_Item_u0020_G_u002f_L_u0020_Account_u0020_Number', 'FI_u0020_Invoice_u0020_Item_u0020_Gross_u0020_Amount_u0020_Document_u0020_Curr_u002e_', 'FI_u0020_Invoice_u0020_Item_u0020_Gross_u0020_Amount_u0020_Local_u0020_Curr_u002e_', 'FI_u0020_Invoice_u0020_Item_u0020_Gross_u0020_Amount_u0020_in_u0020_USD', 'FI_u0020_Invoice_u0020_Item_u0020_Net_u0020_Payment_u0020_Days', 'FI_u0020_Invoice_u0020_Item_u0020_Profit_u0020_Center', 'FI_u0020_Invoice_u0020_Item_u0020_Quantity', 'FI_u0020_Invoice_u0020_Item_u0020_Terms_u0020_of_u0020_Payment_u0020_Key', 'FI_u0020_Invoice_u0020_Line_u0020_Item', 'FI_u0020_Invoice_u0020_Parking_u0020_Date', 'FI_u0020_Invoice_u0020_Posting_u0020_Date', 'FI_u0020_Invoice_u0020_Posting_u0020_Period', 'FI_u0020_Invoice_u0020_Receipt_u0020_Date', 'GR_u0020_Debit_u002f_Credit_u0020_Indicator', 'GR_u0020_Document_u0020_Date', 'GR_u0020_Document_u0020_ID', 'GR_u0020_Document_u0020_Item', 'GR_u0020_Document_u0020_Posting_u0020_Date', 'GR_u0020_Document_u0020_Year', 'GR_u0020_Quantity', 'GR_u0020_Reference_u0020_Material_u0020_Document_u0020_ID', 'GR_u0020_Reference_u0020_Material_u0020_Document_u0020_Item', 'GR_u0020_Reference_u0020_Material_u0020_Document_u0020_Year', 'GR_u0020_Reference_u0020_PO_u0020_Document_u0020_ID', 'GR_u0020_Reference_u0020_PO_u0020_Document_u0020_Item', 'PO_u0020_Item_u0020_Invoiced_u0020_Net_u0020_Amount_u0020_Document_u0020_Curr_u002e_', 'PO_u0020_Item_u0020_Invoiced_u0020_Net_u0020_Amount_u0020_Local_u0020_Curr_u002e_', 'PO_u0020_Item_u0020_Invoiced_u0020_Net_u0020_Amount_u0020_in_u0020_USD', 'PO_u0020_Item_u0020_Invoiced_u0020_Quantity', 'Quality_u0020_Inspection_u0020_Lot_u0020_ID', 'Quality_u0020_Inspection_u0020_Scheduled_u0020_End_u0020_Date', 'Quality_u0020_Inspection_u0020_Scheduled_u0020_Start_u0020_Date', 'Quality_u0020_Inspection_u0020_UD_u0020_Valuation', 'Contract_u0020_Company_u0020_Code', 'Contract_u0020_Company_u0020_Code_u0020_Text', 'Contract_u0020_Id', 'Contract_u0020_Item', 'Contract_u0020_Item_u0020_Net_u0020_Order_u0020_Value', 'Contract_u0020_Item_u0020_Net_u0020_Order_u0020_Value_u0020_in_u0020_USD', 'Contract_u0020_Item_u0020_Net_u0020_Price', 'Contract_u0020_Purchase_u0020_Group', 'Contract_u0020_Purchase_u0020_Organi ...
# nk-showtell---itp-dashboards-1 [NK] Show&Tell - ITP Dashboards
# ['case_id', 'event_id', 'event_name', 'start_time', 'end_time', 'Accounting_u0020_Document_u0020_Segment_u0020_Primary_u0020_Key', 'Amount_u0020_Eligible_u0020_for_u0020_Cash_u0020_Discount_u0020_in_u0020_Document_u0020_Currency', 'Amount_u0020_in_u0020_Document_u0020_Currency', 'Cash_u0020_Discount_u0020_Amount_u0020_in_u0020_Document_u0020_Currency', 'Change_u0020_New_u0020_Value', 'Change_u0020_Old_u0020_Value', 'Change_u0020_Type', 'Changed_u0020_Field', 'Changed_u0020_Object_u0020_Id', 'Changed_u0020_Table', 'Converted_u0020_USD_u0020_Amount', 'Converted_u0020_USD_u0020_Amount_u0020_Eligible_u0020_for_u0020_Cash_u0020_Discount', 'Converted_u0020_USD_u0020_Cash_u0020_Discount_u0020_Amount', 'Documet_u0020_Currency', 'Event_u0020_Created_u0020_By_u0020_User_u0020_Id', 'Event_u0020_Created_u0020_By_u0020_User_u0020_Type', 'GR_u0020_Debit_u002f_Credit_u0020_Indicator', 'GR_u0020_Document_u0020_Date', 'GR_u0020_Document_u0020_ID', 'GR_u0020_Document_u0020_Item', 'GR_u0020_Document_u0020_Posting_u0020_Date', 'GR_u0020_Document_u0020_Year', 'GR_u0020_Quantity', 'GR_u0020_Reference_u0020_Material_u0020_Document_u0020_ID', 'GR_u0020_Reference_u0020_Material_u0020_Document_u0020_Item', 'GR_u0020_Reference_u0020_Material_u0020_Document_u0020_Year', 'GR_u0020_Reference_u0020_PO_u0020_Document_u0020_ID', 'GR_u0020_Reference_u0020_PO_u0020_Document_u0020_Item', 'Invoice_u0020_Due_u0020_Date', 'Invoice_u0020_Line_u0020_Item', 'Invoice_u0020_Receipt_u0020_ID', 'Invoice_u0020_Receipt_u0020_Item', 'Invoice_u0020_Receipt_u0020_Year', 'PO_u0020_Number', 'Quality_u0020_Inspection_u0020_Lot_u0020_ID', 'Quality_u0020_Inspection_u0020_Scheduled_u0020_End_u0020_Date', 'Quality_u0020_Inspection_u0020_Scheduled_u0020_Start_u0020_Date', 'Quality_u0020_Inspection_u0020_UD_u0020_Valuation', 'Reversal_u0020_Indicator', 'Reverse_u0020_Document_u0020_Fiscal_u0020_Year', 'Reverse_u0020_Document_u0020_Number', 'Transaction_u0020_Code', 'Inv_u002e__u0020_Accounting_u0020_Document_u0020_Date', 'Inv_u002e__u0020_Accounting_u0020_Document_u0020_Number', 'Inv_u002e__u0020_Amount_u0020_Eligible_u0020_for_u0020_Cash_u0020_Discount_u0020_in_u0020_Document_u0020_Currency', 'Inv_u002e__u0020_Amount_u0020_in_u0020_Document_u0020_Currency', 'Inv_u002e__u0020_Amount_u0020_in_u0020_Local_u0020_Currency', 'Inv_u002e__u0020_Cash_u0020_Discount_u0020_Amount_u0020_in_u0020_Document_u0020_Currency', 'Inv_u002e__u0020_Cash_u0020_Discount_u0020_Amount_u0020_in_u0020_Local_u0020_Currency', 'Inv_u002e__u0020_Client', 'Inv_u002e__u0020_Company_u0020_Code', 'Inv_u002e__u0020_Company_u0020_Code_u0020_Text', 'Inv_u002e__u0020_Converted_u0020_USD_u0020_Amount', 'Inv_u002e__u0020_Converted_u0020_USD_u0020_Amount_u0020_Eligible_u0020_for_u0020_Cash_u0020_Discount', 'Inv_u002e__u0020_Converted_u0020_USD_u0020_Cash_u0020_Discount_u0020_Amount', 'Inv_u002e__u0020_Creation_u0020_User', 'Inv_u002e__u0020_Creation_u0020_User_u0020_Type', 'Inv_u002e__u0020_Currency_u0020_Key', 'Inv_u002e__u0020_Currency_u0020_Key_u0020_for_u0020_the_u0020_Group_u0020_Currency', 'Inv_u002e__u0020_Currency_u0020_Key_u0020_of_u0020_Second_u0020_Local_u0020_Currency', 'Inv_u002e__u0020_Currency_u0020_Key_u0020_of_u0020_Third_u0020_Local_u0020_Currency', 'Inv_u002e__u0020_Date', 'Inv_u002e__u0020_Document_u0020_Status', 'Inv_u002e__u0020_Document_u0020_Type', 'Inv_u002e__u0020_Document_u0020_Type_u0020_Text', 'Inv_u002e__u0020_Exchange_u0020_Rate_u0020_Type', 'Inv_u002e__u0020_Exchange_u0020_rate', 'Inv_u002e__u0020_Fiscal_u0020_Year', 'Inv_u002e__u0020_Group_u0020_Currency_u0020_Exchange_u0020_Rate', 'Inv_u002e__u0020_Local_u0020_Currency', 'Inv_u002e__u0020_Original_u0020_Reduction_u0020_Amount_u0020_in_u0020_Local_u0020_Currency', 'Inv_u002e__u0020_Posting_u0020_Document_u0020_Date', 'Inv_u002e__u0020_Reference_u0020_Key', 'Inv_u002e__u0020_Reference_u0020_Transaction', 'Inv_u002e__u0020_Reversal_u0020_Indicator', 'Inv_u002e__u0020_Transaction_u0020_Code', 'Last_u0020_Doc_u0020_Posting_u0020_Date_u0020_in_u0020 ...
# sm-ptpariba-1 [SIGPIA-2936] Dashboard_PTP_Ariba
# ['case_id', 'event_name', 'end_time', 'invoice_u0020_number', 'invoice_u0020_id', 'invoice_u0020_reconciliation_u0020_status', 'invoice_u0020_item_u0020_amount', 'invoice_u0020_item_u0020_amount_u0020_accepted', 'invoice_u0020_item_u0020_charge_u0020_amount', 'invoice_u0020_item_u0020_discount_u0020_amount', 'invoice_u0020_item_u0020_tax_u0020_amount', 'invoice_u0020_item_u0020_quantity', 'invoice_u0020_total_u0020_exceptions_u0020_count', 'receipt_u0020_id', 'receipt_u0020_item_u0020_total_u0020_amount', 'receipt_u0020_item_u0020_unit_u0020_price', 'receipt_u0020_item_u0020_quantity', 'receipt_u0020_item_u0020_processed_u0020_state', 'receipt_u0020_item_u0020_delivery_u0020_date', 'last_u0020_invoice_u0020_item_u0020_charge_u0020_amount', 'last_u0020_invoice_u0020_item_u0020_discount_u0020_amount', 'last_u0020_invoice_u0020_item_u0020_estimated_u0020_savings', 'last_u0020_invoice_u0020_item_u0020_tax_u0020_amount', 'last_u0020_invoice_u0020_item_u0020_expected_u0020_tax_u0020_amount', 'last_u0020_invoice_u0020_item_u0020_accrual_u0020_tax_u0020_amount', 'last_u0020_invoice_u0020_item_u0020_tax_u0020_rate', 'last_u0020_invoice_u0020_number', 'last_u0020_invoice_u0020_id', 'last_u0020_invoice_u0020_line_u0020_item_u0020_id', 'last_u0020_invoice_u0020_type', 'last_u0020_invoice_u0020_item_u0020_type', 'last_u0020_invoice_u0020_item_u0020_category', 'last_u0020_invoice_u0020_quantity', 'last_u0020_invoice_u0020_date', 'last_u0020_invoice_u0020_created_u0020_date', 'last_u0020_invoice_u0020_submission_u0020_date', 'last_u0020_invoice_u0020_due_u0020_date', 'last_u0020_invoice_u0020_approval_u0020_date', 'last_u0020_invoice_u0020_reconciled_u0020_date', 'last_u0020_invoice_u0020_payment_u0020_date', 'last_u0020_invoice_u0020_accounting_u0020_date', 'last_u0020_invoice_u0020_po_u0020_buyer_u0020_type', 'last_u0020_invoice_u0020_ship_u0020_from_u0020_location_u0020_id', 'last_u0020_invoice_u0020_payment_u0020_terms', 'last_u0020_invoice_u0020_origin', 'last_u0020_invoice_u0020_purpose', 'last_u0020_invoice_u0020_source_u0020_document', 'last_u0020_invoice_u0020_status', 'last_u0020_invoice_u0020_submission_u0020_method', 'last_u0020_invoice_u0020_reconciliation_u0020_status', 'last_u0020_invoice_u0020_currency', 'last_u0020_invoice_u0020_item_u0020_amount', 'last_u0020_invoice_u0020_item_u0020_amount_u0020_accepted', 'last_u0020_invoice_u0020_item_u0020_amount_u0020_disputed', 'last_u0020_invoice_u0020_item_u0020_amount_u0020_paid', 'po_u0020_id', 'po_u0020_item_u0020_id', 'parent_u0020_po_u0020_line_u0020_item_u0020_id', 'po_u0020_erp_u0020_id', 'po_u0020_type', 'po_u0020_item_u0020_category', 'po_u0020_material_u0020_number', 'po_u0020_item_u0020_line_u0020_type', 'po_u0020_item_u0020_supplier_u0020_id', 'po_u0020_item_u0020_contract_u0020_id', 'po_u0020_requires_u0020_service_u0020_entry_u0020_flag', 'po_u0020_service_u0020_order', 'po_u0020_confirmation_u0020_status', 'account_u0020_type', 'account_u0020_id', 'accounting_u0020_company_u0020_code', 'accounting_u0020_project_u0020_id', 'accounting_u0020_region_u0020_id', 'po_u0020_tax_u0020_amount', 'po_u0020_amount_u0020_discount', 'po_u0020_amount_u0020_accepted', 'po_u0020_amount_u0020_billed', 'po_u0020_amount_u0020_cleared', 'po_u0020_amount_u0020_reconciled', 'po_u0020_amount_u0020_invoiced', 'po_u0020_amount_u0020_left_u0020_to_u0020_invoice', 'po_u0020_amount_u0020_left_u0020_to_u0020_reconcile', 'po_u0020_charge_u0020_amount', 'po_u0020_delivery_u0020_status', 'po_u0020_asset_u0020_id', 'bill_u0020_to_u0020_location_u0020_id', 'commodity_u0020_id', 'po_u0020_business_u0020_unit', 'po_u0020_purchasing_u0020_group', 'ship_u0020_to_u0020_location_u0020_id', 'supplier_u0020_location_u0020_id', 'po_u0020_currency', 'po_u0020_tax_u0020_code_u0020_id', 'po_u0020_tax_u0020_code_u0020_name', 'po_u0020_tax_u0020_code_u0020_description', 'blanket_u0020_purchase_u0020_order', 'po_u0020_ordered_u0020_date', 'po_u0020_requested_u0020_delivery_u0020_date', 'po_u0020_service_u0020_start_u ...

# %% [markdown]
# ## Step 1. Select Signavio workspace here and Get list of processes in given workspace
# Later we will extract all Dashboards/Investigations and Metrics from the selected workspace
#
# The selection of the workspace is controlled by:
#
# ```python
# # Select workspace
# workspace_name="Solutions Demo Workspace"
# #workspace_name="Process AI"
#  ```

# %%
# Workspace selection 
workspace_name="Solutions Demo Workspace"
#workspace_name="SAP Signavio Suite Power Challenge"
#workspace_name="Process AI"

# %%
# Get list of available process:
workspace_name="Solutions Demo Workspace"
signavio_client = auth_clients[workspace_name]
list_processes =  signavio_client.pi.subjects()
print(f"In Workspace Name: {workspace_name}. Number of processes: {len(list_processes)}")

workspace_name="Process AI"
signavio_client = auth_clients[workspace_name]
list_processes =  signavio_client.pi.subjects()
print(f"In Workspace Name: {workspace_name}. Number of processes: {len(list_processes)}")
# Out:
# In Workspace Name: Solutions Demo Workspace. Number of processes: 30
# In Workspace Name: Process AI. Number of processes: 7

# %%
list_processes
# Out:
# [PISubject(
#      id='demo01-1',
#      name='demo01',
#      business_area='ba-3',
#      currency_code=None,
#      preprocessing_status=<PISubjectPreprocessingStatus.PROCESSING_FINISHED: 'PROCESSING_FINISHED'>,
#      changed_at=datetime.datetime(2023, 10, 20, 8, 35, 59, 373000, tzinfo=TzInfo(UTC)),
#      source_system=None,
#      process_types=None,
#      event_log_updated_at=datetime.datetime(2023, 10, 20, 8, 35, 57, 484000, tzinfo=TzInfo(UTC)),
#      investigation_count=0,
#      dashboard_count=0
#  ),
#  PISubject(
#      id='dvtest-1',
#      name='dv_test',
#      business_area='ba-3',
#      currency_code=None,
#      preprocessing_status=<PISubjectPreprocessingStatus.PROCESSING_FINISHED: 'PROCESSING_FINISHED'>,
#      changed_at=datetime.datetime(2023, 11, 9, 17, 14, 55, 609000, tzinfo=TzInfo(UTC)),
#      source_system=None,
#      process_types=None,
#      event_log_updated_at=datetime.datetime(2023, 11, 9, 17, 14, 53, 385000, tzinfo=TzInfo(UTC)),
#      investigation_count=1,
#      dashboard_count=0
#  ),
#  PISubject(
#      id='sfdsdf-1',
#      name='sfdsdf',
#      business_area='ba-3',
#      currency_code=None,
#      preprocessing_status=<PISubjectPreprocessingStatus.NO_DATA: 'NO_DATA'>,
#      changed_at=datetime.datetime(2023, 11, 3, 15, 9, 8, 586000, tzinfo=TzInfo(UTC)),
#      source_system=None,
#      process_types=None,
#      event_log_updated_at=None,
#      investigation_count=0,
#      dashboard_count=0
#  ),
#  PISubject(
#      id='test-1',
#      name='Test',
#      business_area='ba-3',
#      currency_code=None,
#      preprocessing_status=<PISubjectPreprocessingStatus.NO_DATA: 'NO_DATA'>,
#      changed_at=datetime.datetime(2023, 11, 8, 8, 45, 56, 834000, tzinfo=TzInfo(UTC)),
#      source_system=None,
#      process_types=None,
#      event_log_updated_at=None,
#      investigation_count=0,
#      dashboard_count=0
#  ),
#  PISubject(
#      id='test00-1',
#      name='test00',
#      business_area='ba-3',
#      currency_code=None,
#      preprocessing_status=<PISubjectPreprocessingStatus.PROCESSING_FINISHED: 'PROCESSING_FINISHED'>,
#      changed_at=datetime.datetime(2023, 10, 24, 12, 57, 50, 774000, tzinfo=TzInfo(UTC)),
#      source_system='SAP_SALES_CLOUD',
#      process_types=None,
#      event_log_updated_at=datetime.datetime(2023, 10, 24, 12, 57, 49, 318000, tzinfo=TzInfo(UTC)),
#      investigation_count=2,
#      dashboard_count=0
#  ),
#  PISubject(
#      id='test001-1',
#      name='test001',
#      business_area='ba-3',
#      currency_code=None,
#      preprocessing_status=<PISubjectPreprocessingStatus.PROCESSING_FINISHED: 'PROCESSING_FINISHED'>,
#      changed_at=datetime.datetime(2023, 10, 12, 11, 3, 20, 873000, tzinfo=TzInfo(UTC)),
#      source_system=None,
#      process_types=None,
#      event_log_updated_at=datetime.datetime(2023, 10, 12, 11, 3, 16, 897000, tzinfo=TzInfo(UTC)),
#      investigation_count=0,
#      dashboard_count=0
#  ),
#  PISubject(
#      id='test002-1',
#      name='test002',
#      business_area='ba-3',
#      currency_code=None,
#      preprocessing_status=<PISubjectPreprocessingStatus.PROCESSING_FINISHED: 'PROCESSING_FINISHED'>,
#      changed_at=datetime.datetime(2023, 10, 12, 10, 53, 45, 363000, tzinfo=TzInfo(UTC)),
#      source_system=None,
#      process_types=None,
#      event_log_updated_at=datetime.datetime(2023, 10, 12, 10, 53, 43, 839000, tzinfo=TzInfo(UTC)),
#      investigation_count=0,
#      dashboard_count=0
#  )]

# %% [markdown]
# ## Step 2. Get lists of Dashboards, Investigations, Metrics for each of the processes from the above Step 1. nd store in all_json JSON
#
# The selection of the workspace is controlled by:
#
# ```python
# # Select workspace
# workspace_name="Solutions Demo Workspace"
# #workspace_name="Process AI"
#  ```

# %% [markdown]
# First,  we run collection of Signavio API calls to upload information about Dashboards , Investigations for each process in the defined above workspace
#
# Then, we save all of them also in fs as  **"all_json_WORKSPACENAME_DATE.json"** and al respective dashboards, investigations, metrics.
# e.g for workspace_name="Solutions Demo Workspace":
#
# Dumping all extracted Dashboards, Investigations, Metrics data to ../data/all_json_Solutions_Demo_Workspace_2023-12-01T07_54_49.json
#
# ```js
# data
# ├── [0]_Dashboards_ITP\ Process
# │   │   ├── dashboards
# │   │   │   ├── 00_Empty\ Template_2023-12-01.json
# │   │   │   ├── 0[SL]-\ Payment\ Term\ Optimization\ (for\ Final\ dashboard)_2023-12-01.json
# │   │   │   └── [SL]\ Payment\ Term\ Analysis\ -\ Use\ case\ 3\ -\ SOL-\ 2727_2023-12-01.json
# │   │   ├── investigations
# │   │   │   └── Event\ lvl\ metrics\ test_2023-12-01.json
# │   │   ├── metrics
# │   │   │   └── metrics.json
# │   │   └── views
# │   │       └── views.json
# │   ├── [NK]\ Show&Tell\ -\ ITP\ Dashboards
# │   │   ├── dashboards
# │   │   │   └── [04]\ Payment\ Behaviour_2023-12-01.json
# │   │   ├── metrics
# │   │   │   └── metrics.json
# │   │   └── views
# │   │       └── views.json
# │   └── [SIGPIA-2936]\ Dashboard_PTP_Ariba
# │       ├── dashboards
# │       │   ├── 00_Overview\ Dashboard_2023-12-01.json
# │       │   ├── Automation\ Dashboard_2023-12-01.json
# │       │   ├── Cycle\ Time\ Dashboard_2023-12-01.json
# │       │   ├── Payment\ Behaviour_2023-12-01.json
# │       │   └── Spend\ Analysis_2023-12-01.json
# │       ├── investigations
# │       │   ├── SAP_ARIBA_PTP_2023-12-01.json
# │       │   └── Test_2023-12-01.json
# │       ├── metrics
# │       │   └── metrics.json
# │       └── views
# │           └── views.json
# └── all_json_Solutions_Demo_Workspace_2023-12-01T07_54_49.json
# ```

# %%
from text2signal.data.utils import load_configurations
from text2signal.data.pi_extractor import PIDataManager

config = load_configurations('../text2signal/configs/workspaces_temp.yaml')
workspaces = config.get('workspaces', {})
root_dir = config.get('root_dir', '../data/temp')

manager = PIDataManager(workspaces)

for workspace_name in workspaces.keys():
    print(f"Processing workspace: {workspace_name}")
    all_json = manager.fetch_data(workspace_name, root_dir)
    manager.save_all_jsons(root_dir, workspace_name, all_json)
# Out:
# Processing workspace: Process AI
# Failed to perform request for entity askdata-poc-1: 403 Client Error: Forbidden for url: https://editor.signavio.com/g/api/pi-graphql/investigations/askdata-poc-1/export
# Failed to perform request for entity q1-1: 403 Client Error: Forbidden for url: https://editor.signavio.com/g/api/pi-graphql/investigations/q1-1/export
# Dumping all extracted Dashboards, Investigations, Metrics data to data/temp/all_json_Process_AI_2024-02-11T23_09_18.json

# %% [markdown]
# ## Step 3. Get Signals from json/json_files
#
# Here we use all_json JSONs to extract Signals therein.
#
# Additionally, we can extract Signals from files metrics, dashboards, investigations JSON-files stored on your filesystem.
#
# Problem here is that we have specify view variable - needed to run API calls against real log DB, typically we need this to
# validate Signals, human or LLM-generated.
#
# ```js
# data/
# ├── ContentPackage_November2023
# │   ├── KFFI000960\ -\ Supplier\ payment\ without\ purchasing
# │   ├── KFFI001060\ -\ Cash\ collection\ for\ non-sales\ (invoices)
# │   ├── KPLE000360\ -\ Delivery\ processing\ for\ subcontracting\ wit
# ...
# ── NLP\ POC\ (JustAsk)
# │   ├── 01\ Introduction
# │   ├── 02\ OTC\ Data\ Set
# │   ├── 03\ Mining\ Questions\ and\ SIGNAL\ Queries
# │   ├── 04\ PI\ Investigation
# │   └── JustAsk\ -\ Signavio\ Widget\ Builder.pptx
# ├── OPAL
# │   ├── DRAFT_1.json
# │   └── DRAFT_2.json
# data/From_API/
# ├── Process\ AI
# │   ├── Test
# │   ├── demo01
# ...
# ├── Solutions\ Demo\ Workspace
# │   ├── 000_DEMO�\234�\ -\ Dashboards\ ITC\ ECC\ &\ S4H\ (DO\ NOT\ CHANGE)
# │   ├── 000_DEMO�\234�\ -\ Dashboards\ ITP\ ECC\ &\ S4H\ (DO\ NOT\ CHANGE
# ...
# ├── all_extracted_signals_2023-12-01T09_59_45.json
# ├── all_json_Process_AI_2023-12-01T09_53_37.json
# └── all_json_Solutions_Demo_Workspace_2023-12-01T09_53_24.json
# ...
# ```

# %% [markdown]
# ###  Extract Signals and save them to all_extracted_signals_DATE.json

# %%
import datetime
import pandas as pd

from pathlib import Path

from text2signal.data.signal_extraction import SignalExtractor
from text2signal.data.utils import load_configurations, save_json_to_file

"""Extract signals from JSON files."""
yaml_config = load_configurations('../text2signal/configs/signal_extraction_config_temp.yaml')
print(f"Loaded configuration: {yaml_config.get('ouput_dir')}")
configurations = yaml_config.get('configurations', [])
all_signals = []

for config in configurations:
    extractor = SignalExtractor(workspace_name=config["workspace"], view_id=config["view_id"], base_path=Path(config["path"]))
    signals = extractor.process_jsons()
    all_signals.extend(signals)

print(f"Total signals extracted: {len(all_signals)}")
# Save extracted signals
date_str = datetime.datetime.now().strftime("%Y-%m-%dT%H_%M_%S")
file_path = Path(f"{yaml_config.get('ouput_dir')}/all_extracted_signals_{date_str}.json")
print(f"Dumping {len(all_signals)} extracted signals  to {file_path}")
save_json_to_file(all_signals, file_path)

df = pd.DataFrame(all_signals)
signals_file_path = Path(f"{yaml_config.get('ouput_dir')}/signals_{date_str}.csv")
print(f"Saving CSV file with Signals: {signals_file_path}")
df.to_csv(signals_file_path)
# Out:
# Loaded configuration: data/temp
# None: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards ITC ECC & S4H (DO NOT CHANGE)/metrics/metrics.json : 1
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards ITC ECC & S4H (DO NOT CHANGE)/dashboards/Cycle Times_2024-02-01.json : 20
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards ITC ECC & S4H (DO NOT CHANGE)/dashboards/Automation_2024-02-01.json : 30
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards ITC ECC & S4H (DO NOT CHANGE)/dashboards/00_Overview_2024-02-01.json : 28
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards ITC ECC & S4H (DO NOT CHANGE)/dashboards/Optimize Your Payment Term Usage_2024-02-01.json : 22
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards ITC ECC & S4H (DO NOT CHANGE)/dashboards/Improve Days Sales Outstanding (DSO) _2024-02-01.json : 39
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards ITC ECC & S4H (DO NOT CHANGE)/dashboards/Global Value Approach_2024-02-01.json : 74
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards ITC ECC & S4H (DO NOT CHANGE)/dashboards/_Global Value Approach_2024-02-01.json : 74
# 000_DEMO✨ - Dashboards ITC ECC & S4H (DO NOT CHANGE) subtotal Signals: 288
# None: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards ITP ECC & S4H (DO NOT CHANGE)/metrics/metrics.json : 6
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards ITP ECC & S4H (DO NOT CHANGE)/dashboards/Automation_2024-02-01.json : 33
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards ITP ECC & S4H (DO NOT CHANGE)/dashboards/SAP S/4HANA - Invoice to Pay_2024-02-01.json : 3
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards ITP ECC & S4H (DO NOT CHANGE)/dashboards/00_Overview_2024-02-01.json : 29
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards ITP ECC & S4H (DO NOT CHANGE)/dashboards/Cycle Times_2024-02-01.json : 20
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards ITP ECC & S4H (DO NOT CHANGE)/dashboards/Open Overdue Invoices_2024-02-01.json : 49
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards ITP ECC & S4H (DO NOT CHANGE)/dashboards/Payment Behaviour_2024-02-01.json : 59
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards ITP ECC & S4H (DO NOT CHANGE)/dashboards/Payment Term_2024-02-01.json : 34
# 000_DEMO✨ - Dashboards ITP ECC & S4H (DO NOT CHANGE) subtotal Signals: 233
# None: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards OTC ECC & S4H (DO NOT CHANGE) /metrics/metrics.json : 5
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards OTC ECC & S4H (DO NOT CHANGE) /dashboards/zz-SAP S/4HANA - Order to Cash_2024-02-01.json : 3
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards OTC ECC & S4H (DO NOT CHANGE) /dashboards/Customer Satisfaction_2024-02-01.json : 27
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards OTC ECC & S4H (DO NOT CHANGE) /dashboards/00_Overview_2024-02-01.json : 27
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards OTC ECC & S4H (DO NOT CHANGE) /dashboards/Cycle Times_2024-02-01.json : 32
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards OTC ECC & S4H (DO NOT CHANGE) /dashboards/Automation_2024-02-01.json : 37
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards OTC ECC & S4H (DO NOT CHANGE) /dashboards/Working Capital_2024-02-01.json : 39
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards OTC ECC & S4H (DO NOT CHANGE) /dashboards/Efficiency and Rework_2024-02-01.json : 47
# ['investigation', 'metrics']: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards OTC ECC & S4H (DO NOT CHANGE) /investigations/General_2024-02-01.json : 0
# 000_DEMO✨ - Dashboards OTC ECC & S4H (DO NOT CHANGE)  subtotal Signals: 217
# None: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)/metrics/metrics.json : 71
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)/dashboards/zz Dashboard 4: Changes_2024-02-01.json : 22
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)/dashboards/zz - PO Vendor Dashboard_2024-02-01.json : 15
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)/dashboards/zz_Agnostic - Overview_2024-02-01.json : 22
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)/dashboards/zz: Data Validation _2024-02-01.json : 7
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)/dashboards/zz - Empty Dashboard Template_2024-02-01.json : 10
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)/dashboards/zz: General Recommendations_2024-02-01.json : 0
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)/dashboards/zz - CBI Test Dashboard_2024-02-01.json : 9
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)/dashboards/zz_CBI - Payment Term Optimization (for Final dashboard)_2024-02-01.json : 20
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)/dashboards/zz_SAP S/4HANA - Procure to Pay_2024-02-01.json : 3
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)/dashboards/   Dashboard Feature Test_2024-02-01.json : 10
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)/dashboards/Open Overdue Invoices_2024-02-01.json : 31
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)/dashboards/Cycle Times_2024-02-01.json : 16
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)/dashboards/00_Overview_2024-02-01.json : 24
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)/dashboards/Late Payments _2024-02-01.json : 15
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)/dashboards/Automation_2024-02-01.json : 21
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)/dashboards/Global Value Approach_2024-02-01.json : 54
# Warning: No substitution found for variable 'po_change_event_flow'. Using placeholder.
# Warning: No substitution found for variable 'po_creation_events'. Using placeholder.
# Warning: No substitution found for variable 'itp_clearing_date'. Using placeholder.
# ['investigation', 'metrics']: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)/investigations/Presales Template - HZL POV_Insights_2024-02-01.json : 201
# ['investigation', 'metrics']: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)/investigations/Dashboard Feature Validation_2024-02-01.json : 0
# 000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE) subtotal Signals: 551
# None: ../data/From_API/Solutions Demo Workspace/00_DEMO - Acquire-to-Onboard for  SAP ECC & S/4 HANA (DO NOT CHANGE)/metrics/metrics.json : 25
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/00_DEMO - Acquire-to-Onboard for  SAP ECC & S/4 HANA (DO NOT CHANGE)/dashboards/00_Overview_2024-02-01.json : 27
# 00_DEMO - Acquire-to-Onboard for  SAP ECC & S/4 HANA (DO NOT CHANGE) subtotal Signals: 52
# None: ../data/From_API/Solutions Demo Workspace/00_DEMO - Attract-to-Acquire-Talent for SuccessFactors/metrics/metrics.json : 7
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/00_DEMO - Attract-to-Acquire-Talent for SuccessFactors/dashboards/SAP SuccessFactors - Attract to Acquire Talent_2024-02-01.json : 3
# 00_DEMO - Attract-to-Acquire-Talent for SuccessFactors subtotal Signals: 10
# None: ../data/From_API/Solutions Demo Workspace/00_DEMO - Inspect-to-Quality for SAP S/4 HANA (DO NOT CHANGE)/metrics/metrics.json : 13
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/00_DEMO - Inspect-to-Quality for SAP S/4 HANA (DO NOT CHANGE)/dashboards/SAP S/4HANA - Inspect to Quality_2024-02-01.json : 3
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/00_DEMO - Inspect-to-Quality for SAP S/4 HANA (DO NOT CHANGE)/dashboards/00_Overview_2024-02-01.json : 25
# 00_DEMO - Inspect-to-Quality for SAP S/4 HANA (DO NOT CHANGE) subtotal Signals: 41
# None: ../data/From_API/Solutions Demo Workspace/00_DEMO - Invoice-to-Cash for SAP S/4 HANA (DO NOT CHANGE)/metrics/metrics.json : 63
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/00_DEMO - Invoice-to-Cash for SAP S/4 HANA (DO NOT CHANGE)/dashboards/Process Overview _2024-02-01.json : 4
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/00_DEMO - Invoice-to-Cash for SAP S/4 HANA (DO NOT CHANGE)/dashboards/Agnostic - Overview_2024-02-01.json : 22
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/00_DEMO - Invoice-to-Cash for SAP S/4 HANA (DO NOT CHANGE)/dashboards/SAP S/4HANA - Invoice to Cash_2024-02-01.json : 4
# ['investigation', 'metrics']: ../data/From_API/Solutions Demo Workspace/00_DEMO - Invoice-to-Cash for SAP S/4 HANA (DO NOT CHANGE)/investigations/ITC Metrics testing_2024-02-01.json : 8
# ['investigation', 'metrics']: ../data/From_API/Solutions Demo Workspace/00_DEMO - Invoice-to-Cash for SAP S/4 HANA (DO NOT CHANGE)/investigations/Demo ITC_2024-02-01.json : 11
# ['investigation', 'metrics']: ../data/From_API/Solutions Demo Workspace/00_DEMO - Invoice-to-Cash for SAP S/4 HANA (DO NOT CHANGE)/investigations/Invoice-to-Cash_2024-02-01.json : 6
# 00_DEMO - Invoice-to-Cash for SAP S/4 HANA (DO NOT CHANGE) subtotal Signals: 118
# None: ../data/From_API/Solutions Demo Workspace/00_DEMO - Invoice-to-Pay for SAP S/4 HANA (DO NOT CHANGE)/metrics/metrics.json : 10
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/00_DEMO - Invoice-to-Pay for SAP S/4 HANA (DO NOT CHANGE)/dashboards/Automation_2024-02-01.json : 33
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/00_DEMO - Invoice-to-Pay for SAP S/4 HANA (DO NOT CHANGE)/dashboards/Payment Behaviour_2024-02-01.json : 59
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/00_DEMO - Invoice-to-Pay for SAP S/4 HANA (DO NOT CHANGE)/dashboards/Open Overdue Invoices_2024-02-01.json : 49
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/00_DEMO - Invoice-to-Pay for SAP S/4 HANA (DO NOT CHANGE)/dashboards/Payment Terms_2024-02-01.json : 35
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/00_DEMO - Invoice-to-Pay for SAP S/4 HANA (DO NOT CHANGE)/dashboards/Cycle Times_2024-02-01.json : 20
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/00_DEMO - Invoice-to-Pay for SAP S/4 HANA (DO NOT CHANGE)/dashboards/00_Overview_2024-02-01.json : 29
# 00_DEMO - Invoice-to-Pay for SAP S/4 HANA (DO NOT CHANGE) subtotal Signals: 235
# None: ../data/From_API/Solutions Demo Workspace/00_DEMO Issue-to-Resolution for Jira/metrics/metrics.json : 36
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/00_DEMO Issue-to-Resolution for Jira/dashboards/00_Overview_2024-02-01.json : 43
# ['investigation', 'metrics']: ../data/From_API/Solutions Demo Workspace/00_DEMO Issue-to-Resolution for Jira/investigations/Issue-to-Resolution_2024-02-01.json : 4
# ['investigation', 'metrics']: ../data/From_API/Solutions Demo Workspace/00_DEMO Issue-to-Resolution for Jira/investigations/Issue-to-Resolution (Copy)_2024-02-01.json : 4
# 00_DEMO Issue-to-Resolution for Jira subtotal Signals: 87
# None: ../data/From_API/Solutions Demo Workspace/00_DEMO - Make-to-Stock for SAP S/4 HANA (DO NOT CHANGE)/metrics/metrics.json : 2
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/00_DEMO - Make-to-Stock for SAP S/4 HANA (DO NOT CHANGE)/dashboards/General_2024-02-01.json : 13
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/00_DEMO - Make-to-Stock for SAP S/4 HANA (DO NOT CHANGE)/dashboards/Reduce manufacturing costs & improve process harmonization_2024-02-01.json : 29
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/00_DEMO - Make-to-Stock for SAP S/4 HANA (DO NOT CHANGE)/dashboards/Overview_2024-02-01.json : 4
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/00_DEMO - Make-to-Stock for SAP S/4 HANA (DO NOT CHANGE)/dashboards/Agnostic - Overview Dashboard_2024-02-01.json : 22
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/00_DEMO - Make-to-Stock for SAP S/4 HANA (DO NOT CHANGE)/dashboards/SAP S/4HANA - Make to Stock_2024-02-01.json : 3
# ['investigation', 'metrics']: ../data/From_API/Solutions Demo Workspace/00_DEMO - Make-to-Stock for SAP S/4 HANA (DO NOT CHANGE)/investigations/KPI Validation_2024-02-01.json : 48
# ['investigation', 'metrics']: ../data/From_API/Solutions Demo Workspace/00_DEMO - Make-to-Stock for SAP S/4 HANA (DO NOT CHANGE)/investigations/Presentation_2024-02-01.json : 60
# ['investigation', 'metrics']: ../data/From_API/Solutions Demo Workspace/00_DEMO - Make-to-Stock for SAP S/4 HANA (DO NOT CHANGE)/investigations/Plan to Fulfill_2024-02-01.json : 17
# ['investigation', 'metrics']: ../data/From_API/Solutions Demo Workspace/00_DEMO - Make-to-Stock for SAP S/4 HANA (DO NOT CHANGE)/investigations/KPI Status_2024-02-01.json : 35
# 00_DEMO - Make-to-Stock for SAP S/4 HANA (DO NOT CHANGE) subtotal Signals: 233
# None: ../data/From_API/Solutions Demo Workspace/00_DEMO - Manage-Personal-Employee-Information for SAP SuccessFactors Employee Central (DO NOT CHANGE)/metrics/metrics.json : 7
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/00_DEMO - Manage-Personal-Employee-Information for SAP SuccessFactors Employee Central (DO NOT CHANGE)/dashboards/Manage Personal Employee Information - DEMO_2024-02-01.json : 8
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/00_DEMO - Manage-Personal-Employee-Information for SAP SuccessFactors Employee Central (DO NOT CHANGE)/dashboards/SAP SuccessFactors - Manage Personal Employee Information_2024-02-01.json : 8
# ['investigation', 'metrics']: ../data/From_API/Solutions Demo Workspace/00_DEMO - Manage-Personal-Employee-Information for SAP SuccessFactors Employee Central (DO NOT CHANGE)/investigations/Process Overview_2024-02-01.json : 7
# 00_DEMO - Manage-Personal-Employee-Information for SAP SuccessFactors Employee Central (DO NOT CHANGE) subtotal Signals: 30
# None: ../data/From_API/Solutions Demo Workspace/00_DEMO - Manage Warehouse and Inventory (Outbound) in SAP EWM (DO NOT CHANGE)/metrics/metrics.json : 32
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/00_DEMO - Manage Warehouse and Inventory (Outbound) in SAP EWM (DO NOT CHANGE)/dashboards/Manage Warehouse and Inventory (Outbound) in SAP EWM_2024-02-01.json : 43
# 00_DEMO - Manage Warehouse and Inventory (Outbound) in SAP EWM (DO NOT CHANGE) subtotal Signals: 75
# None: ../data/From_API/Solutions Demo Workspace/00_DEMO - Meter-to-Cash for SAP IS-U and S/4HANA (DO NOT CHANGE)/metrics/metrics.json : 18
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/00_DEMO - Meter-to-Cash for SAP IS-U and S/4HANA (DO NOT CHANGE)/dashboards/00_Overview_2024-02-01.json : 22
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/00_DEMO - Meter-to-Cash for SAP IS-U and S/4HANA (DO NOT CHANGE)/dashboards/Demo_SP_2024-02-01.json : 0
# 00_DEMO - Meter-to-Cash for SAP IS-U and S/4HANA (DO NOT CHANGE) subtotal Signals: 40
# None: ../data/From_API/Solutions Demo Workspace/00_DEMO_Operate Manufacturing in SAP Digital Manufacturing (DO NOT CHANGE)/metrics/metrics.json : 15
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/00_DEMO_Operate Manufacturing in SAP Digital Manufacturing (DO NOT CHANGE)/dashboards/Overview Dashboard_2024-02-01.json : 25
# 00_DEMO_Operate Manufacturing in SAP Digital Manufacturing (DO NOT CHANGE) subtotal Signals: 40
# None: ../data/From_API/Solutions Demo Workspace/00_DEMO - Operate-to-Maintain/Plant_Maintenance for SAP ECC/metrics/metrics.json : 30
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/00_DEMO - Operate-to-Maintain/Plant_Maintenance for SAP ECC/dashboards/Process Overview_2024-02-01.json : 0
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/00_DEMO - Operate-to-Maintain/Plant_Maintenance for SAP ECC/dashboards/SAP S/4HANA - Operate to Maintain_2024-02-01.json : 2
# ['investigation', 'metrics']: ../data/From_API/Solutions Demo Workspace/00_DEMO - Operate-to-Maintain/Plant_Maintenance for SAP ECC/investigations/First Test - JRP_2024-02-01.json : 0
# ['investigation', 'metrics']: ../data/From_API/Solutions Demo Workspace/00_DEMO - Operate-to-Maintain/Plant_Maintenance for SAP ECC/investigations/Operate-to-Maintain_2024-02-01.json : 3
# ['investigation', 'metrics']: ../data/From_API/Solutions Demo Workspace/00_DEMO - Operate-to-Maintain/Plant_Maintenance for SAP ECC/investigations/Operate to Maintain_2024-02-01.json : 0
# 00_DEMO - Operate-to-Maintain/Plant_Maintenance for SAP ECC subtotal Signals: 35
# None: ../data/From_API/Solutions Demo Workspace/00_DEMO - OTC SAP ECC V2 (DO NOT CHANGE)/metrics/metrics.json : 17
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/00_DEMO - OTC SAP ECC V2 (DO NOT CHANGE)/dashboards/test_2024-02-01.json : 0
# ['investigation', 'metrics']: ../data/From_API/Solutions Demo Workspace/00_DEMO - OTC SAP ECC V2 (DO NOT CHANGE)/investigations/DEMO - Order-to-Cash ECC_2024-02-01.json : 29
# 00_DEMO - OTC SAP ECC V2 (DO NOT CHANGE) subtotal Signals: 46
# None: ../data/From_API/Solutions Demo Workspace/00_DEMO - OTC SAP S/4 HANA (DO NOT CHANGE)/metrics/metrics.json : 18
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/00_DEMO - OTC SAP S/4 HANA (DO NOT CHANGE)/dashboards/OTC Process Overview_2024-02-01.json : 1
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/00_DEMO - OTC SAP S/4 HANA (DO NOT CHANGE)/dashboards/Agnostic - Overview Dashboard_2024-02-01.json : 22
# ['investigation', 'metrics']: ../data/From_API/Solutions Demo Workspace/00_DEMO - OTC SAP S/4 HANA (DO NOT CHANGE)/investigations/DEMO - Order-to-Cash S/4HANA_2024-02-01.json : 29
# ['investigation', 'metrics']: ../data/From_API/Solutions Demo Workspace/00_DEMO - OTC SAP S/4 HANA (DO NOT CHANGE)/investigations/Spike Sustainability _2024-02-01.json : 0
# 00_DEMO - OTC SAP S/4 HANA (DO NOT CHANGE) subtotal Signals: 70
# None: ../data/From_API/Solutions Demo Workspace/00_DEMO PTP Cross Mining SAP Ariba + SAP ERP (DO NOT CHANGE)/metrics/metrics.json : 32
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/00_DEMO PTP Cross Mining SAP Ariba + SAP ERP (DO NOT CHANGE)/dashboards/SAP Ariba and SAP ERP - Procure to Pay_2024-02-01.json : 4
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/00_DEMO PTP Cross Mining SAP Ariba + SAP ERP (DO NOT CHANGE)/dashboards/00_Overview_2024-02-01.json : 24
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/00_DEMO PTP Cross Mining SAP Ariba + SAP ERP (DO NOT CHANGE)/dashboards/Cycle Times_2024-02-01.json : 16
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/00_DEMO PTP Cross Mining SAP Ariba + SAP ERP (DO NOT CHANGE)/dashboards/Late Payments _2024-02-01.json : 15
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/00_DEMO PTP Cross Mining SAP Ariba + SAP ERP (DO NOT CHANGE)/dashboards/Open Overdue Invoices_2024-02-01.json : 31
# ['investigation', 'metrics']: ../data/From_API/Solutions Demo Workspace/00_DEMO PTP Cross Mining SAP Ariba + SAP ERP (DO NOT CHANGE)/investigations/test_2024-02-01.json : 0
# 00_DEMO PTP Cross Mining SAP Ariba + SAP ERP (DO NOT CHANGE) subtotal Signals: 122
# None: ../data/From_API/Solutions Demo Workspace/00_DEMO - PTP in Ariba (DO NOT CHANGE)/metrics/metrics.json : 17
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/00_DEMO - PTP in Ariba (DO NOT CHANGE)/dashboards/00_Overview (old)_2024-02-01.json : 25
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/00_DEMO - PTP in Ariba (DO NOT CHANGE)/dashboards/Spend Analysis_2024-02-01.json : 38
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/00_DEMO - PTP in Ariba (DO NOT CHANGE)/dashboards/00_Overview_2024-02-01.json : 36
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/00_DEMO - PTP in Ariba (DO NOT CHANGE)/dashboards/Cycle Times_2024-02-01.json : 22
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/00_DEMO - PTP in Ariba (DO NOT CHANGE)/dashboards/Payment Behaviour_2024-02-01.json : 38
# ['investigation', 'metrics']: ../data/From_API/Solutions Demo Workspace/00_DEMO - PTP in Ariba (DO NOT CHANGE)/investigations/Demo_2024-02-01.json : 17
# 00_DEMO - PTP in Ariba (DO NOT CHANGE) subtotal Signals: 193
# None: ../data/From_API/Solutions Demo Workspace/00_DEMO - PTP SAP S4H (DO NOT CHANGE)/metrics/metrics.json : 20
# Warning: No substitution found for variable 'late_payment_condition'. Using placeholder.
# Warning: No substitution found for variable 'invoice_clearing_date'. Using placeholder.
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/00_DEMO - PTP SAP S4H (DO NOT CHANGE)/dashboards/PO Late Payments (Historical Analysis)_2024-02-01.json : 15
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/00_DEMO - PTP SAP S4H (DO NOT CHANGE)/dashboards/Cycle Time Dashboard_2024-02-01.json : 16
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/00_DEMO - PTP SAP S4H (DO NOT CHANGE)/dashboards/Overview Dashboard_2024-02-01.json : 24
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/00_DEMO - PTP SAP S4H (DO NOT CHANGE)/dashboards/PO Open Overdue Payments (Monitoring)_2024-02-01.json : 32
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/00_DEMO - PTP SAP S4H (DO NOT CHANGE)/dashboards/Testing Dashboard_2024-02-01.json : 3
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/00_DEMO - PTP SAP S4H (DO NOT CHANGE)/dashboards/Sustainability (Working in Progress)_2024-02-01.json : 6
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/00_DEMO - PTP SAP S4H (DO NOT CHANGE)/dashboards/Automation Dashboard_2024-02-01.json : 21
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/00_DEMO - PTP SAP S4H (DO NOT CHANGE)/dashboards/Agnostic - Overview_2024-02-01.json : 22
# ['investigation', 'metrics']: ../data/From_API/Solutions Demo Workspace/00_DEMO - PTP SAP S4H (DO NOT CHANGE)/investigations/Procure-to-Pay_2024-02-01.json : 0
# ['investigation', 'metrics']: ../data/From_API/Solutions Demo Workspace/00_DEMO - PTP SAP S4H (DO NOT CHANGE)/investigations/PTP Accelerator Demo: Metrics_2024-02-01.json : 30
# 00_DEMO - PTP SAP S4H (DO NOT CHANGE) subtotal Signals: 189
# None: ../data/From_API/Solutions Demo Workspace/00_DEMO - SAP IBP S&OP (DO NOT CHANGE)/metrics/metrics.json : 26
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/00_DEMO - SAP IBP S&OP (DO NOT CHANGE)/dashboards/Overview Dashboard_2024-02-01.json : 21
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/00_DEMO - SAP IBP S&OP (DO NOT CHANGE)/dashboards/Overview Dashboard (copy)_2024-02-01.json : 36
# ['investigation', 'metrics']: ../data/From_API/Solutions Demo Workspace/00_DEMO - SAP IBP S&OP (DO NOT CHANGE)/investigations/Demo_2024-02-01.json : 0
# 00_DEMO - SAP IBP S&OP (DO NOT CHANGE) subtotal Signals: 83
# None: ../data/From_API/Solutions Demo Workspace/00_DEMO - SAP S/4HANA Cloud - Invoice-to-Cash/metrics/metrics.json : 33
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/00_DEMO - SAP S/4HANA Cloud - Invoice-to-Cash/dashboards/[TEMP] Demo 10/07/2023_2024-02-01.json : 26
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/00_DEMO - SAP S/4HANA Cloud - Invoice-to-Cash/dashboards/SAP S/4HANA public cloud - Invoice to Cash_2024-02-01.json : 3
# ['investigation', 'metrics']: ../data/From_API/Solutions Demo Workspace/00_DEMO - SAP S/4HANA Cloud - Invoice-to-Cash/investigations/01. I2C - General Analysis (Copy)_2024-02-01.json : 72
# ['investigation', 'metrics']: ../data/From_API/Solutions Demo Workspace/00_DEMO - SAP S/4HANA Cloud - Invoice-to-Cash/investigations/01. I2C - General Analysis_2024-02-01.json : 72
# 00_DEMO - SAP S/4HANA Cloud - Invoice-to-Cash subtotal Signals: 206
# None: ../data/From_API/Solutions Demo Workspace/00_DEMO - SAP S/4HANA Cloud - Project-to-Cash/metrics/metrics.json : 50
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/00_DEMO - SAP S/4HANA Cloud - Project-to-Cash/dashboards/Overview_2024-02-01.json : 2
# ['investigation', 'metrics']: ../data/From_API/Solutions Demo Workspace/00_DEMO - SAP S/4HANA Cloud - Project-to-Cash/investigations/01. P2C - General Analysis_2024-02-01.json : 78
# ['investigation', 'metrics']: ../data/From_API/Solutions Demo Workspace/00_DEMO - SAP S/4HANA Cloud - Project-to-Cash/investigations/Metrics Validation_2024-02-01.json : 49
# 00_DEMO - SAP S/4HANA Cloud - Project-to-Cash subtotal Signals: 179
# None: ../data/From_API/Solutions Demo Workspace/00_DMC_Showcase (DO NOT CHANGE)/metrics/metrics.json : 3
# ['investigation', 'metrics']: ../data/From_API/Solutions Demo Workspace/00_DMC_Showcase (DO NOT CHANGE)/investigations/PoC DMC Bike Production_2024-02-01.json : 17
# 00_DMC_Showcase (DO NOT CHANGE) subtotal Signals: 20
# None: ../data/From_API/Solutions Demo Workspace/[00]_PIA Jira Process/metrics/metrics.json : 12
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/[00]_PIA Jira Process/dashboards/ZZ_Placeholder Dashboard Group 1 GDSN_2024-02-01.json : 38
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/[00]_PIA Jira Process/dashboards/ZZ_MACKATTACK Jira Dashboard _2024-02-01.json : 6
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/[00]_PIA Jira Process/dashboards/ZZ_Placeholder Dashboard Group 2 - JMCF       _2024-02-01.json : 36
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/[00]_PIA Jira Process/dashboards/ZZ_Placeholder Dashboard Group 2 - JMCF        - MC_2024-02-01.json : 49
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/[00]_PIA Jira Process/dashboards/ZZ_Placeholder Dashboard Group 2 - JMCF        FJ_2024-02-01.json : 42
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/[00]_PIA Jira Process/dashboards/PIA Jira Issue-to-Resolution (Master)_2024-02-01.json : 36
# ['investigation', 'metrics']: ../data/From_API/Solutions Demo Workspace/[00]_PIA Jira Process/investigations/Group 4 - part 2_2024-02-01.json : 1
# ['investigation', 'metrics']: ../data/From_API/Solutions Demo Workspace/[00]_PIA Jira Process/investigations/FZ_Playground_2024-02-01.json : 0
# ['investigation', 'metrics']: ../data/From_API/Solutions Demo Workspace/[00]_PIA Jira Process/investigations/Placeholder Group 1 GDSN_2024-02-01.json : 10
# ['investigation', 'metrics']: ../data/From_API/Solutions Demo Workspace/[00]_PIA Jira Process/investigations/Placeholder Group 4 - LYTH_2024-02-01.json : 14
# ['investigation', 'metrics']: ../data/From_API/Solutions Demo Workspace/[00]_PIA Jira Process/investigations/Jira Summary_2024-02-01.json : 49
# ['investigation', 'metrics']: ../data/From_API/Solutions Demo Workspace/[00]_PIA Jira Process/investigations/Placeholder Group 2 - JMCF       _2024-02-01.json : 0
# ['investigation', 'metrics']: ../data/From_API/Solutions Demo Workspace/[00]_PIA Jira Process/investigations/Placeholder Group 3 - MACK_2024-02-01.json : 11
# ['investigation', 'metrics']: ../data/From_API/Solutions Demo Workspace/[00]_PIA Jira Process/investigations/Jira Process Final_2024-02-01.json : 23
# [00]_PIA Jira Process subtotal Signals: 327
# None: ../data/From_API/Solutions Demo Workspace/[0]_Dashboards_ITP Process/metrics/metrics.json : 40
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/[0]_Dashboards_ITP Process/dashboards/Payment Behaviour_2024-02-01.json : 59
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/[0]_Dashboards_ITP Process/dashboards/Automation Dashboard_2024-02-01.json : 33
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/[0]_Dashboards_ITP Process/dashboards/[SL] Payment Term Analysis - Use case 3 - SOL- 2727_2024-02-01.json : 41
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/[0]_Dashboards_ITP Process/dashboards/Overview Dashboard_2024-02-01.json : 29
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/[0]_Dashboards_ITP Process/dashboards/[SL] Overview Dashboard_2024-02-01.json : 58
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/[0]_Dashboards_ITP Process/dashboards/[NK] - Late Payments (Historical Analysis)_2024-02-01.json : 18
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/[0]_Dashboards_ITP Process/dashboards/00_Empty Template_2024-02-01.json : 0
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/[0]_Dashboards_ITP Process/dashboards/[FZ] Open Overdue Invoices_2024-02-01.json : 32
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/[0]_Dashboards_ITP Process/dashboards/Cycle Time Dashboard_2024-02-01.json : 20
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/[0]_Dashboards_ITP Process/dashboards/[SL] Payment Term Analysis - Use case 1 - SOL-2617_2024-02-01.json : 35
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/[0]_Dashboards_ITP Process/dashboards/Open Overdue Invoices_2024-02-01.json : 49
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/[0]_Dashboards_ITP Process/dashboards/[AA] Automation Dashboard_2024-02-01.json : 18
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/[0]_Dashboards_ITP Process/dashboards/[JS] Payment Term Analysis - Use Case 2 - SOL-2725 (shorter PT on Invoice than in MD )_2024-02-01.json : 7
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/[0]_Dashboards_ITP Process/dashboards/0[SL]- Payment Term Optimization (for Final dashboard)_2024-02-01.json : 21
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/[0]_Dashboards_ITP Process/dashboards/Payment Term Analysis_2024-02-01.json : 34
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/[0]_Dashboards_ITP Process/dashboards/Payment Term Analysis-modified_2024-02-01.json : 34
# ['investigation', 'metrics']: ../data/From_API/Solutions Demo Workspace/[0]_Dashboards_ITP Process/investigations/Event lvl metrics test_2024-02-01.json : 0
# [0]_Dashboards_ITP Process subtotal Signals: 528
# None: ../data/From_API/Solutions Demo Workspace/0_demo_accelerators_generic (PTP S4H, changes allowed)/metrics/metrics.json : 31
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/0_demo_accelerators_generic (PTP S4H, changes allowed)/dashboards/Cycle Time Dashboard_2024-02-01.json : 16
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/0_demo_accelerators_generic (PTP S4H, changes allowed)/dashboards/PO Late Payments (Historical Analysis)_2024-02-01.json : 15
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/0_demo_accelerators_generic (PTP S4H, changes allowed)/dashboards/Overview Dashboard_2024-02-01.json : 24
# ['investigation', 'metrics']: ../data/From_API/Solutions Demo Workspace/0_demo_accelerators_generic (PTP S4H, changes allowed)/investigations/HS pi academy _2024-02-01.json : 2
# ['investigation', 'metrics']: ../data/From_API/Solutions Demo Workspace/0_demo_accelerators_generic (PTP S4H, changes allowed)/investigations/overview_2024-02-01.json : 4
# 0_demo_accelerators_generic (PTP S4H, changes allowed) subtotal Signals: 92
# None: ../data/From_API/Solutions Demo Workspace/[NK] Show&Tell - ITP Dashboards/metrics/metrics.json : 1
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/[NK] Show&Tell - ITP Dashboards/dashboards/[04] Payment Behaviour_2024-02-01.json : 59
# [NK] Show&Tell - ITP Dashboards subtotal Signals: 60
# None: ../data/From_API/Solutions Demo Workspace/[SIGPIA-2936] Dashboard_PTP_Ariba/metrics/metrics.json : 12
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/[SIGPIA-2936] Dashboard_PTP_Ariba/dashboards/Automation Dashboard_2024-02-01.json : 21
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/[SIGPIA-2936] Dashboard_PTP_Ariba/dashboards/Cycle Time Dashboard_2024-02-01.json : 22
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/[SIGPIA-2936] Dashboard_PTP_Ariba/dashboards/00_Overview Dashboard_2024-02-01.json : 36
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/[SIGPIA-2936] Dashboard_PTP_Ariba/dashboards/Payment Behaviour_2024-02-01.json : 38
# ['dashboard', 'metrics']: ../data/From_API/Solutions Demo Workspace/[SIGPIA-2936] Dashboard_PTP_Ariba/dashboards/Spend Analysis_2024-02-01.json : 38
# ['investigation', 'metrics']: ../data/From_API/Solutions Demo Workspace/[SIGPIA-2936] Dashboard_PTP_Ariba/investigations/Test_2024-02-01.json : 0
# ['investigation', 'metrics']: ../data/From_API/Solutions Demo Workspace/[SIGPIA-2936] Dashboard_PTP_Ariba/investigations/SAP_ARIBA_PTP_2024-02-01.json : 122
# [SIGPIA-2936] Dashboard_PTP_Ariba subtotal Signals: 289
# Total Signals: 4689
# Extracted 4689 signals from ../data/From_API/all_json_Solutions_Demo_Workspace_2024-02-01T08_17_38.json
# Processing file: ../data/NLP POC (JustAsk)/04 PI Investigation/JustAsk SIGNAL POC - PI Investigation.json
# 14
# Extracted 14 signals from ../data/NLP POC (JustAsk)
# Processing file: ../data/metric_definitions/__source_systems.json
# 0
# Processing file: ../data/metric_definitions/incident_to_resolution.json
# 10
# Processing file: ../data/metric_definitions/invoice_to_cash_s4h_cloud.json
# 30
# Processing file: ../data/metric_definitions/ewm_basic_outbound.json
# 16
# Processing file: ../data/metric_definitions/ariba_strategic_sourcing.json
# 9
# Processing file: ../data/metric_definitions/lead-to-opportunity-sap-sales-cloud.json
# 25
# Processing file: ../data/metric_definitions/request-to-service.json
# 5
# Processing file: ../data/metric_definitions/manage_personal_employee_information.json
# 6
# Processing file: ../data/metric_definitions/meter_to_cash.json
# 18
# Processing file: ../data/metric_definitions/__process_types.json
# 0
# Processing file: ../data/metric_definitions/invoice_to_cash.json
# 16
# Processing file: ../data/metric_definitions/ariba_procure_to_pay.json
# 16
# Processing file: ../data/metric_definitions/invoice_to_pay.json
# 28
# Processing file: ../data/metric_definitions/issue_to_resolution.json
# 20
# Processing file: ../data/metric_definitions/inspect_to_quality.json
# 12
# Processing file: ../data/metric_definitions/project_to_cash_s4h_cloud.json
# 56
# Processing file: ../data/metric_definitions/acquire_to_onboard.json
# 24
# Processing file: ../data/metric_definitions/opportunity_management.json
# 18
# Processing file: ../data/metric_definitions/attract-to-acquire-talent.json
# 6
# Processing file: ../data/metric_definitions/cycle_time.json
# 6
# Processing file: ../data/metric_definitions/order_to_cash.json
# 21
# Processing file: ../data/metric_definitions/automation.json
# 3
# Processing file: ../data/metric_definitions/changes.json
# 4
# Processing file: ../data/metric_definitions/dropouts.json
# 4
# Processing file: ../data/metric_definitions/make_to_order_stock.json
# 16
# Processing file: ../data/metric_definitions/conformance.json
# 3
# Processing file: ../data/metric_definitions/make_to_stock.json
# 17
# Processing file: ../data/metric_definitions/manage_transportation.json
# 12
# Processing file: ../data/metric_definitions/operate_manufacturing.json
# 11
# Processing file: ../data/metric_definitions/procure_to_pay.json
# 30
# Processing file: ../data/metric_definitions/ariba_contracting.json
# 14
# Processing file: ../data/metric_definitions/opentext_vendor_invoice_management.json
# 7
# Processing file: ../data/metric_definitions/sales_and_operations_sap_ibp.json
# 26
# Processing file: ../data/metric_definitions/rework.json
# 7
# Processing file: ../data/metric_definitions/SLAs.json
# 4
# Extracted 500 signals from ../data/metric_definitions
# Extracted 0 signals from ../data/pia-dashboards
# Processing file: ../data/OPAL/DRAFT_2.json
# 30
# Processing file: ../data/OPAL/DRAFT_1.json
# 39
# Extracted 69 signals from ../data/OPAL
# Processing file: ../data/ContentPackage_December2023/KFFI000960 - Supplier payment without purchasing/KFFI000960 - Supplier payment without purchasing - V1.json
# 0
# Processing file: ../data/ContentPackage_December2023/KFFI000960 - Supplier payment without purchasing/Investigations/02. Process Variant Analysis.json
# 0
# Processing file: ../data/ContentPackage_December2023/KFFI000960 - Supplier payment without purchasing/Investigations/99. Process Quantity Structure.json
# 57
# Processing file: ../data/ContentPackage_December2023/KFFI000960 - Supplier payment without purchasing/Investigations/01. Process Execution.json
# 4
# Processing file: ../data/ContentPackage_December2023/KFFI000960 - Supplier payment without purchasing/Investigations/03. Transaction Code Analysis.json
# 30
# Processing file: ../data/ContentPackage_December2023/KPPURCH261 - Procurement for text items (without material number and account assignment) with expected goods receipt/KPPURCH261 - Procurement for text items (without material number and account assignment) with expected goods receipt - V1.json
# 0
# Processing file: ../data/ContentPackage_December2023/KPPURCH261 - Procurement for text items (without material number and account assignment) with expected goods receipt/Investigations/02. Process Variant Analysis.json
# 0
# Processing file: ../data/ContentPackage_December2023/KPPURCH261 - Procurement for text items (without material number and account assignment) with expected goods receipt/Investigations/99. Process Quantity Structure.json
# 42
# Processing file: ../data/ContentPackage_December2023/KPPURCH261 - Procurement for text items (without material number and account assignment) with expected goods receipt/Investigations/01. Process Execution.json
# 2
# Processing file: ../data/ContentPackage_December2023/KPPURCH261 - Procurement for text items (without material number and account assignment) with expected goods receipt/Investigations/03. Transaction Code Analysis.json
# 16
# Processing file: ../data/ContentPackage_December2023/KPPURCH460 - Supplier payment from purchasing/KPPURCH460 - Supplier payment from purchasing - V1.json
# 0
# Processing file: ../data/ContentPackage_December2023/KPPURCH460 - Supplier payment from purchasing/Investigations/02. Process Variant Analysis.json
# 0
# Processing file: ../data/ContentPackage_December2023/KPPURCH460 - Supplier payment from purchasing/Investigations/99. Process Quantity Structure.json
# 66
# Processing file: ../data/ContentPackage_December2023/KPPURCH460 - Supplier payment from purchasing/Investigations/01. Process Execution.json
# 5
# Processing file: ../data/ContentPackage_December2023/KPPURCH460 - Supplier payment from purchasing/Investigations/03. Transaction Code Analysis.json
# 30
# Processing file: ../data/ContentPackage_December2023/KPPURCH268 - Procurement for projects or networks with expected goods receipt/KPPURCH268 - Procurement for projects or networks with expected goods receipt - V1.json
# 0
# Processing file: ../data/ContentPackage_December2023/KPPURCH268 - Procurement for projects or networks with expected goods receipt/Investigations/02. Process Variant Analysis.json
# 0
# Processing file: ../data/ContentPackage_December2023/KPPURCH268 - Procurement for projects or networks with expected goods receipt/Investigations/99. Process Quantity Structure.json
# 52
# Processing file: ../data/ContentPackage_December2023/KPPURCH268 - Procurement for projects or networks with expected goods receipt/Investigations/01. Process Execution.json
# 2
# Processing file: ../data/ContentPackage_December2023/KPPURCH268 - Procurement for projects or networks with expected goods receipt/Investigations/03. Transaction Code Analysis.json
# 16
# Processing file: ../data/ContentPackage_December2023/KPPP000163 - Direct procurement for non-stock components in discrete manufacturing/KPPP000163 - Direct procurement for non-stock components in discrete manufacturing - V1.json
# 0
# Processing file: ../data/ContentPackage_December2023/KPPP000163 - Direct procurement for non-stock components in discrete manufacturing/Investigations/02. Process Variant Analysis.json
# 0
# Processing file: ../data/ContentPackage_December2023/KPPP000163 - Direct procurement for non-stock components in discrete manufacturing/Investigations/99. Process Quantity Structure.json
# 34
# Processing file: ../data/ContentPackage_December2023/KPPP000163 - Direct procurement for non-stock components in discrete manufacturing/Investigations/01. Process Execution.json
# 0
# Processing file: ../data/ContentPackage_December2023/KPLE000361 - Processing of outbound deliveries without order reference and with classic Warehouse Management/KPLE000361 - Outbound delivery processing without order reference and with classic Warehouse Management - V1.json
# 0
# Processing file: ../data/ContentPackage_December2023/KPLE000361 - Processing of outbound deliveries without order reference and with classic Warehouse Management/Investigations/02. Process Variant Analysis.json
# 0
# Processing file: ../data/ContentPackage_December2023/KPLE000361 - Processing of outbound deliveries without order reference and with classic Warehouse Management/Investigations/99. Process Quantity Structure.json
# 38
# Processing file: ../data/ContentPackage_December2023/KPLE000361 - Processing of outbound deliveries without order reference and with classic Warehouse Management/Investigations/01. Process Execution.json
# 3
# Processing file: ../data/ContentPackage_December2023/KPLE000361 - Processing of outbound deliveries without order reference and with classic Warehouse Management/Investigations/03. Transaction Code Analysis.json
# 16
# Processing file: ../data/ContentPackage_December2023/KPLE000361 - Delivery processing for subcontracting with classic Warehouse Management/KPLE000361 - Delivery processing for subcontracting with classic Warehouse Management - V1.json
# 0
# Processing file: ../data/ContentPackage_December2023/KPLE000361 - Delivery processing for subcontracting with classic Warehouse Management/Investigations/02. Process Variant Analysis.json
# 0
# Processing file: ../data/ContentPackage_December2023/KPLE000361 - Delivery processing for subcontracting with classic Warehouse Management/Investigations/99. Process Quantity Structure.json
# 36
# Processing file: ../data/ContentPackage_December2023/KPLE000361 - Delivery processing for subcontracting with classic Warehouse Management/Investigations/01. Process Execution.json
# 3
# Processing file: ../data/ContentPackage_December2023/KPLE000361 - Delivery processing for subcontracting with classic Warehouse Management/Investigations/03. Transaction Code Analysis.json
# 16
# Processing file: ../data/ContentPackage_December2023/KPPURCH265 - Procurement for orders without expected goods receipt/KPPURCH265 - Procurement for orders without expected goods receipt - V1.json
# 0
# Processing file: ../data/ContentPackage_December2023/KPPURCH265 - Procurement for orders without expected goods receipt/Investigations/02. Process Variant Analysis.json
# 0
# Processing file: ../data/ContentPackage_December2023/KPPURCH265 - Procurement for orders without expected goods receipt/Investigations/99. Process Quantity Structure.json
# 35
# Processing file: ../data/ContentPackage_December2023/KPPURCH265 - Procurement for orders without expected goods receipt/Investigations/01. Process Execution.json
# 2
# Processing file: ../data/ContentPackage_December2023/KPPURCH265 - Procurement for orders without expected goods receipt/Investigations/03. Transaction Code Analysis.json
# 16
# Processing file: ../data/ContentPackage_December2023/KPPURCH265 - Procurement for assets without expected goods receipt/KPPURCH265 - Procurement for assets without expected goods receipt - V1.json
# 0
# Processing file: ../data/ContentPackage_December2023/KPPURCH265 - Procurement for assets without expected goods receipt/Investigations/02. Process Variant Analysis.json
# 0
# Processing file: ../data/ContentPackage_December2023/KPPURCH265 - Procurement for assets without expected goods receipt/Investigations/99. Process Quantity Structure.json
# 35
# Processing file: ../data/ContentPackage_December2023/KPPURCH265 - Procurement for assets without expected goods receipt/Investigations/01. Process Execution.json
# 2
# Processing file: ../data/ContentPackage_December2023/KPPURCH265 - Procurement for assets without expected goods receipt/Investigations/03. Transaction Code Analysis.json
# 16
# Processing file: ../data/ContentPackage_December2023/KWPM000161 - Customer Service via activity report notification/KWPM000161 - Customer service via activity report notification - V1.json
# 0
# Processing file: ../data/ContentPackage_December2023/KWPM000161 - Customer Service via activity report notification/Investigations/02. Process Variant Analysis.json
# 0
# Processing file: ../data/ContentPackage_December2023/KWPM000161 - Customer Service via activity report notification/Investigations/99. Process Quantity Structure.json
# 45
# Processing file: ../data/ContentPackage_December2023/KWPM000161 - Customer Service via activity report notification/Investigations/01. Process Execution.json
# 3
# Processing file: ../data/ContentPackage_December2023/KWPM000161 - Customer Service via activity report notification/Investigations/03. Transaction Code Analysis.json
# 23
# Processing file: ../data/ContentPackage_December2023/KPPURCH560 - Intracompany replenishment without logistics execution/KPPURCH560 - Intracompany replenishment without logistics execution - V1.json
# 0
# Processing file: ../data/ContentPackage_December2023/KPPURCH560 - Intracompany replenishment without logistics execution/Investigations/02. Process Variant Analysis.json
# 0
# Processing file: ../data/ContentPackage_December2023/KPPURCH560 - Intracompany replenishment without logistics execution/Investigations/99. Process Quantity Structure.json
# 19
# Processing file: ../data/ContentPackage_December2023/KPPURCH560 - Intracompany replenishment without logistics execution/Investigations/01. Process Execution.json
# 2
# Processing file: ../data/ContentPackage_December2023/KPPP000160 - Make to stock (discrete manufacturing)/KPPP000160 - Make to stock (discrete manufacturing) - V1.json
# 0
# Processing file: ../data/ContentPackage_December2023/KPPP000160 - Make to stock (discrete manufacturing)/Investigations/02. Process Variant Analysis.json
# 0
# Processing file: ../data/ContentPackage_December2023/KPPP000160 - Make to stock (discrete manufacturing)/Investigations/99. Process Quantity Structure.json
# 41
# Processing file: ../data/ContentPackage_December2023/KPPP000160 - Make to stock (discrete manufacturing)/Investigations/01. Process Execution.json
# 3
# ...
# 0
# Processing file: ../data/ContentPackage_December2023/KPSD000460 - Debit memo request item creation to FI-AR clearing/Investigations/02. Process Variant Analysis.json
# 0
# Processing file: ../data/ContentPackage_December2023/KPSD000460 - Debit memo request item creation to FI-AR clearing/Investigations/99. Process Quantity Structure.json
# 42
# Processing file: ../data/ContentPackage_December2023/KPSD000460 - Debit memo request item creation to FI-AR clearing/Investigations/01. Process Execution.json
# 4
# Processing file: ../data/ContentPackage_December2023/KPSD000460 - Debit memo request item creation to FI-AR clearing/Investigations/03. Transaction Code Analysis.json
# 23
# Processing file: ../data/ContentPackage_December2023/KPLE000362 - Inbound delivery processing without order reference with classic Warehouse Management/KPLE000362 - Inbound delivery processing without order reference with classic Warehouse Management - V1.json
# 0
# Processing file: ../data/ContentPackage_December2023/KPLE000362 - Inbound delivery processing without order reference with classic Warehouse Management/Investigations/02. Process Variant Analysis.json
# 0
# Processing file: ../data/ContentPackage_December2023/KPLE000362 - Inbound delivery processing without order reference with classic Warehouse Management/Investigations/99. Process Quantity Structure.json
# 35
# Processing file: ../data/ContentPackage_December2023/KPLE000362 - Inbound delivery processing without order reference with classic Warehouse Management/Investigations/01. Process Execution.json
# 2
# Processing file: ../data/ContentPackage_December2023/KPLE000362 - Inbound delivery processing without order reference with classic Warehouse Management/Investigations/03. Transaction Code Analysis.json
# 16
# Processing file: ../data/ContentPackage_December2023/KWPM000160 - Maintenance via activity report notification/KWPM000160 - Maintenance via activity report notification - V1.json
# 0
# Processing file: ../data/ContentPackage_December2023/KWPM000160 - Maintenance via activity report notification/Investigations/02. Process Variant Analysis.json
# 0
# Processing file: ../data/ContentPackage_December2023/KWPM000160 - Maintenance via activity report notification/Investigations/99. Process Quantity Structure.json
# 44
# Processing file: ../data/ContentPackage_December2023/KWPM000160 - Maintenance via activity report notification/Investigations/01. Process Execution.json
# 3
# Processing file: ../data/ContentPackage_December2023/KWPM000160 - Maintenance via activity report notification/Investigations/03. Transaction Code Analysis.json
# 23
# Processing file: ../data/ContentPackage_December2023/KPLE000362 - Inbound delivery processing for scheduling agreements without classic Warehouse Management/KPLE000362 - Inbound delivery processing for scheduling agreements without classic Warehouse Management - V1.json
# 0
# Processing file: ../data/ContentPackage_December2023/KPLE000362 - Inbound delivery processing for scheduling agreements without classic Warehouse Management/Investigations/02. Process Variant Analysis.json
# 0
# Processing file: ../data/ContentPackage_December2023/KPLE000362 - Inbound delivery processing for scheduling agreements without classic Warehouse Management/Investigations/99. Process Quantity Structure.json
# 34
# Processing file: ../data/ContentPackage_December2023/KPLE000362 - Inbound delivery processing for scheduling agreements without classic Warehouse Management/Investigations/01. Process Execution.json
# 2
# Processing file: ../data/ContentPackage_December2023/KPLE000362 - Inbound delivery processing for scheduling agreements without classic Warehouse Management/Investigations/03. Transaction Code Analysis.json
# 16
# Processing file: ../data/ContentPackage_December2023/KFFI001060 - Cash collection for non-sales (invoices)/KFFI001060 - Cash collection for non-sales (invoices) - V1.json
# 0
# Processing file: ../data/ContentPackage_December2023/KFFI001060 - Cash collection for non-sales (invoices)/Investigations/02. Process Variant Analysis.json
# 0
# Processing file: ../data/ContentPackage_December2023/KFFI001060 - Cash collection for non-sales (invoices)/Investigations/99. Process Quantity Structure.json
# 41
# Processing file: ../data/ContentPackage_December2023/KFFI001060 - Cash collection for non-sales (invoices)/Investigations/01. Process Execution.json
# 3
# Processing file: ../data/ContentPackage_December2023/KFFI001060 - Cash collection for non-sales (invoices)/Investigations/03. Transaction Code Analysis.json
# 23
# Processing file: ../data/ContentPackage_December2023/KPLE000361 - Outbound delivery processing for orders without charge with classic Warehouse Management/KPLE000361 - Outbound delivery processing for orders without charge with classic Warehouse Management  - V1.json
# 0
# Processing file: ../data/ContentPackage_December2023/KPLE000361 - Outbound delivery processing for orders without charge with classic Warehouse Management/Investigations/02. Process Variant Analysis.json
# 0
# Processing file: ../data/ContentPackage_December2023/KPLE000361 - Outbound delivery processing for orders without charge with classic Warehouse Management/Investigations/99. Process Quantity Structure.json
# 38
# Processing file: ../data/ContentPackage_December2023/KPLE000361 - Outbound delivery processing for orders without charge with classic Warehouse Management/Investigations/01. Process Execution.json
# 3
# Processing file: ../data/ContentPackage_December2023/KPLE000361 - Outbound delivery processing for orders without charge with classic Warehouse Management/Investigations/03. Transaction Code Analysis.json
# 16
# Processing file: ../data/ContentPackage_December2023/KPPP000260 - Make to order (process manufacturing)/KPPP000260 - Make to order (process manufacturing) - V1.json
# 0
# Processing file: ../data/ContentPackage_December2023/KPPP000260 - Make to order (process manufacturing)/Investigations/02. Process Variant Analysis.json
# 0
# Processing file: ../data/ContentPackage_December2023/KPPP000260 - Make to order (process manufacturing)/Investigations/99. Process Quantity Structure.json
# 40
# Processing file: ../data/ContentPackage_December2023/KPPP000260 - Make to order (process manufacturing)/Investigations/01. Process Execution.json
# 3
# Processing file: ../data/ContentPackage_December2023/KPPURCH265 - Procurement for other account assignment categories without expected goods receipt/KPPURCH265 - Procurement for other account assignment categories without expected goods receipt - V1.json
# 0
# Processing file: ../data/ContentPackage_December2023/KPPURCH265 - Procurement for other account assignment categories without expected goods receipt/Investigations/02. Process Variant Analysis.json
# 0
# Processing file: ../data/ContentPackage_December2023/KPPURCH265 - Procurement for other account assignment categories without expected goods receipt/Investigations/99. Process Quantity Structure.json
# 35
# Processing file: ../data/ContentPackage_December2023/KPPURCH265 - Procurement for other account assignment categories without expected goods receipt/Investigations/01. Process Execution.json
# 2
# Processing file: ../data/ContentPackage_December2023/KPPURCH265 - Procurement for other account assignment categories without expected goods receipt/Investigations/03. Transaction Code Analysis.json
# 16
# Processing file: ../data/ContentPackage_December2023/KPSD000363 - Third party sales order item to sales invoice item creation/KPSD000363 - Third party sales order item to sales invoice item creation - V1.json
# 0
# Processing file: ../data/ContentPackage_December2023/KPSD000363 - Third party sales order item to sales invoice item creation/Investigations/02. Process Variant Analysis.json
# 0
# Processing file: ../data/ContentPackage_December2023/KPSD000363 - Third party sales order item to sales invoice item creation/Investigations/99. Process Quantity Structure.json
# 25
# Processing file: ../data/ContentPackage_December2023/KPSD000363 - Third party sales order item to sales invoice item creation/Investigations/01. Process Execution.json
# 0
# Processing file: ../data/ContentPackage_December2023/KPLE000362 - Inbound delivery processing for purchase orders with classic Warehouse Management/KPLE000362 - Inbound delivery processing for purchase orders with classic Warehouse Management - V1.json
# 0
# Processing file: ../data/ContentPackage_December2023/KPLE000362 - Inbound delivery processing for purchase orders with classic Warehouse Management/Investigations/02. Process Variant Analysis.json
# 0
# Processing file: ../data/ContentPackage_December2023/KPLE000362 - Inbound delivery processing for purchase orders with classic Warehouse Management/Investigations/99. Process Quantity Structure.json
# 34
# Processing file: ../data/ContentPackage_December2023/KPLE000362 - Inbound delivery processing for purchase orders with classic Warehouse Management/Investigations/01. Process Execution.json
# 2
# Processing file: ../data/ContentPackage_December2023/KPLE000362 - Inbound delivery processing for purchase orders with classic Warehouse Management/Investigations/03. Transaction Code Analysis.json
# 16
# Processing file: ../data/ContentPackage_December2023/KPSD000260 - Cash collection for sales (invoices)/KPSD000260 - Cash collection for sales (invoices) - V1.json
# 0
# Processing file: ../data/ContentPackage_December2023/KPSD000260 - Cash collection for sales (invoices)/Investigations/02. Process Variant Analysis.json
# 0
# Processing file: ../data/ContentPackage_December2023/KPSD000260 - Cash collection for sales (invoices)/Investigations/99. Process Quantity Structure.json
# 56
# Processing file: ../data/ContentPackage_December2023/KPSD000260 - Cash collection for sales (invoices)/Investigations/01. Process Execution.json
# 4
# Processing file: ../data/ContentPackage_December2023/KPSD000260 - Cash collection for sales (invoices)/Investigations/03. Transaction Code Analysis.json
# 23
# Processing file: ../data/ContentPackage_December2023/KPSD000260 - Cash collection for sales (debit memos)/KPSD000260 - Cash collection for sales (debit memos) - V1.json
# 0
# Processing file: ../data/ContentPackage_December2023/KPSD000260 - Cash collection for sales (debit memos)/Investigations/02. Process Variant Analysis.json
# 0
# Processing file: ../data/ContentPackage_December2023/KPSD000260 - Cash collection for sales (debit memos)/Investigations/99. Process Quantity Structure.json
# 54
# Processing file: ../data/ContentPackage_December2023/KPSD000260 - Cash collection for sales (debit memos)/Investigations/01. Process Execution.json
# 4
# Processing file: ../data/ContentPackage_December2023/KPSD000260 - Cash collection for sales (debit memos)/Investigations/03. Transaction Code Analysis.json
# 23
# Processing file: ../data/ContentPackage_December2023/KPPURCH268 - Procurement for cost center with expected goods receipt/KPPURCH268 - Procurement for cost center with expected goods receipt - V1.json
# 0
# Processing file: ../data/ContentPackage_December2023/KPPURCH268 - Procurement for cost center with expected goods receipt/Investigations/02. Process Variant Analysis.json
# 0
# Processing file: ../data/ContentPackage_December2023/KPPURCH268 - Procurement for cost center with expected goods receipt/Investigations/99. Process Quantity Structure.json
# 48
# Processing file: ../data/ContentPackage_December2023/KPPURCH268 - Procurement for cost center with expected goods receipt/Investigations/01. Process Execution.json
# 2
# Processing file: ../data/ContentPackage_December2023/KPPURCH268 - Procurement for cost center with expected goods receipt/Investigations/03. Transaction Code Analysis.json
# 16
# Processing file: ../data/ContentPackage_December2023/KPLE000362 - Inbound delivery processing for purchase orders without classic Warehouse Management/KPLE000362 - Inbound delivery processing for purchase orders without classic Warehouse Management - V1.json
# 0
# Processing file: ../data/ContentPackage_December2023/KPLE000362 - Inbound delivery processing for purchase orders without classic Warehouse Management/Investigations/02. Process Variant Analysis.json
# 0
# Processing file: ../data/ContentPackage_December2023/KPLE000362 - Inbound delivery processing for purchase orders without classic Warehouse Management/Investigations/99. Process Quantity Structure.json
# 34
# Processing file: ../data/ContentPackage_December2023/KPLE000362 - Inbound delivery processing for purchase orders without classic Warehouse Management/Investigations/01. Process Execution.json
# 2
# Processing file: ../data/ContentPackage_December2023/KPLE000362 - Inbound delivery processing for purchase orders without classic Warehouse Management/Investigations/03. Transaction Code Analysis.json
# 16
# Processing file: ../data/ContentPackage_December2023/KPLE000360 - Outbound delivery processing for sales orders without classic Warehouse Management/KPLE000360 - Outbound delivery processing for sales orders without classic Warehouse Management - V1.json
# 0
# Processing file: ../data/ContentPackage_December2023/KPLE000360 - Outbound delivery processing for sales orders without classic Warehouse Management/Investigations/02. Process Variant Analysis.json
# 0
# Processing file: ../data/ContentPackage_December2023/KPLE000360 - Outbound delivery processing for sales orders without classic Warehouse Management/Investigations/99. Process Quantity Structure.json
# 35
# Processing file: ../data/ContentPackage_December2023/KPLE000360 - Outbound delivery processing for sales orders without classic Warehouse Management/Investigations/01. Process Execution.json
# 2
# Processing file: ../data/ContentPackage_December2023/KPLE000360 - Outbound delivery processing for sales orders without classic Warehouse Management/Investigations/03. Transaction Code Analysis.json
# 16
# Processing file: ../data/ContentPackage_December2023/KPPP000160 - Engineer to order (discrete manufacturing)/KPPP000160 - Engineer to order (discrete manufacturing) - V1.json
# 0
# Processing file: ../data/ContentPackage_December2023/KPPP000160 - Engineer to order (discrete manufacturing)/Investigations/02. Process Variant Analysis.json
# 0
# Processing file: ../data/ContentPackage_December2023/KPPP000160 - Engineer to order (discrete manufacturing)/Investigations/99. Process Quantity Structure.json
# 41
# Processing file: ../data/ContentPackage_December2023/KPPP000160 - Engineer to order (discrete manufacturing)/Investigations/01. Process Execution.json
# 3
# Processing file: ../data/ContentPackage_December2023/KPPP000260 - Make to stock (process manufacturing)/KPPP000260 - Make to Stock (process manufacturing) - V1.json
# 0
# Processing file: ../data/ContentPackage_December2023/KPPP000260 - Make to stock (process manufacturing)/Investigations/02. Process Variant Analysis.json
# 0
# Processing file: ../data/ContentPackage_December2023/KPPP000260 - Make to stock (process manufacturing)/Investigations/99. Process Quantity Structure.json
# 40
# Processing file: ../data/ContentPackage_December2023/KPPP000260 - Make to stock (process manufacturing)/Investigations/01. Process Execution.json
# 3
# Processing file: ../data/ContentPackage_December2023/KPPP000263 - Process order component creation to goods receipt (using direct procurement)/KPPP000263 - Direct procurement for non-stock components in process manufacturing - V1.json
# 0
# Processing file: ../data/ContentPackage_December2023/KPPP000263 - Process order component creation to goods receipt (using direct procurement)/Investigations/02. Process Variant Analysis.json
# 0
# Processing file: ../data/ContentPackage_December2023/KPPP000263 - Process order component creation to goods receipt (using direct procurement)/Investigations/99. Process Quantity Structure.json
# 34
# Processing file: ../data/ContentPackage_December2023/KPPP000263 - Process order component creation to goods receipt (using direct procurement)/Investigations/01. Process Execution.json
# 0
# Extracted 4156 signals from ../data/ContentPackage_December2023
# Total signals extracted: 9428
# Dumping 9428 extracted signals  to data/temp/all_extracted_signals_2024-02-12T18_02_18.json
# Saving CSV file with Signals: data/temp/signals_2024-02-12T18_02_18.csv

# %% [markdown]
# # Pandas and data Analysis
#
# Here we:
# - *vdf* - Load view column names for each involved view: from all_json and all_json1
# - *df* -  Combine Signals from different sources into Pandas for Statistical analysis.

# %% [markdown]
# ## Schemas to Data Frames

# %%
from text2signal.data.utils import load_json
from text2signal.data.fetch_schema_info import fetch_and_prepare_schema_data

workspace_name = "Solutions Demo Workspace"
signavio_client = auth_clients[workspace_name]

json_filepath = "../data/From_API/all_json_Solutions_Demo_Workspace_2024-02-01T08_17_38.json"
all_json = load_json(json_filepath)

df_schema = fetch_and_prepare_schema_data(signavio_client, all_json)
df_schema
# Out:
# Fetching schema for process: sl-itc-dashboard-test-1, 000_DEMO✨ - Dashboards ITC ECC & S4H (DO NOT CHANGE)
# Found views ['defaultview-529'] for process: 000_DEMO✨ - Dashboards ITC ECC & S4H (DO NOT CHANGE)
# Fetching schema for process: 00demo---sap-s4h-itp-dashboar-1, 000_DEMO✨ - Dashboards ITP ECC & S4H (DO NOT CHANGE)
# Found views ['defaultview-320'] for process: 000_DEMO✨ - Dashboards ITP ECC & S4H (DO NOT CHANGE)
# Fetching schema for process: 00demo---sap-s4h-otc-dashboar-1, 000_DEMO✨ - Dashboards OTC ECC & S4H (DO NOT CHANGE)
# Found views ['defaultview-383'] for process: 000_DEMO✨ - Dashboards OTC ECC & S4H (DO NOT CHANGE)
# Fetching schema for process: sademo-dashboardss4h-p2p-proc-1, 000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)
# Found views ['defaultview-124'] for process: 000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)
# Fetching schema for process: lg-00demo---ato-sap-s4-hana-d-1, 00_DEMO - Acquire-to-Onboard for  SAP ECC & S/4 HANA (DO NOT CHANGE)
# Found views ['defaultview-459'] for process: 00_DEMO - Acquire-to-Onboard for  SAP ECC & S/4 HANA (DO NOT CHANGE)
# Fetching schema for process: attract-to-acquire-talent---s-1, 00_DEMO - Attract-to-Acquire-Talent for SuccessFactors
# Found views ['defaultview-462'] for process: 00_DEMO - Attract-to-Acquire-Talent for SuccessFactors
# Fetching schema for process: 00demo---ato-sap-s4-hana-do-n-4, 00_DEMO - Inspect-to-Quality for SAP S/4 HANA (DO NOT CHANGE)
# Found views ['defaultview-525'] for process: 00_DEMO - Inspect-to-Quality for SAP S/4 HANA (DO NOT CHANGE)
# Fetching schema for process: demo---itc-sap-s4-hana-do-not-1, 00_DEMO - Invoice-to-Cash for SAP S/4 HANA (DO NOT CHANGE)
# Found views ['defaultview-59'] for process: 00_DEMO - Invoice-to-Cash for SAP S/4 HANA (DO NOT CHANGE)
# Fetching schema for process: 00demo---itp-sap-s4-hana-1, 00_DEMO - Invoice-to-Pay for SAP S/4 HANA (DO NOT CHANGE)
# Found views ['defaultview-133'] for process: 00_DEMO - Invoice-to-Pay for SAP S/4 HANA (DO NOT CHANGE)
# Fetching schema for process: 00demo-jira-issue-to-resoluti-1, 00_DEMO Issue-to-Resolution for Jira
# Found views ['defaultview-370'] for process: 00_DEMO Issue-to-Resolution for Jira
# Fetching schema for process: s4-plan-to-fulfill-1, 00_DEMO - Make-to-Stock for SAP S/4 HANA (DO NOT CHANGE)
# Found views ['defaultview-183'] for process: 00_DEMO - Make-to-Stock for SAP S/4 HANA (DO NOT CHANGE)
# Fetching schema for process: 00demo---manage-personal-empl-2, 00_DEMO - Manage-Personal-Employee-Information for SAP SuccessFactors Employee Central (DO NOT CHANGE)
# Found views ['defaultview-299'] for process: 00_DEMO - Manage-Personal-Employee-Information for SAP SuccessFactors Employee Central (DO NOT CHANGE)
# Fetching schema for process: 00testewmoutbound-1, 00_DEMO - Manage Warehouse and Inventory (Outbound) in SAP EWM (DO NOT CHANGE)
# Found views ['defaultview-528'] for process: 00_DEMO - Manage Warehouse and Inventory (Outbound) in SAP EWM (DO NOT CHANGE)
# Fetching schema for process: bs-sap-is-u-m2c-demo-1, 00_DEMO - Meter-to-Cash for SAP IS-U and S/4HANA (DO NOT CHANGE)
# Found views ['defaultview-50'] for process: 00_DEMO - Meter-to-Cash for SAP IS-U and S/4HANA (DO NOT CHANGE)
# Fetching schema for process: sl-dmc-20231009---4-original--1, 00_DEMO_Operate Manufacturing in SAP Digital Manufacturing (DO NOT CHANGE)
# Found views ['defaultview-538'] for process: 00_DEMO_Operate Manufacturing in SAP Digital Manufacturing (DO NOT CHANGE)
# Fetching schema for process: sol-1734sapeccplantmaintenanc-1, 00_DEMO - Operate-to-Maintain/Plant_Maintenance for SAP ECC
# Found views ['defaultview-95'] for process: 00_DEMO - Operate-to-Maintain/Plant_Maintenance for SAP ECC
# Fetching schema for process: 00demo---otc-sap-ecc-v2-do-no-1, 00_DEMO - OTC SAP ECC V2 (DO NOT CHANGE)
# Found views ['defaultview-290'] for process: 00_DEMO - OTC SAP ECC V2 (DO NOT CHANGE)
# Fetching schema for process: 00demo---otc-sap-s4-hana-v2-d-1, 00_DEMO - OTC SAP S/4 HANA (DO NOT CHANGE)
# Found views ['defaultview-291'] for process: 00_DEMO - OTC SAP S/4 HANA (DO NOT CHANGE)
# Fetching schema for process: ad-eventlog-generator-for-ptp-1, 00_DEMO PTP Cross Mining SAP Ariba + SAP ERP (DO NOT CHANGE)
# Found views ['defaultview-471'] for process: 00_DEMO PTP Cross Mining SAP Ariba + SAP ERP (DO NOT CHANGE)
# Fetching schema for process: 00demo-ptp-in-ariba-do-not-ch-1, 00_DEMO - PTP in Ariba (DO NOT CHANGE)
# Found views ['defaultview-431'] for process: 00_DEMO - PTP in Ariba (DO NOT CHANGE)
# Fetching schema for process: yw-sap-s4h-ptp-full-run---met-1, 00_DEMO - PTP SAP S4H (DO NOT CHANGE)
# Found views ['defaultview-57'] for process: 00_DEMO - PTP SAP S4H (DO NOT CHANGE)
# Fetching schema for process: 00demo---sap-ibp-sop-do-not-c-1, 00_DEMO - SAP IBP S&OP (DO NOT CHANGE)
# Found views ['defaultview-404'] for process: 00_DEMO - SAP IBP S&OP (DO NOT CHANGE)
# Fetching schema for process: sap-s4hana-cloud---invoice-to-1, 00_DEMO - SAP S/4HANA Cloud - Invoice-to-Cash
# Found views ['defaultview-222'] for process: 00_DEMO - SAP S/4HANA Cloud - Invoice-to-Cash
# Fetching schema for process: sap-s4hana-cloud---projecat-t-1, 00_DEMO - SAP S/4HANA Cloud - Project-to-Cash
# Found views ['defaultview-197'] for process: 00_DEMO - SAP S/4HANA Cloud - Project-to-Cash
# Fetching schema for process: ce-dmc-test-1, 00_DMC_Showcase (DO NOT CHANGE)
# Found views ['defaultview-270'] for process: 00_DMC_Showcase (DO NOT CHANGE)
# Fetching schema for process: 00pia-jira-process-1, [00]_PIA Jira Process
# Found views ['defaultview-217'] for process: [00]_PIA Jira Process
# Fetching schema for process: 01demo-dashboardsitp-process-1, [0]_Dashboards_ITP Process
# Found views ['defaultview-225'] for process: [0]_Dashboards_ITP Process
# Fetching schema for process: hs-163-demo-1, 0_demo_accelerators_generic (PTP S4H, changes allowed)
# Found views ['defaultview-288'] for process: 0_demo_accelerators_generic (PTP S4H, changes allowed)
# Fetching schema for process: nk-showtell---itp-dashboards-1, [NK] Show&Tell - ITP Dashboards
# Found views ['defaultview-362'] for process: [NK] Show&Tell - ITP Dashboards
# Fetching schema for process: sm-ptpariba-1, [SIGPIA-2936] Dashboard_PTP_Ariba
# Found views ['defaultview-545'] for process: [SIGPIA-2936] Dashboard_PTP_Ariba
#                                             column_name  \
# 0                                               case_id
# 1                                            event_name
# 2                                              end_time
# 3        Invoice_u0020_Posting_u0020_Gross_u0020_Amount
# 4      Event_u0020_Created_u0020_By_u0020_User_u0020_Id
# ...                                                 ...
# 3876  last_u0020_gr_u0020_shipment_u0020_notice_u002...
# 3877              last_u0020_gr_u0020_supplier_u0020_id
# 3878  last_u0020_gr_u0020_supplier_u0020_location_u0...
# 3879  last_u0020_gr_u0020_item_u0020_processed_u0020...
# 3880            last_u0020_gr_u0020_creation_u0020_date
#
#                                    name column_role        dataType  \
# 0                               case_id   DIMENSION            TEXT
# 1                            event_name   DIMENSION       LIST_TEXT
# 2                              end_time   DIMENSION  LIST_TIMESTAMP
# 3          Invoice Posting Gross Amount   DIMENSION     LIST_NUMBER
# 4              Event Created By User Id   DIMENSION       LIST_TEXT
# ...                                 ...         ...             ...
# 3876  Last GR Shipment Notice Reference   DIMENSION            TEXT
# 3877                Last GR Supplier Id   DIMENSION            TEXT
# 3878       Last GR Supplier Location Id   DIMENSION            TEXT
# 3879       Last GR Item Processed State   DIMENSION            TEXT
# 3880              Last GR Creation Date   DIMENSION       TIMESTAMP
#
#                  view                                            process  \
# 0     defaultview-529  000_DEMO✨ - Dashboards ITC ECC & S4H (DO NOT C...
# 1     defaultview-529  000_DEMO✨ - Dashboards ITC ECC & S4H (DO NOT C...
# 2     defaultview-529  000_DEMO✨ - Dashboards ITC ECC & S4H (DO NOT C...
# 3     defaultview-529  000_DEMO✨ - Dashboards ITC ECC & S4H (DO NOT C...
# 4     defaultview-529  000_DEMO✨ - Dashboards ITC ECC & S4H (DO NOT C...
# ...               ...                                                ...
# 3876  defaultview-545                  [SIGPIA-2936] Dashboard_PTP_Ariba
# 3877  defaultview-545                  [SIGPIA-2936] Dashboard_PTP_Ariba
# 3878  defaultview-545                  [SIGPIA-2936] Dashboard_PTP_Ariba
# 3879  defaultview-545                  [SIGPIA-2936] Dashboard_PTP_Ariba
# 3880  defaultview-545                  [SIGPIA-2936] Dashboard_PTP_Ariba
#
#                    process_id
# 0     sl-itc-dashboard-test-1
# 1     sl-itc-dashboard-test-1
# 2     sl-itc-dashboard-test-1
# 3     sl-itc-dashboard-test-1
# 4     sl-itc-dashboard-test-1
# ...                       ...
# 3876            sm-ptpariba-1
# 3877            sm-ptpariba-1
# 3878            sm-ptpariba-1
# 3879            sm-ptpariba-1
# 3880            sm-ptpariba-1
#
# [3881 rows x 7 columns]

# %%
filepath = Path(f'data/temp/schemas_from_views_{date_str}.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
df_schema.to_csv(filepath)  
print(f"CSV files with Schemas for Signals: {filepath}")
# Out:
# CSV files with Schemas for Signals: data/temp/schemas_from_views_2024-02-11T23_24_11.csv
