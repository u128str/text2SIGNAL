# %% [markdown]
# # Get and Extract Signals from Signavio sources: API calls to workspaces and load from saved JSON files
# This notebook provides a collection of cells where we extract Signals from several workspaces by means of Signavio API backend calls.
# You would need Signavio credentials - check if you can access:
#
# https://editor.signavio.com/g/statics/pi/areas
#
# Create *.env* file
# ```js
# MY_SIGNAVIO_PASSWORD=*****
# MY_SIGNAVIO_NAME=alexey.streltsov@sap.com
# ```

# %% [markdown]
# # Credentials / API  initialization

# %%
# Define your access to Signavio UI here or in bash env
#%env MY_SIGNAVIO_PASSWORD=*****
#%env MY_SIGNAVIO_NAME=alexey.streltsov@sap.com

# Or via .env file
#! pip install python-dotenv
from dotenv import load_dotenv
from pathlib import Path  # Python 3.6+ only
import sys
import os
sys.path.append("./")
env_path = Path('..') / '.env'
load_dotenv(dotenv_path=env_path)

! echo $MY_SIGNAVIO_NAME
# Out:
# alexey.streltsov@sap.com

# %%
# Class coped and modified  from https://github.com/signavio/bpmn2constraints/blob/main/tutorial/SignavioAuthenticator.py
class SignavioAuthenticatorCoE:
    def __init__(self, system_instance, tenant_id, email, pw):
        self.system_instance = system_instance
        self.tenant_id = tenant_id
        self.email = email
        self.pw = pw

    """
    Takes care of authentication against Signavio systems
    """

    def authenticate(self):
        """
        Authenticates user at Signavio system instance and initiates session.
        Returns:
            dictionary: Session information
        """
        login_url = self.system_instance + "/p/login"
        data = {"name": self.email, "password": self.pw, "tokenonly": "true"}
        #if "tenant_id" in locals():
        #    data["tenant"] = self.tenant_id
        data["tenant"] = self.tenant_id
        # authenticate
        login_request = requests.post(login_url, data)

        # retrieve token and session ID
        auth_token = login_request.content.decode("utf-8")
        jsesssion_ID = login_request.cookies["JSESSIONID"]

        # The cookie is named 'LBROUTEID' for base_url 'editor.signavio.com'
        # and 'editor.signavio.com', and 'AWSELB' for base_url
        # 'app-au.signavio.com' and 'app-us.signavio.com'
        lb_route_ID = login_request.cookies["LBROUTEID"]

        # return credentials
        return {
            "jsesssion_ID": jsesssion_ID,
            "lb_route_ID": lb_route_ID,
            "auth_token": auth_token,
        }

def credentials_actualization(system_instance, workspace_id, user_name, pw, auth={}):
    # get credentials for current session. They are valid for 24 hours 
    authenticator = SignavioAuthenticatorCoE(system_instance, workspace_id, user_name, pw)
    auth_data = authenticator.authenticate()
    cookies = {'JSESSIONID': auth_data['jsesssion_ID'], 'LBROUTEID': auth_data['lb_route_ID']}
    headers = {'Accept': 'application/json', 'x-signavio-id':  auth_data['auth_token']}
    print(auth_data['jsesssion_ID'],auth_data['lb_route_ID'])
    print(auth_data['auth_token'])
    auth[workspace_name]={"cookies":cookies,"headers":headers}
    return auth

# %%
# select workspace here 
import json
import pathlib
import logging
import requests
import os
logging.getLogger("urllib3").setLevel(logging.WARNING)


auth={}
 
user_name = os.environ.get('MY_SIGNAVIO_NAME','alexey.streltsov@sap.com') # username
pw = os.environ.get('MY_SIGNAVIO_PASSWORD', None) # Signavio password
print("Your are:",user_name)
system_instance = 'https://editor.signavio.com'
workspace_id = 'b0f07deabd3140aea5344baa686e0d84' # workspace Process AI 
workspace_name="Process AI"
credentials_actualization(system_instance, workspace_id, user_name, pw, auth=auth) 
workspace_id = 'ccf98b692d1d4e0aa895df3aab8cd905' # workspace Solutions Demo Workspace access by alexandra.dang@sap.com
workspace_name="Solutions Demo Workspace"
credentials_actualization(system_instance, workspace_id, user_name, pw, auth=auth)
# This workspace is under discussion with sarah.roessler@sap.com
#workspace_id = "2da9ebfecca0479398ad9905b88c5187"
#workspace_name="SAP Signavio Suite Power Challenge"
#user_name="demo+113@signavio.com"
#pw="signavio"
#credentials_actualization(system_instance, workspace_id, user_name, pw, auth=auth)

auth
# Out:
# Your are: alexey.streltsov@sap.com
# BDDA85B7B96C9528019A689714091F3F "ac423a07e50c6e3f"
# e35c772889f7476fac5bba8811851045
# AC2C1CD401241FA29474F62B9B35A017 "564b969e7bc94720"
# 453721c3ac2b44e38f5ef793daf72038
# {'Process AI': {'cookies': {'JSESSIONID': 'BDDA85B7B96C9528019A689714091F3F',
#    'LBROUTEID': '"ac423a07e50c6e3f"'},
#   'headers': {'Accept': 'application/json',
#    'x-signavio-id': 'e35c772889f7476fac5bba8811851045'}},
#  'Solutions Demo Workspace': {'cookies': {'JSESSIONID': 'AC2C1CD401241FA29474F62B9B35A017',
#    'LBROUTEID': '"564b969e7bc94720"'},
#   'headers': {'Accept': 'application/json',
#    'x-signavio-id': '453721c3ac2b44e38f5ef793daf72038'}}}

# %% [markdown]
# ## Example how to run manually -constructed SIGNALS against workspace DB:

# %%
# Run manually -constructed SIGNALS need for VIEW 
def signal_template(signal,view):
    return f'SELECT {signal} FROM "{view}"'
signal_endpoint = system_instance + '/g/api/pi-graphql/signal'

workspace_name="Solutions Demo Workspace"
#workspace_name="Process AI"
#workspace_name="SAP Signavio Suite Power Challenge"

# https://editor.signavio.com/g/statics/pi/areas/ba-3/processes/test00-1/views/defaultview-2
# https://editor.signavio.com/g/statics/pi/areas/etl-403/processes/sl-itc-dashboard-test-1/views/defaultview-529
view="defaultview-529" # for workspace_name="Solutions Demo Workspace"
#view="strview-1" 
#view="defaultview-35"
signal='AVG( (SELECT LAST(end_time) - FIRST(end_time)))'
q = {'query': signal_template(signal=signal,view=view)}
q = {'query': 'SELECT count(1) \nFROM FLATTEN("defaultview-1")'}
query_request = requests.post(
        signal_endpoint,
        cookies=auth[workspace_name]["cookies"],
        headers=auth[workspace_name]["headers"] ,
        json={'query': signal_template(signal=signal,view=view)})
query_request.json()
# Out:
# {'header': [{'columnName': 'AVG((SELECT LAST(end_time) - FIRST(end_time)))',
#    'columnAlias': 'AVG((SELECT LAST(end_time) - FIRST(end_time)))',
#    'columnRole': 'MEASURE',
#    'dataType': 'DURATION'}],
#  'data': [[13659129279.096045]]}

# %% [markdown]
# ## REST API endpoint

# %%
# POST - need to re-run to inject the above generated credentials
#q=q_list_processes #

#def POST_Signavio(query={},cookies=cookies,headers=headers):
def POST_Signavio(query={},workspace_name="",auth=auth):
        signal_endpoint = system_instance + '/g/api/pi-graphql/graphql'
        timeout=50
        try:
            query_request = requests.post(
                signal_endpoint,
                cookies=auth[workspace_name]["cookies"],
                headers=auth[workspace_name]["headers"],
                timeout=timeout,
                json=query)
            query_request.raise_for_status()
        except requests.HTTPError as ex:
            # possibly check response for a message
            raise ex  # let the caller handle it
        except requests.Timeout:
            print("request took too long")


        return query_request.json()

# %% [markdown]
# ## Step 1. Select Signavio workspace here and Get list of processes in given workspace
# Later we will extract all Dashboards/Investigations and Metrics from the selected workspace
#
# The selection of the workspace is controlled by:
#
# ```python
# # Select workspace
# workspace_name="Solutions Demo Workspace"
# #workspace_name="Process AI"
#  ```

# %%
# Workspace selection 
workspace_name="Solutions Demo Workspace"
#workspace_name="SAP Signavio Suite Power Challenge"
#workspace_name="Process AI"

# %%
# List of processes & number of investigations
### q_list_processes={
###     "operationName": "Subjects",
###     "variables": {},
###     "query": "query Subjects {\n  subjects {\n    id\n    name\n    businessArea\n    investigationCount\n    __typename\n  }\n}"
### }
### 
### # process and investigations details
### q_list_processes={
###     "operationName": "Subjects",
###     "variables": {},
###     "query": "query Subjects {\n  subjects {\n    id\n    name\n    businessArea\n    investigationCount\n  investigations {\n    id\n    name\n  } }}"
### }



q_list_processes={
    "operationName": "Subjects",
    "variables": {},
    "query": "query Subjects {\n  subjects {\n    id\n    name\n    businessArea\n  investigationCount dashboardCount }}"
}

# Get list of available process:
workspace_name="Solutions Demo Workspace"
list_processes =  POST_Signavio(query=q_list_processes,workspace_name=workspace_name)['data']['subjects']
print(f"In Workspace Name: {workspace_name}. Number of processes: {len(list_processes)}")

workspace_name="Process AI"
list_processes_1 =  POST_Signavio(query=q_list_processes,workspace_name=workspace_name)['data']['subjects']
print(f"In Workspace Name: {workspace_name}. Number of processes: {len(list_processes_1)}")
# Out:
# In Workspace Name: Solutions Demo Workspace. Number of processes: 30
# In Workspace Name: Process AI. Number of processes: 7

# %%
list_processes
# Out:
# [{'id': 'sl-itc-dashboard-test-1',
#   'name': '000_DEMO✨ - Dashboards ITC ECC & S4H (DO NOT CHANGE)',
#   'businessArea': 'etl-403',
#   'investigationCount': 0,
#   'dashboardCount': 7},
#  {'id': '00demo---sap-s4h-itp-dashboar-1',
#   'name': '000_DEMO✨ - Dashboards ITP ECC & S4H (DO NOT CHANGE)',
#   'businessArea': 'etl-220',
#   'investigationCount': 0,
#   'dashboardCount': 7},
#  {'id': '00demo---sap-s4h-otc-dashboar-1',
#   'name': '000_DEMO✨ - Dashboards OTC ECC & S4H (DO NOT CHANGE) ',
#   'businessArea': 'etl-38',
#   'investigationCount': 1,
#   'dashboardCount': 7},
#  {'id': 'sademo-dashboardss4h-p2p-proc-1',
#   'name': '000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)',
#   'businessArea': 'etl-67',
#   'investigationCount': 2,
#   'dashboardCount': 16},
#  {'id': 'lg-00demo---ato-sap-s4-hana-d-1',
#   'name': '00_DEMO - Acquire-to-Onboard for  SAP ECC & S/4 HANA (DO NOT CHANGE)',
#   'businessArea': 'etl-336',
#   'investigationCount': 0,
#   'dashboardCount': 1},
#  {'id': 'attract-to-acquire-talent---s-1',
#   'name': '00_DEMO - Attract-to-Acquire-Talent for SuccessFactors',
#   'businessArea': 'etl-339',
#   'investigationCount': 0,
#   'dashboardCount': 1},
#  {'id': '00demo---ato-sap-s4-hana-do-n-4',
#   'name': '00_DEMO - Inspect-to-Quality for SAP S/4 HANA (DO NOT CHANGE)',
#   'businessArea': 'etl-399',
#   'investigationCount': 0,
#   'dashboardCount': 2},
#  {'id': 'demo---itc-sap-s4-hana-do-not-1',
#   'name': '00_DEMO - Invoice-to-Cash for SAP S/4 HANA (DO NOT CHANGE)',
#   'businessArea': 'etl-38',
#   'investigationCount': 3,
#   'dashboardCount': 3},
#  {'id': '00demo---itp-sap-s4-hana-1',
#   'name': '00_DEMO - Invoice-to-Pay for SAP S/4 HANA (DO NOT CHANGE)',
#   'businessArea': 'etl-74',
#   'investigationCount': 0,
#   'dashboardCount': 6},
#  {'id': '00demo-jira-issue-to-resoluti-1',
#   'name': '00_DEMO Issue-to-Resolution for Jira',
#   'businessArea': 'etl-38',
#   'investigationCount': 2,
#   'dashboardCount': 1},
#  {'id': 's4-plan-to-fulfill-1',
#   'name': '00_DEMO - Make-to-Stock for SAP S/4 HANA (DO NOT CHANGE)',
#   'businessArea': 'etl-106',
#   'investigationCount': 4,
#   'dashboardCount': 5},
#  {'id': '00demo---manage-personal-empl-2',
#   'name': '00_DEMO - Manage-Personal-Employee-Information for SAP SuccessFactors Employee Central (DO NOT CHANGE)',
#   'businessArea': 'etl-199',
#   'investigationCount': 1,
#   'dashboardCount': 2},
#  {'id': '00testewmoutbound-1',
#   'name': '00_DEMO - Manage Warehouse and Inventory (Outbound) in SAP EWM (DO NOT CHANGE)',
#   'businessArea': 'etl-402',
#   'investigationCount': 0,
#   'dashboardCount': 1},
#  {'id': 'bs-sap-is-u-m2c-demo-1',
#   'name': '00_DEMO - Meter-to-Cash for SAP IS-U and S/4HANA (DO NOT CHANGE)',
#   'businessArea': 'etl-29',
#   'investigationCount': 0,
#   'dashboardCount': 2},
#  {'id': 'sl-dmc-20231009---4-original--1',
#   'name': '00_DEMO_Operate Manufacturing in SAP Digital Manufacturing (DO NOT CHANGE)',
#   'businessArea': 'etl-412',
#   'investigationCount': 0,
#   'dashboardCount': 1},
#  {'id': 'sol-1734sapeccplantmaintenanc-1',
#   'name': '00_DEMO - Operate-to-Maintain/Plant_Maintenance for SAP ECC',
#   'businessArea': 'ba-13',
#   'investigationCount': 3,
#   'dashboardCount': 2},
#  {'id': '00demo---otc-sap-ecc-v2-do-no-1',
#   'name': '00_DEMO - OTC SAP ECC V2 (DO NOT CHANGE)',
#   'businessArea': 'etl-191',
#   'investigationCount': 1,
#   'dashboardCount': 1},
#  {'id': '00demo---otc-sap-s4-hana-v2-d-1',
#   'name': '00_DEMO - OTC SAP S/4 HANA (DO NOT CHANGE)',
#   'businessArea': 'etl-192',
#   'investigationCount': 2,
#   'dashboardCount': 2},
#  {'id': 'ad-eventlog-generator-for-ptp-1',
#   'name': '00_DEMO PTP Cross Mining SAP Ariba + SAP ERP (DO NOT CHANGE)',
#   'businessArea': 'etl-220',
#   'investigationCount': 1,
#   'dashboardCount': 5},
#  {'id': '00demo-ptp-in-ariba-do-not-ch-1',
#   'name': '00_DEMO - PTP in Ariba (DO NOT CHANGE)',
#   'businessArea': 'etl-311',
#   'investigationCount': 1,
#   'dashboardCount': 5},
#  {'id': 'yw-sap-s4h-ptp-full-run---met-1',
#   'name': '00_DEMO - PTP SAP S4H (DO NOT CHANGE)',
#   'businessArea': 'etl-36',
#   'investigationCount': 2,
#   'dashboardCount': 8},
#  {'id': '00demo---sap-ibp-sop-do-not-c-1',
#   'name': '00_DEMO - SAP IBP S&OP (DO NOT CHANGE)',
#   'businessArea': 'etl-288',
#   'investigationCount': 1,
#   'dashboardCount': 2},
#  {'id': 'sap-s4hana-cloud---invoice-to-1',
#   'name': '00_DEMO - SAP S/4HANA Cloud - Invoice-to-Cash',
#   'businessArea': 'etl-134',
#   'investigationCount': 2,
#   'dashboardCount': 2},
#  {'id': 'sap-s4hana-cloud---projecat-t-1',
#   'name': '00_DEMO - SAP S/4HANA Cloud - Project-to-Cash',
#   'businessArea': 'etl-118',
#   'investigationCount': 2,
#   'dashboardCount': 1},
#  {'id': 'ce-dmc-test-1',
#   'name': '00_DMC_Showcase (DO NOT CHANGE)',
#   'businessArea': 'etl-175',
#   'investigationCount': 1,
#   'dashboardCount': 0},
#  {'id': '00pia-jira-process-1',
#   'name': '[00]_PIA Jira Process',
#   'businessArea': 'etl-129',
#   'investigationCount': 8,
#   'dashboardCount': 6},
#  {'id': '01demo-dashboardsitp-process-1',
#   'name': '[0]_Dashboards_ITP Process',
#   'businessArea': 'ba-13',
#   'investigationCount': 1,
#   'dashboardCount': 16},
#  {'id': 'hs-163-demo-1',
#   'name': '0_demo_accelerators_generic (PTP S4H, changes allowed)',
#   'businessArea': 'etl-38',
#   'investigationCount': 2,
#   'dashboardCount': 3},
#  {'id': 'nk-showtell---itp-dashboards-1',
#   'name': '[NK] Show&Tell - ITP Dashboards',
#   'businessArea': 'etl-255',
#   'investigationCount': 0,
#   'dashboardCount': 1},
#  {'id': 'sm-ptpariba-1',
#   'name': '[SIGPIA-2936] Dashboard_PTP_Ariba',
#   'businessArea': 'etl-417',
#   'investigationCount': 2,
#   'dashboardCount': 5}]

# %% [markdown]
# ## Step 2. Get lists of Dashboards, Investigations, Metrics for each of the processes from the above Step 1. nd store in all_json JSON
#
# The selection of the workspace is controlled by:
#
# ```python
# # Select workspace
# workspace_name="Solutions Demo Workspace"
# #workspace_name="Process AI"
#  ```
#
#  Here we run collection of Signavio API calls to upload information about Dashboards , Investigations for each process in the defined above workspace
#
# ### Execution of the cell below can take: up to  **53 sec**

# %%
# Change the Selected workspace 
#workspace_name="Solutions Demo Workspace"
#workspace_name="Process AI"

# %%
### q_list_dashboards={"operationName":"Dashboards",
###    #"variables":{"subjectId":"demo01-1",},
###    "variables":{"subjectId":'test00-1'},
###    "query":"query Dashboards($subjectId: ID!) {\n  dashboards(subjectId: $subjectId) {\n    access\n    id\n    name\n    view {\n      name\n      id\n      isDefaultView\n    }\n     }\n}\n"}
### 
q_list_dashboards={"operationName":"Dashboards",
   "variables":{"subjectId":'test00-1'},
   "query":"query Dashboards($subjectId: ID!) {\n  dashboards(subjectId: $subjectId) {\n    access\n    id\n    name\n    view {\n      name\n      id\n    }\n     }\n}\n"}


### q_list_investigations={
###     "operationName": "Subject",
###     "variables": {     "subjectId": "test00-1" },
###     "query": """query Subject($subjectId: ID!) {\n  subject(id: $subjectId) {\n    ...Subject\n    __typename\n  }\n}\n\nfragment Subject on 
###     Subject {\n  id\n  name\n  currencyCode\n  businessArea\n  sourceSystem\n  processTypes\n  preprocessingStatus\n  investigationCount\n  
###     investigations {\n    id\n    name\n    __typename\n  }\n  changedAt\n  __typename\n}\n"""
### }

q_list_investigations={
    "operationName": "Subject",
    "variables": {     "subjectId": "test00-1" },
    "query": """query Subject($subjectId: ID!) {\n  subject(id: $subjectId) {\n    ...Subject\n  }\n}\n\nfragment Subject on 
    Subject {\n  id\n  name\n  investigationCount\n  
    investigations {\n    id\n    name\n   view {\n      name\n      id\n    }\n  }}\n"""
}

#
q_list_metrics={
    "operationName": "metricsAndVariables",
    "variables": { "subjectId": "test001-1"},
    "query": """ 
    query metricsAndVariables($subjectId: ID!) 
     {  metrics(subjectId: $subjectId) 
        {   ...Metric\n    __typename\n  } 
        metricVariables(subjectId: $subjectId) {\n    id\n    name\n    description\n    value\n    __typename\n  }
     }
        fragment Metric on Metric {\n  id\n  name\n  description\n  signalFragment\n  variables\n  
        }
         """
}

q_list_columns={
    "operationName": "subjectView",
    "variables": {
        "id": "defaultview-2",
        "subjectId": "test00-1"
    },
    "query": "query subjectView($id: ID!, $subjectId: ID!) {\n  subjectView(id: $id, subjectId: $subjectId) {\n    ...SubjectView\n    __typename\n  }\n}\n\nfragment SubjectView on SubjectView {\n  id\n  name\n  isDefaultView\n  isAccessView\n  columns {\n    ...SubjectViewColumn\n    __typename\n  }\n  users {\n    ...SubjectViewUser\n    __typename\n  }\n  __typename\n}\n\nfragment SubjectViewColumn on SubjectViewColumn {\n  name\n  isVisible\n  dataType\n  processVariableId\n  filter {\n    ... on SubjectViewColumnDateTimeFilter {\n      startDate\n      endDate\n      type\n      processVariableId\n      __typename\n    }\n    ... on SubjectViewColumnChoiceFilter {\n      includes\n      excludes\n      type\n      processVariableId\n      __typename\n    }\n    ... on SubjectViewColumnNumberFilter {\n      min\n      max\n      type\n      processVariableId\n      __typename\n    }\n    __typename\n  }\n  __typename\n}\n\nfragment SubjectViewUser on SubjectViewUser {\n  id\n  role\n  entity {\n    ...UserOrGroup\n    __typename\n  }\n  __typename\n}\n\nfragment UserOrGroup on UserOrGroup {\n  ... on User {\n    ...User\n    __typename\n  }\n  ... on UserGroup {\n    ...UserGroup\n    __typename\n  }\n  ... on Everyone {\n    ...Everyone\n    __typename\n  }\n  __typename\n}\n\nfragment Everyone on Everyone {\n  type\n  __typename\n}\n\nfragment User on User {\n  id\n  firstName\n  lastName\n  name\n  email\n  type\n  __typename\n}\n\nfragment UserGroup on UserGroup {\n  id\n  name\n  type\n  __typename\n}\n"
}


def create_all_json_from_list_of_processes(list_processes,workspace_name,
                                           q_list_dashboards=q_list_dashboards,
                                           q_list_investigations=q_list_investigations,
                                           q_list_metrics=q_list_metrics,
                                           q_list_columns=q_list_columns
                                           ):
    ndash=0
    ninvs=0
    nmtrx=0
    all_json={}
    cnt=0

    for p in list_processes:
        cnt+=1
        dashboardCount=p["dashboardCount"]
        investigationCount=p["investigationCount"]
        q_list_dashboards['variables']["subjectId"]=p['id']
        list_dashboards=POST_Signavio(query=q_list_dashboards,workspace_name=workspace_name)
        q_list_investigations['variables']["subjectId"]=p['id']
        list_investigations=POST_Signavio(query=q_list_investigations,workspace_name=workspace_name)
        q_list_metrics['variables']["subjectId"]=p['id']
        list_metrics=POST_Signavio(query=q_list_metrics,workspace_name=workspace_name)['data']
        metricCount=len(list_metrics['metrics'])
        q_list_columns["variables"]["subjectId"]=p['id']
        print(cnt, len(list_processes), "Process:",p['name'],"d:",p["dashboardCount"],"i:",p["investigationCount"],"m:",metricCount)

        v=[]
        if dashboardCount > 0:
            v+=[d['view']['id'] for d in list_dashboards['data']['dashboards'] ]
            print("     View from DashBoards", set(v))
            print("Process:",p['name'], p["dashboardCount"],"Dashboards",list_dashboards)
            ndash+=dashboardCount
        if investigationCount > 0:
            v+=[d['view']['id'] for d in list_investigations['data']['subject']['investigations'] ]
            print("     View from Investigations", set(v))
            print("Process:",p['name'], p["investigationCount"], "Investigations",POST_Signavio(query=q_list_investigations,workspace_name=workspace_name))
            ninvs+=investigationCount
        if metricCount >0:
            nmtrx+=metricCount
            print("Process:", p['name'], metricCount, " Metrics", POST_Signavio(query=q_list_metrics,workspace_name=workspace_name))
        viewCount=len(list(set(v)))
        views={}
        if viewCount > 0:
            for view in list(set(v)):
                q_list_columns["variables"]["id"]=view
                views[view]=POST_Signavio(query=q_list_columns,workspace_name=workspace_name)

        all_json[p['name']]={'process_id': p['name'], 
                   'dashboardCount':dashboardCount,
                   'investigationCount':investigationCount,
                   'metricCount': metricCount,
                  'list_dashboards':list_dashboards,
                  'list_investigations':list_investigations,
                  'list_metrics':list_metrics,
                  'views':views}
   
    print(f'Workspace name: {workspace_name}')
    print(f'N processes {len(list_processes)}. Dashboards: {ndash}. Investigations {ninvs}. Metrics: {nmtrx}')
    return all_json, ndash, ninvs, nmtrx

# %%
# 18 sec get all_json_1 with all lists of dahsboards, investigation , metrics
# Workspace name: Process AI
# N processes 7. Dashboards: 3. Investigations 6. Metrics: 186
# takes 12.2s 
workspace_name="Process AI"
list_processes_1 =  POST_Signavio(query=q_list_processes,workspace_name=workspace_name)['data']['subjects']
print(f"In Workspace Name: {workspace_name}. Number of processes: {len(list_processes_1)}")
all_json_1, ndash_1, ninvs_1, nmtrx_1 =create_all_json_from_list_of_processes(list_processes_1,workspace_name)
# Out:
# In Workspace Name: Process AI. Number of processes: 7
# 1 7 Process: demo01 d: 2 i: 2 m: 5
#      View from DashBoards {'defaultview-9'}
# Process: demo01 2 Dashboards {'data': {'dashboards': [{'access': 'PRIVATE', 'id': 'fgcf-1', 'name': 'workingdashboard', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-9'}}, {'access': 'PRIVATE', 'id': 'qqqq-1', 'name': 'qqqq', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-9'}}]}}
#      View from Investigations {'defaultview-9'}
# Process: demo01 2 Investigations {'data': {'subject': {'id': 'demo01-1', 'name': 'demo01', 'investigationCount': 2, 'investigations': [{'id': 'askdata-poc-6', 'name': 'AskData POC', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-9'}}, {'id': 'askdata-poc-copy-1', 'name': 'AskData POC (Copy)', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-9'}}]}}}
# Process: demo01 5  Metrics {'data': {'metrics': [{'id': 'amount-of-time-spent-on-dropo-1', 'name': 'Amount of time spent on dropouts', 'description': 'Total cycle time of all cases until the last event before dropout', 'signalFragment': 'SUM(\n\t(SELECT LAST(end_time)) - (SELECT FIRST(end_time))) FILTER (\n\t\tWHERE (SELECT LAST(event_name) IN (${dropout_events}))\n   )', 'variables': ['dropoutevents-1'], '__typename': 'Metric'}, {'id': 'unpaid-invoices-with-non-eval-8', 'name': 'Unpaid Invoices with Non Evaluated Risk Class', 'description': None, 'signalFragment': 'COUNT (1) AS "Case Count"', 'variables': [], '__typename': 'Metric'}, {'id': 'invoice-payment-compliance-ra-7', 'name': 'Invoice Payment Compliance Rate', 'description': None, 'signalFragment': '(COUNT (1) FILTER (WHERE EVENT_NAME MATCHES (\'Create Invoice\'~> \'Receive Payment\')) / COUNT (1)) * 100 AS "Standard Invoicing Compliance Rate"', 'variables': [], '__typename': 'Metric'}, {'id': 'median-returns-cycle-time-7', 'name': 'Median Returns Cycle Time', 'description': None, 'signalFragment': 'MEDIAN ((SELECT LAST (END_TIME) WHERE EVENT_NAME = \'Receive Return\') - (SELECT FIRST (END_TIME) WHERE EVENT_NAME = \'Create Return Request\')) AS "Median Return Cycle Time"', 'variables': [], '__typename': 'Metric'}, {'id': 'average-cycle-time-14', 'name': 'Average cycle time', 'description': 'Average cycle time calculated from the first to the last event', 'signalFragment': 'AVG((SELECT LAST(end_time)) - (SELECT FIRST(end_time)))', 'variables': [], '__typename': 'Metric'}], 'metricVariables': [{'id': 'dropoutevents-1', 'name': 'dropout_events', 'description': "Events that identify a dropout case, for example 'Reject Quote', 'Update Opportunity Stage to: Dead - No Decision'", 'value': None, '__typename': 'MetricVariable'}]}}
# 2 7 Process: dv_test d: 0 i: 0 m: 0
# 3 7 Process: sfdsdf d: 0 i: 0 m: 1
# Process: sfdsdf 1  Metrics {'data': {'metrics': [{'id': 'average-cycle-time-16', 'name': 'Average cycle time', 'description': 'Average cycle time calculated from the first to the last event', 'signalFragment': 'AVG((SELECT LAST(end_time)) - (SELECT FIRST(end_time)))', 'variables': [], '__typename': 'Metric'}], 'metricVariables': []}}
# 4 7 Process: Test d: 0 i: 0 m: 0
# 5 7 Process: test00 d: 1 i: 2 m: 177
#      View from DashBoards {'strview-1'}
# Process: test00 1 Dashboards {'data': {'dashboards': [{'access': 'PRIVATE', 'id': 'testdashboard-1', 'name': 'testdashboard', 'view': {'name': 'str_view', 'id': 'strview-1'}}]}}
#      View from Investigations {'defaultview-2', 'strview-1'}
# Process: test00 2 Investigations {'data': {'subject': {'id': 'test00-1', 'name': 'test00', 'investigationCount': 2, 'investigations': [{'id': 'askdata-poc-1', 'name': 'AskData POC', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-2'}}, {'id': 'q1-1', 'name': 'q1', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-2'}}]}}}
# Process: test00 177  Metrics {'data': {'metrics': [{'id': 'percentage-of-reversed-invoic-2', 'name': 'Percentage of reversed invoices', 'description': 'Percentage of invoices that were reversed', 'signalFragment': 'COUNT(case_id) FILTER (\n\tWHERE event_name MATCHES(${itc_invoice_reversal_events}))\n/\nCOUNT(case_id)\n* 100', 'variables': ['itcinvoicereversalevents-1'], '__typename': 'Metric'}, {'id': 'on-time-payment-rate-1', 'name': 'On-time payment rate', 'description': 'Percentage of invoices that were cleared less than 5 days before and no later than 1 day after their due dates', 'signalFragment': 'COUNT(case_id) FILTER (\n\tWHERE (${itp_clearing_date} - ${itp_due_date} \n\t\t< DURATION ${itp_late_payment_condition}\n\tAND ${itp_due_date} - ${itp_clearing_date}\n\t\t< DURATION ${itp_early_payment_condition}\n\t)\n)\n/\nCOUNT(case_id) FILTER (\n\tWHERE (${itp_clearing_date}IS NOT NULL)\n)\n* 100', 'variables': ['itpclearingdate-1', 'itpduedate-1', 'itplatepaymentcondition-1', 'itpearlypaymentcondition-1'], '__typename': 'Metric'}, {'id': 'percentage-of-change-events-p-1', 'name': 'Percentage of change events per case', 'description': 'Average percentage of change events per case', 'signalFragment': 'AVG(\n\t(SELECT COUNT(event_name) FILTER (\n\t\tWHERE event_name ${change_events})\n\t) / (SELECT COUNT(event_name))\n\t) * 100', 'variables': ['changeevents-1'], '__typename': 'Metric'}, {'id': 'total-overdue-invoice-amounts-2', 'name': 'Total overdue invoice amounts', 'description': 'Sum of all invoice amounts that are overdue (converted in USD)', 'signalFragment': "SUM(${itc_amount_conv}) FILTER(\n\t WHERE (${itc_clearing_date} IS NULL)\n\t\tAND ${itc_due_date} < DATE_TRUNC('day', NOW())\n\t)", 'variables': ['itcamountconv-1', 'itcclearingdate-1', 'itcduedate-1'], '__typename': 'Metric'}, {'id': 'on-time-delivery-raten-1', 'name': 'On-Time Delivery raten', 'description': 'Percentage of cases with on-time deliveries. Only cases that have been completely delivered are considered.', 'signalFragment': '(1 - \n\tCOUNT(case_id) FILTER (\n\t\tWHERE ${ato_late_delivery_condition}\n\t\t\tAND ${ato_delivery_completed_condition}\n\t\t)\n\t/\n\tCOUNT(case_id) FILTER (\n\t\tWHERE ${ato_delivery_completed_condition}\n\t\t)\n)\n* 100', 'variables': ['atolatedeliverycondition-1', 'atodeliverycompletedcondition-1'], '__typename': 'Metric'}, {'id': 'two-way-match-ratehu-1', 'name': 'Two-way match ratehu', 'description': 'Percentage of purchase orders with a two-way match', 'signalFragment': 'COUNT(case_id) FILTER (\n\tWHERE (${two_way_match_condition})\n\t)\n/ COUNT(case_id)\n* 100', 'variables': ['twowaymatchcondition-1'], '__typename': 'Metric'}, {'id': 'on-time-delivery-rate-2', 'name': 'On-time delivery rate', 'description': 'Percentage of deliveries arriving at their destination before or on the expected date', 'signalFragment': 'COUNT(case_id) FILTER (\n\tWHERE (SELECT COUNT(event_name)\n\t\t\tWHERE (${ontime_delivery_condition})) > 0\n\t)\n/ COUNT(case_id) FILTER (\n\tWHERE (SELECT BOOL_OR(event_name IN (${outbound_delivery_creation_events})))\n\t) \n* 100\n', 'variables': ['ontimedeliverycondition-1', 'outbounddeliverycreationevent-1'], '__typename': 'Metric'}, {'id': 'overdue-deliveries-casesn-1', 'name': 'Overdue deliveries casesn,', 'description': 'Number of cases with overdue deliveries. Only cases that have not been (completely) delivered yet are considered.', 'signalFragment': 'COUNT(case_id) FILTER (\n\tWHERE ${overdue_delivery_condition}\n\t)', 'variables': ['overduedeliverycondition-1'], '__typename': 'Metric'}, {'id': 'net-average-cycle-time-spent--1', 'name': 'Net average cycle time spent on rework', 'description': 'Difference between the average cycle time of the cases that have any rework and the average cycle time of the whole process', 'signalFragment': '(AVG(\n\t(SELECT LAST(end_time) - FIRST(end_time))\n)\n\tFILTER (WHERE (SELECT BOOL_OR (${minimum_loops_condition})\n\t\tFROM(SELECT OCCURRENCE(event_name) AS occurrenc ...
# 6 7 Process: test001 d: 0 i: 1 m: 2
#      View from Investigations {'defaultview-4'}
# Process: test001 1 Investigations {'data': {'subject': {'id': 'test001-1', 'name': 'test001', 'investigationCount': 1, 'investigations': [{'id': 'askdata-poc-3', 'name': 'AskData POC', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-4'}}]}}}
# Process: test001 2  Metrics {'data': {'metrics': [{'id': 'average-actual-to-target-sla--1', 'name': 'Average actual to target SLA ratio', 'description': 'Ratio between the average incident resolution duration to target SLA duration', 'signalFragment': 'AVG(\n\t((SELECT LAST(end_time) WHERE event_name IN (${sla_closure_events}))\n\t-(SELECT FIRST(end_time) WHERE event_name IN (${sla_creation_events})))\n) / (DURATION ${target_sla_time})\n*100', 'variables': ['slaclosureevents-1', 'slacreationevents-1', 'targetslatime-1'], '__typename': 'Metric'}, {'id': 'average-cycle-time-6', 'name': 'Average cycle time', 'description': 'Average cycle time calculated from the first to the last event', 'signalFragment': 'AVG((SELECT LAST(end_time)) - (SELECT FIRST(end_time)))', 'variables': [], '__typename': 'Metric'}], 'metricVariables': [{'id': 'slacreationevents-1', 'name': 'sla_creation_events', 'description': "Events defining the start events of a case, for example 'Create Incident'", 'value': "'Create Incident'", '__typename': 'MetricVariable'}, {'id': 'targetslatime-1', 'name': 'target_sla_time', 'description': "SLA time expectation, for example '15 days'", 'value': "'15days'", '__typename': 'MetricVariable'}, {'id': 'slaclosureevents-1', 'name': 'sla_closure_events', 'description': "Events defining the closing events of a case, for example 'Close Incident'", 'value': "'Close Incident'", '__typename': 'MetricVariable'}]}}
# 7 7 Process: test002 d: 0 i: 1 m: 1
#      View from Investigations {'defaultview-3'}
# Process: test002 1 Investigations {'data': {'subject': {'id': 'test002-1', 'name': 'test002', 'investigationCount': 1, 'investigations': [{'id': 'askdata-poc-2', 'name': 'AskData POC', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-3'}}]}}}
# Process: test002 1  Metrics {'data': {'metrics': [{'id': 'average-cycle-time-3', 'name': 'Average cycle time', 'description': 'Average cycle time calculated from the first to the last event', 'signalFragment': 'AVG((SELECT LAST(end_time)) - (SELECT FIRST(end_time)))', 'variables': [], '__typename': 'Metric'}], 'metricVariables': []}}
# Workspace name: Process AI
# N processes 7. Dashboards: 3. Investigations 6. Metrics: 186

# %%
# 1m 42.9s Get all_json for "Solutions Demo Workspace"
# Workspace name: Solutions Demo Workspace
# N processes 31. Dashboards: 112. Investigations 43. Metrics: 669
# takes 1m 5.8s
workspace_name="Solutions Demo Workspace"
list_processes =  POST_Signavio(query=q_list_processes,workspace_name=workspace_name)['data']['subjects']
print(f"In Workspace Name: {workspace_name}. Number of processes: {len(list_processes)}")

all_json, ndash, ninvs, nmtrx =create_all_json_from_list_of_processes(list_processes,workspace_name)
# Out:
# In Workspace Name: Solutions Demo Workspace. Number of processes: 30
# 1 30 Process: 000_DEMO✨ - Dashboards ITC ECC & S4H (DO NOT CHANGE) d: 7 i: 0 m: 1
#      View from DashBoards {'defaultview-529'}
# Process: 000_DEMO✨ - Dashboards ITC ECC & S4H (DO NOT CHANGE) 7 Dashboards {'data': {'dashboards': [{'access': 'ANYONE_VIEW', 'id': '01-cycle-time-dashboard-10', 'name': 'Cycle Times', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-529'}}, {'access': 'ANYONE_VIEW', 'id': '03-automation-dashboard-12', 'name': 'Automation', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-529'}}, {'access': 'ANYONE_VIEW', 'id': '00-overview-dashboard-15', 'name': '00_Overview', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-529'}}, {'access': 'ANYONE_VIEW', 'id': 'optimize-your-payment-term-us-2', 'name': 'Optimize Your Payment Term Usage', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-529'}}, {'access': 'ANYONE_VIEW', 'id': 'wip-improve-days-sales-outsta-1', 'name': 'Improve Days Sales Outstanding (DSO)\u200b', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-529'}}, {'access': 'PRIVATE', 'id': 'danoneglobal-value-approach---1', 'name': 'Global Value Approach', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-529'}}, {'access': 'PRIVATE', 'id': 'danoneglobal-value-approach---3', 'name': '_Global Value Approach', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-529'}}]}}
# Process: 000_DEMO✨ - Dashboards ITC ECC & S4H (DO NOT CHANGE) 1  Metrics {'data': {'metrics': [{'id': 'average-cycle-time-758', 'name': 'Average cycle time', 'description': 'Average cycle time calculated from the first to the last event', 'signalFragment': 'AVG((SELECT LAST(end_time)) - (SELECT FIRST(end_time)))', 'variables': [], '__typename': 'Metric'}], 'metricVariables': [{'id': 'salesorderdoccreationperiod-27', 'name': 'sales_order_doc_creation_period', 'description': "Reference time period to monitor sales order documents that were created, for example, for sales order documents that were created during last week: '7days'", 'value': "'21days'", '__typename': 'MetricVariable'}, {'id': 'salesorderdoccreationevents-27', 'name': 'sales_order_doc_creation_events', 'description': "Events referring to the creation of any sales document, for example: 'Create Sales Order Item', 'Create Contract Item'", 'value': "'Create Sales Order Item', 'Create Contract Item', 'Create Return Sales Order Item', 'Create Sales Order Item w/o Charge', 'Create Credit Memo Request Item', 'Create Debit Memo Request Item'", '__typename': 'MetricVariable'}, {'id': 'otcautomationcondition-27', 'name': 'otc_automation_condition', 'description': 'Attributes indicating that an event was automated, for example: "EventCreatedByUserType" != \'Dialog\'', 'value': '"EventCreatedByUserType" != \'Dialog\'', '__typename': 'MetricVariable'}]}}
# 2 30 Process: 000_DEMO✨ - Dashboards ITP ECC & S4H (DO NOT CHANGE) d: 7 i: 0 m: 6
#      View from DashBoards {'defaultview-320'}
# Process: 000_DEMO✨ - Dashboards ITP ECC & S4H (DO NOT CHANGE) 7 Dashboards {'data': {'dashboards': [{'access': 'ANYONE_VIEW', 'id': 'automation-dashboard-9', 'name': 'Automation', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-320'}}, {'access': 'PRIVATE', 'id': 'sap-s4hana---invoice-to-pay-1', 'name': 'SAP S/4HANA - Invoice to Pay', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-320'}}, {'access': 'ANYONE_VIEW', 'id': 'overview-dashboard-13', 'name': '00_Overview', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-320'}}, {'access': 'ANYONE_VIEW', 'id': 'cycle-time-dashboard-9', 'name': 'Cycle Times', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-320'}}, {'access': 'PRIVATE', 'id': 'open-overdue-invoices-33', 'name': 'Open Overdue Invoices', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-320'}}, {'access': 'PRIVATE', 'id': 'payment-behaviour-7', 'name': 'Payment Behaviour', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-320'}}, {'access': 'PRIVATE', 'id': 'payment-term-1', 'name': 'Payment Term', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-320'}}]}}
# Process: 000_DEMO✨ - Dashboards ITP ECC & S4H (DO NOT CHANGE) 6  Metrics {'data': {'metrics': [{'id': 'number-of-open-overdue-invoic-145', 'name': 'Number of open overdue invoices', 'description': 'Number of invoices that are currently open and overdue', 'signalFragment': "COUNT(case_id) FILTER (\n\tWHERE (${itp_clearing_date} IS NULL)\n\t\tAND ${itp_due_date} < DATE_TRUNC('day', NOW()))", 'variables': ['itpclearingdate-15', 'itpduedate-14'], '__typename': 'Metric'}, {'id': 'production-orders-overdue-for-7', 'name': 'Production orders overdue for status closed', 'description': 'Number of open overdue production orders which are technically closed', 'signalFragment': 'COUNT( case_id) FILTER (\n\tWHERE ( SELECT COUNT(event_name)\n    \t    WHERE ${mots_prod_order_item_status} IN (${mots_prod_order_item_status_teco})\n    ) > 0\n    AND ( SELECT COUNT(event_name)\n    \t    WHERE ${mots_prod_order_item_status} IN (${mots_prod_order_item_status_clsd_dlfl})\n    ) = 0\n\tAND (NOW() - ${mots_prod_order_scheduled_finish_date}) < DURATION ${mots_scheduled_finish_overdue_period}\n)\n', 'variables': ['motsprodorderitemstatus-2', 'motsprodorderitemstatusteco-2', 'motsprodorderitemstatusclsddl-2', 'motsprodorderscheduledfinishd-2', 'motsscheduledfinishoverdueper-2'], '__typename': 'Metric'}, {'id': 'number-of-open-overdue-invoic-144', 'name': 'Number of open overdue invoices', 'description': 'Number of invoices that are currently open and overdue', 'signalFragment': "COUNT(case_id) FILTER (\n\tWHERE (${itc_ecc_s4h_clearing_date} IS NULL)\n\t\tAND ${itc_ecc_s4h_due_date} < DATE_TRUNC('day', NOW())\n)", 'variables': ['itceccs4hclearingdate-1', 'itceccs4hduedate-1'], '__typename': 'Metric'}, {'id': 'number-of-open-overdue-invoic-143', 'name': 'Number of open overdue invoices', 'description': 'Number of invoices that are currently open and overdue', 'signalFragment': "COUNT(case_id) FILTER (\n\tWHERE (${i2c_s4hc_clearing_date} IS NULL)\n\t\t AND ${i2c_s4hc_due_date} < DATE_TRUNC('day', NOW())\n)", 'variables': ['i2cs4hcclearingdate-2', 'i2cs4hcduedate-2'], '__typename': 'Metric'}, {'id': 'automatic-payment-block-remov-14', 'name': 'Automatic payment block removal', 'description': 'Number of invoices where payment blocks where removed by non-dialog users', 'signalFragment': 'COUNT(case_id) FILTER (\n\tWHERE (event_name MATCHES(${itp_remove_payment_block_events}))\n\t\tAND NOT (${itp_automatic_condition_nested}))', 'variables': ['itpremovepaymentblockevents-11', 'itpautomaticconditionnested-11'], '__typename': 'Metric'}, {'id': 'average-cycle-time-429', 'name': 'Average cycle time', 'description': 'Average cycle time calculated from the first to the last event', 'signalFragment': 'AVG((SELECT LAST(end_time)) - (SELECT FIRST(end_time)))', 'variables': [], '__typename': 'Metric'}], 'metricVariables': [{'id': 'itpremovepaymentblockevents-11', 'name': 'itp_remove_payment_block_events', 'description': "Event identifying the removal of a payment block for an invoice, for example 'Remove Payment Block'", 'value': "'Remove Payment Block'", '__typename': 'MetricVariable'}, {'id': 'itpautomaticconditionnested-11', 'name': 'itp_automatic_condition_nested', 'description': 'Condition indicating that an event was manual, for example "Event Created By User Type" MATCHES(\'Dialog\')', 'value': '"Event Created By User Type" MATCHES (\'Dialog\')', '__typename': 'MetricVariable'}, {'id': 'itpinvoicepaymentterms-12', 'name': 'itp_invoice_payment_terms', 'description': 'Attribute referring to the invoice payment terms in days, for example "Last Inv. Item Net Payment Terms Period"', 'value': '"Last FI Invoice Item Cash Discount Days 1"', '__typename': 'MetricVariable'}, {'id': 'itppurchaseorderpaymentterms-12', 'name': 'itp_purchase_order_payment_terms', 'description': 'Attribute referring to the purchase order payment terms in days, for example "PO Net Payment Days"', 'value': '"PO Cash Discount Days 1"', '__typename': 'MetricVariable'}, {'id': 'i2cs4hcclearingdate ...
# 3 30 Process: 000_DEMO✨ - Dashboards OTC ECC & S4H (DO NOT CHANGE)  d: 7 i: 1 m: 5
#      View from DashBoards {'defaultview-383'}
# Process: 000_DEMO✨ - Dashboards OTC ECC & S4H (DO NOT CHANGE)  7 Dashboards {'data': {'dashboards': [{'access': 'PRIVATE', 'id': 'sap-s4hana---order-to-cash-1', 'name': 'zz-SAP S/4HANA - Order to Cash', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-383'}}, {'access': 'ANYONE_VIEW', 'id': '02-customer-satisfaction-1', 'name': 'Customer Satisfaction', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-383'}}, {'access': 'ANYONE_VIEW', 'id': '00-overview-dashboard-4', 'name': '00_Overview', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-383'}}, {'access': 'ANYONE_VIEW', 'id': '01-cycle-time-dashboard-4', 'name': 'Cycle Times', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-383'}}, {'access': 'ANYONE_VIEW', 'id': '03-automation-dashboard-5', 'name': 'Automation', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-383'}}, {'access': 'ANYONE_VIEW', 'id': '05-working-capital-analysis-1', 'name': 'Working Capital', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-383'}}, {'access': 'ANYONE_VIEW', 'id': '04-efficiency--rework-analysi-2', 'name': 'Efficiency and Rework', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-383'}}]}}
#      View from Investigations {'defaultview-383'}
# Process: 000_DEMO✨ - Dashboards OTC ECC & S4H (DO NOT CHANGE)  1 Investigations {'data': {'subject': {'id': '00demo---sap-s4h-otc-dashboar-1', 'name': '000_DEMO✨ - Dashboards OTC ECC & S4H (DO NOT CHANGE) ', 'investigationCount': 1, 'investigations': [{'id': 'general-35', 'name': 'General', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-383'}}]}}}
# Process: 000_DEMO✨ - Dashboards OTC ECC & S4H (DO NOT CHANGE)  5  Metrics {'data': {'metrics': [{'id': 'overdue-and-open-accounts-rec-78', 'name': 'Overdue and open Accounts Receivable items', 'description': 'Number of overdue open customer items', 'signalFragment': 'COUNT(case_id) FILTER (\n\tWHERE (SELECT COUNT(event_name)\n\t\t\tWHERE (${invoice_overdue_condition} OR ${open_accounts_receivable_condition})) > 0\n\t)', 'variables': ['invoiceoverduecondition-28', 'openaccountsreceivableconditi-29'], '__typename': 'Metric'}, {'id': '1-overdue-and-open-accounts-r-1', 'name': '1 Overdue and open Accounts Receivable items items', 'description': '', 'signalFragment': 'COUNT(case_id) FILTER (\n    WHERE \n      (SELECT COUNT(event_name)\n      \tWHERE("InvoiceAccountingClearingDate" IS NULL\n\t\t  AND "InvoiceDueDate" < DATE_TRUNC(\'day\', NOW()))\n          ) > 0\n\t)\n', 'variables': [], '__typename': 'Metric'}, {'id': 'overdue-open-accounts-receiva-2', 'name': 'Overdue payment items', 'description': '', 'signalFragment': 'COUNT(case_id) FILTER (\n\tWHERE (SELECT COUNT(event_name)\n\t\t\tWHERE (${invoice_overdue_condition} )) > 0\n\t)', 'variables': [], '__typename': 'Metric'}, {'id': 'late-payment-rate-385', 'name': 'Late payment rate', 'description': 'Percentage of cases where the invoice was cleared after its due date', 'signalFragment': 'COUNT(case_id) FILTER (\n\tWHERE (SELECT COUNT(event_name)\n\t\t\tWHERE (${invoice_overdue_condition})) > 0\n\t)\n/ COUNT(case_id) FILTER (\n\tWHERE (SELECT BOOL_OR(event_name IN (${billing_clearing_events})))\n\t) \n* 100\n', 'variables': ['invoiceoverduecondition-28', 'billingclearingevents-28'], '__typename': 'Metric'}, {'id': 'average-cycle-time-521', 'name': 'Average cycle time', 'description': 'Average cycle time calculated from the first to the last event', 'signalFragment': 'AVG((SELECT LAST(end_time)) - (SELECT FIRST(end_time)))', 'variables': [], '__typename': 'Metric'}], 'metricVariables': [{'id': 'billingclearingevents-28', 'name': 'billing_clearing_events', 'description': "Events identifying that an invoice was cleared, for example 'Clear Invoice'", 'value': "'Clear Invoice'", '__typename': 'MetricVariable'}, {'id': 'openaccountsreceivableconditi-29', 'name': 'open_accounts_receivable_condition', 'description': 'Condition defining that an invoice has not been cleared so far, although it was expected to. For example: NOW() > "InvoiceDueDate"', 'value': 'NOW() > "InvoiceDueDate"', '__typename': 'MetricVariable'}, {'id': 'invoiceoverduecondition-28', 'name': 'invoice_overdue_condition', 'description': 'Condition defining that an invoice was cleared after the due date, for example "InvoiceAccountingClearingDate" > "InvoiceDueDate"', 'value': '"InvoiceAccountingClearingDate" > "InvoiceDueDate"', '__typename': 'MetricVariable'}, {'id': 'ontimedeliverycondition-24', 'name': 'ontime_delivery_condition', 'description': 'Condition defining that a delivery is on time, for example "DeliveryGoodsMovementOnTime" = \'Yes\'', 'value': '"DeliveryGoodsMovementOnTime" = \'Yes\'', '__typename': 'MetricVariable'}]}}
# 4 30 Process: 000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE) d: 16 i: 2 m: 71
#      View from DashBoards {'defaultview-124'}
# Process: 000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE) 16 Dashboards {'data': {'dashboards': [{'access': 'PRIVATE', 'id': 'dashboard-5-changes---in-revi-1', 'name': 'zz Dashboard 4: Changes', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-124'}}, {'access': 'PRIVATE', 'id': 'dashboard-demo-vendor-analysi-1', 'name': 'zz - PO Vendor Dashboard', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-124'}}, {'access': 'PRIVATE', 'id': 'dashboard-0-overview-process--2', 'name': 'zz_Agnostic - Overview', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-124'}}, {'access': 'PRIVATE', 'id': 'dashboard-99-data-validation--1', 'name': 'zz: Data Validation ', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-124'}}, {'access': 'PRIVATE', 'id': 'dashboard-empty-template-1', 'name': 'zz - Empty Dashboard Template', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-124'}}, {'access': 'PRIVATE', 'id': 'x-2', 'name': 'zz: General Recommendations', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-124'}}, {'access': 'PRIVATE', 'id': 'zz---empty-dashboard-template-1', 'name': 'zz - CBI Test Dashboard', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-124'}}, {'access': 'PRIVATE', 'id': 'zcbi---payment-term-optimizat-1', 'name': 'zz_CBI - Payment Term Optimization (for Final dashboard)', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-124'}}, {'access': 'PRIVATE', 'id': 'sap-s4hana---procure-to-pay-1', 'name': 'zz_SAP S/4HANA - Procure to Pay', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-124'}}, {'access': 'PRIVATE', 'id': 'dashboard-feature-test-1', 'name': '💡 Dashboard Feature Test', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-124'}}, {'access': 'ANYONE_VIEW', 'id': 'po-open-overdue-invoices-moni-1', 'name': 'Open Overdue Invoices', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-124'}}, {'access': 'ANYONE_VIEW', 'id': 'ptp---cycle-time-analysis-3', 'name': 'Cycle Times', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-124'}}, {'access': 'ANYONE_VIEW', 'id': 'overview-dashboard-48', 'name': '00_Overview', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-124'}}, {'access': 'ANYONE_VIEW', 'id': 'po-late-payments-historical-a-2', 'name': 'Late Payments ', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-124'}}, {'access': 'ANYONE_VIEW', 'id': 'ptp---automation-1', 'name': 'Automation', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-124'}}, {'access': 'PRIVATE', 'id': 'stellantis-global-value-appro-1', 'name': 'Global Value Approach', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-124'}}]}}
#      View from Investigations {'defaultview-124'}
# Process: 000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE) 2 Investigations {'data': {'subject': {'id': 'sademo-dashboardss4h-p2p-proc-1', 'name': '000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)', 'investigationCount': 2, 'investigations': [{'id': 'hzl-povinsights-1', 'name': 'Presales Template - HZL POV_Insights', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-124'}}, {'id': 'cn-test-2', 'name': 'Dashboard Feature Validation', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-124'}}]}}}
# Process: 000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE) 71  Metrics {'data': {'metrics': [{'id': 'automation-rate-for-invoice-c-21', 'name': 'Automation rate for invoice clearing', 'description': "Percentage of automated invoice clearing events. For example 'Clear Invoice' events that are not performed by a Dialog user", 'signalFragment': 'SUM(\n\t(SELECT COUNT(event_name) FILTER (\n\t\tWHERE (event_name IN (${itp_clear_invoice_events})\n\t\t\tAND (${itp_automation_condition})))\n\t)\n)\n/ SUM(\n\t(SELECT COUNT(event_name) FILTER (\n\tWHERE (event_name IN (${itp_clear_invoice_events})))\n\t)\n)\n* 100', 'variables': ['itpclearinvoiceevents-4', 'itpautomationcondition-4'], '__typename': 'Metric'}, {'id': 'invoices-with-immediate-payme-12', 'name': 'Invoices with immediate payment terms', 'description': 'Number of invoices where the payment terms (BSEG.ZBD1T) are 0 or NULL', 'signalFragment': 'COUNT("Last FI Invoice ID") FILTER(\n\tWHERE ${itp_cash_discount_terms} IS NULL\n\t\tOR ${itp_cash_discount_terms} = 0)', 'variables': ['itpcashdiscountterms-11'], '__typename': 'Metric'}, {'id': 'payment-terms-differences-whe-4', 'name': 'Payment Terms Differences where PO is better (Median)', 'description': 'Number of invoices for which the payment terms on the invoice differ from the payment terms on the purchase order', 'signalFragment': 'AVG("PO Cash Discount Days 1"-"Last FI Invoice Item Cash Discount Days 1") FILTER(\n\tWHERE ("Last FI Invoice Item Cash Discount Days 1") \n\t\t< (CASE WHEN "PO Cash Discount Days 1" IS NULL THEN 0 \n\tELSE "PO Cash Discount Days 1" END))', 'variables': ['itpinvoicepaymentterms-11', 'itppurchaseorderpaymentterms-11'], '__typename': 'Metric'}, {'id': 'payment-terms-differences-whe-5', 'name': 'Payment Terms Differences where PO is better (Amount)', 'description': 'Number of invoices for which the payment terms on the invoice differ from the payment terms on the purchase order', 'signalFragment': 'SUM("Last FI Invoice Item Gross Amount in USD") FILTER(\n\tWHERE ("Last FI Invoice Item Cash Discount Days 1") \n\t\t< (CASE WHEN "PO Cash Discount Days 1" IS NULL THEN 0 \n\tELSE "PO Cash Discount Days 1" END))', 'variables': ['itpinvoicepaymentterms-11', 'itppurchaseorderpaymentterms-11'], '__typename': 'Metric'}, {'id': 'wc-impact-of-invoices-with-im-2', 'name': 'WC Impact of Invoices with immediate payment terms', 'description': 'Amount of invoices where the payment terms (BSEG.ZBD1T) are 0 or NULL', 'signalFragment': 'SUM("Last FI Invoice Item Gross Amount in USD") FILTER(\n\tWHERE ${itp_cash_discount_terms} IS NULL\n\t\tOR ${itp_cash_discount_terms} = 0) *15*0.04/365', 'variables': ['itpcashdiscountterms-11'], '__typename': 'Metric'}, {'id': 'percentage-of-baseline-date-c-6', 'name': 'Percentage of baseline date changes', 'description': 'Percentage of Baseline Date Changes after the Invoice was posted to SAP', 'signalFragment': 'COUNT(case_id) FILTER (\n\tWHERE event_name MATCHES(${itc_change_baseline_date})\n\t\tAND event_name MATCHES(${itc_posting_to_baseline_update_events}))\n/\nCOUNT(case_id)\n* 100', 'variables': ['itcchangebaselinedate-3', 'itcpostingtobaselineupdateeve-3'], '__typename': 'Metric'}, {'id': 'percentage-of-reversed-invoic-9', 'name': 'Percentage of reversed invoices', 'description': 'Percentage of invoices that were reversed', 'signalFragment': 'COUNT(case_id) FILTER (\n\tWHERE event_name MATCHES(${itc_invoice_reversal_events}))\n/\nCOUNT(case_id)\n* 100', 'variables': ['itcinvoicereversalevents-5'], '__typename': 'Metric'}, {'id': 'number-of-open-overdue-invoic-21', 'name': 'Number of open overdue invoices', 'description': 'Number of invoices that are currently open and overdue', 'signalFragment': "COUNT(case_id) FILTER (\n\tWHERE (${itc_clearing_date} IS NULL)\n\t\tAND ${itc_due_date} < DATE_TRUNC('day', NOW())\n)", 'variables': ['itcclearingdate-8', 'itcduedate-7'], '__typename': 'Metric'}, {'id': 'total-overdue-invoice-amounts-16', 'name': 'Total overdue invoice amounts', ' ...
# 5 30 Process: 00_DEMO - Acquire-to-Onboard for  SAP ECC & S/4 HANA (DO NOT CHANGE) d: 1 i: 0 m: 25
#      View from DashBoards {'defaultview-459'}
# Process: 00_DEMO - Acquire-to-Onboard for  SAP ECC & S/4 HANA (DO NOT CHANGE) 1 Dashboards {'data': {'dashboards': [{'access': 'ANYONE_VIEW', 'id': 'ato-overview-dashboard-8', 'name': '00_Overview', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-459'}}]}}
# Process: 00_DEMO - Acquire-to-Onboard for  SAP ECC & S/4 HANA (DO NOT CHANGE) 25  Metrics {'data': {'metrics': [{'id': 'pos-created-after-invoice-cre-2', 'name': 'POs created after Invoice Creation', 'description': 'Total number of cases in which a PO Item has been created after the Invoice Creation event', 'signalFragment': 'COUNT(case_id) FILTER\n\t(WHERE (event_name MATCHES(${ato_po_created_after_invoice_created})))', 'variables': ['atopocreatedafterinvoicecreat-2'], '__typename': 'Metric'}, {'id': 'perfect-order-fulfillment-rat-33', 'name': 'Perfect order fulfillment rate', 'description': 'Percentage of cases that went through without any reversal of Goods Receipts', 'signalFragment': '(COUNT(case_id) FILTER (\n\tWHERE (event_name MATCHES(${ato_goods_receipt_events}))\n\t)\n\t-\n\tCOUNT(case_id) FILTER (\n\tWHERE (event_name MATCHES(${ato_goods_receipt_reversal_events}))\n\t))\n\t/\n\tCOUNT(case_id) FILTER (\n\tWHERE (event_name MATCHES(${ato_goods_receipt_events}))\n\t)\n\t* 100', 'variables': ['atogoodsreceiptevents-2', 'atogoodsreceiptreversalevents-2'], '__typename': 'Metric'}, {'id': 'process-compliance-38', 'name': 'Process compliance', 'description': 'Percentage of compliant Acquire-to-Onboard cases', 'signalFragment': 'COUNT(case_id) FILTER (\n\tWHERE event_name MATCHES(${ato_compliant_event_sequence})\n\t)\n/ COUNT(case_id)\n* 100', 'variables': ['atocomplianteventsequence-2'], '__typename': 'Metric'}, {'id': 'two-way-match-rate-50', 'name': 'Two-way match rate', 'description': 'Percentage of purchase orders with a two-way match', 'signalFragment': 'COUNT(case_id) FILTER (\n\tWHERE (${ato_two_way_match_condition})\n\t)\n/ COUNT(case_id)\n* 100', 'variables': ['atotwowaymatchcondition-2'], '__typename': 'Metric'}, {'id': 'average-cycle-time-purchase-o-2', 'name': 'Average cycle time purchase order to invoice posting', 'description': 'Average cycle time between purchase order creation and invoice posting', 'signalFragment': "AVG ((SELECT LAST (END_TIME) FILTER (\n\tWHERE EVENT_NAME IN ('Post FI Invoice'))) \n\t- (SELECT FIRST (END_TIME) FILTER (\n\tWHERE EVENT_NAME IN ('Create PO Item')))) \n        ", 'variables': [], '__typename': 'Metric'}, {'id': 'maverick-buying-rate---po-cre-3', 'name': 'Maverick Buying Rate - PO Creation after Invoice Creation', 'description': 'Percentage of cases in which the PO Item was created after the Invoice, a common indicator for Maverick Buying', 'signalFragment': 'COUNT(case_id) FILTER (\n\tWHERE event_name MATCHES(${ato_maverick_buying_po_after_invoice_condition})\n\t)\n/ COUNT(case_id) * 100', 'variables': ['atomaverickbuyingpoafterinvoi-2'], '__typename': 'Metric'}, {'id': 'goods-return-rate-26', 'name': 'Goods return rate', 'description': 'Percentage of cases with delivery returns', 'signalFragment': 'COUNT(case_id) FILTER (\n\tWHERE (SELECT COUNT(event_name)\n\t\t\tWHERE event_name IN (${ato_return_delivery_events})) > 0\n\t)\n/ COUNT(case_id)\n* 100', 'variables': ['atoreturndeliveryevents-2'], '__typename': 'Metric'}, {'id': 'on-time-delivery-rate-179', 'name': 'On-Time Delivery rate', 'description': 'Percentage of cases with on-time deliveries. Only cases that have been completely delivered are considered.', 'signalFragment': '(1 - \n\tCOUNT(case_id) FILTER (\n\t\tWHERE ${ato_late_delivery_condition}\n\t\t\tAND ${ato_delivery_completed_condition}\n\t\t)\n\t/\n\tCOUNT(case_id) FILTER (\n\t\tWHERE ${ato_delivery_completed_condition}\n\t\t)\n)\n* 100', 'variables': ['atolatedeliverycondition-2', 'atodeliverycompletedcondition-2'], '__typename': 'Metric'}, {'id': 'invoices-waiting-for-goods-re-40', 'name': 'Invoices waiting for Goods Receipt', 'description': 'Total number of cases with Invoices waiting for the Goods Receipt event', 'signalFragment': 'COUNT(case_id) FILTER (\n\tWHERE NOT (event_name MATCHES(${ato_goods_receipt_events}))\n\tAND (event_name MATCHES(${ato_invoice_event_flow}))\n\t)', 'variables': ['atogoodsreceiptevents-2', 'atoinvoiceeventflow-2'], '__typename': 'M ...
# 6 30 Process: 00_DEMO - Attract-to-Acquire-Talent for SuccessFactors d: 1 i: 0 m: 7
#      View from DashBoards {'defaultview-462'}
# Process: 00_DEMO - Attract-to-Acquire-Talent for SuccessFactors 1 Dashboards {'data': {'dashboards': [{'access': 'PRIVATE', 'id': 'sap-successfactors---attract--1', 'name': 'SAP SuccessFactors - Attract to Acquire Talent', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-462'}}]}}
# Process: 00_DEMO - Attract-to-Acquire-Talent for SuccessFactors 7  Metrics {'data': {'metrics': [{'id': 'number-of-open-job-requisitio-4', 'name': 'Number of Open Job Requisitions', 'description': 'The number of currently open job requisitions, based on the count of unique Job Requisition IDs and their Job Requisition Status', 'signalFragment': 'COUNT(DISTINCT "Job Requisition ID") FILTER (\n\tWHERE "Job Requisition Status" IN (${job_req_status_open}))', 'variables': ['jobreqstatusopen-2'], '__typename': 'Metric'}, {'id': 'percentage-of-hired-candidate-4', 'name': 'Percentage of Hired Candidates', 'description': 'Percentage of job applications that result in a hiring event', 'signalFragment': 'COUNT(case_id) FILTER (\n\tWHERE (SELECT COUNT(event_name)\n\t\tWHERE event_name IN (${hiring_events}))\n\t> 0)\n/ COUNT(case_id)\n* 100', 'variables': ['hiringevents-2'], '__typename': 'Metric'}, {'id': 'average-time-to-fill-5', 'name': 'Average Time to Fill', 'description': 'Average Time Between Job Requisition Created and Position Filled', 'signalFragment': 'AVG(\n\t(SELECT LAST(end_time) FILTER (\n\t\tWHERE (event_name IN (${hiring_events}))))\n\t-(SELECT FIRST(end_time) FILTER (\n\t\tWHERE (event_name IN (${job_requisition_creation_events}))))\n)', 'variables': ['hiringevents-2', 'jobrequisitioncreationevents-2'], '__typename': 'Metric'}, {'id': 'average-time-to-extend-job-of-5', 'name': 'Average Time to Extend Job Offer', 'description': 'Average Time Between Candidate Selected by Hiring Manager and Offer Extended to Candidate', 'signalFragment': 'AVG(\n\t(SELECT LAST(end_time) FILTER (\n\t\tWHERE (event_name IN (${offer_extended_events}))))\n\t-(SELECT FIRST(end_time) FILTER (\n\t\tWHERE (event_name IN (${hiring_manager_hired_events}))))\n)', 'variables': ['offerextendedevents-2', 'hiringmanagerhiredevents-2'], '__typename': 'Metric'}, {'id': 'number-of-hired-candidates-5', 'name': 'Number of Hired Candidates', 'description': 'Number of job applications that result in a hiring event', 'signalFragment': 'COUNT(case_id) FILTER (\n\tWHERE (SELECT COUNT(event_name)\n\t\tWHERE event_name IN (${hiring_events}))\n\t> 0)', 'variables': ['hiringevents-2'], '__typename': 'Metric'}, {'id': 'average-time-to-hire-5', 'name': 'Average Time to Hire', 'description': 'Average Time Between Job Application Received and Candidate Hired', 'signalFragment': 'AVG(\n\t(SELECT LAST(end_time) FILTER (\n\t\tWHERE (event_name IN (${hiring_events}))))\n\t-(SELECT FIRST(end_time) FILTER (\n\t\tWHERE (event_name IN (${job_application_creation_events}))))\n)', 'variables': ['hiringevents-2', 'jobapplicationcreationevents-2'], '__typename': 'Metric'}, {'id': 'average-cycle-time-643', 'name': 'Average cycle time', 'description': 'Average cycle time calculated from the first to the last event', 'signalFragment': 'AVG((SELECT LAST(end_time)) - (SELECT FIRST(end_time)))', 'variables': [], '__typename': 'Metric'}], 'metricVariables': [{'id': 'offerextendedevents-2', 'name': 'offer_extended_events', 'description': "List of events indicating that the job offer has been extended to the candidate, e.g. 'Offer Extended'", 'value': None, '__typename': 'MetricVariable'}, {'id': 'jobreqstatusopen-2', 'name': 'job_req_status_open', 'description': "List of Job Requisition status entries that indicate a Job Requisition is still open, e.g. 'Open'", 'value': "'Open'", '__typename': 'MetricVariable'}, {'id': 'jobrequisitioncreationevents-2', 'name': 'job_requisition_creation_events', 'description': "List of events indicating that the job requisition was created, e.g. 'Create Job Requisition'", 'value': "'Create Job Requisition'", '__typename': 'MetricVariable'}, {'id': 'hiringmanagerhiredevents-2', 'name': 'hiring_manager_hired_events', 'description': "List of events indicating that the candidate has been selected by the hiring manager, e.g. 'Prepare Offer'", 'value': None, '__typename': 'MetricVariable'}, {'id': 'hiringevents-2', 'name': 'hiring_events', 'description': "List of eve ...
# 7 30 Process: 00_DEMO - Inspect-to-Quality for SAP S/4 HANA (DO NOT CHANGE) d: 2 i: 0 m: 13
#      View from DashBoards {'defaultview-525'}
# Process: 00_DEMO - Inspect-to-Quality for SAP S/4 HANA (DO NOT CHANGE) 2 Dashboards {'data': {'dashboards': [{'access': 'PRIVATE', 'id': 'sap-s4hana---inspect-to-quali-1', 'name': 'SAP S/4HANA - Inspect to Quality', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-525'}}, {'access': 'ANYONE_VIEW', 'id': 'itq-overview-dashboard-3', 'name': '00_Overview', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-525'}}]}}
# Process: 00_DEMO - Inspect-to-Quality for SAP S/4 HANA (DO NOT CHANGE) 13  Metrics {'data': {'metrics': [{'id': 'result-recording-cycle-time-1', 'name': 'Result recording cycle time', 'description': 'Time from begin to complete result recording', 'signalFragment': "AVG(\n\t(SELECT FIRST(end_time) FILTER(\n\tWHERE event_name = 'Complete Result Recording'))\n\t-\n\t(SELECT LAST(end_time) FILTER(\n\tWHERE event_name='Begin Result Recording'))\n\t)", 'variables': [], '__typename': 'Metric'}, {'id': 'result-recording-to-usage-dec-1', 'name': 'Result recording to usage decision lead time', 'description': 'Time from complete result recording to create usage decision', 'signalFragment': "AVG(\n\t(SELECT FIRST(end_time) FILTER(\n\tWHERE event_name='Create Usage Decision'))\n\t-\n\t(SELECT LAST(end_time) FILTER(\n\tWHERE event_name = 'Complete Result Recording'))\n\t)", 'variables': [], '__typename': 'Metric'}, {'id': 'rejected-usage-decisions-rate-2', 'name': 'Rejected usage decisions rate', 'description': 'Percentage of rejected usage decisions', 'signalFragment': 'COUNT(case_id) FILTER (\n WHERE\n(SELECT COUNT(event_name) WHERE ("UD Code" = \'R\')) > 0\n\t AND event_name MATCHES (\'Create Usage Decision\')\n) /\n  COUNT(case_id) FILTER (\n\t WHERE event_name MATCHES (\'Create Usage Decision\'))*100', 'variables': [], '__typename': 'Metric'}, {'id': 'cases-with-free-and-restricte-7', 'name': 'Cases with free and restricted material movement', 'description': 'Number of cases with both free and restricted material movement', 'signalFragment': "COUNT (CASE_ID) FILTER (\n WHERE EVENT_NAME MATCHES ('Material Movement Free')\n AND EVENT_NAME MATCHES ('Material Movement Restricted')) \n", 'variables': [], '__typename': 'Metric'}, {'id': 'number-of-delayed-inspections-4', 'name': 'Number of delayed inspections', 'description': 'Number of cases where create usage decision accrued after the planned inspection end date', 'signalFragment': 'COUNT(case_id) FILTER(\nWHERE ("Planned Inspection End Date"<\n\t  (SELECT LAST(END_TIME) FILTER (\n WHERE EVENT_NAME IN (\'Create Usage Decision\')))))\n', 'variables': [], '__typename': 'Metric'}, {'id': 'restricted-material-movement--6', 'name': 'Restricted material movement rate', 'description': 'Percentage of cases with restricted material movement', 'signalFragment': "COUNT (event_name) FILTER (\n\tWHERE event_name IN ('Material Movement Restricted')\n )\n /\nCOUNT (event_name) FILTER (\n\tWHERE event_name ILIKE 'Material Movement%'\n)\n*100", 'variables': [], '__typename': 'Metric'}, {'id': 'free-material-movement-rate-6', 'name': 'Free material movement rate', 'description': 'Percentage of cases with free material movement', 'signalFragment': "COUNT (event_name) FILTER (\n\tWHERE event_name IN ('Material Movement Free')\n )\n/\nCOUNT (event_name) FILTER (\n\tWHERE event_name ILIKE 'Material Movement%'\n)\n*100", 'variables': [], '__typename': 'Metric'}, {'id': 'automation-rate-material-move-2', 'name': 'Automation rate material movement', 'description': 'Percentage of automated material movement events', 'signalFragment': 'SUM((SELECT\n\tCOUNT(event_name) FILTER (\n\t\tWHERE ((${itq_automation_condition})\n\t\tAND event_name ILIKE \'Material Movement%\'\n\t)))) / \nSUM((SELECT\n\tCOUNT(event_name) FILTER (\n    \tWHERE ("Event Created By User Type" IS NOT NULL)\n\t\tAND event_name ILIKE \'Material Movement%\'))\n) * 100', 'variables': ['itqautomationcondition-1'], '__typename': 'Metric'}, {'id': 'average-cycle-time-of-delayed-2', 'name': 'Average cycle time of delayed inspections', 'description': 'Average cycle time of cases where usage decision accrued after the planned Inspection end date', 'signalFragment': '\tAVG(\n\t\t(SELECT LAST(END_TIME) FILTER (\n \t\t WHERE EVENT_NAME IN (\'Create Usage Decision\')))\n\t\t\t-"Planned Inspection End Date"\n\t) FILTER(\n\t  \t\tWHERE("Planned Inspection End Date"<\n\t\t\t\t(SELECT LAST(END_TIME) FILTER (\n \t\tWHERE EVENT_NAME IN (\'Create Usage Decision\'))\n\ ...
# 8 30 Process: 00_DEMO - Invoice-to-Cash for SAP S/4 HANA (DO NOT CHANGE) d: 3 i: 3 m: 63
#      View from DashBoards {'defaultview-59'}
# Process: 00_DEMO - Invoice-to-Cash for SAP S/4 HANA (DO NOT CHANGE) 3 Dashboards {'data': {'dashboards': [{'access': 'ANYONE_VIEW', 'id': 'new-db-1', 'name': 'Process Overview ', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-59'}}, {'access': 'ANYONE_VIEW', 'id': 'agnostic---overview-dashboard-3', 'name': 'Agnostic - Overview', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-59'}}, {'access': 'PRIVATE', 'id': 'sap-s4hana---invoice-to-cash-1', 'name': 'SAP S/4HANA - Invoice to Cash', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-59'}}]}}
#      View from Investigations {'defaultview-59'}
# Process: 00_DEMO - Invoice-to-Cash for SAP S/4 HANA (DO NOT CHANGE) 3 Investigations {'data': {'subject': {'id': 'demo---itc-sap-s4-hana-do-not-1', 'name': '00_DEMO - Invoice-to-Cash for SAP S/4 HANA (DO NOT CHANGE)', 'investigationCount': 3, 'investigations': [{'id': 'itc-metrics-testing-1', 'name': 'ITC Metrics testing', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-59'}}, {'id': 'demo-itc-1', 'name': 'Demo ITC', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-59'}}, {'id': 'invoice-to-cash-1', 'name': 'Invoice-to-Cash', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-59'}}]}}}
# Process: 00_DEMO - Invoice-to-Cash for SAP S/4 HANA (DO NOT CHANGE) 63  Metrics {'data': {'metrics': [{'id': 'total-overdue-invoice-amounts-9', 'name': 'Total overdue invoice amounts', 'description': 'Sum of all invoice amounts that are open and overdue (converted to USD)', 'signalFragment': "SUM(${itp_amount_conv}) FILTER(\n\t WHERE (${itp_clearing_date} IS NULL)\n\t\tAND ${itp_due_date} < DATE_TRUNC('day', NOW()))", 'variables': ['itpamountconv-1', 'itpclearingdate-1', 'itpduedate-1'], '__typename': 'Metric'}, {'id': 'percentage-of-reversed-invoic-3', 'name': 'Percentage of reversed invoices', 'description': 'Percentage of invoices that were reversed', 'signalFragment': 'COUNT(case_id) FILTER (\n\tWHERE event_name MATCHES(${itc_invoice_reversal_events}))\n/\nCOUNT(case_id)\n* 100', 'variables': ['itcinvoicereversalevents-3'], '__typename': 'Metric'}, {'id': 'percentage-of-baseline-date-c-1', 'name': 'Percentage of baseline date changes', 'description': 'Percentage of Baseline Date Changes after the Invoice was posted to SAP', 'signalFragment': 'COUNT(case_id) FILTER (\n\tWHERE event_name MATCHES(${itc_change_baseline_date})\n\t\tAND event_name MATCHES(${itc_posting_to_baseline_update_events}))\n/\nCOUNT(case_id)\n* 100', 'variables': ['itcchangebaselinedate-1', 'itcpostingtobaselineupdateeve-1'], '__typename': 'Metric'}, {'id': 'early-payment-rate-5', 'name': 'Early payment rate', 'description': 'Percentage of invoices that were cleared more than 5 days before their due dates', 'signalFragment': 'COUNT(case_id) FILTER (\n\tWHERE (${itc_due_date} - ${itc_clearing_date} \n\t\t> DURATION ${itc_early_payment_condition})\n)\n/COUNT(case_id) FILTER (\n\tWHERE (${itc_clearing_date} IS NOT NULL)\n)* 100', 'variables': ['itcduedate-1', 'itcclearingdate-1', 'itcearlypaymentcondition-3'], '__typename': 'Metric'}, {'id': 'invoices-without-billing-doc--1', 'name': 'Invoices without billing doc from SO', 'description': 'Invoices without Billing Document from Sales Order', 'signalFragment': 'COUNT(case_id) FILTER (\n\tWHERE event_name MATCHES(NOT ${itc_billing_doc_to_invoice_events})\n)', 'variables': ['itcbillingdoctoinvoiceevents-1'], '__typename': 'Metric'}, {'id': 'no-touch-invoice-processing-r-3', 'name': 'No-Touch invoice processing rate', 'description': 'Percentage of invoices with no change events', 'signalFragment': 'COUNT(case_id) FILTER (\n\tWHERE NOT (event_name MATCHES(${itc_no_touch_condition})) \n\t\tAND (event_name MATCHES(${itc_clear_invoice_events}))\n)\n/ (COUNT(case_id) FILTER (\n\tWHERE event_name MATCHES(${itc_clear_invoice_events}))\n\t)\n* 100', 'variables': ['itcnotouchcondition-2', 'itcclearinvoiceevents-3'], '__typename': 'Metric'}, {'id': 'on-time-payment-rate-4', 'name': 'On-time payment rate', 'description': 'Percentage of invoices that were cleared less than 5 days before and no later than 1 day after their due dates', 'signalFragment': 'COUNT(case_id) FILTER (\n\tWHERE (${itc_clearing_date} - ${itc_due_date} \n\t\t> DURATION ${itc_late_payment_condition}\n\tAND ${itc_due_date} - ${itc_clearing_date}\n\t\t< DURATION ${itc_early_payment_condition}\n\t)\n)\n/\nCOUNT(case_id) FILTER (\n\tWHERE (${itc_clearing_date}IS NOT NULL)\n)\n* 100', 'variables': ['itcclearingdate-1', 'itcduedate-1', 'itclatepaymentcondition-3', 'itcearlypaymentcondition-3'], '__typename': 'Metric'}, {'id': 'duration-of-dunning-blocks-1', 'name': 'Duration of dunning blocks', 'description': 'Average lead time from setting a dunning block to removing the last dunning block', 'signalFragment': 'AVG(\n\t(SELECT LAST(end_time) FILTER \n\t\t(WHERE event_name IN (${itc_remove_dunning_block_events})))\n\t-\n\t(SELECT FIRST(end_time) FILTER\n\t\t(WHERE event_name IN (${itc_set_dunning_block_events})))\n)', 'variables': ['itcremovedunningblockevents-1', 'itcsetdunningblockevents-1'], '__typename': 'Metric'}, {'id': 'automation-rate-for-invoice-c-3', 'name': 'Automation rate for invoice clearing', 'description': 'Percentage of automated invoice clear ...
# 9 30 Process: 00_DEMO - Invoice-to-Pay for SAP S/4 HANA (DO NOT CHANGE) d: 6 i: 0 m: 10
#      View from DashBoards {'defaultview-133'}
# Process: 00_DEMO - Invoice-to-Pay for SAP S/4 HANA (DO NOT CHANGE) 6 Dashboards {'data': {'dashboards': [{'access': 'PRIVATE', 'id': 'automation-42', 'name': 'Automation', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-133'}}, {'access': 'PRIVATE', 'id': 'payment-behaviour-6', 'name': 'Payment Behaviour', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-133'}}, {'access': 'PRIVATE', 'id': 'open-overdue-invoices-31', 'name': 'Open Overdue Invoices', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-133'}}, {'access': 'PRIVATE', 'id': 'payment-terms-2', 'name': 'Payment Terms', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-133'}}, {'access': 'PRIVATE', 'id': 'cycle-times-36', 'name': 'Cycle Times', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-133'}}, {'access': 'PRIVATE', 'id': '00overview-21', 'name': '00_Overview', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-133'}}]}}
# Process: 00_DEMO - Invoice-to-Pay for SAP S/4 HANA (DO NOT CHANGE) 10  Metrics {'data': {'metrics': [{'id': 'late-payment-rate-75', 'name': 'Late payment rate', 'description': 'Percentage of cases with late payments. Only cases that are paid are considered.', 'signalFragment': 'COUNT(case_id) FILTER (\n\tWHERE (${late_payment_condition})\n\t)\n/ COUNT(case_id) FILTER (\n\tWHERE (${invoice_clearing_date} IS NOT NULL)\n\t)\n* 100', 'variables': ['latepaymentcondition-9', 'invoiceclearingdate-10'], '__typename': 'Metric'}, {'id': 'percentage-of-reversed-invoic-7', 'name': 'Percentage of reversed invoices', 'description': "Percentage of invoices that were reversed counted for example by the number of 'Reverse Invoice' events", 'signalFragment': 'COUNT(case_id) FILTER (\n\tWHERE event_name MATCHES(${itp_invoice_reversal_events}))\n/\nCOUNT(case_id)\n* 100', 'variables': ['itpinvoicereversalevents-3'], '__typename': 'Metric'}, {'id': 'two-way-match-rate-13', 'name': 'Two-way match rate', 'description': 'Percentage of cases where the invoice amount equals the purchase order net order value', 'signalFragment': 'COUNT(case_id) FILTER (\n\tWHERE (${itp_two_way_match_condition})\n\t)\n/ COUNT(case_id)\n* 100', 'variables': ['itptwowaymatchcondition-3'], '__typename': 'Metric'}, {'id': 'price-difference-on-the-invoi-4', 'name': 'Price difference on the invoice compared to the purchase order', 'description': 'Number of invoices with different prices compared to the purchase order', 'signalFragment': 'COUNT(case_id) FILTER (\n\tWHERE (${itp_different_price_condition}))', 'variables': ['itpdifferentpricecondition-3'], '__typename': 'Metric'}, {'id': 'payment-terms-differences-3', 'name': 'Payment Terms Differences', 'description': 'Number of invoices for which the payment terms on the invoice differ from the payment terms on the purchase order', 'signalFragment': 'COUNT(case_id) FILTER(\n\tWHERE (${itp_invoice_payment_terms}) \n\t\t<> (CASE WHEN ${itp_purchase_order_payment_terms} IS NULL THEN 0 \n\tELSE ${itp_purchase_order_payment_terms} END))', 'variables': ['itpinvoicepaymentterms-3', 'itppurchaseorderpaymentterms-3'], '__typename': 'Metric'}, {'id': 'total-overdue-invoice-amounts-12', 'name': 'Total overdue invoice amounts', 'description': 'Sum of all invoice amounts that are open and overdue (converted to USD)', 'signalFragment': "SUM(${itp_amount_conv}) FILTER(\n\t WHERE (${itp_clearing_date} IS NULL)\n\t\tAND ${itp_due_date} < DATE_TRUNC('day', NOW()))", 'variables': ['itpamountconv-4', 'itpclearingdate-4', 'itpduedate-4'], '__typename': 'Metric'}, {'id': 'ratio-of-overdue-invoices-3', 'name': 'Ratio of overdue invoices', 'description': 'Percentage of overdue invoices from all open invoices', 'signalFragment': "COUNT (case_id) FILTER (\n\tWHERE (${itp_clearing_date} IS NULL AND ${itp_due_date} < DATE_TRUNC('day', NOW()))\n\t)\n/ COUNT (case_id) FILTER(\n\tWHERE (${itp_clearing_date} IS NULL)) * 100", 'variables': ['itpclearingdate-4', 'itpduedate-4'], '__typename': 'Metric'}, {'id': 'percentage-of-baseline-date-c-4', 'name': 'Percentage of baseline date changes', 'description': 'Percentage of Baseline Date Changes after the Invoice was posted', 'signalFragment': 'COUNT(case_id) FILTER (\n\tWHERE event_name MATCHES(${itp_change_baseline_date})\n\t\tAND event_name MATCHES(${itp_posting_to_baseline_update_events}))\n/\nCOUNT(case_id)\n* 100', 'variables': ['itpchangebaselinedate-3', 'itppostingtobaselineupdateeve-3'], '__typename': 'Metric'}, {'id': 'number-of-open-overdue-invoic-6', 'name': 'Number of open overdue invoices', 'description': 'Number of invoices that are currently open and overdue', 'signalFragment': "COUNT(case_id) FILTER (\n\tWHERE (${itp_clearing_date} IS NULL)\n\t\tAND ${itp_due_date} < DATE_TRUNC('day', NOW()))", 'variables': ['itpclearingdate-4', 'itpduedate-4'], '__typename': 'Metric'}, {'id': 'average-cycle-time-130', 'name': 'Average cycle time', 'description': 'Average cycle time calculated from the first to the ...
# 10 30 Process: 00_DEMO Issue-to-Resolution for Jira d: 1 i: 2 m: 36
#      View from DashBoards {'defaultview-370'}
# Process: 00_DEMO Issue-to-Resolution for Jira 1 Dashboards {'data': {'dashboards': [{'access': 'ANYONE_VIEW', 'id': 'jira-issue-to-resolution-dash-16', 'name': '00_Overview', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-370'}}]}}
#      View from Investigations {'defaultview-370'}
# Process: 00_DEMO Issue-to-Resolution for Jira 2 Investigations {'data': {'subject': {'id': '00demo-jira-issue-to-resoluti-1', 'name': '00_DEMO Issue-to-Resolution for Jira', 'investigationCount': 2, 'investigations': [{'id': 'test-144', 'name': 'Issue-to-Resolution', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-370'}}, {'id': 'issue-to-resolution-copy-3', 'name': 'Issue-to-Resolution (Copy)', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-370'}}]}}}
# ...
#      View from Investigations {'defaultview-225'}
# Process: [0]_Dashboards_ITP Process 1 Investigations {'data': {'subject': {'id': '01demo-dashboardsitp-process-1', 'name': '[0]_Dashboards_ITP Process', 'investigationCount': 1, 'investigations': [{'id': 'event-lvl-metrics-test-1', 'name': 'Event lvl metrics test', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-225'}}]}}}
# Process: [0]_Dashboards_ITP Process 40  Metrics {'data': {'metrics': [{'id': 'wc-impact-of-invoices-with-im-3', 'name': 'WC Impact of Invoices with immediate payment terms', 'description': 'Amount of invoices where the payment terms (BSEG.ZBD1T) are 0 or NULL', 'signalFragment': 'SUM("Inv. Converted USD Amount") FILTER(\n\tWHERE ${itp_cash_discount_terms} IS NULL\n\t\tOR ${itp_cash_discount_terms} = 0) *15*0.04/365', 'variables': ['itpcashdiscountterms1-1'], '__typename': 'Metric'}, {'id': 'payment-terms-differences-whe-6', 'name': 'Payment Terms Differences where PO is better (Median)', 'description': 'Number of invoices for which the payment terms on the invoice differ from the payment terms on the purchase order', 'signalFragment': 'AVG("PO Cash Discount Days 1"-"Last FI Invoice Item Cash Discount Days 1") FILTER(\n\tWHERE ("Last FI Invoice Item Cash Discount Days 1") \n\t\t< (CASE WHEN "PO Cash Discount Days 1" IS NULL THEN 0 \n\tELSE "PO Cash Discount Days 1" END))', 'variables': ['itpinvoicepaymentterms1-1', 'itppurchaseorderpaymentterms1-1'], '__typename': 'Metric'}, {'id': 'payment-terms-differences-whe-7', 'name': 'Payment Terms Differences where PO is better (Amount)', 'description': 'Number of invoices for which the payment terms on the invoice differ from the payment terms on the purchase order', 'signalFragment': 'SUM("Last FI Invoice Item Gross Amount in USD") FILTER(\n\tWHERE ("Last FI Invoice Item Cash Discount Days 1") \n\t\t< (CASE WHEN "PO Cash Discount Days 1" IS NULL THEN 0 \n\tELSE "PO Cash Discount Days 1" END))', 'variables': ['itpinvoicepaymentterms1-1', 'itppurchaseorderpaymentterms1-1'], '__typename': 'Metric'}, {'id': 'invoices-with-immediate-payme-13', 'name': 'Invoices with immediate payment terms_1', 'description': 'Number of invoices where the payment terms (BSEG.ZBD1T) are 0 or NULL', 'signalFragment': 'COUNT("Last FI Invoice ID") FILTER(\n\tWHERE ${itp_cash_discount_terms} IS NULL\n\t\tOR ${itp_cash_discount_terms} = 0)', 'variables': ['itpcashdiscountterms1-1'], '__typename': 'Metric'}, {'id': 'automation-rate-over-events-8', 'name': 'Automation rate over events', 'description': 'Percentage of automated events', 'signalFragment': 'count(event_name) FILTER \n(WHERE (${automation_condition})) \n/ count(event_name) * 100', 'variables': ['automationcondition-17'], '__typename': 'Metric'}, {'id': 'number-of-open-accounts-recei-4', 'name': 'Number of open accounts receivable documents (with time frame)', 'description': 'Number of accounts receivable documents open for longer than a certain time frame', 'signalFragment': 'COUNT(DISTINCT "ARUniqueKey") FILTER (\n\tWHERE\n\t\tevent_name = \'Create Accounts Receivable\'\n\t\tAND "ClearingDate" IS NULL\n\t\tAND (NOW()-"DocumentDate")> DURATION ${p2c_s4hc_open_ar_period}\n\t)', 'variables': ['p2cs4hcopenarperiod-1'], '__typename': 'Metric'}, {'id': 'automation-rate-90', 'name': 'Automation rate', 'description': 'Percentage of automated events', 'signalFragment': 'SUM(\n\t(SELECT COUNT(event_name) FILTER (\n\t\tWHERE (${automation_condition}))\n\t)\n   )\n/ SUM((SELECT COUNT(event_name)))\n* 100', 'variables': ['automationcondition-17'], '__typename': 'Metric'}, {'id': 'time-savings-due-to-automatio-28', 'name': 'Time savings due to automation', 'description': 'Difference between the average cycle time of automated and manual activities in the process', 'signalFragment': '(AVG((SELECT last(end_time)) - (SELECT first(end_time))) \n\tFILTER (WHERE (SELECT BOOL_OR(${automation_condition}))))\n-\n(AVG((SELECT last(end_time)) - (SELECT first(end_time))) \n\tFILTER (WHERE (SELECT BOOL_OR(${manual_condition}))))', 'variables': ['automationcondition-17', 'manualcondition-10'], '__typename': 'Metric'}, {'id': 'process-compliance-14', 'name': 'Process compliance', 'description': 'Percentage of compliant Procure-to-Pay cases', 'signalFragment': 'COUNT(case_id) FILTER (\n\tWHERE event_name MATCHES(${ptp_compliant_event_sequence})\n\t)\n/ COUNT(case_id)\n* 100', 'vari ...
# 28 30 Process: 0_demo_accelerators_generic (PTP S4H, changes allowed) d: 3 i: 2 m: 31
#      View from DashBoards {'defaultview-288'}
# Process: 0_demo_accelerators_generic (PTP S4H, changes allowed) 3 Dashboards {'data': {'dashboards': [{'access': 'PRIVATE', 'id': 'cycle-time-dashboard-6', 'name': 'Cycle Time Dashboard', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-288'}}, {'access': 'PRIVATE', 'id': 'po-late-payments-historical-a-9', 'name': 'PO Late Payments (Historical Analysis)', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-288'}}, {'access': 'PRIVATE', 'id': 'overview-dashboard-15', 'name': 'Overview Dashboard', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-288'}}]}}
#      View from Investigations {'defaultview-288'}
# Process: 0_demo_accelerators_generic (PTP S4H, changes allowed) 2 Investigations {'data': {'subject': {'id': 'hs-163-demo-1', 'name': '0_demo_accelerators_generic (PTP S4H, changes allowed)', 'investigationCount': 2, 'investigations': [{'id': 'hs-pi-academy--1', 'name': 'HS pi academy ', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-288'}}, {'id': 'overview-92', 'name': 'overview', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-288'}}]}}}
# Process: 0_demo_accelerators_generic (PTP S4H, changes allowed) 31  Metrics {'data': {'metrics': [{'id': 'cancellation-of-goods-receipt-16', 'name': 'Cancellation of Goods Receipts', 'description': 'Total number of cases in which a Goods Receipt has been reversed', 'signalFragment': 'COUNT(case_id) FILTER (\n\tWHERE (event_name MATCHES(${goods_receipt_reversal_events}))\n\tAND (event_name MATCHES(${goods_receipt_events}))\n\t)', 'variables': ['goodsreceiptreversalevents-10', 'goodsreceiptevents-13'], '__typename': 'Metric'}, {'id': 'maverick-buying---prices-chan-16', 'name': 'Maverick Buying - Prices Changes after Goods Receipt', 'description': 'Total number of cases with price changes that happened after the Goods Receipt had already been registered', 'signalFragment': 'COUNT(case_id) FILTER (\n\tWHERE event_name MATCHES(${ptp_maverick_buying_condition})\n\t)\n/ COUNT(case_id) * 100', 'variables': ['ptpmaverickbuyingcondition-4'], '__typename': 'Metric'}, {'id': 'average-processing-time-for-p-25', 'name': 'Average processing time for purchase orders', 'description': 'Average time from the creation of a purchase order to its acknowledgment', 'signalFragment': 'AVG(\n\t(SELECT LAST(end_time)\n\t\tWHERE event_name IN (${po_acknowledgement_events}))\n\t-(SELECT FIRST(end_time)\n\t\tWHERE event_name IN (${po_creation_events}))\n   )', 'variables': ['poacknowledgementevents-16', 'pocreationevents-18'], '__typename': 'Metric'}, {'id': 'overdue-deliveries-rate-15', 'name': 'Overdue deliveries rate', 'description': 'Percentage of cases with overdue deliveries. Only cases that have not been (completely) delivered yet are considered.', 'signalFragment': 'COUNT(case_id) FILTER (\n\tWHERE ${overdue_delivery_condition}\n\t)\n/\nCOUNT(case_id) FILTER (\n\tWHERE (${delivery_completed_condition}) IS NULL\n\t)\n* 100', 'variables': ['overduedeliverycondition-10', 'deliverycompletedcondition-10'], '__typename': 'Metric'}, {'id': 'payment-block-rate-25', 'name': 'Payment block rate', 'description': 'Percentage of cases in which a payment block was set', 'signalFragment': 'COUNT(case_id) FILTER (\n\tWHERE (SELECT FIRST(event_name) FILTER (\n\t\t\tWHERE event_name IN (${payment_block_events}))) IS NOT NULL\n\t)\n/ COUNT(case_id)\n* 100', 'variables': ['paymentblockevents-10'], '__typename': 'Metric'}, {'id': 'average-time-from-purchase-or-20', 'name': 'Average time from purchase order to delivery', 'description': 'Average time from purchase order to goods receipt', 'signalFragment': 'AVG(\n\t(SELECT LAST(end_time)\n\t\tWHERE event_name IN (${goods_receipt_events}))\n\t-(SELECT FIRST(end_time)\n\t\tWHERE event_name IN (${po_creation_events}))\n   )', 'variables': ['goodsreceiptevents-13', 'pocreationevents-18'], '__typename': 'Metric'}, {'id': 'po-item-changes-rate-12', 'name': 'PO Item changes rate', 'description': 'Percentage of cases with PO Item changes', 'signalFragment': 'COUNT(case_id) FILTER (\n\tWHERE (event_name MATCHES(${po_change_event_flow})))\n\t/\n\tCOUNT(case_id) FILTER (\n\tWHERE (event_name MATCHES(${po_creation_events}))\n\t)\n\t* 100', 'variables': ['pochangeeventflow-11', 'pocreationevents-18'], '__typename': 'Metric'}, {'id': 'missed-discounts-12', 'name': 'Missed discounts', 'description': 'Total amount of discounts missed due to late payments', 'signalFragment': 'SUM(\n\t((${total_invoice_amount}) * (${discount_percentage}))\n\t-(${discount_applied_to_invoice})\n   )', 'variables': ['totalinvoiceamount-10', 'discountpercentage-10', 'discountappliedtoinvoice-10'], '__typename': 'Metric'}, {'id': 'pos-created-after-invoice-rec-15', 'name': 'POs created after Invoice Receipt', 'description': 'Total number of cases in which a PO Item has been created after the Invoice Receipt event', 'signalFragment': 'COUNT(case_id) FILTER\n\t(WHERE (event_name MATCHES(${po_created_after_invoice_receipt})))', 'variables': ['pocreatedafterinvoicereceipt-10'], '__typename': 'Metric'}, {'id': 'cancellation-rate-of-purchase-14', 'name': 'Cancellati ...
# 29 30 Process: [NK] Show&Tell - ITP Dashboards d: 1 i: 0 m: 1
#      View from DashBoards {'defaultview-362'}
# Process: [NK] Show&Tell - ITP Dashboards 1 Dashboards {'data': {'dashboards': [{'access': 'PRIVATE', 'id': '04-payment-behaviour-3', 'name': '[04] Payment Behaviour', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-362'}}]}}
# Process: [NK] Show&Tell - ITP Dashboards 1  Metrics {'data': {'metrics': [{'id': 'average-cycle-time-493', 'name': 'Average cycle time', 'description': 'Average cycle time calculated from the first to the last event', 'signalFragment': 'AVG((SELECT LAST(end_time)) - (SELECT FIRST(end_time)))', 'variables': [], '__typename': 'Metric'}], 'metricVariables': []}}
# 30 30 Process: [SIGPIA-2936] Dashboard_PTP_Ariba d: 5 i: 2 m: 12
#      View from DashBoards {'defaultview-545'}
# Process: [SIGPIA-2936] Dashboard_PTP_Ariba 5 Dashboards {'data': {'dashboards': [{'access': 'PRIVATE', 'id': 'automation-dashboard-12', 'name': 'Automation Dashboard', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-545'}}, {'access': 'PRIVATE', 'id': 'cycle-time-dashboard-11', 'name': 'Cycle Time Dashboard', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-545'}}, {'access': 'PRIVATE', 'id': 'overview-dashboard-46', 'name': '00_Overview Dashboard', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-545'}}, {'access': 'PRIVATE', 'id': '04-payment-behaviour-7', 'name': 'Payment Behaviour', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-545'}}, {'access': 'PRIVATE', 'id': 'sap-ariba-ptp----dashboard-ex-2', 'name': 'Spend Analysis', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-545'}}]}}
#      View from Investigations {'defaultview-545'}
# Process: [SIGPIA-2936] Dashboard_PTP_Ariba 2 Investigations {'data': {'subject': {'id': 'sm-ptpariba-1', 'name': '[SIGPIA-2936] Dashboard_PTP_Ariba', 'investigationCount': 2, 'investigations': [{'id': 'test-183', 'name': 'Test', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-545'}}, {'id': 'saparibaptp-3', 'name': 'SAP_ARIBA_PTP', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-545'}}]}}}
# Process: [SIGPIA-2936] Dashboard_PTP_Ariba 12  Metrics {'data': {'metrics': [{'id': 'po-spend-per-supplier-in-arib-6', 'name': 'PO spend per supplier in Ariba', 'description': 'Average PO spend transacted with supplier on Ariba', 'signalFragment': 'SUM("PO Item Amount (INR)" ) / (COUNT( DISTINCT "PO Item Supplier ID" )) \n   ', 'variables': [], '__typename': 'Metric'}, {'id': '-of-po-spend-created-from-con-6', 'name': '% of PO spend created from Contracts, Catalog and Blanket Purchase Order', 'description': 'PO spend associated with Contracts, Catalog and Blanket Purchase Order as a % of total spend originating from Ariba', 'signalFragment': '(\n  SUM("PO Item Amount (INR)") FILTER ( \n      WHERE "PO Item Contract ID" IS NOT NULL\n      AND "PO Item Line Type" IN (\'Catalog\' , \'NonCatalog\')\n      ) \n  +\n  SUM("PO Item Amount (INR)") FILTER ( \n      WHERE "PO Item Contract ID" IS NULL\n      AND "PO Item Line Type" = \'Catalog\'\n      ) \n)\n/   \nSUM("PO Item Amount (INR)") FILTER (\n  \tWHERE "PO Item Line Type" IN (\'Catalog\' , \'NonCatalog\')    \t\n\t)    \n* 100    ', 'variables': [], '__typename': 'Metric'}, {'id': '-of-po-spend-on-contracts-2', 'name': '% of PO spend on Contracts', 'description': 'PO spend associated with contract as a % of total spend originating from Ariba', 'signalFragment': 'SUM("PO Item Amount (INR)") FILTER ( \n\tWHERE "PO Item Contract ID" IS NOT NULL\n\t) \n/   \nSUM("PO Item Amount (INR)") FILTER (\n  \tWHERE "PO Item Line Type" IN (\'Catalog\' , \'NonCatalog\')    \t\n\t)     \n* 100   ', 'variables': [], '__typename': 'Metric'}, {'id': 'process-compliance-42', 'name': 'Process compliance', 'description': 'Percentage of compliant Procure-to-Pay cases', 'signalFragment': 'COUNT(case_id) FILTER (\n\tWHERE event_name MATCHES(${ptp_compliant_event_sequence})\n\t)\n/ COUNT(case_id)\n* 100', 'variables': ['ptpcomplianteventsequence-25'], '__typename': 'Metric'}, {'id': '-of-po-spend-on-non-catalog-3', 'name': '% of PO Spend on Non Catalog', 'description': 'PO spend associated with non catalog as a % of total spend originating from Ariba', 'signalFragment': 'SUM("PO Item Amount (INR)") FILTER (\n  \tWHERE "PO Item Line Type" = \'NonCatalog\'\n\t) \n/   \nSUM("PO Item Amount (INR)") \n* 100   ', 'variables': [], '__typename': 'Metric'}, {'id': 'average-invoice-payment-time-119', 'name': 'Average invoice payment time', 'description': 'Average time to clear invoices', 'signalFragment': 'AVG(\n\t(SELECT LAST(end_time)\n\t\tWHERE event_name IN (${invoice_clearing_events}))\n\t-(SELECT FIRST(end_time)\n\t\tWHERE event_name IN (${invoice_receipt_events}))\n   )', 'variables': ['invoiceclearingevents-27', 'invoicereceiptevents-27'], '__typename': 'Metric'}, {'id': '-of-po-spend-on-catalog-3', 'name': '% of PO Spend on Catalog', 'description': 'PO spend associated with non catalog as a % of total spend originating from Ariba', 'signalFragment': 'SUM("PO Item Amount (INR)") FILTER (\n  \tWHERE "PO Item Line Type" = \'Catalog\'\n\t) \n/   \nSUM("PO Item Amount (INR)") \n* 100   ', 'variables': [], '__typename': 'Metric'}, {'id': 'average-ariba-approval-invoic-7', 'name': 'Average Ariba Approval Invoice Cycle Time in Days', 'description': 'Average Time Taken from Invoice Submission to Invoice Approval\u200b', 'signalFragment': "AVG(\n\t(SELECT LAST(end_time)\n\t\tWHERE event_name = 'Approve Invoice'\t\n    )\n\t- ( SELECT FIRST(end_time)\n\t\tWHERE event_name = 'Receive invoice' \n     )\n)\n     \n", 'variables': [], '__typename': 'Metric'}, {'id': 'average-confirmation-time-for-68', 'name': 'Average confirmation time for purchase requisitions', 'description': 'Average time needed to confirm a purchase requisition by creating a purchase order', 'signalFragment': 'AVG(\n\t(SELECT LAST(end_time)\n\t\tWHERE event_name IN (${po_creation_events}))\n\t-(SELECT FIRST(end_time)\n\t\tWHERE event_name IN (${pr_creation_events}))\n   )', 'variables': ['pocreationevents-33', 'prcreationevents-29'], '__typename':  ...
# Workspace name: Solutions Demo Workspace
# N processes 30. Dashboards: 121. Investigations 42. Metrics: 653

# %% [markdown]
# ### Statistics from the above cells

# %%
workspace_name="Process AI"
print(f'Workspace name: {workspace_name}')
print(f'N processes {len(list_processes_1)}. Dashboards: {ndash_1}. Investigations {ninvs_1}. Metrics: {nmtrx_1}')
workspace_name="Solutions Demo Workspace"
print(f'Workspace name: {workspace_name}')
print(f'N processes {len(list_processes)}. Dashboards: {ndash}. Investigations {ninvs}. Metrics: {nmtrx}')
# Out:
# Workspace name: Process AI
# N processes 7. Dashboards: 3. Investigations 6. Metrics: 186
# Workspace name: Solutions Demo Workspace
# N processes 30. Dashboards: 121. Investigations 42. Metrics: 653

# %% [markdown]
# ## Step 3. Get Files here we run API call to download the dashboards, investigations metrics JSON files from Signavio UI
#
# In the above step we get lists of all available Dashboards/Investigations and Metrics in a given workspace and put  them to **all_json** JSON.
# Here we upload and save the content of all these items in json format in the SAME **all_json** JSON.
#
# We save all of them also in fs as  **"all_json_WORKSPACENAME_DATE.json"** and al respective dashboards, investigations, metrics.
# e.g for workspace_name="Solutions Demo Workspace":
#
# Dumping all extracted Dashboards, Investigations, Metrics data to ../data/all_json_Solutions_Demo_Workspace_2023-12-01T07_54_49.json
#
# ```js
# data
# ├── [0]_Dashboards_ITP\ Process
# │   │   ├── dashboards
# │   │   │   ├── 00_Empty\ Template_2023-12-01.json
# │   │   │   ├── 0[SL]-\ Payment\ Term\ Optimization\ (for\ Final\ dashboard)_2023-12-01.json
# │   │   │   └── [SL]\ Payment\ Term\ Analysis\ -\ Use\ case\ 3\ -\ SOL-\ 2727_2023-12-01.json
# │   │   ├── investigations
# │   │   │   └── Event\ lvl\ metrics\ test_2023-12-01.json
# │   │   ├── metrics
# │   │   │   └── metrics.json
# │   │   └── views
# │   │       └── views.json
# │   ├── [NK]\ Show&Tell\ -\ ITP\ Dashboards
# │   │   ├── dashboards
# │   │   │   └── [04]\ Payment\ Behaviour_2023-12-01.json
# │   │   ├── metrics
# │   │   │   └── metrics.json
# │   │   └── views
# │   │       └── views.json
# │   └── [SIGPIA-2936]\ Dashboard_PTP_Ariba
# │       ├── dashboards
# │       │   ├── 00_Overview\ Dashboard_2023-12-01.json
# │       │   ├── Automation\ Dashboard_2023-12-01.json
# │       │   ├── Cycle\ Time\ Dashboard_2023-12-01.json
# │       │   ├── Payment\ Behaviour_2023-12-01.json
# │       │   └── Spend\ Analysis_2023-12-01.json
# │       ├── investigations
# │       │   ├── SAP_ARIBA_PTP_2023-12-01.json
# │       │   └── Test_2023-12-01.json
# │       ├── metrics
# │       │   └── metrics.json
# │       └── views
# │           └── views.json
# └── all_json_Solutions_Demo_Workspace_2023-12-01T07_54_49.json
# ```

# %%
import requests
import re, os
import pathlib
import json
import os, pathlib

def get_filename_from_cd(cd):
    """
    Get filename from content-disposition
    """
    if not cd:
        return None
    fname = re.findall('filename=(.+)', cd)
    if len(fname) == 0:
        return None
    return fname[0]

def export_investigations_dashboards_to_fs(rootdir="",path="",invest_id=None,dashbd_id=None, save_file=False,workspace_name=workspace_name,auth={}):
    """ 
    execute API export endpoints
    #signal_endpoint="https://editor.signavio.com/g/api/pi-graphql/investigations/askdata-poc-1/export" # /g/api/pi-graphql/investigations/askdata-poc-1/export
    # dashboard      https://editor.signavio.com/g/api/pi-graphql/dashboards/fgcf-1/export
    """
    headers=auth[workspace_name]["headers"]
    headers['Accept']='*/*'
    timeout=50  
    if invest_id is not None:
        signal_endpoint=system_instance + '/g/api/pi-graphql/investigations/'+invest_id+'/export'
        subdir="investigations"
    if dashbd_id is not None: # dashboard      https://editor.signavio.com/g/api/pi-graphql/dashboards/fgcf-1/export
        signal_endpoint=system_instance + '/g/api/pi-graphql/dashboards/'+dashbd_id+'/export'
        subdir="dashboards"
        
    try:
        resp = requests.get(
            signal_endpoint,
            cookies=auth[workspace_name]["cookies"],
            headers=headers,
            timeout=timeout,
            stream=True) 
        resp.raise_for_status()
    except requests.HTTPError as ex:
        # possibly check response for a message
        #raise ex  # let the caller handle it
        print("HTTPError:",ex)
        print(signal_endpoint)
        return "err", "", True
    except requests.Timeout:
        print("request took too long")
    err = False 
    try:
        filename = pathlib.Path(os.path.join( rootdir, path, subdir, eval(get_filename_from_cd(resp.headers.get('content-disposition')))))
        pathlib.Path(filename.parent).mkdir(parents=True, exist_ok=True)
        print(signal_endpoint,"Save File:",filename)
        if save_file:
            with open(filename, 'wb') as f:
                f.write(resp.content)
    except Exception as e:
        raise e
    return str(filename), resp.json(), err
# get dashboards and investigations export files
#%%script echo skipping
import datetime

# Change the Selected workspace here if needed

#workspace_name="Solutions Demo Workspace"
#workspace_name="Process AI"

def get_dashboards_investigations_metrics_to_all_json_and_fs(rdir,workspace_name, all_json, save_file=True):
    """_summary_

    Args:
        rdir (_type_): where to store e.g. "../data"
        workspace_name (_type_): _description_
        all_json from above steps
        save_file (bool, optional): _description_. Defaults to True.
    """
    rootdir=os.path.join(rdir, workspace_name)
    if  not os.path.isdir(rootdir):
        #save_file=True
        for p in all_json:
            list_dashboards=all_json[p]['list_dashboards']['data']['dashboards']
            list_investigations=all_json[p]['list_investigations']['data']['subject']['investigations']   # ['data']['subject']['investigations']
            dashboards_jsons=[]
            investigations_jsons=[]
            #metrics_jsons=[]
            path=p
            for d in list_dashboards:
                dashbd_id=d['id']
                view_id=d['view']['id']
                filename, d_json, err = export_investigations_dashboards_to_fs(rootdir=rootdir, path=path,invest_id=None,dashbd_id=dashbd_id, save_file=save_file,workspace_name=workspace_name,auth=auth)
                if not err:
                    dashboards_jsons.append({ filename: {'json': d_json, 'view_id': view_id}})
                print(p,dashbd_id,d)
            for i in list_investigations:
                invest_id=i['id']
                view_id=i['view']['id']
                filename, i_json, err = export_investigations_dashboards_to_fs(rootdir=rootdir,path=path,invest_id=invest_id, dashbd_id=None, save_file=save_file,workspace_name=workspace_name,auth=auth)
                if not err:
                    investigations_jsons.append({ filename: {'json': i_json, 'view_id': view_id}})
                print(p,invest_id,i)

            all_json[p]['dashboards_jsons']=dashboards_jsons
            all_json[p]['investigations_jsons']=investigations_jsons

            # Views are per process
            filename = pathlib.Path(os.path.join( rootdir, path, 'views','views.json' ))
            if save_file:  
                pathlib.Path(filename.parent).mkdir(parents=True, exist_ok=True)
                with open(filename, 'w') as f:
                        json.dump( all_json[p]['views'],f)

            # metrics are available and therefore treated separately
            filename = pathlib.Path(os.path.join( rootdir, path, 'metrics','metrics.json' ))
            #metrics_jsons.append({ filename: {'json': all_json[p]['list_metrics'], 'view_id': view_id}}) # view_id is taken from above
            all_json[p]['metrics_jsons']=[{ str(filename): {'json': all_json[p]['list_metrics'], 'view_id': view_id}}]
            if save_file:  
                pathlib.Path(filename.parent).mkdir(parents=True, exist_ok=True)
                with open(filename, 'w') as f:
                        json.dump( all_json[p]['list_metrics'],f)

        date_str = datetime.datetime.now().strftime("%Y-%m-%dT%H_%M_%S")
        fl=f"all_json_{workspace_name}_{date_str}.json".replace(" ","_")
        filename_json_all=os.path.join(pathlib.Path(rootdir).parent,fl)
        with open(filename_json_all, 'w') as f:
            json.dump( all_json,f)
            print(f"Dumping all extracted Dashboards, Investigations, Metrics data to {filename_json_all}")
            all_json[p]['metrics_jsons']=[{ str(filename): {'json': all_json[p]['list_metrics'], 'view_id': view_id}}]
        return all_json, filename_json_all
    else:
        pdir=pathlib.Path(rootdir).parent
        rdir=os.path.join(pdir, workspace_name)
        p=rdir.replace(" ", "\\ ")
        print(f" You are trying to upload all data to DIR: {rdir}. \n Does {p} aready exist? {os.path.isdir(rdir)} ")
        if os.path.isdir(rdir):
            n_queries1= ! grep -ro 'query"' $p | wc -l
            n_queries2= ! grep -ro "signalF" $p | wc -l
            fls= ! ls -ltr $pdir/all_json*
        print(f"The already uploaded files have {int(n_queries1[0])+int(n_queries2[0])} Signals.")
        print("Detected json_all files:", fls)
        return all_json, fls

# %% [markdown]
# ###  Actual run: Get dashboards, metrics and investigations export files
#
# 5m 43.2s - to download all files from Workspace name: Solutions Demo Workspace

# %%
# Here we check number of Signals in rootdir and subdirs
# Where to save uploaded files - can take some time 6 mins
import os, pathlib

#rootdir="../../data/SignavioText2Signal/ContentPackage_November2023/" # 3967 Signals.
#rootdir="experiment01"
#rootdir=workspace_name
#workspace_name="Process AI"
workspace_name="SAP Signavio Suite Power Challenge" # 4763 Signals.
workspace_name="Solutions Demo Workspace"
rootdir=os.path.join("../data", workspace_name)
pdir=pathlib.Path(rootdir).parent
rdir=os.path.join(pdir, workspace_name)
p=rdir.replace(" ", "\\ ")
print(f" You are trying to upload all data to DIR: {rdir}. \n Does {p} aready exist? {os.path.isdir(rdir)} ")
if os.path.isdir(rdir):
    n_queries1= ! grep -ro 'query"' $p | wc -l
    n_queries2= ! grep -ro "signalF" $p | wc -l
    fls= ! ls -ltr $pdir/all_json*
    print(f"The already uploaded files have {int(n_queries1[0])+int(n_queries2[0])} Signals.")
    print("Detected json_all files:", fls)
# Out:
#  You are trying to upload all data to DIR: ../data/Solutions Demo Workspace.
#  Does ../data/Solutions\ Demo\ Workspace aready exist? False

# %%
# Here actual API - driven uploading and savings to FS take place
workspace_name="Solutions Demo Workspace" # takes 5m 42.3s
all_json, fl = get_dashboards_investigations_metrics_to_all_json_and_fs("../data/From_API",workspace_name,all_json, save_file=True)
workspace_name="Process AI" # takes 41s
all_json_1, fl1 = get_dashboards_investigations_metrics_to_all_json_and_fs("../data/From_API",workspace_name,all_json_1, save_file=True)
# Out:
# https://editor.signavio.com/g/api/pi-graphql/dashboards/01-cycle-time-dashboard-10/export Save File: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards ITC ECC & S4H (DO NOT CHANGE)/dashboards/Cycle Times_2024-02-01.json
# 000_DEMO✨ - Dashboards ITC ECC & S4H (DO NOT CHANGE) 01-cycle-time-dashboard-10 {'access': 'ANYONE_VIEW', 'id': '01-cycle-time-dashboard-10', 'name': 'Cycle Times', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-529'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/03-automation-dashboard-12/export Save File: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards ITC ECC & S4H (DO NOT CHANGE)/dashboards/Automation_2024-02-01.json
# 000_DEMO✨ - Dashboards ITC ECC & S4H (DO NOT CHANGE) 03-automation-dashboard-12 {'access': 'ANYONE_VIEW', 'id': '03-automation-dashboard-12', 'name': 'Automation', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-529'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/00-overview-dashboard-15/export Save File: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards ITC ECC & S4H (DO NOT CHANGE)/dashboards/00_Overview_2024-02-01.json
# 000_DEMO✨ - Dashboards ITC ECC & S4H (DO NOT CHANGE) 00-overview-dashboard-15 {'access': 'ANYONE_VIEW', 'id': '00-overview-dashboard-15', 'name': '00_Overview', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-529'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/optimize-your-payment-term-us-2/export Save File: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards ITC ECC & S4H (DO NOT CHANGE)/dashboards/Optimize Your Payment Term Usage_2024-02-01.json
# 000_DEMO✨ - Dashboards ITC ECC & S4H (DO NOT CHANGE) optimize-your-payment-term-us-2 {'access': 'ANYONE_VIEW', 'id': 'optimize-your-payment-term-us-2', 'name': 'Optimize Your Payment Term Usage', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-529'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/wip-improve-days-sales-outsta-1/export Save File: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards ITC ECC & S4H (DO NOT CHANGE)/dashboards/Improve Days Sales Outstanding (DSO) _2024-02-01.json
# 000_DEMO✨ - Dashboards ITC ECC & S4H (DO NOT CHANGE) wip-improve-days-sales-outsta-1 {'access': 'ANYONE_VIEW', 'id': 'wip-improve-days-sales-outsta-1', 'name': 'Improve Days Sales Outstanding (DSO)\u200b', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-529'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/danoneglobal-value-approach---1/export Save File: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards ITC ECC & S4H (DO NOT CHANGE)/dashboards/Global Value Approach_2024-02-01.json
# 000_DEMO✨ - Dashboards ITC ECC & S4H (DO NOT CHANGE) danoneglobal-value-approach---1 {'access': 'PRIVATE', 'id': 'danoneglobal-value-approach---1', 'name': 'Global Value Approach', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-529'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/danoneglobal-value-approach---3/export Save File: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards ITC ECC & S4H (DO NOT CHANGE)/dashboards/_Global Value Approach_2024-02-01.json
# 000_DEMO✨ - Dashboards ITC ECC & S4H (DO NOT CHANGE) danoneglobal-value-approach---3 {'access': 'PRIVATE', 'id': 'danoneglobal-value-approach---3', 'name': '_Global Value Approach', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-529'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/automation-dashboard-9/export Save File: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards ITP ECC & S4H (DO NOT CHANGE)/dashboards/Automation_2024-02-01.json
# 000_DEMO✨ - Dashboards ITP ECC & S4H (DO NOT CHANGE) automation-dashboard-9 {'access': 'ANYONE_VIEW', 'id': 'automation-dashboard-9', 'name': 'Automation', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-320'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/sap-s4hana---invoice-to-pay-1/export Save File: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards ITP ECC & S4H (DO NOT CHANGE)/dashboards/SAP S/4HANA - Invoice to Pay_2024-02-01.json
# 000_DEMO✨ - Dashboards ITP ECC & S4H (DO NOT CHANGE) sap-s4hana---invoice-to-pay-1 {'access': 'PRIVATE', 'id': 'sap-s4hana---invoice-to-pay-1', 'name': 'SAP S/4HANA - Invoice to Pay', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-320'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/overview-dashboard-13/export Save File: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards ITP ECC & S4H (DO NOT CHANGE)/dashboards/00_Overview_2024-02-01.json
# 000_DEMO✨ - Dashboards ITP ECC & S4H (DO NOT CHANGE) overview-dashboard-13 {'access': 'ANYONE_VIEW', 'id': 'overview-dashboard-13', 'name': '00_Overview', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-320'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/cycle-time-dashboard-9/export Save File: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards ITP ECC & S4H (DO NOT CHANGE)/dashboards/Cycle Times_2024-02-01.json
# 000_DEMO✨ - Dashboards ITP ECC & S4H (DO NOT CHANGE) cycle-time-dashboard-9 {'access': 'ANYONE_VIEW', 'id': 'cycle-time-dashboard-9', 'name': 'Cycle Times', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-320'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/open-overdue-invoices-33/export Save File: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards ITP ECC & S4H (DO NOT CHANGE)/dashboards/Open Overdue Invoices_2024-02-01.json
# 000_DEMO✨ - Dashboards ITP ECC & S4H (DO NOT CHANGE) open-overdue-invoices-33 {'access': 'PRIVATE', 'id': 'open-overdue-invoices-33', 'name': 'Open Overdue Invoices', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-320'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/payment-behaviour-7/export Save File: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards ITP ECC & S4H (DO NOT CHANGE)/dashboards/Payment Behaviour_2024-02-01.json
# 000_DEMO✨ - Dashboards ITP ECC & S4H (DO NOT CHANGE) payment-behaviour-7 {'access': 'PRIVATE', 'id': 'payment-behaviour-7', 'name': 'Payment Behaviour', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-320'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/payment-term-1/export Save File: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards ITP ECC & S4H (DO NOT CHANGE)/dashboards/Payment Term_2024-02-01.json
# 000_DEMO✨ - Dashboards ITP ECC & S4H (DO NOT CHANGE) payment-term-1 {'access': 'PRIVATE', 'id': 'payment-term-1', 'name': 'Payment Term', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-320'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/sap-s4hana---order-to-cash-1/export Save File: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards OTC ECC & S4H (DO NOT CHANGE) /dashboards/zz-SAP S/4HANA - Order to Cash_2024-02-01.json
# 000_DEMO✨ - Dashboards OTC ECC & S4H (DO NOT CHANGE)  sap-s4hana---order-to-cash-1 {'access': 'PRIVATE', 'id': 'sap-s4hana---order-to-cash-1', 'name': 'zz-SAP S/4HANA - Order to Cash', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-383'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/02-customer-satisfaction-1/export Save File: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards OTC ECC & S4H (DO NOT CHANGE) /dashboards/Customer Satisfaction_2024-02-01.json
# 000_DEMO✨ - Dashboards OTC ECC & S4H (DO NOT CHANGE)  02-customer-satisfaction-1 {'access': 'ANYONE_VIEW', 'id': '02-customer-satisfaction-1', 'name': 'Customer Satisfaction', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-383'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/00-overview-dashboard-4/export Save File: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards OTC ECC & S4H (DO NOT CHANGE) /dashboards/00_Overview_2024-02-01.json
# 000_DEMO✨ - Dashboards OTC ECC & S4H (DO NOT CHANGE)  00-overview-dashboard-4 {'access': 'ANYONE_VIEW', 'id': '00-overview-dashboard-4', 'name': '00_Overview', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-383'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/01-cycle-time-dashboard-4/export Save File: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards OTC ECC & S4H (DO NOT CHANGE) /dashboards/Cycle Times_2024-02-01.json
# 000_DEMO✨ - Dashboards OTC ECC & S4H (DO NOT CHANGE)  01-cycle-time-dashboard-4 {'access': 'ANYONE_VIEW', 'id': '01-cycle-time-dashboard-4', 'name': 'Cycle Times', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-383'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/03-automation-dashboard-5/export Save File: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards OTC ECC & S4H (DO NOT CHANGE) /dashboards/Automation_2024-02-01.json
# 000_DEMO✨ - Dashboards OTC ECC & S4H (DO NOT CHANGE)  03-automation-dashboard-5 {'access': 'ANYONE_VIEW', 'id': '03-automation-dashboard-5', 'name': 'Automation', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-383'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/05-working-capital-analysis-1/export Save File: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards OTC ECC & S4H (DO NOT CHANGE) /dashboards/Working Capital_2024-02-01.json
# 000_DEMO✨ - Dashboards OTC ECC & S4H (DO NOT CHANGE)  05-working-capital-analysis-1 {'access': 'ANYONE_VIEW', 'id': '05-working-capital-analysis-1', 'name': 'Working Capital', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-383'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/04-efficiency--rework-analysi-2/export Save File: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards OTC ECC & S4H (DO NOT CHANGE) /dashboards/Efficiency and Rework_2024-02-01.json
# 000_DEMO✨ - Dashboards OTC ECC & S4H (DO NOT CHANGE)  04-efficiency--rework-analysi-2 {'access': 'ANYONE_VIEW', 'id': '04-efficiency--rework-analysi-2', 'name': 'Efficiency and Rework', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-383'}}
# https://editor.signavio.com/g/api/pi-graphql/investigations/general-35/export Save File: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards OTC ECC & S4H (DO NOT CHANGE) /investigations/General_2024-02-01.json
# 000_DEMO✨ - Dashboards OTC ECC & S4H (DO NOT CHANGE)  general-35 {'id': 'general-35', 'name': 'General', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-383'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/dashboard-5-changes---in-revi-1/export Save File: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)/dashboards/zz Dashboard 4: Changes_2024-02-01.json
# 000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE) dashboard-5-changes---in-revi-1 {'access': 'PRIVATE', 'id': 'dashboard-5-changes---in-revi-1', 'name': 'zz Dashboard 4: Changes', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-124'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/dashboard-demo-vendor-analysi-1/export Save File: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)/dashboards/zz - PO Vendor Dashboard_2024-02-01.json
# 000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE) dashboard-demo-vendor-analysi-1 {'access': 'PRIVATE', 'id': 'dashboard-demo-vendor-analysi-1', 'name': 'zz - PO Vendor Dashboard', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-124'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/dashboard-0-overview-process--2/export Save File: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)/dashboards/zz_Agnostic - Overview_2024-02-01.json
# 000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE) dashboard-0-overview-process--2 {'access': 'PRIVATE', 'id': 'dashboard-0-overview-process--2', 'name': 'zz_Agnostic - Overview', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-124'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/dashboard-99-data-validation--1/export Save File: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)/dashboards/zz: Data Validation _2024-02-01.json
# 000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE) dashboard-99-data-validation--1 {'access': 'PRIVATE', 'id': 'dashboard-99-data-validation--1', 'name': 'zz: Data Validation ', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-124'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/dashboard-empty-template-1/export Save File: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)/dashboards/zz - Empty Dashboard Template_2024-02-01.json
# 000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE) dashboard-empty-template-1 {'access': 'PRIVATE', 'id': 'dashboard-empty-template-1', 'name': 'zz - Empty Dashboard Template', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-124'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/x-2/export Save File: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)/dashboards/zz: General Recommendations_2024-02-01.json
# 000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE) x-2 {'access': 'PRIVATE', 'id': 'x-2', 'name': 'zz: General Recommendations', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-124'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/zz---empty-dashboard-template-1/export Save File: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)/dashboards/zz - CBI Test Dashboard_2024-02-01.json
# 000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE) zz---empty-dashboard-template-1 {'access': 'PRIVATE', 'id': 'zz---empty-dashboard-template-1', 'name': 'zz - CBI Test Dashboard', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-124'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/zcbi---payment-term-optimizat-1/export Save File: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)/dashboards/zz_CBI - Payment Term Optimization (for Final dashboard)_2024-02-01.json
# 000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE) zcbi---payment-term-optimizat-1 {'access': 'PRIVATE', 'id': 'zcbi---payment-term-optimizat-1', 'name': 'zz_CBI - Payment Term Optimization (for Final dashboard)', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-124'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/sap-s4hana---procure-to-pay-1/export Save File: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)/dashboards/zz_SAP S/4HANA - Procure to Pay_2024-02-01.json
# 000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE) sap-s4hana---procure-to-pay-1 {'access': 'PRIVATE', 'id': 'sap-s4hana---procure-to-pay-1', 'name': 'zz_SAP S/4HANA - Procure to Pay', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-124'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/dashboard-feature-test-1/export Save File: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)/dashboards/   Dashboard Feature Test_2024-02-01.json
# 000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE) dashboard-feature-test-1 {'access': 'PRIVATE', 'id': 'dashboard-feature-test-1', 'name': '💡 Dashboard Feature Test', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-124'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/po-open-overdue-invoices-moni-1/export Save File: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)/dashboards/Open Overdue Invoices_2024-02-01.json
# 000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE) po-open-overdue-invoices-moni-1 {'access': 'ANYONE_VIEW', 'id': 'po-open-overdue-invoices-moni-1', 'name': 'Open Overdue Invoices', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-124'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/ptp---cycle-time-analysis-3/export Save File: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)/dashboards/Cycle Times_2024-02-01.json
# 000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE) ptp---cycle-time-analysis-3 {'access': 'ANYONE_VIEW', 'id': 'ptp---cycle-time-analysis-3', 'name': 'Cycle Times', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-124'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/overview-dashboard-48/export Save File: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)/dashboards/00_Overview_2024-02-01.json
# 000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE) overview-dashboard-48 {'access': 'ANYONE_VIEW', 'id': 'overview-dashboard-48', 'name': '00_Overview', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-124'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/po-late-payments-historical-a-2/export Save File: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)/dashboards/Late Payments _2024-02-01.json
# 000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE) po-late-payments-historical-a-2 {'access': 'ANYONE_VIEW', 'id': 'po-late-payments-historical-a-2', 'name': 'Late Payments ', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-124'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/ptp---automation-1/export Save File: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)/dashboards/Automation_2024-02-01.json
# 000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE) ptp---automation-1 {'access': 'ANYONE_VIEW', 'id': 'ptp---automation-1', 'name': 'Automation', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-124'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/stellantis-global-value-appro-1/export Save File: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)/dashboards/Global Value Approach_2024-02-01.json
# 000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE) stellantis-global-value-appro-1 {'access': 'PRIVATE', 'id': 'stellantis-global-value-appro-1', 'name': 'Global Value Approach', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-124'}}
# https://editor.signavio.com/g/api/pi-graphql/investigations/hzl-povinsights-1/export Save File: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)/investigations/Presales Template - HZL POV_Insights_2024-02-01.json
# 000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE) hzl-povinsights-1 {'id': 'hzl-povinsights-1', 'name': 'Presales Template - HZL POV_Insights', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-124'}}
# https://editor.signavio.com/g/api/pi-graphql/investigations/cn-test-2/export Save File: ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)/investigations/Dashboard Feature Validation_2024-02-01.json
# 000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE) cn-test-2 {'id': 'cn-test-2', 'name': 'Dashboard Feature Validation', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-124'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/ato-overview-dashboard-8/export Save File: ../data/From_API/Solutions Demo Workspace/00_DEMO - Acquire-to-Onboard for  SAP ECC & S/4 HANA (DO NOT CHANGE)/dashboards/00_Overview_2024-02-01.json
# 00_DEMO - Acquire-to-Onboard for  SAP ECC & S/4 HANA (DO NOT CHANGE) ato-overview-dashboard-8 {'access': 'ANYONE_VIEW', 'id': 'ato-overview-dashboard-8', 'name': '00_Overview', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-459'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/sap-successfactors---attract--1/export Save File: ../data/From_API/Solutions Demo Workspace/00_DEMO - Attract-to-Acquire-Talent for SuccessFactors/dashboards/SAP SuccessFactors - Attract to Acquire Talent_2024-02-01.json
# 00_DEMO - Attract-to-Acquire-Talent for SuccessFactors sap-successfactors---attract--1 {'access': 'PRIVATE', 'id': 'sap-successfactors---attract--1', 'name': 'SAP SuccessFactors - Attract to Acquire Talent', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-462'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/sap-s4hana---inspect-to-quali-1/export Save File: ../data/From_API/Solutions Demo Workspace/00_DEMO - Inspect-to-Quality for SAP S/4 HANA (DO NOT CHANGE)/dashboards/SAP S/4HANA - Inspect to Quality_2024-02-01.json
# 00_DEMO - Inspect-to-Quality for SAP S/4 HANA (DO NOT CHANGE) sap-s4hana---inspect-to-quali-1 {'access': 'PRIVATE', 'id': 'sap-s4hana---inspect-to-quali-1', 'name': 'SAP S/4HANA - Inspect to Quality', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-525'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/itq-overview-dashboard-3/export Save File: ../data/From_API/Solutions Demo Workspace/00_DEMO - Inspect-to-Quality for SAP S/4 HANA (DO NOT CHANGE)/dashboards/00_Overview_2024-02-01.json
# 00_DEMO - Inspect-to-Quality for SAP S/4 HANA (DO NOT CHANGE) itq-overview-dashboard-3 {'access': 'ANYONE_VIEW', 'id': 'itq-overview-dashboard-3', 'name': '00_Overview', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-525'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/new-db-1/export Save File: ../data/From_API/Solutions Demo Workspace/00_DEMO - Invoice-to-Cash for SAP S/4 HANA (DO NOT CHANGE)/dashboards/Process Overview _2024-02-01.json
# 00_DEMO - Invoice-to-Cash for SAP S/4 HANA (DO NOT CHANGE) new-db-1 {'access': 'ANYONE_VIEW', 'id': 'new-db-1', 'name': 'Process Overview ', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-59'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/agnostic---overview-dashboard-3/export Save File: ../data/From_API/Solutions Demo Workspace/00_DEMO - Invoice-to-Cash for SAP S/4 HANA (DO NOT CHANGE)/dashboards/Agnostic - Overview_2024-02-01.json
# 00_DEMO - Invoice-to-Cash for SAP S/4 HANA (DO NOT CHANGE) agnostic---overview-dashboard-3 {'access': 'ANYONE_VIEW', 'id': 'agnostic---overview-dashboard-3', 'name': 'Agnostic - Overview', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-59'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/sap-s4hana---invoice-to-cash-1/export Save File: ../data/From_API/Solutions Demo Workspace/00_DEMO - Invoice-to-Cash for SAP S/4 HANA (DO NOT CHANGE)/dashboards/SAP S/4HANA - Invoice to Cash_2024-02-01.json
# 00_DEMO - Invoice-to-Cash for SAP S/4 HANA (DO NOT CHANGE) sap-s4hana---invoice-to-cash-1 {'access': 'PRIVATE', 'id': 'sap-s4hana---invoice-to-cash-1', 'name': 'SAP S/4HANA - Invoice to Cash', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-59'}}
# https://editor.signavio.com/g/api/pi-graphql/investigations/itc-metrics-testing-1/export Save File: ../data/From_API/Solutions Demo Workspace/00_DEMO - Invoice-to-Cash for SAP S/4 HANA (DO NOT CHANGE)/investigations/ITC Metrics testing_2024-02-01.json
# 00_DEMO - Invoice-to-Cash for SAP S/4 HANA (DO NOT CHANGE) itc-metrics-testing-1 {'id': 'itc-metrics-testing-1', 'name': 'ITC Metrics testing', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-59'}}
# https://editor.signavio.com/g/api/pi-graphql/investigations/demo-itc-1/export Save File: ../data/From_API/Solutions Demo Workspace/00_DEMO - Invoice-to-Cash for SAP S/4 HANA (DO NOT CHANGE)/investigations/Demo ITC_2024-02-01.json
# 00_DEMO - Invoice-to-Cash for SAP S/4 HANA (DO NOT CHANGE) demo-itc-1 {'id': 'demo-itc-1', 'name': 'Demo ITC', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-59'}}
# https://editor.signavio.com/g/api/pi-graphql/investigations/invoice-to-cash-1/export Save File: ../data/From_API/Solutions Demo Workspace/00_DEMO - Invoice-to-Cash for SAP S/4 HANA (DO NOT CHANGE)/investigations/Invoice-to-Cash_2024-02-01.json
# 00_DEMO - Invoice-to-Cash for SAP S/4 HANA (DO NOT CHANGE) invoice-to-cash-1 {'id': 'invoice-to-cash-1', 'name': 'Invoice-to-Cash', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-59'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/automation-42/export Save File: ../data/From_API/Solutions Demo Workspace/00_DEMO - Invoice-to-Pay for SAP S/4 HANA (DO NOT CHANGE)/dashboards/Automation_2024-02-01.json
# 00_DEMO - Invoice-to-Pay for SAP S/4 HANA (DO NOT CHANGE) automation-42 {'access': 'PRIVATE', 'id': 'automation-42', 'name': 'Automation', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-133'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/payment-behaviour-6/export Save File: ../data/From_API/Solutions Demo Workspace/00_DEMO - Invoice-to-Pay for SAP S/4 HANA (DO NOT CHANGE)/dashboards/Payment Behaviour_2024-02-01.json
# 00_DEMO - Invoice-to-Pay for SAP S/4 HANA (DO NOT CHANGE) payment-behaviour-6 {'access': 'PRIVATE', 'id': 'payment-behaviour-6', 'name': 'Payment Behaviour', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-133'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/open-overdue-invoices-31/export Save File: ../data/From_API/Solutions Demo Workspace/00_DEMO - Invoice-to-Pay for SAP S/4 HANA (DO NOT CHANGE)/dashboards/Open Overdue Invoices_2024-02-01.json
# 00_DEMO - Invoice-to-Pay for SAP S/4 HANA (DO NOT CHANGE) open-overdue-invoices-31 {'access': 'PRIVATE', 'id': 'open-overdue-invoices-31', 'name': 'Open Overdue Invoices', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-133'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/payment-terms-2/export Save File: ../data/From_API/Solutions Demo Workspace/00_DEMO - Invoice-to-Pay for SAP S/4 HANA (DO NOT CHANGE)/dashboards/Payment Terms_2024-02-01.json
# 00_DEMO - Invoice-to-Pay for SAP S/4 HANA (DO NOT CHANGE) payment-terms-2 {'access': 'PRIVATE', 'id': 'payment-terms-2', 'name': 'Payment Terms', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-133'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/cycle-times-36/export Save File: ../data/From_API/Solutions Demo Workspace/00_DEMO - Invoice-to-Pay for SAP S/4 HANA (DO NOT CHANGE)/dashboards/Cycle Times_2024-02-01.json
# 00_DEMO - Invoice-to-Pay for SAP S/4 HANA (DO NOT CHANGE) cycle-times-36 {'access': 'PRIVATE', 'id': 'cycle-times-36', 'name': 'Cycle Times', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-133'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/00overview-21/export Save File: ../data/From_API/Solutions Demo Workspace/00_DEMO - Invoice-to-Pay for SAP S/4 HANA (DO NOT CHANGE)/dashboards/00_Overview_2024-02-01.json
# 00_DEMO - Invoice-to-Pay for SAP S/4 HANA (DO NOT CHANGE) 00overview-21 {'access': 'PRIVATE', 'id': '00overview-21', 'name': '00_Overview', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-133'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/jira-issue-to-resolution-dash-16/export Save File: ../data/From_API/Solutions Demo Workspace/00_DEMO Issue-to-Resolution for Jira/dashboards/00_Overview_2024-02-01.json
# 00_DEMO Issue-to-Resolution for Jira jira-issue-to-resolution-dash-16 {'access': 'ANYONE_VIEW', 'id': 'jira-issue-to-resolution-dash-16', 'name': '00_Overview', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-370'}}
# https://editor.signavio.com/g/api/pi-graphql/investigations/test-144/export Save File: ../data/From_API/Solutions Demo Workspace/00_DEMO Issue-to-Resolution for Jira/investigations/Issue-to-Resolution_2024-02-01.json
# 00_DEMO Issue-to-Resolution for Jira test-144 {'id': 'test-144', 'name': 'Issue-to-Resolution', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-370'}}
# https://editor.signavio.com/g/api/pi-graphql/investigations/issue-to-resolution-copy-3/export Save File: ../data/From_API/Solutions Demo Workspace/00_DEMO Issue-to-Resolution for Jira/investigations/Issue-to-Resolution (Copy)_2024-02-01.json
# 00_DEMO Issue-to-Resolution for Jira issue-to-resolution-copy-3 {'id': 'issue-to-resolution-copy-3', 'name': 'Issue-to-Resolution (Copy)', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-370'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/general-13/export Save File: ../data/From_API/Solutions Demo Workspace/00_DEMO - Make-to-Stock for SAP S/4 HANA (DO NOT CHANGE)/dashboards/General_2024-02-01.json
# 00_DEMO - Make-to-Stock for SAP S/4 HANA (DO NOT CHANGE) general-13 {'access': 'ANYONE_VIEW', 'id': 'general-13', 'name': 'General', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-183'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/reduce-manufacturing-costs--i-1/export Save File: ../data/From_API/Solutions Demo Workspace/00_DEMO - Make-to-Stock for SAP S/4 HANA (DO NOT CHANGE)/dashboards/Reduce manufacturing costs & improve process harmonization_2024-02-01.json
# 00_DEMO - Make-to-Stock for SAP S/4 HANA (DO NOT CHANGE) reduce-manufacturing-costs--i-1 {'access': 'ANYONE_VIEW', 'id': 'reduce-manufacturing-costs--i-1', 'name': 'Reduce manufacturing costs & improve process harmonization', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-183'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/overview-26/export Save File: ../data/From_API/Solutions Demo Workspace/00_DEMO - Make-to-Stock for SAP S/4 HANA (DO NOT CHANGE)/dashboards/Overview_2024-02-01.json
# 00_DEMO - Make-to-Stock for SAP S/4 HANA (DO NOT CHANGE) overview-26 {'access': 'ANYONE_EDIT', 'id': 'overview-26', 'name': 'Overview', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-183'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/agnostic---overview-dashboard-6/export Save File: ../data/From_API/Solutions Demo Workspace/00_DEMO - Make-to-Stock for SAP S/4 HANA (DO NOT CHANGE)/dashboards/Agnostic - Overview Dashboard_2024-02-01.json
# 00_DEMO - Make-to-Stock for SAP S/4 HANA (DO NOT CHANGE) agnostic---overview-dashboard-6 {'access': 'PRIVATE', 'id': 'agnostic---overview-dashboard-6', 'name': 'Agnostic - Overview Dashboard', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-183'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/sap-s4hana---make-to-stock-1/export Save File: ../data/From_API/Solutions Demo Workspace/00_DEMO - Make-to-Stock for SAP S/4 HANA (DO NOT CHANGE)/dashboards/SAP S/4HANA - Make to Stock_2024-02-01.json
# 00_DEMO - Make-to-Stock for SAP S/4 HANA (DO NOT CHANGE) sap-s4hana---make-to-stock-1 {'access': 'PRIVATE', 'id': 'sap-s4hana---make-to-stock-1', 'name': 'SAP S/4HANA - Make to Stock', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-183'}}
# https://editor.signavio.com/g/api/pi-graphql/investigations/kpi-validation-1/export Save File: ../data/From_API/Solutions Demo Workspace/00_DEMO - Make-to-Stock for SAP S/4 HANA (DO NOT CHANGE)/investigations/KPI Validation_2024-02-01.json
# 00_DEMO - Make-to-Stock for SAP S/4 HANA (DO NOT CHANGE) kpi-validation-1 {'id': 'kpi-validation-1', 'name': 'KPI Validation', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-183'}}
# https://editor.signavio.com/g/api/pi-graphql/investigations/presentation-1/export Save File: ../data/From_API/Solutions Demo Workspace/00_DEMO - Make-to-Stock for SAP S/4 HANA (DO NOT CHANGE)/investigations/Presentation_2024-02-01.json
# 00_DEMO - Make-to-Stock for SAP S/4 HANA (DO NOT CHANGE) presentation-1 {'id': 'presentation-1', 'name': 'Presentation', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-183'}}
# https://editor.signavio.com/g/api/pi-graphql/investigations/ptf-metrics-testing-space-1/export Save File: ../data/From_API/Solutions Demo Workspace/00_DEMO - Make-to-Stock for SAP S/4 HANA (DO NOT CHANGE)/investigations/Plan to Fulfill_2024-02-01.json
# 00_DEMO - Make-to-Stock for SAP S/4 HANA (DO NOT CHANGE) ptf-metrics-testing-space-1 {'id': 'ptf-metrics-testing-space-1', 'name': 'Plan to Fulfill', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-183'}}
# https://editor.signavio.com/g/api/pi-graphql/investigations/kpi-status-1/export Save File: ../data/From_API/Solutions Demo Workspace/00_DEMO - Make-to-Stock for SAP S/4 HANA (DO NOT CHANGE)/investigations/KPI Status_2024-02-01.json
# 00_DEMO - Make-to-Stock for SAP S/4 HANA (DO NOT CHANGE) kpi-status-1 {'id': 'kpi-status-1', 'name': 'KPI Status', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-183'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/manage-personal-employee-info-3/export Save File: ../data/From_API/Solutions Demo Workspace/00_DEMO - Manage-Personal-Employee-Information for SAP SuccessFactors Employee Central (DO NOT CHANGE)/dashboards/Manage Personal Employee Information - DEMO_2024-02-01.json
# 00_DEMO - Manage-Personal-Employee-Information for SAP SuccessFactors Employee Central (DO NOT CHANGE) manage-personal-employee-info-3 {'access': 'PRIVATE', 'id': 'manage-personal-employee-info-3', 'name': 'Manage Personal Employee Information - DEMO', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-299'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/manage-personal-employee-info-5/export Save File: ../data/From_API/Solutions Demo Workspace/00_DEMO - Manage-Personal-Employee-Information for SAP SuccessFactors Employee Central (DO NOT CHANGE)/dashboards/SAP SuccessFactors - Manage Personal Employee Information_2024-02-01.json
# 00_DEMO - Manage-Personal-Employee-Information for SAP SuccessFactors Employee Central (DO NOT CHANGE) manage-personal-employee-info-5 {'access': 'PRIVATE', 'id': 'manage-personal-employee-info-5', 'name': 'SAP SuccessFactors - Manage Personal Employee Information', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-299'}}
# https://editor.signavio.com/g/api/pi-graphql/investigations/process-overview-14/export Save File: ../data/From_API/Solutions Demo Workspace/00_DEMO - Manage-Personal-Employee-Information for SAP SuccessFactors Employee Central (DO NOT CHANGE)/investigations/Process Overview_2024-02-01.json
# 00_DEMO - Manage-Personal-Employee-Information for SAP SuccessFactors Employee Central (DO NOT CHANGE) process-overview-14 {'id': 'process-overview-14', 'name': 'Process Overview', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-299'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/manage-warehouse-and-inventor-1/export Save File: ../data/From_API/Solutions Demo Workspace/00_DEMO - Manage Warehouse and Inventory (Outbound) in SAP EWM (DO NOT CHANGE)/dashboards/Manage Warehouse and Inventory (Outbound) in SAP EWM_2024-02-01.json
# 00_DEMO - Manage Warehouse and Inventory (Outbound) in SAP EWM (DO NOT CHANGE) manage-warehouse-and-inventor-1 {'access': 'PRIVATE', 'id': 'manage-warehouse-and-inventor-1', 'name': 'Manage Warehouse and Inventory (Outbound) in SAP EWM', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-528'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/agnostic---overview-dashboard-5/export Save File: ../data/From_API/Solutions Demo Workspace/00_DEMO - Meter-to-Cash for SAP IS-U and S/4HANA (DO NOT CHANGE)/dashboards/00_Overview_2024-02-01.json
# 00_DEMO - Meter-to-Cash for SAP IS-U and S/4HANA (DO NOT CHANGE) agnostic---overview-dashboard-5 {'access': 'PRIVATE', 'id': 'agnostic---overview-dashboard-5', 'name': '00_Overview', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-50'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/thitest-1/export Save File: ../data/From_API/Solutions Demo Workspace/00_DEMO - Meter-to-Cash for SAP IS-U and S/4HANA (DO NOT CHANGE)/dashboards/Demo_SP_2024-02-01.json
# 00_DEMO - Meter-to-Cash for SAP IS-U and S/4HANA (DO NOT CHANGE) thitest-1 {'access': 'PRIVATE', 'id': 'thitest-1', 'name': 'Demo_SP', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-50'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/overview-dashboard-45/export Save File: ../data/From_API/Solutions Demo Workspace/00_DEMO_Operate Manufacturing in SAP Digital Manufacturing (DO NOT CHANGE)/dashboards/Overview Dashboard_2024-02-01.json
# 00_DEMO_Operate Manufacturing in SAP Digital Manufacturing (DO NOT CHANGE) overview-dashboard-45 {'access': 'ANYONE_VIEW', 'id': 'overview-dashboard-45', 'name': 'Overview Dashboard', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-538'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/process-overview-10/export Save File: ../data/From_API/Solutions Demo Workspace/00_DEMO - Operate-to-Maintain/Plant_Maintenance for SAP ECC/dashboards/Process Overview_2024-02-01.json
# 00_DEMO - Operate-to-Maintain/Plant_Maintenance for SAP ECC process-overview-10 {'access': 'ANYONE_VIEW', 'id': 'process-overview-10', 'name': 'Process Overview', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-95'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/sap-s4hana---operate-to-maint-1/export Save File: ../data/From_API/Solutions Demo Workspace/00_DEMO - Operate-to-Maintain/Plant_Maintenance for SAP ECC/dashboards/SAP S/4HANA - Operate to Maintain_2024-02-01.json
# 00_DEMO - Operate-to-Maintain/Plant_Maintenance for SAP ECC sap-s4hana---operate-to-maint-1 {'access': 'PRIVATE', 'id': 'sap-s4hana---operate-to-maint-1', 'name': 'SAP S/4HANA - Operate to Maintain', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-95'}}
# https://editor.signavio.com/g/api/pi-graphql/investigations/first-test---jrp-1/export Save File: ../data/From_API/Solutions Demo Workspace/00_DEMO - Operate-to-Maintain/Plant_Maintenance for SAP ECC/investigations/First Test - JRP_2024-02-01.json
# 00_DEMO - Operate-to-Maintain/Plant_Maintenance for SAP ECC first-test---jrp-1 {'id': 'first-test---jrp-1', 'name': 'First Test - JRP', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-95'}}
# https://editor.signavio.com/g/api/pi-graphql/investigations/first-glance-1/export Save File: ../data/From_API/Solutions Demo Workspace/00_DEMO - Operate-to-Maintain/Plant_Maintenance for SAP ECC/investigations/Operate-to-Maintain_2024-02-01.json
# 00_DEMO - Operate-to-Maintain/Plant_Maintenance for SAP ECC first-glance-1 {'id': 'first-glance-1', 'name': 'Operate-to-Maintain', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-95'}}
# https://editor.signavio.com/g/api/pi-graphql/investigations/operate-to-maintain-5/export Save File: ../data/From_API/Solutions Demo Workspace/00_DEMO - Operate-to-Maintain/Plant_Maintenance for SAP ECC/investigations/Operate to Maintain_2024-02-01.json
# 00_DEMO - Operate-to-Maintain/Plant_Maintenance for SAP ECC operate-to-maintain-5 {'id': 'operate-to-maintain-5', 'name': 'Operate to Maintain', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-95'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/test-148/export Save File: ../data/From_API/Solutions Demo Workspace/00_DEMO - OTC SAP ECC V2 (DO NOT CHANGE)/dashboards/test_2024-02-01.json
# 00_DEMO - OTC SAP ECC V2 (DO NOT CHANGE) test-148 {'access': 'PRIVATE', 'id': 'test-148', 'name': 'test', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-290'}}
# https://editor.signavio.com/g/api/pi-graphql/investigations/demo---order-to-cash-s4hana-6/export Save File: ../data/From_API/Solutions Demo Workspace/00_DEMO - OTC SAP ECC V2 (DO NOT CHANGE)/investigations/DEMO - Order-to-Cash ECC_2024-02-01.json
# 00_DEMO - OTC SAP ECC V2 (DO NOT CHANGE) demo---order-to-cash-s4hana-6 {'id': 'demo---order-to-cash-s4hana-6', 'name': 'DEMO - Order-to-Cash ECC', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-290'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/otc-process-overview-2/export Save File: ../data/From_API/Solutions Demo Workspace/00_DEMO - OTC SAP S/4 HANA (DO NOT CHANGE)/dashboards/OTC Process Overview_2024-02-01.json
# 00_DEMO - OTC SAP S/4 HANA (DO NOT CHANGE) otc-process-overview-2 {'access': 'PRIVATE', 'id': 'otc-process-overview-2', 'name': 'OTC Process Overview', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-291'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/agnostic---overview-dashboard-8/export Save File: ../data/From_API/Solutions Demo Workspace/00_DEMO - OTC SAP S/4 HANA (DO NOT CHANGE)/dashboards/Agnostic - Overview Dashboard_2024-02-01.json
# 00_DEMO - OTC SAP S/4 HANA (DO NOT CHANGE) agnostic---overview-dashboard-8 {'access': 'PRIVATE', 'id': 'agnostic---overview-dashboard-8', 'name': 'Agnostic - Overview Dashboard', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-291'}}
# https://editor.signavio.com/g/api/pi-graphql/investigations/test---old-version-copy-2/export Save File: ../data/From_API/Solutions Demo Workspace/00_DEMO - OTC SAP S/4 HANA (DO NOT CHANGE)/investigations/DEMO - Order-to-Cash S/4HANA_2024-02-01.json
# 00_DEMO - OTC SAP S/4 HANA (DO NOT CHANGE) test---old-version-copy-2 {'id': 'test---old-version-copy-2', 'name': 'DEMO - Order-to-Cash S/4HANA', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-291'}}
# https://editor.signavio.com/g/api/pi-graphql/investigations/spike-sustainability--1/export Save File: ../data/From_API/Solutions Demo Workspace/00_DEMO - OTC SAP S/4 HANA (DO NOT CHANGE)/investigations/Spike Sustainability _2024-02-01.json
# 00_DEMO - OTC SAP S/4 HANA (DO NOT CHANGE) spike-sustainability--1 {'id': 'spike-sustainability--1', 'name': 'Spike Sustainability ', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-291'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/sap-ariba-and-sap-erp---procu-1/export Save File: ../data/From_API/Solutions Demo Workspace/00_DEMO PTP Cross Mining SAP Ariba + SAP ERP (DO NOT CHANGE)/dashboards/SAP Ariba and SAP ERP - Procure to Pay_2024-02-01.json
# 00_DEMO PTP Cross Mining SAP Ariba + SAP ERP (DO NOT CHANGE) sap-ariba-and-sap-erp---procu-1 {'access': 'PRIVATE', 'id': 'sap-ariba-and-sap-erp---procu-1', 'name': 'SAP Ariba and SAP ERP - Procure to Pay', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-471'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/overview-dashboard-31/export Save File: ../data/From_API/Solutions Demo Workspace/00_DEMO PTP Cross Mining SAP Ariba + SAP ERP (DO NOT CHANGE)/dashboards/00_Overview_2024-02-01.json
# 00_DEMO PTP Cross Mining SAP Ariba + SAP ERP (DO NOT CHANGE) overview-dashboard-31 {'access': 'ANYONE_VIEW', 'id': 'overview-dashboard-31', 'name': '00_Overview', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-471'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/cycle-times-34/export Save File: ../data/From_API/Solutions Demo Workspace/00_DEMO PTP Cross Mining SAP Ariba + SAP ERP (DO NOT CHANGE)/dashboards/Cycle Times_2024-02-01.json
# 00_DEMO PTP Cross Mining SAP Ariba + SAP ERP (DO NOT CHANGE) cycle-times-34 {'access': 'PRIVATE', 'id': 'cycle-times-34', 'name': 'Cycle Times', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-471'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/late-payments--7/export Save File: ../data/From_API/Solutions Demo Workspace/00_DEMO PTP Cross Mining SAP Ariba + SAP ERP (DO NOT CHANGE)/dashboards/Late Payments _2024-02-01.json
# 00_DEMO PTP Cross Mining SAP Ariba + SAP ERP (DO NOT CHANGE) late-payments--7 {'access': 'PRIVATE', 'id': 'late-payments--7', 'name': 'Late Payments ', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-471'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/open-overdue-invoices-28/export Save File: ../data/From_API/Solutions Demo Workspace/00_DEMO PTP Cross Mining SAP Ariba + SAP ERP (DO NOT CHANGE)/dashboards/Open Overdue Invoices_2024-02-01.json
# 00_DEMO PTP Cross Mining SAP Ariba + SAP ERP (DO NOT CHANGE) open-overdue-invoices-28 {'access': 'PRIVATE', 'id': 'open-overdue-invoices-28', 'name': 'Open Overdue Invoices', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-471'}}
# https://editor.signavio.com/g/api/pi-graphql/investigations/test-206/export Save File: ../data/From_API/Solutions Demo Workspace/00_DEMO PTP Cross Mining SAP Ariba + SAP ERP (DO NOT CHANGE)/investigations/test_2024-02-01.json
# 00_DEMO PTP Cross Mining SAP Ariba + SAP ERP (DO NOT CHANGE) test-206 {'id': 'test-206', 'name': 'test', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-471'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/overview-dashboard-27/export Save File: ../data/From_API/Solutions Demo Workspace/00_DEMO - PTP in Ariba (DO NOT CHANGE)/dashboards/00_Overview (old)_2024-02-01.json
# 00_DEMO - PTP in Ariba (DO NOT CHANGE) overview-dashboard-27 {'access': 'PRIVATE', 'id': 'overview-dashboard-27', 'name': '00_Overview (old)', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-431'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/spend-analysis-9/export Save File: ../data/From_API/Solutions Demo Workspace/00_DEMO - PTP in Ariba (DO NOT CHANGE)/dashboards/Spend Analysis_2024-02-01.json
# 00_DEMO - PTP in Ariba (DO NOT CHANGE) spend-analysis-9 {'access': 'PRIVATE', 'id': 'spend-analysis-9', 'name': 'Spend Analysis', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-431'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/00overview-dashboard-1/export Save File: ../data/From_API/Solutions Demo Workspace/00_DEMO - PTP in Ariba (DO NOT CHANGE)/dashboards/00_Overview_2024-02-01.json
# 00_DEMO - PTP in Ariba (DO NOT CHANGE) 00overview-dashboard-1 {'access': 'PRIVATE', 'id': '00overview-dashboard-1', 'name': '00_Overview', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-431'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/cycle-time-dashboard-14/export Save File: ../data/From_API/Solutions Demo Workspace/00_DEMO - PTP in Ariba (DO NOT CHANGE)/dashboards/Cycle Times_2024-02-01.json
# 00_DEMO - PTP in Ariba (DO NOT CHANGE) cycle-time-dashboard-14 {'access': 'PRIVATE', 'id': 'cycle-time-dashboard-14', 'name': 'Cycle Times', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-431'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/payment-behaviour-3/export Save File: ../data/From_API/Solutions Demo Workspace/00_DEMO - PTP in Ariba (DO NOT CHANGE)/dashboards/Payment Behaviour_2024-02-01.json
# 00_DEMO - PTP in Ariba (DO NOT CHANGE) payment-behaviour-3 {'access': 'PRIVATE', 'id': 'payment-behaviour-3', 'name': 'Payment Behaviour', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-431'}}
# https://editor.signavio.com/g/api/pi-graphql/investigations/demo-4/export Save File: ../data/From_API/Solutions Demo Workspace/00_DEMO - PTP in Ariba (DO NOT CHANGE)/investigations/Demo_2024-02-01.json
# 00_DEMO - PTP in Ariba (DO NOT CHANGE) demo-4 {'id': 'demo-4', 'name': 'Demo', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-431'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/po-late-payments-historical-a-8/export Save File: ../data/From_API/Solutions Demo Workspace/00_DEMO - PTP SAP S4H (DO NOT CHANGE)/dashboards/PO Late Payments (Historical Analysis)_2024-02-01.json
# 00_DEMO - PTP SAP S4H (DO NOT CHANGE) po-late-payments-historical-a-8 {'access': 'ANYONE_VIEW', 'id': 'po-late-payments-historical-a-8', 'name': 'PO Late Payments (Historical Analysis)', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-57'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/cycle-time-dashboard-5/export Save File: ../data/From_API/Solutions Demo Workspace/00_DEMO - PTP SAP S4H (DO NOT CHANGE)/dashboards/Cycle Time Dashboard_2024-02-01.json
# 00_DEMO - PTP SAP S4H (DO NOT CHANGE) cycle-time-dashboard-5 {'access': 'ANYONE_VIEW', 'id': 'cycle-time-dashboard-5', 'name': 'Cycle Time Dashboard', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-57'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/overview-dashboard-11/export Save File: ../data/From_API/Solutions Demo Workspace/00_DEMO - PTP SAP S4H (DO NOT CHANGE)/dashboards/Overview Dashboard_2024-02-01.json
# 00_DEMO - PTP SAP S4H (DO NOT CHANGE) overview-dashboard-11 {'access': 'ANYONE_VIEW', 'id': 'overview-dashboard-11', 'name': 'Overview Dashboard', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-57'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/po-open-overdue-payments-moni-3/export Save File: ../data/From_API/Solutions Demo Workspace/00_DEMO - PTP SAP S4H (DO NOT CHANGE)/dashboards/PO Open Overdue Payments (Monitoring)_2024-02-01.json
# 00_DEMO - PTP SAP S4H (DO NOT CHANGE) po-open-overdue-payments-moni-3 {'access': 'ANYONE_VIEW', 'id': 'po-open-overdue-payments-moni-3', 'name': 'PO Open Overdue Payments (Monitoring)', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-57'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/testing-dashboard-1/export Save File: ../data/From_API/Solutions Demo Workspace/00_DEMO - PTP SAP S4H (DO NOT CHANGE)/dashboards/Testing Dashboard_2024-02-01.json
# 00_DEMO - PTP SAP S4H (DO NOT CHANGE) testing-dashboard-1 {'access': 'PRIVATE', 'id': 'testing-dashboard-1', 'name': 'Testing Dashboard', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-57'}}
# ...
# [0]_Dashboards_ITP Process nk---late-payments-historical-1 {'access': 'PRIVATE', 'id': 'nk---late-payments-historical-1', 'name': 'Payment Behaviour', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-225'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/automation-dashboard-6/export Save File: ../data/From_API/Solutions Demo Workspace/[0]_Dashboards_ITP Process/dashboards/Automation Dashboard_2024-02-01.json
# [0]_Dashboards_ITP Process automation-dashboard-6 {'access': 'PRIVATE', 'id': 'automation-dashboard-6', 'name': 'Automation Dashboard', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-225'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/sl-payment-term-analysis---us-2/export Save File: ../data/From_API/Solutions Demo Workspace/[0]_Dashboards_ITP Process/dashboards/[SL] Payment Term Analysis - Use case 3 - SOL- 2727_2024-02-01.json
# [0]_Dashboards_ITP Process sl-payment-term-analysis---us-2 {'access': 'PRIVATE', 'id': 'sl-payment-term-analysis---us-2', 'name': '[SL] Payment Term Analysis - Use case 3 - SOL- 2727', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-225'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/sl-overview-dashboard-2/export Save File: ../data/From_API/Solutions Demo Workspace/[0]_Dashboards_ITP Process/dashboards/Overview Dashboard_2024-02-01.json
# [0]_Dashboards_ITP Process sl-overview-dashboard-2 {'access': 'PRIVATE', 'id': 'sl-overview-dashboard-2', 'name': 'Overview Dashboard', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-225'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/sl-overview-dashboard-1/export Save File: ../data/From_API/Solutions Demo Workspace/[0]_Dashboards_ITP Process/dashboards/[SL] Overview Dashboard_2024-02-01.json
# [0]_Dashboards_ITP Process sl-overview-dashboard-1 {'access': 'PRIVATE', 'id': 'sl-overview-dashboard-1', 'name': '[SL] Overview Dashboard', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-225'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/po-late-payments-historical-a-7/export Save File: ../data/From_API/Solutions Demo Workspace/[0]_Dashboards_ITP Process/dashboards/[NK] - Late Payments (Historical Analysis)_2024-02-01.json
# [0]_Dashboards_ITP Process po-late-payments-historical-a-7 {'access': 'PRIVATE', 'id': 'po-late-payments-historical-a-7', 'name': '[NK] - Late Payments (Historical Analysis)', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-225'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/empty-template-1/export Save File: ../data/From_API/Solutions Demo Workspace/[0]_Dashboards_ITP Process/dashboards/00_Empty Template_2024-02-01.json
# [0]_Dashboards_ITP Process empty-template-1 {'access': 'ANYONE_EDIT', 'id': 'empty-template-1', 'name': '00_Empty Template', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-225'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/fz-po-open-overdue-payments-m-1/export Save File: ../data/From_API/Solutions Demo Workspace/[0]_Dashboards_ITP Process/dashboards/[FZ] Open Overdue Invoices_2024-02-01.json
# [0]_Dashboards_ITP Process fz-po-open-overdue-payments-m-1 {'access': 'PRIVATE', 'id': 'fz-po-open-overdue-payments-m-1', 'name': '[FZ] Open Overdue Invoices', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-225'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/cycle-time-dashboard-4/export Save File: ../data/From_API/Solutions Demo Workspace/[0]_Dashboards_ITP Process/dashboards/Cycle Time Dashboard_2024-02-01.json
# [0]_Dashboards_ITP Process cycle-time-dashboard-4 {'access': 'PRIVATE', 'id': 'cycle-time-dashboard-4', 'name': 'Cycle Time Dashboard', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-225'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/empty-template-3/export Save File: ../data/From_API/Solutions Demo Workspace/[0]_Dashboards_ITP Process/dashboards/[SL] Payment Term Analysis - Use case 1 - SOL-2617_2024-02-01.json
# [0]_Dashboards_ITP Process empty-template-3 {'access': 'PRIVATE', 'id': 'empty-template-3', 'name': '[SL] Payment Term Analysis - Use case 1 - SOL-2617', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-225'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/fz-open-overdue-invoices-exte-2/export Save File: ../data/From_API/Solutions Demo Workspace/[0]_Dashboards_ITP Process/dashboards/Open Overdue Invoices_2024-02-01.json
# [0]_Dashboards_ITP Process fz-open-overdue-invoices-exte-2 {'access': 'PRIVATE', 'id': 'fz-open-overdue-invoices-exte-2', 'name': 'Open Overdue Invoices', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-225'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/aa-automation-dashboard-1/export Save File: ../data/From_API/Solutions Demo Workspace/[0]_Dashboards_ITP Process/dashboards/[AA] Automation Dashboard_2024-02-01.json
# [0]_Dashboards_ITP Process aa-automation-dashboard-1 {'access': 'PRIVATE', 'id': 'aa-automation-dashboard-1', 'name': '[AA] Automation Dashboard', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-225'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/js-payment-term-analysis---us-1/export Save File: ../data/From_API/Solutions Demo Workspace/[0]_Dashboards_ITP Process/dashboards/[JS] Payment Term Analysis - Use Case 2 - SOL-2725 (shorter PT on Invoice than in MD )_2024-02-01.json
# [0]_Dashboards_ITP Process js-payment-term-analysis---us-1 {'access': 'PRIVATE', 'id': 'js-payment-term-analysis---us-1', 'name': '[JS] Payment Term Analysis - Use Case 2 - SOL-2725 (shorter PT on Invoice than in MD )', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-225'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/zcbi---payment-term-optimizat-2/export Save File: ../data/From_API/Solutions Demo Workspace/[0]_Dashboards_ITP Process/dashboards/0[SL]- Payment Term Optimization (for Final dashboard)_2024-02-01.json
# [0]_Dashboards_ITP Process zcbi---payment-term-optimizat-2 {'access': 'PRIVATE', 'id': 'zcbi---payment-term-optimizat-2', 'name': '0[SL]- Payment Term Optimization (for Final dashboard)', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-225'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/sl-payment-term-analysis---us-3/export Save File: ../data/From_API/Solutions Demo Workspace/[0]_Dashboards_ITP Process/dashboards/Payment Term Analysis_2024-02-01.json
# [0]_Dashboards_ITP Process sl-payment-term-analysis---us-3 {'access': 'PRIVATE', 'id': 'sl-payment-term-analysis---us-3', 'name': 'Payment Term Analysis', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-225'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/payment-term-analysis-modifie-3/export Save File: ../data/From_API/Solutions Demo Workspace/[0]_Dashboards_ITP Process/dashboards/Payment Term Analysis-modified_2024-02-01.json
# [0]_Dashboards_ITP Process payment-term-analysis-modifie-3 {'access': 'PRIVATE', 'id': 'payment-term-analysis-modifie-3', 'name': 'Payment Term Analysis-modified', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-225'}}
# https://editor.signavio.com/g/api/pi-graphql/investigations/event-lvl-metrics-test-1/export Save File: ../data/From_API/Solutions Demo Workspace/[0]_Dashboards_ITP Process/investigations/Event lvl metrics test_2024-02-01.json
# [0]_Dashboards_ITP Process event-lvl-metrics-test-1 {'id': 'event-lvl-metrics-test-1', 'name': 'Event lvl metrics test', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-225'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/cycle-time-dashboard-6/export Save File: ../data/From_API/Solutions Demo Workspace/0_demo_accelerators_generic (PTP S4H, changes allowed)/dashboards/Cycle Time Dashboard_2024-02-01.json
# 0_demo_accelerators_generic (PTP S4H, changes allowed) cycle-time-dashboard-6 {'access': 'PRIVATE', 'id': 'cycle-time-dashboard-6', 'name': 'Cycle Time Dashboard', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-288'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/po-late-payments-historical-a-9/export Save File: ../data/From_API/Solutions Demo Workspace/0_demo_accelerators_generic (PTP S4H, changes allowed)/dashboards/PO Late Payments (Historical Analysis)_2024-02-01.json
# 0_demo_accelerators_generic (PTP S4H, changes allowed) po-late-payments-historical-a-9 {'access': 'PRIVATE', 'id': 'po-late-payments-historical-a-9', 'name': 'PO Late Payments (Historical Analysis)', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-288'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/overview-dashboard-15/export Save File: ../data/From_API/Solutions Demo Workspace/0_demo_accelerators_generic (PTP S4H, changes allowed)/dashboards/Overview Dashboard_2024-02-01.json
# 0_demo_accelerators_generic (PTP S4H, changes allowed) overview-dashboard-15 {'access': 'PRIVATE', 'id': 'overview-dashboard-15', 'name': 'Overview Dashboard', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-288'}}
# https://editor.signavio.com/g/api/pi-graphql/investigations/hs-pi-academy--1/export Save File: ../data/From_API/Solutions Demo Workspace/0_demo_accelerators_generic (PTP S4H, changes allowed)/investigations/HS pi academy _2024-02-01.json
# 0_demo_accelerators_generic (PTP S4H, changes allowed) hs-pi-academy--1 {'id': 'hs-pi-academy--1', 'name': 'HS pi academy ', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-288'}}
# https://editor.signavio.com/g/api/pi-graphql/investigations/overview-92/export Save File: ../data/From_API/Solutions Demo Workspace/0_demo_accelerators_generic (PTP S4H, changes allowed)/investigations/overview_2024-02-01.json
# 0_demo_accelerators_generic (PTP S4H, changes allowed) overview-92 {'id': 'overview-92', 'name': 'overview', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-288'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/04-payment-behaviour-3/export Save File: ../data/From_API/Solutions Demo Workspace/[NK] Show&Tell - ITP Dashboards/dashboards/[04] Payment Behaviour_2024-02-01.json
# [NK] Show&Tell - ITP Dashboards 04-payment-behaviour-3 {'access': 'PRIVATE', 'id': '04-payment-behaviour-3', 'name': '[04] Payment Behaviour', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-362'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/automation-dashboard-12/export Save File: ../data/From_API/Solutions Demo Workspace/[SIGPIA-2936] Dashboard_PTP_Ariba/dashboards/Automation Dashboard_2024-02-01.json
# [SIGPIA-2936] Dashboard_PTP_Ariba automation-dashboard-12 {'access': 'PRIVATE', 'id': 'automation-dashboard-12', 'name': 'Automation Dashboard', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-545'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/cycle-time-dashboard-11/export Save File: ../data/From_API/Solutions Demo Workspace/[SIGPIA-2936] Dashboard_PTP_Ariba/dashboards/Cycle Time Dashboard_2024-02-01.json
# [SIGPIA-2936] Dashboard_PTP_Ariba cycle-time-dashboard-11 {'access': 'PRIVATE', 'id': 'cycle-time-dashboard-11', 'name': 'Cycle Time Dashboard', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-545'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/overview-dashboard-46/export Save File: ../data/From_API/Solutions Demo Workspace/[SIGPIA-2936] Dashboard_PTP_Ariba/dashboards/00_Overview Dashboard_2024-02-01.json
# [SIGPIA-2936] Dashboard_PTP_Ariba overview-dashboard-46 {'access': 'PRIVATE', 'id': 'overview-dashboard-46', 'name': '00_Overview Dashboard', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-545'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/04-payment-behaviour-7/export Save File: ../data/From_API/Solutions Demo Workspace/[SIGPIA-2936] Dashboard_PTP_Ariba/dashboards/Payment Behaviour_2024-02-01.json
# [SIGPIA-2936] Dashboard_PTP_Ariba 04-payment-behaviour-7 {'access': 'PRIVATE', 'id': '04-payment-behaviour-7', 'name': 'Payment Behaviour', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-545'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/sap-ariba-ptp----dashboard-ex-2/export Save File: ../data/From_API/Solutions Demo Workspace/[SIGPIA-2936] Dashboard_PTP_Ariba/dashboards/Spend Analysis_2024-02-01.json
# [SIGPIA-2936] Dashboard_PTP_Ariba sap-ariba-ptp----dashboard-ex-2 {'access': 'PRIVATE', 'id': 'sap-ariba-ptp----dashboard-ex-2', 'name': 'Spend Analysis', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-545'}}
# https://editor.signavio.com/g/api/pi-graphql/investigations/test-183/export Save File: ../data/From_API/Solutions Demo Workspace/[SIGPIA-2936] Dashboard_PTP_Ariba/investigations/Test_2024-02-01.json
# [SIGPIA-2936] Dashboard_PTP_Ariba test-183 {'id': 'test-183', 'name': 'Test', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-545'}}
# https://editor.signavio.com/g/api/pi-graphql/investigations/saparibaptp-3/export Save File: ../data/From_API/Solutions Demo Workspace/[SIGPIA-2936] Dashboard_PTP_Ariba/investigations/SAP_ARIBA_PTP_2024-02-01.json
# [SIGPIA-2936] Dashboard_PTP_Ariba saparibaptp-3 {'id': 'saparibaptp-3', 'name': 'SAP_ARIBA_PTP', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-545'}}
# Dumping all extracted Dashboards, Investigations, Metrics data to ../data/From_API/all_json_Solutions_Demo_Workspace_2024-02-01T08_17_38.json
# https://editor.signavio.com/g/api/pi-graphql/dashboards/fgcf-1/export Save File: ../data/From_API/Process AI/demo01/dashboards/workingdashboard_2024-02-01.json
# demo01 fgcf-1 {'access': 'PRIVATE', 'id': 'fgcf-1', 'name': 'workingdashboard', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-9'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/qqqq-1/export Save File: ../data/From_API/Process AI/demo01/dashboards/qqqq_2024-02-01.json
# demo01 qqqq-1 {'access': 'PRIVATE', 'id': 'qqqq-1', 'name': 'qqqq', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-9'}}
# https://editor.signavio.com/g/api/pi-graphql/investigations/askdata-poc-6/export Save File: ../data/From_API/Process AI/demo01/investigations/AskData POC_2024-02-01.json
# demo01 askdata-poc-6 {'id': 'askdata-poc-6', 'name': 'AskData POC', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-9'}}
# https://editor.signavio.com/g/api/pi-graphql/investigations/askdata-poc-copy-1/export Save File: ../data/From_API/Process AI/demo01/investigations/AskData POC (Copy)_2024-02-01.json
# demo01 askdata-poc-copy-1 {'id': 'askdata-poc-copy-1', 'name': 'AskData POC (Copy)', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-9'}}
# https://editor.signavio.com/g/api/pi-graphql/dashboards/testdashboard-1/export Save File: ../data/From_API/Process AI/test00/dashboards/testdashboard_2024-02-01.json
# test00 testdashboard-1 {'access': 'PRIVATE', 'id': 'testdashboard-1', 'name': 'testdashboard', 'view': {'name': 'str_view', 'id': 'strview-1'}}
# https://editor.signavio.com/g/api/pi-graphql/investigations/askdata-poc-1/export Save File: ../data/From_API/Process AI/test00/investigations/AskData POC_2024-02-01.json
# test00 askdata-poc-1 {'id': 'askdata-poc-1', 'name': 'AskData POC', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-2'}}
# https://editor.signavio.com/g/api/pi-graphql/investigations/q1-1/export Save File: ../data/From_API/Process AI/test00/investigations/q1_2024-02-01.json
# test00 q1-1 {'id': 'q1-1', 'name': 'q1', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-2'}}
# https://editor.signavio.com/g/api/pi-graphql/investigations/askdata-poc-3/export Save File: ../data/From_API/Process AI/test001/investigations/AskData POC_2024-02-01.json
# test001 askdata-poc-3 {'id': 'askdata-poc-3', 'name': 'AskData POC', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-4'}}
# https://editor.signavio.com/g/api/pi-graphql/investigations/askdata-poc-2/export Save File: ../data/From_API/Process AI/test002/investigations/AskData POC_2024-02-01.json
# test002 askdata-poc-2 {'id': 'askdata-poc-2', 'name': 'AskData POC', 'view': {'name': 'DEFAULT_VIEW', 'id': 'defaultview-3'}}
# Dumping all extracted Dashboards, Investigations, Metrics data to ../data/From_API/all_json_Process_AI_2024-02-01T08_17_57.json

# %%
print("Available all_jsons files from above run",fl,fl1)
# Out:
# Available all_jsons files from above run ../data/From_API/all_json_Solutions_Demo_Workspace_2024-02-01T08_17_38.json ../data/From_API/all_json_Process_AI_2024-02-01T08_17_57.json

# %% [markdown]
# ## Step 4. Get Signals from json/json_files
# Here we use all_json / all_json_1 JSONs to extract Signals therein.

# %% [markdown]
# ### Here we can read the all_json files if they are available from the previous runs:
#
# - all_json with "Solutions Demo Workspace"
# - all_json_1 with "Process AI"
# - ../data/From_API/all_json_Solutions_Demo_Workspace_2024-02-01T08_17_38.json
# - ../data/From_API/all_json_Process_AI_2024-02-01T08_17_57.json

# %%
# Read all data from saves all_json
# workspace_name="Solutions Demo Workspace"
filename="../data/From_API/all_json_Solutions_Demo_Workspace_2024-02-01T08_17_38.json"
with open(filename, 'r') as f:
    all_json = json.load(f)
    print(f"Loading Dashboards, Investigations, Metrics data from {filename}")

# workspace_name="Process AI"
filename="../data/From_API/all_json_Process_AI_2024-02-01T08_17_57.json"
with open(filename, 'r') as f:
    all_json_1 = json.load(f)
    print(f"Loading Dashboards, Investigations, Metrics data from {filename}")

#  workspace_name='SAP Signavio Suite Power Challenge'
#filename="./all_json_SAP_Signavio_Suite_Power_Challenge_2023-11-28T14_24_23.json"
#with open(filename, 'r') as f:
#    all_json_2 = json.load(f)
#    print(f"Loading Dashboards, Investigations, Metrics data from {filename}")
# Out:
# Loading Dashboards, Investigations, Metrics data from ../data/From_API/all_json_Solutions_Demo_Workspace_2024-02-01T08_17_38.json
# Loading Dashboards, Investigations, Metrics data from ../data/From_API/all_json_Process_AI_2024-02-01T08_17_57.json

# %% [markdown]
# ### Here we define extract Signals from above all_json files
# construct lib to extract Signal queries from JSONS

# %%
# Here we define lib to extract Signal queries from JSONS 
# Signals From Metrics Investigations Dashboard JSONs
# Add JSON metrics
import datetime
import pathlib
from string import Formatter
from string import Template 

def vars_substitution(mindex=0,m={}):
        """    
        input: m -json with metrics from file with all variables in it
        mindex - index of metric
        s=m['metrics'][0]['signalFragment'] e.g
        'AVG(\n\t(SELECT LAST(end_time)\n\t\tWHERE event_name IN (${ato_po_acknowledgement_events}))\n\t-(SELECT FIRST(end_time)\n\t\tWHERE event_name IN (${ato_po_creation_events}))\n   )'
        """
        s=m['metrics'][mindex]['signalFragment']
        #print(s)
        temp=Template(s)
        mvars= [ele[1] for ele in Formatter().parse(s) if ele[1]]
        mapm={}
        metric_vars={}
        if 'variables' in m.keys():
            mapm={mv: var['defaultValues'][0]['defaultValue'] for mv in mvars for var in m['variables']  if var['name'] == mv}
            metric_vars={mv: var for mv in mvars for var in m['variables']  if var['name'] == mv}
            { metric_vars[mv].update(value=mapm[mv]) for mv in metric_vars} # add value to unify with other sources
        if 'metricsVariables' in m.keys():
            mapm={mv: var['value'] for mv in mvars for var in m['metricsVariables']  if var['name'] == mv}
            metric_vars={  mv: var for mv in mvars for var in m['metricsVariables']  if var['name'] == mv}
        if 'metricVariables' in m.keys():
            mapm={mv: var['value'] for mv in mvars for var in m['metricVariables']  if var['name'] == mv}
            metric_vars={  mv: var for mv in mvars for var in m['metricVariables']  if var['name'] == mv}
        # Sanity check
        if len(set(mvars)) != len(mapm):
            print(">>>>>>>>>>>>>>>>>>>>>>>>>>>>>Mapping Error:\n ", mvars, mapm)
            bug_vars={ mv: str(mv) for mv in mvars if mv not in mapm.keys()}
            mapm.update(bug_vars)
        #print("STR DDBG mapm",mapm)
        #print("STR DDBG s, m['metrics'][mindex],metric_vars:",s, m['metrics'][mindex],metric_vars )
        #s.format(**mapm) # produces extra $
        return temp.substitute(**mapm) , s,  mapm, m['metrics'][mindex] , metric_vars


def docs_from_metric_json(path, from_json=None, view="strview-1"):
        """
        INput path to file with metrics
        output: langchain docs collection
        """
        jdocs=[]
        
        if from_json != None: 
            metrics=from_json
        else:
            # path is real path to json-file
            with pathlib.Path(path).open(encoding="utf8") as stream:
                metrics= json.load(stream)
        
        for i in range(len(metrics['metrics'])):
                signal, s, mapm, metric, metric_vars = vars_substitution(mindex=i,m=metrics)
                string_to_prompt="""
SELECT
{signal}
FROM "{THIS_PROCESS}"
                """.format(signal=signal,THIS_PROCESS=view)
                name=metric['name']
                doc={name:string_to_prompt}
                description=metric['description']
                #print(doc)
                if len(doc) == 1:
                    #jdocs.append(doc)
                    jdocs.append({"name":name,"query":string_to_prompt,
                                  "description":description,
                                  "meta":"metric",
                                  "metric_vars":metric_vars,
                                  "view":view,
                                  "signalFragment":f'SELECT {s} FROM THIS_PROCESS',
                                  "process":path
                                  })
                else:
                    print(len(doc)," ERROR in loading metric - it is too long change chunk_size=500", doc)

        #   
        print('Number of Metrics Signals: {} in: {}'.format(len(jdocs), path))
        return {path:jdocs}

def docs_from_investigations_dashboard_json(path, from_json=None, sourcekeys=['investigations','dashboard','metrics'], view="strview-1"): 
    """
    sourcekey="investigations" for investigation files
    sourcekey="dashboard" for dashboards
    sourcekey="metrics" for 
    INput path to file with dashboard and metrics
    output: docs with SIGNAL collection
    """
    jdocs=[]
    jdocsm=[]
    if from_json != None: 
        dashboards=from_json
    else:
        # path is real path to json-file
        with pathlib.Path(path).open(encoding="utf8") as stream:
            dashboards= json.load(stream)
   
    for sourcekey in dashboards.keys():
        if sourcekey in sourcekeys and sourcekey != 'metrics':
            for c0 in dashboards[sourcekey]['rootWidget']['children']:
                for c1 in c0['children']:
                    if 'dataSource' in c1.keys() and c1['dataSource']['type'] == "SIGNAL":
                        signalFragment=c1['dataSource']['query']
                        # to handle ""THIS_PROCESS"" -> "THIS_PROCESS" substitution issue
                        query=signalFragment.replace('"THIS_PROCESS"','THIS_PROCESS').replace("THIS_PROCESS",f'"{view}"')
                        name=c1['name']
                        if 'description' in c1.keys():
                            description=c1['description']
                        else:
                            description=""
                        #print(c1['dataSource']['type'],name, description, query )
                        jdocs.append({"name":name,
                                      "query":query,
                                      "description":description,
                                      "meta":sourcekey,
                                      "metric_vars":"",
                                      "view":view,
                                      "signalFragment":f'{signalFragment}',
                                      "process":path
                                      })                        
                        
            print(' Number of {} Signals: {} in: {}'.format(sourcekey,len(jdocs),path))
        elif sourcekey == "metrics":
            if "metrics" in dashboards.keys() and len (dashboards['metrics']) > 0:
                for i in range(len(dashboards['metrics'])):
                    signal, s, mapm, metric, metric_vars = vars_substitution(mindex=i,m=dashboards)
                    #print("Dashboard ",i, "map vars:",mapm)
                    string_to_prompt="""
SELECT
{signal}
FROM "{THIS_PROCESS}"
                """.format(signal=signal,THIS_PROCESS=view)
                    name=metric['name']
                    if 'description' in metric.keys():
                        description=metric['description']
                    else:
                        description=""
                    jdocsm.append({"name":name,"query":string_to_prompt,
                               "description":description,
                               "meta":"metric",
                               "metric_vars":metric_vars,
                                "view":view,
                                "signalFragment":f'SELECT {s} FROM THIS_PROCESS',
                                "process":path
                               })
            print('Number of {} Metrics in Dashboards/Investigations Signals: {} in: {}'.format(sourcekey,len(jdocsm),path))
            
            
    return {path:jdocs+jdocsm}    
# Signals from all_json queries
# Signals from metric query json
#%%script echo skipping
#
def from_all_json_to_all_extracted_signals(all_json,workspacename="Process AI"):
    """_summary_

    Args:
        all_json (_type_): input
        signals_all - JSON
        all_extracted_signals_DATE.json
    """
    signals_all=[]
    for path in all_json:
        #if path != "test00":
        #    continue
        #path='demo01'
        signals_m=[]
        print('dashboardCount:{} investigationCount {} metricCount {}'.format(all_json[path]['dashboardCount'], all_json[path]['investigationCount'], all_json[path]['metricCount']))
        # Metrics
        for j in  all_json[path]['metrics_jsons']:
            #j = all_json[path]['list_metrics']
            print(next(iter(j)))
            fromjson, viewid= j[next(iter(j))]['json'], j[next(iter(j))]['view_id']
            #workspacename=str(pathlib.Path(next(iter(j)))).rsplit(os.sep)[-4]
            m = docs_from_metric_json(path, from_json=fromjson, view=viewid)[path] #"strview-1") #[path][0]['metric_vars']['sla_closure_events']
            [s.update(origin=next(iter(j)),workspace_name=workspacename) for s in m]
            #print(q)
            print("W:",workspacename, " M",next(iter(j)), len(m))
            signals_m+=m
        print("        From metric file:", len(signals_m))
        #print(m[path])

        # Dashboards
        signals_d=[]
        for j in  all_json[path]['dashboards_jsons']:
        # j = all_json[path]['dashboards_jsons'][0]
            fromjson, viewid= j[next(iter(j))]['json'], j[next(iter(j))]['view_id']
            #workspacename=str(pathlib.Path(next(iter(j)))).rsplit(os.sep)[-4] 
            d = docs_from_investigations_dashboard_json(path,from_json=fromjson, sourcekeys=["dashboard","metrics"],view=viewid)[path]
            [s.update(origin=next(iter(j)),workspace_name=workspacename) for s in d]
            print("W:",workspacename, "D",next(iter(j)), len(d))
            signals_d+=d
        print("         From dashboard files:", len(signals_d))
        #print(d)

        # Investigations
        signals_i=[]    
        for j in  all_json[path]['investigations_jsons']:
            #j = all_json[path]['investigations_jsons'][0]
            print("I",next(iter(j)))
            fromjson, viewid= j[next(iter(j))]['json'], j[next(iter(j))]['view_id']
            #workspacename=str(pathlib.Path(next(iter(j)))).rsplit(os.sep)[-4] 
            i = docs_from_investigations_dashboard_json(path,from_json=fromjson, sourcekeys=["investigation","metrics"],view=viewid)[path]
            [s.update(origin=next(iter(j)),workspace_name=workspacename) for s in i]
            print("W:",workspacename," I",next(iter(j)), len(i))
            signals_i+=i
            #print(i)
        print("         From investigations files:", len(signals_i))

        signals=signals_m+signals_d+signals_i    
        print(path," subtotal Signals",len(signals))
        signals_all+=signals
    print("Total Signals",len(signals_all))
    return signals_all

# %% [markdown]
# ###  Extract Signals from all_json and save them to all_extracted_signals_DATE.json

# %%
# Get signals from all_json and aal_json_1
#- all_json with "Solutions Demo Workspace"
#- all_json_1 with "Process AI"
signals_all  = from_all_json_to_all_extracted_signals(all_json, workspacename="Solutions Demo Workspace")
signals_all += from_all_json_to_all_extracted_signals(all_json_1, workspacename= "Process AI")
#signals_all = from_all_json_to_all_extracted_signals(all_json)
#signals_all = from_all_json_to_all_extracted_signals(all_json_2)
print("Total Signals to save",len(signals_all))
# Out:
# dashboardCount:7 investigationCount 0 metricCount 1
# ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards ITC ECC & S4H (DO NOT CHANGE)/metrics/metrics.json
# Number of Metrics Signals: 1 in: 000_DEMO✨ - Dashboards ITC ECC & S4H (DO NOT CHANGE)
# W: Solutions Demo Workspace  M ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards ITC ECC & S4H (DO NOT CHANGE)/metrics/metrics.json 1
#         From metric file: 1
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: 000_DEMO✨ - Dashboards ITC ECC & S4H (DO NOT CHANGE)
#  Number of dashboard Signals: 20 in: 000_DEMO✨ - Dashboards ITC ECC & S4H (DO NOT CHANGE)
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards ITC ECC & S4H (DO NOT CHANGE)/dashboards/Cycle Times_2024-02-01.json 20
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: 000_DEMO✨ - Dashboards ITC ECC & S4H (DO NOT CHANGE)
#  Number of dashboard Signals: 30 in: 000_DEMO✨ - Dashboards ITC ECC & S4H (DO NOT CHANGE)
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards ITC ECC & S4H (DO NOT CHANGE)/dashboards/Automation_2024-02-01.json 30
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: 000_DEMO✨ - Dashboards ITC ECC & S4H (DO NOT CHANGE)
#  Number of dashboard Signals: 28 in: 000_DEMO✨ - Dashboards ITC ECC & S4H (DO NOT CHANGE)
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards ITC ECC & S4H (DO NOT CHANGE)/dashboards/00_Overview_2024-02-01.json 28
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: 000_DEMO✨ - Dashboards ITC ECC & S4H (DO NOT CHANGE)
#  Number of dashboard Signals: 22 in: 000_DEMO✨ - Dashboards ITC ECC & S4H (DO NOT CHANGE)
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards ITC ECC & S4H (DO NOT CHANGE)/dashboards/Optimize Your Payment Term Usage_2024-02-01.json 22
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: 000_DEMO✨ - Dashboards ITC ECC & S4H (DO NOT CHANGE)
#  Number of dashboard Signals: 39 in: 000_DEMO✨ - Dashboards ITC ECC & S4H (DO NOT CHANGE)
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards ITC ECC & S4H (DO NOT CHANGE)/dashboards/Improve Days Sales Outstanding (DSO) _2024-02-01.json 39
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: 000_DEMO✨ - Dashboards ITC ECC & S4H (DO NOT CHANGE)
#  Number of dashboard Signals: 74 in: 000_DEMO✨ - Dashboards ITC ECC & S4H (DO NOT CHANGE)
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards ITC ECC & S4H (DO NOT CHANGE)/dashboards/Global Value Approach_2024-02-01.json 74
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: 000_DEMO✨ - Dashboards ITC ECC & S4H (DO NOT CHANGE)
#  Number of dashboard Signals: 74 in: 000_DEMO✨ - Dashboards ITC ECC & S4H (DO NOT CHANGE)
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards ITC ECC & S4H (DO NOT CHANGE)/dashboards/_Global Value Approach_2024-02-01.json 74
#          From dashboard files: 287
#          From investigations files: 0
# 000_DEMO✨ - Dashboards ITC ECC & S4H (DO NOT CHANGE)  subtotal Signals 288
# dashboardCount:7 investigationCount 0 metricCount 6
# ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards ITP ECC & S4H (DO NOT CHANGE)/metrics/metrics.json
# Number of Metrics Signals: 6 in: 000_DEMO✨ - Dashboards ITP ECC & S4H (DO NOT CHANGE)
# W: Solutions Demo Workspace  M ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards ITP ECC & S4H (DO NOT CHANGE)/metrics/metrics.json 6
#         From metric file: 6
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: 000_DEMO✨ - Dashboards ITP ECC & S4H (DO NOT CHANGE)
#  Number of dashboard Signals: 33 in: 000_DEMO✨ - Dashboards ITP ECC & S4H (DO NOT CHANGE)
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards ITP ECC & S4H (DO NOT CHANGE)/dashboards/Automation_2024-02-01.json 33
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: 000_DEMO✨ - Dashboards ITP ECC & S4H (DO NOT CHANGE)
#  Number of dashboard Signals: 3 in: 000_DEMO✨ - Dashboards ITP ECC & S4H (DO NOT CHANGE)
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards ITP ECC & S4H (DO NOT CHANGE)/dashboards/SAP S/4HANA - Invoice to Pay_2024-02-01.json 3
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: 000_DEMO✨ - Dashboards ITP ECC & S4H (DO NOT CHANGE)
#  Number of dashboard Signals: 29 in: 000_DEMO✨ - Dashboards ITP ECC & S4H (DO NOT CHANGE)
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards ITP ECC & S4H (DO NOT CHANGE)/dashboards/00_Overview_2024-02-01.json 29
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: 000_DEMO✨ - Dashboards ITP ECC & S4H (DO NOT CHANGE)
#  Number of dashboard Signals: 20 in: 000_DEMO✨ - Dashboards ITP ECC & S4H (DO NOT CHANGE)
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards ITP ECC & S4H (DO NOT CHANGE)/dashboards/Cycle Times_2024-02-01.json 20
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: 000_DEMO✨ - Dashboards ITP ECC & S4H (DO NOT CHANGE)
#  Number of dashboard Signals: 49 in: 000_DEMO✨ - Dashboards ITP ECC & S4H (DO NOT CHANGE)
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards ITP ECC & S4H (DO NOT CHANGE)/dashboards/Open Overdue Invoices_2024-02-01.json 49
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: 000_DEMO✨ - Dashboards ITP ECC & S4H (DO NOT CHANGE)
#  Number of dashboard Signals: 59 in: 000_DEMO✨ - Dashboards ITP ECC & S4H (DO NOT CHANGE)
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards ITP ECC & S4H (DO NOT CHANGE)/dashboards/Payment Behaviour_2024-02-01.json 59
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: 000_DEMO✨ - Dashboards ITP ECC & S4H (DO NOT CHANGE)
#  Number of dashboard Signals: 34 in: 000_DEMO✨ - Dashboards ITP ECC & S4H (DO NOT CHANGE)
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards ITP ECC & S4H (DO NOT CHANGE)/dashboards/Payment Term_2024-02-01.json 34
#          From dashboard files: 227
#          From investigations files: 0
# 000_DEMO✨ - Dashboards ITP ECC & S4H (DO NOT CHANGE)  subtotal Signals 233
# dashboardCount:7 investigationCount 1 metricCount 5
# ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards OTC ECC & S4H (DO NOT CHANGE) /metrics/metrics.json
# Number of Metrics Signals: 5 in: 000_DEMO✨ - Dashboards OTC ECC & S4H (DO NOT CHANGE)
# W: Solutions Demo Workspace  M ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards OTC ECC & S4H (DO NOT CHANGE) /metrics/metrics.json 5
#         From metric file: 5
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: 000_DEMO✨ - Dashboards OTC ECC & S4H (DO NOT CHANGE)
#  Number of dashboard Signals: 3 in: 000_DEMO✨ - Dashboards OTC ECC & S4H (DO NOT CHANGE)
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards OTC ECC & S4H (DO NOT CHANGE) /dashboards/zz-SAP S/4HANA - Order to Cash_2024-02-01.json 3
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: 000_DEMO✨ - Dashboards OTC ECC & S4H (DO NOT CHANGE)
#  Number of dashboard Signals: 27 in: 000_DEMO✨ - Dashboards OTC ECC & S4H (DO NOT CHANGE)
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards OTC ECC & S4H (DO NOT CHANGE) /dashboards/Customer Satisfaction_2024-02-01.json 27
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: 000_DEMO✨ - Dashboards OTC ECC & S4H (DO NOT CHANGE)
#  Number of dashboard Signals: 27 in: 000_DEMO✨ - Dashboards OTC ECC & S4H (DO NOT CHANGE)
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards OTC ECC & S4H (DO NOT CHANGE) /dashboards/00_Overview_2024-02-01.json 27
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: 000_DEMO✨ - Dashboards OTC ECC & S4H (DO NOT CHANGE)
#  Number of dashboard Signals: 32 in: 000_DEMO✨ - Dashboards OTC ECC & S4H (DO NOT CHANGE)
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards OTC ECC & S4H (DO NOT CHANGE) /dashboards/Cycle Times_2024-02-01.json 32
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: 000_DEMO✨ - Dashboards OTC ECC & S4H (DO NOT CHANGE)
#  Number of dashboard Signals: 37 in: 000_DEMO✨ - Dashboards OTC ECC & S4H (DO NOT CHANGE)
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards OTC ECC & S4H (DO NOT CHANGE) /dashboards/Automation_2024-02-01.json 37
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: 000_DEMO✨ - Dashboards OTC ECC & S4H (DO NOT CHANGE)
#  Number of dashboard Signals: 39 in: 000_DEMO✨ - Dashboards OTC ECC & S4H (DO NOT CHANGE)
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards OTC ECC & S4H (DO NOT CHANGE) /dashboards/Working Capital_2024-02-01.json 39
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: 000_DEMO✨ - Dashboards OTC ECC & S4H (DO NOT CHANGE)
#  Number of dashboard Signals: 47 in: 000_DEMO✨ - Dashboards OTC ECC & S4H (DO NOT CHANGE)
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards OTC ECC & S4H (DO NOT CHANGE) /dashboards/Efficiency and Rework_2024-02-01.json 47
#          From dashboard files: 212
# I ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards OTC ECC & S4H (DO NOT CHANGE) /investigations/General_2024-02-01.json
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: 000_DEMO✨ - Dashboards OTC ECC & S4H (DO NOT CHANGE)
#  Number of investigation Signals: 0 in: 000_DEMO✨ - Dashboards OTC ECC & S4H (DO NOT CHANGE)
# W: Solutions Demo Workspace  I ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards OTC ECC & S4H (DO NOT CHANGE) /investigations/General_2024-02-01.json 0
#          From investigations files: 0
# 000_DEMO✨ - Dashboards OTC ECC & S4H (DO NOT CHANGE)   subtotal Signals 217
# dashboardCount:16 investigationCount 2 metricCount 71
# ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)/metrics/metrics.json
# Number of Metrics Signals: 71 in: 000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)
# W: Solutions Demo Workspace  M ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)/metrics/metrics.json 71
#         From metric file: 71
# Number of metrics Metrics in Dashboards/Investigations Signals: 7 in: 000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)
#  Number of dashboard Signals: 15 in: 000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)/dashboards/zz Dashboard 4: Changes_2024-02-01.json 22
# Number of metrics Metrics in Dashboards/Investigations Signals: 10 in: 000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)
#  Number of dashboard Signals: 5 in: 000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)/dashboards/zz - PO Vendor Dashboard_2024-02-01.json 15
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: 000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)
#  Number of dashboard Signals: 22 in: 000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)/dashboards/zz_Agnostic - Overview_2024-02-01.json 22
# Number of metrics Metrics in Dashboards/Investigations Signals: 1 in: 000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)
#  Number of dashboard Signals: 6 in: 000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)/dashboards/zz: Data Validation _2024-02-01.json 7
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: 000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)
#  Number of dashboard Signals: 10 in: 000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)/dashboards/zz - Empty Dashboard Template_2024-02-01.json 10
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: 000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)
#  Number of dashboard Signals: 0 in: 000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)/dashboards/zz: General Recommendations_2024-02-01.json 0
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: 000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)
#  Number of dashboard Signals: 9 in: 000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)/dashboards/zz - CBI Test Dashboard_2024-02-01.json 9
# Number of metrics Metrics in Dashboards/Investigations Signals: 4 in: 000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)
#  Number of dashboard Signals: 16 in: 000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)/dashboards/zz_CBI - Payment Term Optimization (for Final dashboard)_2024-02-01.json 20
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: 000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)
#  Number of dashboard Signals: 3 in: 000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)/dashboards/zz_SAP S/4HANA - Procure to Pay_2024-02-01.json 3
# Number of metrics Metrics in Dashboards/Investigations Signals: 2 in: 000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)
#  Number of dashboard Signals: 8 in: 000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)/dashboards/   Dashboard Feature Test_2024-02-01.json 10
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: 000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)
#  Number of dashboard Signals: 31 in: 000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)/dashboards/Open Overdue Invoices_2024-02-01.json 31
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: 000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)
#  Number of dashboard Signals: 16 in: 000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)/dashboards/Cycle Times_2024-02-01.json 16
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: 000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)
#  Number of dashboard Signals: 24 in: 000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)/dashboards/00_Overview_2024-02-01.json 24
# Number of metrics Metrics in Dashboards/Investigations Signals: 1 in: 000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)
#  Number of dashboard Signals: 14 in: 000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)/dashboards/Late Payments _2024-02-01.json 15
# Number of metrics Metrics in Dashboards/Investigations Signals: 1 in: 000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)
#  Number of dashboard Signals: 20 in: 000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)/dashboards/Automation_2024-02-01.json 21
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: 000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)
#  Number of dashboard Signals: 54 in: 000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)/dashboards/Global Value Approach_2024-02-01.json 54
#          From dashboard files: 279
# I ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)/investigations/Presales Template - HZL POV_Insights_2024-02-01.json
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>Mapping Error:
#   ['po_change_event_flow', 'po_creation_events'] {}
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>Mapping Error:
#   ['itp_clearing_date', 'itp_invoice_clearing_period', 'itp_posting_date', 'itp_invoice_posting_period'] {'itp_invoice_clearing_period': "'52weeks'", 'itp_posting_date': '"Last FI Invoice Posting Date"', 'itp_invoice_posting_period': "'52weeks'"}
# Number of metrics Metrics in Dashboards/Investigations Signals: 9 in: 000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)
#  Number of investigation Signals: 192 in: 000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)
# W: Solutions Demo Workspace  I ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)/investigations/Presales Template - HZL POV_Insights_2024-02-01.json 201
# I ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)/investigations/Dashboard Feature Validation_2024-02-01.json
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: 000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)
#  Number of investigation Signals: 0 in: 000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)
# W: Solutions Demo Workspace  I ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)/investigations/Dashboard Feature Validation_2024-02-01.json 0
#          From investigations files: 201
# 000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE)  subtotal Signals 551
# dashboardCount:1 investigationCount 0 metricCount 25
# ../data/From_API/Solutions Demo Workspace/00_DEMO - Acquire-to-Onboard for  SAP ECC & S/4 HANA (DO NOT CHANGE)/metrics/metrics.json
# Number of Metrics Signals: 25 in: 00_DEMO - Acquire-to-Onboard for  SAP ECC & S/4 HANA (DO NOT CHANGE)
# W: Solutions Demo Workspace  M ../data/From_API/Solutions Demo Workspace/00_DEMO - Acquire-to-Onboard for  SAP ECC & S/4 HANA (DO NOT CHANGE)/metrics/metrics.json 25
#         From metric file: 25
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: 00_DEMO - Acquire-to-Onboard for  SAP ECC & S/4 HANA (DO NOT CHANGE)
#  Number of dashboard Signals: 27 in: 00_DEMO - Acquire-to-Onboard for  SAP ECC & S/4 HANA (DO NOT CHANGE)
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/00_DEMO - Acquire-to-Onboard for  SAP ECC & S/4 HANA (DO NOT CHANGE)/dashboards/00_Overview_2024-02-01.json 27
#          From dashboard files: 27
#          From investigations files: 0
# 00_DEMO - Acquire-to-Onboard for  SAP ECC & S/4 HANA (DO NOT CHANGE)  subtotal Signals 52
# dashboardCount:1 investigationCount 0 metricCount 7
# ../data/From_API/Solutions Demo Workspace/00_DEMO - Attract-to-Acquire-Talent for SuccessFactors/metrics/metrics.json
# Number of Metrics Signals: 7 in: 00_DEMO - Attract-to-Acquire-Talent for SuccessFactors
# W: Solutions Demo Workspace  M ../data/From_API/Solutions Demo Workspace/00_DEMO - Attract-to-Acquire-Talent for SuccessFactors/metrics/metrics.json 7
#         From metric file: 7
# Number of metrics Metrics in Dashboards/Investigations Signals: 3 in: 00_DEMO - Attract-to-Acquire-Talent for SuccessFactors
#  Number of dashboard Signals: 0 in: 00_DEMO - Attract-to-Acquire-Talent for SuccessFactors
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/00_DEMO - Attract-to-Acquire-Talent for SuccessFactors/dashboards/SAP SuccessFactors - Attract to Acquire Talent_2024-02-01.json 3
#          From dashboard files: 3
#          From investigations files: 0
# 00_DEMO - Attract-to-Acquire-Talent for SuccessFactors  subtotal Signals 10
# dashboardCount:2 investigationCount 0 metricCount 13
# ../data/From_API/Solutions Demo Workspace/00_DEMO - Inspect-to-Quality for SAP S/4 HANA (DO NOT CHANGE)/metrics/metrics.json
# Number of Metrics Signals: 13 in: 00_DEMO - Inspect-to-Quality for SAP S/4 HANA (DO NOT CHANGE)
# W: Solutions Demo Workspace  M ../data/From_API/Solutions Demo Workspace/00_DEMO - Inspect-to-Quality for SAP S/4 HANA (DO NOT CHANGE)/metrics/metrics.json 13
#         From metric file: 13
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: 00_DEMO - Inspect-to-Quality for SAP S/4 HANA (DO NOT CHANGE)
#  Number of dashboard Signals: 3 in: 00_DEMO - Inspect-to-Quality for SAP S/4 HANA (DO NOT CHANGE)
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/00_DEMO - Inspect-to-Quality for SAP S/4 HANA (DO NOT CHANGE)/dashboards/SAP S/4HANA - Inspect to Quality_2024-02-01.json 3
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: 00_DEMO - Inspect-to-Quality for SAP S/4 HANA (DO NOT CHANGE)
#  Number of dashboard Signals: 25 in: 00_DEMO - Inspect-to-Quality for SAP S/4 HANA (DO NOT CHANGE)
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/00_DEMO - Inspect-to-Quality for SAP S/4 HANA (DO NOT CHANGE)/dashboards/00_Overview_2024-02-01.json 25
#          From dashboard files: 28
#          From investigations files: 0
# 00_DEMO - Inspect-to-Quality for SAP S/4 HANA (DO NOT CHANGE)  subtotal Signals 41
# dashboardCount:3 investigationCount 3 metricCount 63
# ../data/From_API/Solutions Demo Workspace/00_DEMO - Invoice-to-Cash for SAP S/4 HANA (DO NOT CHANGE)/metrics/metrics.json
# Number of Metrics Signals: 63 in: 00_DEMO - Invoice-to-Cash for SAP S/4 HANA (DO NOT CHANGE)
# W: Solutions Demo Workspace  M ../data/From_API/Solutions Demo Workspace/00_DEMO - Invoice-to-Cash for SAP S/4 HANA (DO NOT CHANGE)/metrics/metrics.json 63
#         From metric file: 63
# Number of metrics Metrics in Dashboards/Investigations Signals: 1 in: 00_DEMO - Invoice-to-Cash for SAP S/4 HANA (DO NOT CHANGE)
#  Number of dashboard Signals: 3 in: 00_DEMO - Invoice-to-Cash for SAP S/4 HANA (DO NOT CHANGE)
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/00_DEMO - Invoice-to-Cash for SAP S/4 HANA (DO NOT CHANGE)/dashboards/Process Overview _2024-02-01.json 4
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: 00_DEMO - Invoice-to-Cash for SAP S/4 HANA (DO NOT CHANGE)
#  Number of dashboard Signals: 22 in: 00_DEMO - Invoice-to-Cash for SAP S/4 HANA (DO NOT CHANGE)
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/00_DEMO - Invoice-to-Cash for SAP S/4 HANA (DO NOT CHANGE)/dashboards/Agnostic - Overview_2024-02-01.json 22
# Number of metrics Metrics in Dashboards/Investigations Signals: 4 in: 00_DEMO - Invoice-to-Cash for SAP S/4 HANA (DO NOT CHANGE)
#  Number of dashboard Signals: 0 in: 00_DEMO - Invoice-to-Cash for SAP S/4 HANA (DO NOT CHANGE)
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/00_DEMO - Invoice-to-Cash for SAP S/4 HANA (DO NOT CHANGE)/dashboards/SAP S/4HANA - Invoice to Cash_2024-02-01.json 4
#          From dashboard files: 30
# I ../data/From_API/Solutions Demo Workspace/00_DEMO - Invoice-to-Cash for SAP S/4 HANA (DO NOT CHANGE)/investigations/ITC Metrics testing_2024-02-01.json
# Number of metrics Metrics in Dashboards/Investigations Signals: 7 in: 00_DEMO - Invoice-to-Cash for SAP S/4 HANA (DO NOT CHANGE)
#  Number of investigation Signals: 1 in: 00_DEMO - Invoice-to-Cash for SAP S/4 HANA (DO NOT CHANGE)
# W: Solutions Demo Workspace  I ../data/From_API/Solutions Demo Workspace/00_DEMO - Invoice-to-Cash for SAP S/4 HANA (DO NOT CHANGE)/investigations/ITC Metrics testing_2024-02-01.json 8
# I ../data/From_API/Solutions Demo Workspace/00_DEMO - Invoice-to-Cash for SAP S/4 HANA (DO NOT CHANGE)/investigations/Demo ITC_2024-02-01.json
# Number of metrics Metrics in Dashboards/Investigations Signals: 11 in: 00_DEMO - Invoice-to-Cash for SAP S/4 HANA (DO NOT CHANGE)
#  Number of investigation Signals: 0 in: 00_DEMO - Invoice-to-Cash for SAP S/4 HANA (DO NOT CHANGE)
# W: Solutions Demo Workspace  I ../data/From_API/Solutions Demo Workspace/00_DEMO - Invoice-to-Cash for SAP S/4 HANA (DO NOT CHANGE)/investigations/Demo ITC_2024-02-01.json 11
# I ../data/From_API/Solutions Demo Workspace/00_DEMO - Invoice-to-Cash for SAP S/4 HANA (DO NOT CHANGE)/investigations/Invoice-to-Cash_2024-02-01.json
# Number of metrics Metrics in Dashboards/Investigations Signals: 6 in: 00_DEMO - Invoice-to-Cash for SAP S/4 HANA (DO NOT CHANGE)
#  Number of investigation Signals: 0 in: 00_DEMO - Invoice-to-Cash for SAP S/4 HANA (DO NOT CHANGE)
# W: Solutions Demo Workspace  I ../data/From_API/Solutions Demo Workspace/00_DEMO - Invoice-to-Cash for SAP S/4 HANA (DO NOT CHANGE)/investigations/Invoice-to-Cash_2024-02-01.json 6
#          From investigations files: 25
# 00_DEMO - Invoice-to-Cash for SAP S/4 HANA (DO NOT CHANGE)  subtotal Signals 118
# dashboardCount:6 investigationCount 0 metricCount 10
# ../data/From_API/Solutions Demo Workspace/00_DEMO - Invoice-to-Pay for SAP S/4 HANA (DO NOT CHANGE)/metrics/metrics.json
# Number of Metrics Signals: 10 in: 00_DEMO - Invoice-to-Pay for SAP S/4 HANA (DO NOT CHANGE)
# W: Solutions Demo Workspace  M ../data/From_API/Solutions Demo Workspace/00_DEMO - Invoice-to-Pay for SAP S/4 HANA (DO NOT CHANGE)/metrics/metrics.json 10
#         From metric file: 10
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: 00_DEMO - Invoice-to-Pay for SAP S/4 HANA (DO NOT CHANGE)
#  Number of dashboard Signals: 33 in: 00_DEMO - Invoice-to-Pay for SAP S/4 HANA (DO NOT CHANGE)
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/00_DEMO - Invoice-to-Pay for SAP S/4 HANA (DO NOT CHANGE)/dashboards/Automation_2024-02-01.json 33
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: 00_DEMO - Invoice-to-Pay for SAP S/4 HANA (DO NOT CHANGE)
#  Number of dashboard Signals: 59 in: 00_DEMO - Invoice-to-Pay for SAP S/4 HANA (DO NOT CHANGE)
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/00_DEMO - Invoice-to-Pay for SAP S/4 HANA (DO NOT CHANGE)/dashboards/Payment Behaviour_2024-02-01.json 59
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: 00_DEMO - Invoice-to-Pay for SAP S/4 HANA (DO NOT CHANGE)
#  Number of dashboard Signals: 49 in: 00_DEMO - Invoice-to-Pay for SAP S/4 HANA (DO NOT CHANGE)
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/00_DEMO - Invoice-to-Pay for SAP S/4 HANA (DO NOT CHANGE)/dashboards/Open Overdue Invoices_2024-02-01.json 49
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: 00_DEMO - Invoice-to-Pay for SAP S/4 HANA (DO NOT CHANGE)
#  Number of dashboard Signals: 35 in: 00_DEMO - Invoice-to-Pay for SAP S/4 HANA (DO NOT CHANGE)
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/00_DEMO - Invoice-to-Pay for SAP S/4 HANA (DO NOT CHANGE)/dashboards/Payment Terms_2024-02-01.json 35
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: 00_DEMO - Invoice-to-Pay for SAP S/4 HANA (DO NOT CHANGE)
#  Number of dashboard Signals: 20 in: 00_DEMO - Invoice-to-Pay for SAP S/4 HANA (DO NOT CHANGE)
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/00_DEMO - Invoice-to-Pay for SAP S/4 HANA (DO NOT CHANGE)/dashboards/Cycle Times_2024-02-01.json 20
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: 00_DEMO - Invoice-to-Pay for SAP S/4 HANA (DO NOT CHANGE)
#  Number of dashboard Signals: 29 in: 00_DEMO - Invoice-to-Pay for SAP S/4 HANA (DO NOT CHANGE)
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/00_DEMO - Invoice-to-Pay for SAP S/4 HANA (DO NOT CHANGE)/dashboards/00_Overview_2024-02-01.json 29
#          From dashboard files: 225
#          From investigations files: 0
# 00_DEMO - Invoice-to-Pay for SAP S/4 HANA (DO NOT CHANGE)  subtotal Signals 235
# dashboardCount:1 investigationCount 2 metricCount 36
# ../data/From_API/Solutions Demo Workspace/00_DEMO Issue-to-Resolution for Jira/metrics/metrics.json
# Number of Metrics Signals: 36 in: 00_DEMO Issue-to-Resolution for Jira
# W: Solutions Demo Workspace  M ../data/From_API/Solutions Demo Workspace/00_DEMO Issue-to-Resolution for Jira/metrics/metrics.json 36
#         From metric file: 36
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: 00_DEMO Issue-to-Resolution for Jira
#  Number of dashboard Signals: 43 in: 00_DEMO Issue-to-Resolution for Jira
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/00_DEMO Issue-to-Resolution for Jira/dashboards/00_Overview_2024-02-01.json 43
#          From dashboard files: 43
# I ../data/From_API/Solutions Demo Workspace/00_DEMO Issue-to-Resolution for Jira/investigations/Issue-to-Resolution_2024-02-01.json
# Number of metrics Metrics in Dashboards/Investigations Signals: 4 in: 00_DEMO Issue-to-Resolution for Jira
#  Number of investigation Signals: 0 in: 00_DEMO Issue-to-Resolution for Jira
# W: Solutions Demo Workspace  I ../data/From_API/Solutions Demo Workspace/00_DEMO Issue-to-Resolution for Jira/investigations/Issue-to-Resolution_2024-02-01.json 4
# I ../data/From_API/Solutions Demo Workspace/00_DEMO Issue-to-Resolution for Jira/investigations/Issue-to-Resolution (Copy)_2024-02-01.json
# Number of metrics Metrics in Dashboards/Investigations Signals: 4 in: 00_DEMO Issue-to-Resolution for Jira
#  Number of investigation Signals: 0 in: 00_DEMO Issue-to-Resolution for Jira
# W: Solutions Demo Workspace  I ../data/From_API/Solutions Demo Workspace/00_DEMO Issue-to-Resolution for Jira/investigations/Issue-to-Resolution (Copy)_2024-02-01.json 4
#          From investigations files: 8
# 00_DEMO Issue-to-Resolution for Jira  subtotal Signals 87
# dashboardCount:5 investigationCount 4 metricCount 2
# ../data/From_API/Solutions Demo Workspace/00_DEMO - Make-to-Stock for SAP S/4 HANA (DO NOT CHANGE)/metrics/metrics.json
# Number of Metrics Signals: 2 in: 00_DEMO - Make-to-Stock for SAP S/4 HANA (DO NOT CHANGE)
# W: Solutions Demo Workspace  M ../data/From_API/Solutions Demo Workspace/00_DEMO - Make-to-Stock for SAP S/4 HANA (DO NOT CHANGE)/metrics/metrics.json 2
#         From metric file: 2
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: 00_DEMO - Make-to-Stock for SAP S/4 HANA (DO NOT CHANGE)
#  Number of dashboard Signals: 13 in: 00_DEMO - Make-to-Stock for SAP S/4 HANA (DO NOT CHANGE)
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/00_DEMO - Make-to-Stock for SAP S/4 HANA (DO NOT CHANGE)/dashboards/General_2024-02-01.json 13
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: 00_DEMO - Make-to-Stock for SAP S/4 HANA (DO NOT CHANGE)
#  Number of dashboard Signals: 29 in: 00_DEMO - Make-to-Stock for SAP S/4 HANA (DO NOT CHANGE)
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/00_DEMO - Make-to-Stock for SAP S/4 HANA (DO NOT CHANGE)/dashboards/Reduce manufacturing costs & improve process harmonization_2024-02-01.json 29
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: 00_DEMO - Make-to-Stock for SAP S/4 HANA (DO NOT CHANGE)
#  Number of dashboard Signals: 4 in: 00_DEMO - Make-to-Stock for SAP S/4 HANA (DO NOT CHANGE)
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/00_DEMO - Make-to-Stock for SAP S/4 HANA (DO NOT CHANGE)/dashboards/Overview_2024-02-01.json 4
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: 00_DEMO - Make-to-Stock for SAP S/4 HANA (DO NOT CHANGE)
#  Number of dashboard Signals: 22 in: 00_DEMO - Make-to-Stock for SAP S/4 HANA (DO NOT CHANGE)
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/00_DEMO - Make-to-Stock for SAP S/4 HANA (DO NOT CHANGE)/dashboards/Agnostic - Overview Dashboard_2024-02-01.json 22
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: 00_DEMO - Make-to-Stock for SAP S/4 HANA (DO NOT CHANGE)
#  Number of dashboard Signals: 3 in: 00_DEMO - Make-to-Stock for SAP S/4 HANA (DO NOT CHANGE)
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/00_DEMO - Make-to-Stock for SAP S/4 HANA (DO NOT CHANGE)/dashboards/SAP S/4HANA - Make to Stock_2024-02-01.json 3
#          From dashboard files: 71
# I ../data/From_API/Solutions Demo Workspace/00_DEMO - Make-to-Stock for SAP S/4 HANA (DO NOT CHANGE)/investigations/KPI Validation_2024-02-01.json
# Number of metrics Metrics in Dashboards/Investigations Signals: 1 in: 00_DEMO - Make-to-Stock for SAP S/4 HANA (DO NOT CHANGE)
#  Number of investigation Signals: 47 in: 00_DEMO - Make-to-Stock for SAP S/4 HANA (DO NOT CHANGE)
# W: Solutions Demo Workspace  I ../data/From_API/Solutions Demo Workspace/00_DEMO - Make-to-Stock for SAP S/4 HANA (DO NOT CHANGE)/investigations/KPI Validation_2024-02-01.json 48
# I ../data/From_API/Solutions Demo Workspace/00_DEMO - Make-to-Stock for SAP S/4 HANA (DO NOT CHANGE)/investigations/Presentation_2024-02-01.json
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: 00_DEMO - Make-to-Stock for SAP S/4 HANA (DO NOT CHANGE)
#  Number of investigation Signals: 60 in: 00_DEMO - Make-to-Stock for SAP S/4 HANA (DO NOT CHANGE)
# W: Solutions Demo Workspace  I ../data/From_API/Solutions Demo Workspace/00_DEMO - Make-to-Stock for SAP S/4 HANA (DO NOT CHANGE)/investigations/Presentation_2024-02-01.json 60
# I ../data/From_API/Solutions Demo Workspace/00_DEMO - Make-to-Stock for SAP S/4 HANA (DO NOT CHANGE)/investigations/Plan to Fulfill_2024-02-01.json
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: 00_DEMO - Make-to-Stock for SAP S/4 HANA (DO NOT CHANGE)
#  Number of investigation Signals: 17 in: 00_DEMO - Make-to-Stock for SAP S/4 HANA (DO NOT CHANGE)
# W: Solutions Demo Workspace  I ../data/From_API/Solutions Demo Workspace/00_DEMO - Make-to-Stock for SAP S/4 HANA (DO NOT CHANGE)/investigations/Plan to Fulfill_2024-02-01.json 17
# I ../data/From_API/Solutions Demo Workspace/00_DEMO - Make-to-Stock for SAP S/4 HANA (DO NOT CHANGE)/investigations/KPI Status_2024-02-01.json
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: 00_DEMO - Make-to-Stock for SAP S/4 HANA (DO NOT CHANGE)
#  Number of investigation Signals: 35 in: 00_DEMO - Make-to-Stock for SAP S/4 HANA (DO NOT CHANGE)
# W: Solutions Demo Workspace  I ../data/From_API/Solutions Demo Workspace/00_DEMO - Make-to-Stock for SAP S/4 HANA (DO NOT CHANGE)/investigations/KPI Status_2024-02-01.json 35
#          From investigations files: 160
# 00_DEMO - Make-to-Stock for SAP S/4 HANA (DO NOT CHANGE)  subtotal Signals 233
# dashboardCount:2 investigationCount 1 metricCount 7
# ../data/From_API/Solutions Demo Workspace/00_DEMO - Manage-Personal-Employee-Information for SAP SuccessFactors Employee Central (DO NOT CHANGE)/metrics/metrics.json
# Number of Metrics Signals: 7 in: 00_DEMO - Manage-Personal-Employee-Information for SAP SuccessFactors Employee Central (DO NOT CHANGE)
# W: Solutions Demo Workspace  M ../data/From_API/Solutions Demo Workspace/00_DEMO - Manage-Personal-Employee-Information for SAP SuccessFactors Employee Central (DO NOT CHANGE)/metrics/metrics.json 7
#         From metric file: 7
# Number of metrics Metrics in Dashboards/Investigations Signals: 6 in: 00_DEMO - Manage-Personal-Employee-Information for SAP SuccessFactors Employee Central (DO NOT CHANGE)
#  Number of dashboard Signals: 2 in: 00_DEMO - Manage-Personal-Employee-Information for SAP SuccessFactors Employee Central (DO NOT CHANGE)
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/00_DEMO - Manage-Personal-Employee-Information for SAP SuccessFactors Employee Central (DO NOT CHANGE)/dashboards/Manage Personal Employee Information - DEMO_2024-02-01.json 8
# Number of metrics Metrics in Dashboards/Investigations Signals: 6 in: 00_DEMO - Manage-Personal-Employee-Information for SAP SuccessFactors Employee Central (DO NOT CHANGE)
#  Number of dashboard Signals: 2 in: 00_DEMO - Manage-Personal-Employee-Information for SAP SuccessFactors Employee Central (DO NOT CHANGE)
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/00_DEMO - Manage-Personal-Employee-Information for SAP SuccessFactors Employee Central (DO NOT CHANGE)/dashboards/SAP SuccessFactors - Manage Personal Employee Information_2024-02-01.json 8
#          From dashboard files: 16
# I ../data/From_API/Solutions Demo Workspace/00_DEMO - Manage-Personal-Employee-Information for SAP SuccessFactors Employee Central (DO NOT CHANGE)/investigations/Process Overview_2024-02-01.json
# Number of metrics Metrics in Dashboards/Investigations Signals: 5 in: 00_DEMO - Manage-Personal-Employee-Information for SAP SuccessFactors Employee Central (DO NOT CHANGE)
#  Number of investigation Signals: 2 in: 00_DEMO - Manage-Personal-Employee-Information for SAP SuccessFactors Employee Central (DO NOT CHANGE)
# W: Solutions Demo Workspace  I ../data/From_API/Solutions Demo Workspace/00_DEMO - Manage-Personal-Employee-Information for SAP SuccessFactors Employee Central (DO NOT CHANGE)/investigations/Process Overview_2024-02-01.json 7
#          From investigations files: 7
# 00_DEMO - Manage-Personal-Employee-Information for SAP SuccessFactors Employee Central (DO NOT CHANGE)  subtotal Signals 30
# dashboardCount:1 investigationCount 0 metricCount 32
# ../data/From_API/Solutions Demo Workspace/00_DEMO - Manage Warehouse and Inventory (Outbound) in SAP EWM (DO NOT CHANGE)/metrics/metrics.json
# Number of Metrics Signals: 32 in: 00_DEMO - Manage Warehouse and Inventory (Outbound) in SAP EWM (DO NOT CHANGE)
# W: Solutions Demo Workspace  M ../data/From_API/Solutions Demo Workspace/00_DEMO - Manage Warehouse and Inventory (Outbound) in SAP EWM (DO NOT CHANGE)/metrics/metrics.json 32
#         From metric file: 32
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: 00_DEMO - Manage Warehouse and Inventory (Outbound) in SAP EWM (DO NOT CHANGE)
#  Number of dashboard Signals: 43 in: 00_DEMO - Manage Warehouse and Inventory (Outbound) in SAP EWM (DO NOT CHANGE)
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/00_DEMO - Manage Warehouse and Inventory (Outbound) in SAP EWM (DO NOT CHANGE)/dashboards/Manage Warehouse and Inventory (Outbound) in SAP EWM_2024-02-01.json 43
#          From dashboard files: 43
#          From investigations files: 0
# 00_DEMO - Manage Warehouse and Inventory (Outbound) in SAP EWM (DO NOT CHANGE)  subtotal Signals 75
# dashboardCount:2 investigationCount 0 metricCount 18
# ../data/From_API/Solutions Demo Workspace/00_DEMO - Meter-to-Cash for SAP IS-U and S/4HANA (DO NOT CHANGE)/metrics/metrics.json
# Number of Metrics Signals: 18 in: 00_DEMO - Meter-to-Cash for SAP IS-U and S/4HANA (DO NOT CHANGE)
# W: Solutions Demo Workspace  M ../data/From_API/Solutions Demo Workspace/00_DEMO - Meter-to-Cash for SAP IS-U and S/4HANA (DO NOT CHANGE)/metrics/metrics.json 18
#         From metric file: 18
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: 00_DEMO - Meter-to-Cash for SAP IS-U and S/4HANA (DO NOT CHANGE)
#  Number of dashboard Signals: 22 in: 00_DEMO - Meter-to-Cash for SAP IS-U and S/4HANA (DO NOT CHANGE)
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/00_DEMO - Meter-to-Cash for SAP IS-U and S/4HANA (DO NOT CHANGE)/dashboards/00_Overview_2024-02-01.json 22
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: 00_DEMO - Meter-to-Cash for SAP IS-U and S/4HANA (DO NOT CHANGE)
#  Number of dashboard Signals: 0 in: 00_DEMO - Meter-to-Cash for SAP IS-U and S/4HANA (DO NOT CHANGE)
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/00_DEMO - Meter-to-Cash for SAP IS-U and S/4HANA (DO NOT CHANGE)/dashboards/Demo_SP_2024-02-01.json 0
#          From dashboard files: 22
#          From investigations files: 0
# 00_DEMO - Meter-to-Cash for SAP IS-U and S/4HANA (DO NOT CHANGE)  subtotal Signals 40
# dashboardCount:1 investigationCount 0 metricCount 15
# ../data/From_API/Solutions Demo Workspace/00_DEMO_Operate Manufacturing in SAP Digital Manufacturing (DO NOT CHANGE)/metrics/metrics.json
# Number of Metrics Signals: 15 in: 00_DEMO_Operate Manufacturing in SAP Digital Manufacturing (DO NOT CHANGE)
# W: Solutions Demo Workspace  M ../data/From_API/Solutions Demo Workspace/00_DEMO_Operate Manufacturing in SAP Digital Manufacturing (DO NOT CHANGE)/metrics/metrics.json 15
#         From metric file: 15
# Number of metrics Metrics in Dashboards/Investigations Signals: 1 in: 00_DEMO_Operate Manufacturing in SAP Digital Manufacturing (DO NOT CHANGE)
#  Number of dashboard Signals: 24 in: 00_DEMO_Operate Manufacturing in SAP Digital Manufacturing (DO NOT CHANGE)
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/00_DEMO_Operate Manufacturing in SAP Digital Manufacturing (DO NOT CHANGE)/dashboards/Overview Dashboard_2024-02-01.json 25
#          From dashboard files: 25
#          From investigations files: 0
# 00_DEMO_Operate Manufacturing in SAP Digital Manufacturing (DO NOT CHANGE)  subtotal Signals 40
# dashboardCount:2 investigationCount 3 metricCount 30
# ../data/From_API/Solutions Demo Workspace/00_DEMO - Operate-to-Maintain/Plant_Maintenance for SAP ECC/metrics/metrics.json
# Number of Metrics Signals: 30 in: 00_DEMO - Operate-to-Maintain/Plant_Maintenance for SAP ECC
# W: Solutions Demo Workspace  M ../data/From_API/Solutions Demo Workspace/00_DEMO - Operate-to-Maintain/Plant_Maintenance for SAP ECC/metrics/metrics.json 30
#         From metric file: 30
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: 00_DEMO - Operate-to-Maintain/Plant_Maintenance for SAP ECC
#  Number of dashboard Signals: 0 in: 00_DEMO - Operate-to-Maintain/Plant_Maintenance for SAP ECC
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/00_DEMO - Operate-to-Maintain/Plant_Maintenance for SAP ECC/dashboards/Process Overview_2024-02-01.json 0
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: 00_DEMO - Operate-to-Maintain/Plant_Maintenance for SAP ECC
#  Number of dashboard Signals: 2 in: 00_DEMO - Operate-to-Maintain/Plant_Maintenance for SAP ECC
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/00_DEMO - Operate-to-Maintain/Plant_Maintenance for SAP ECC/dashboards/SAP S/4HANA - Operate to Maintain_2024-02-01.json 2
#          From dashboard files: 2
# I ../data/From_API/Solutions Demo Workspace/00_DEMO - Operate-to-Maintain/Plant_Maintenance for SAP ECC/investigations/First Test - JRP_2024-02-01.json
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: 00_DEMO - Operate-to-Maintain/Plant_Maintenance for SAP ECC
#  Number of investigation Signals: 0 in: 00_DEMO - Operate-to-Maintain/Plant_Maintenance for SAP ECC
# W: Solutions Demo Workspace  I ../data/From_API/Solutions Demo Workspace/00_DEMO - Operate-to-Maintain/Plant_Maintenance for SAP ECC/investigations/First Test - JRP_2024-02-01.json 0
# I ../data/From_API/Solutions Demo Workspace/00_DEMO - Operate-to-Maintain/Plant_Maintenance for SAP ECC/investigations/Operate-to-Maintain_2024-02-01.json
# Number of metrics Metrics in Dashboards/Investigations Signals: 3 in: 00_DEMO - Operate-to-Maintain/Plant_Maintenance for SAP ECC
#  Number of investigation Signals: 0 in: 00_DEMO - Operate-to-Maintain/Plant_Maintenance for SAP ECC
# W: Solutions Demo Workspace  I ../data/From_API/Solutions Demo Workspace/00_DEMO - Operate-to-Maintain/Plant_Maintenance for SAP ECC/investigations/Operate-to-Maintain_2024-02-01.json 3
# I ../data/From_API/Solutions Demo Workspace/00_DEMO - Operate-to-Maintain/Plant_Maintenance for SAP ECC/investigations/Operate to Maintain_2024-02-01.json
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: 00_DEMO - Operate-to-Maintain/Plant_Maintenance for SAP ECC
#  Number of investigation Signals: 0 in: 00_DEMO - Operate-to-Maintain/Plant_Maintenance for SAP ECC
# W: Solutions Demo Workspace  I ../data/From_API/Solutions Demo Workspace/00_DEMO - Operate-to-Maintain/Plant_Maintenance for SAP ECC/investigations/Operate to Maintain_2024-02-01.json 0
#          From investigations files: 3
# 00_DEMO - Operate-to-Maintain/Plant_Maintenance for SAP ECC  subtotal Signals 35
# dashboardCount:1 investigationCount 1 metricCount 17
# ../data/From_API/Solutions Demo Workspace/00_DEMO - OTC SAP ECC V2 (DO NOT CHANGE)/metrics/metrics.json
# Number of Metrics Signals: 17 in: 00_DEMO - OTC SAP ECC V2 (DO NOT CHANGE)
# W: Solutions Demo Workspace  M ../data/From_API/Solutions Demo Workspace/00_DEMO - OTC SAP ECC V2 (DO NOT CHANGE)/metrics/metrics.json 17
#         From metric file: 17
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: 00_DEMO - OTC SAP ECC V2 (DO NOT CHANGE)
#  Number of dashboard Signals: 0 in: 00_DEMO - OTC SAP ECC V2 (DO NOT CHANGE)
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/00_DEMO - OTC SAP ECC V2 (DO NOT CHANGE)/dashboards/test_2024-02-01.json 0
#          From dashboard files: 0
# I ../data/From_API/Solutions Demo Workspace/00_DEMO - OTC SAP ECC V2 (DO NOT CHANGE)/investigations/DEMO - Order-to-Cash ECC_2024-02-01.json
# Number of metrics Metrics in Dashboards/Investigations Signals: 9 in: 00_DEMO - OTC SAP ECC V2 (DO NOT CHANGE)
#  Number of investigation Signals: 20 in: 00_DEMO - OTC SAP ECC V2 (DO NOT CHANGE)
# W: Solutions Demo Workspace  I ../data/From_API/Solutions Demo Workspace/00_DEMO - OTC SAP ECC V2 (DO NOT CHANGE)/investigations/DEMO - Order-to-Cash ECC_2024-02-01.json 29
#          From investigations files: 29
# 00_DEMO - OTC SAP ECC V2 (DO NOT CHANGE)  subtotal Signals 46
# dashboardCount:2 investigationCount 2 metricCount 18
# ../data/From_API/Solutions Demo Workspace/00_DEMO - OTC SAP S/4 HANA (DO NOT CHANGE)/metrics/metrics.json
# Number of Metrics Signals: 18 in: 00_DEMO - OTC SAP S/4 HANA (DO NOT CHANGE)
# W: Solutions Demo Workspace  M ../data/From_API/Solutions Demo Workspace/00_DEMO - OTC SAP S/4 HANA (DO NOT CHANGE)/metrics/metrics.json 18
#         From metric file: 18
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: 00_DEMO - OTC SAP S/4 HANA (DO NOT CHANGE)
#  Number of dashboard Signals: 1 in: 00_DEMO - OTC SAP S/4 HANA (DO NOT CHANGE)
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/00_DEMO - OTC SAP S/4 HANA (DO NOT CHANGE)/dashboards/OTC Process Overview_2024-02-01.json 1
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: 00_DEMO - OTC SAP S/4 HANA (DO NOT CHANGE)
#  Number of dashboard Signals: 22 in: 00_DEMO - OTC SAP S/4 HANA (DO NOT CHANGE)
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/00_DEMO - OTC SAP S/4 HANA (DO NOT CHANGE)/dashboards/Agnostic - Overview Dashboard_2024-02-01.json 22
#          From dashboard files: 23
# I ../data/From_API/Solutions Demo Workspace/00_DEMO - OTC SAP S/4 HANA (DO NOT CHANGE)/investigations/DEMO - Order-to-Cash S/4HANA_2024-02-01.json
# Number of metrics Metrics in Dashboards/Investigations Signals: 9 in: 00_DEMO - OTC SAP S/4 HANA (DO NOT CHANGE)
#  Number of investigation Signals: 20 in: 00_DEMO - OTC SAP S/4 HANA (DO NOT CHANGE)
# ...
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: [0]_Dashboards_ITP Process
#  Number of dashboard Signals: 18 in: [0]_Dashboards_ITP Process
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/[0]_Dashboards_ITP Process/dashboards/[NK] - Late Payments (Historical Analysis)_2024-02-01.json 18
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: [0]_Dashboards_ITP Process
#  Number of dashboard Signals: 0 in: [0]_Dashboards_ITP Process
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/[0]_Dashboards_ITP Process/dashboards/00_Empty Template_2024-02-01.json 0
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: [0]_Dashboards_ITP Process
#  Number of dashboard Signals: 32 in: [0]_Dashboards_ITP Process
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/[0]_Dashboards_ITP Process/dashboards/[FZ] Open Overdue Invoices_2024-02-01.json 32
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: [0]_Dashboards_ITP Process
#  Number of dashboard Signals: 20 in: [0]_Dashboards_ITP Process
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/[0]_Dashboards_ITP Process/dashboards/Cycle Time Dashboard_2024-02-01.json 20
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: [0]_Dashboards_ITP Process
#  Number of dashboard Signals: 35 in: [0]_Dashboards_ITP Process
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/[0]_Dashboards_ITP Process/dashboards/[SL] Payment Term Analysis - Use case 1 - SOL-2617_2024-02-01.json 35
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: [0]_Dashboards_ITP Process
#  Number of dashboard Signals: 49 in: [0]_Dashboards_ITP Process
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/[0]_Dashboards_ITP Process/dashboards/Open Overdue Invoices_2024-02-01.json 49
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: [0]_Dashboards_ITP Process
#  Number of dashboard Signals: 18 in: [0]_Dashboards_ITP Process
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/[0]_Dashboards_ITP Process/dashboards/[AA] Automation Dashboard_2024-02-01.json 18
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: [0]_Dashboards_ITP Process
#  Number of dashboard Signals: 7 in: [0]_Dashboards_ITP Process
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/[0]_Dashboards_ITP Process/dashboards/[JS] Payment Term Analysis - Use Case 2 - SOL-2725 (shorter PT on Invoice than in MD )_2024-02-01.json 7
# Number of metrics Metrics in Dashboards/Investigations Signals: 5 in: [0]_Dashboards_ITP Process
#  Number of dashboard Signals: 16 in: [0]_Dashboards_ITP Process
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/[0]_Dashboards_ITP Process/dashboards/0[SL]- Payment Term Optimization (for Final dashboard)_2024-02-01.json 21
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: [0]_Dashboards_ITP Process
#  Number of dashboard Signals: 34 in: [0]_Dashboards_ITP Process
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/[0]_Dashboards_ITP Process/dashboards/Payment Term Analysis_2024-02-01.json 34
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: [0]_Dashboards_ITP Process
#  Number of dashboard Signals: 34 in: [0]_Dashboards_ITP Process
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/[0]_Dashboards_ITP Process/dashboards/Payment Term Analysis-modified_2024-02-01.json 34
#          From dashboard files: 488
# I ../data/From_API/Solutions Demo Workspace/[0]_Dashboards_ITP Process/investigations/Event lvl metrics test_2024-02-01.json
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: [0]_Dashboards_ITP Process
#  Number of investigation Signals: 0 in: [0]_Dashboards_ITP Process
# W: Solutions Demo Workspace  I ../data/From_API/Solutions Demo Workspace/[0]_Dashboards_ITP Process/investigations/Event lvl metrics test_2024-02-01.json 0
#          From investigations files: 0
# [0]_Dashboards_ITP Process  subtotal Signals 528
# dashboardCount:3 investigationCount 2 metricCount 31
# ../data/From_API/Solutions Demo Workspace/0_demo_accelerators_generic (PTP S4H, changes allowed)/metrics/metrics.json
# Number of Metrics Signals: 31 in: 0_demo_accelerators_generic (PTP S4H, changes allowed)
# W: Solutions Demo Workspace  M ../data/From_API/Solutions Demo Workspace/0_demo_accelerators_generic (PTP S4H, changes allowed)/metrics/metrics.json 31
#         From metric file: 31
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: 0_demo_accelerators_generic (PTP S4H, changes allowed)
#  Number of dashboard Signals: 16 in: 0_demo_accelerators_generic (PTP S4H, changes allowed)
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/0_demo_accelerators_generic (PTP S4H, changes allowed)/dashboards/Cycle Time Dashboard_2024-02-01.json 16
# Number of metrics Metrics in Dashboards/Investigations Signals: 1 in: 0_demo_accelerators_generic (PTP S4H, changes allowed)
#  Number of dashboard Signals: 14 in: 0_demo_accelerators_generic (PTP S4H, changes allowed)
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/0_demo_accelerators_generic (PTP S4H, changes allowed)/dashboards/PO Late Payments (Historical Analysis)_2024-02-01.json 15
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: 0_demo_accelerators_generic (PTP S4H, changes allowed)
#  Number of dashboard Signals: 24 in: 0_demo_accelerators_generic (PTP S4H, changes allowed)
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/0_demo_accelerators_generic (PTP S4H, changes allowed)/dashboards/Overview Dashboard_2024-02-01.json 24
#          From dashboard files: 55
# I ../data/From_API/Solutions Demo Workspace/0_demo_accelerators_generic (PTP S4H, changes allowed)/investigations/HS pi academy _2024-02-01.json
# Number of metrics Metrics in Dashboards/Investigations Signals: 2 in: 0_demo_accelerators_generic (PTP S4H, changes allowed)
#  Number of investigation Signals: 0 in: 0_demo_accelerators_generic (PTP S4H, changes allowed)
# W: Solutions Demo Workspace  I ../data/From_API/Solutions Demo Workspace/0_demo_accelerators_generic (PTP S4H, changes allowed)/investigations/HS pi academy _2024-02-01.json 2
# I ../data/From_API/Solutions Demo Workspace/0_demo_accelerators_generic (PTP S4H, changes allowed)/investigations/overview_2024-02-01.json
# Number of metrics Metrics in Dashboards/Investigations Signals: 4 in: 0_demo_accelerators_generic (PTP S4H, changes allowed)
#  Number of investigation Signals: 0 in: 0_demo_accelerators_generic (PTP S4H, changes allowed)
# W: Solutions Demo Workspace  I ../data/From_API/Solutions Demo Workspace/0_demo_accelerators_generic (PTP S4H, changes allowed)/investigations/overview_2024-02-01.json 4
#          From investigations files: 6
# 0_demo_accelerators_generic (PTP S4H, changes allowed)  subtotal Signals 92
# dashboardCount:1 investigationCount 0 metricCount 1
# ../data/From_API/Solutions Demo Workspace/[NK] Show&Tell - ITP Dashboards/metrics/metrics.json
# Number of Metrics Signals: 1 in: [NK] Show&Tell - ITP Dashboards
# W: Solutions Demo Workspace  M ../data/From_API/Solutions Demo Workspace/[NK] Show&Tell - ITP Dashboards/metrics/metrics.json 1
#         From metric file: 1
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: [NK] Show&Tell - ITP Dashboards
#  Number of dashboard Signals: 59 in: [NK] Show&Tell - ITP Dashboards
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/[NK] Show&Tell - ITP Dashboards/dashboards/[04] Payment Behaviour_2024-02-01.json 59
#          From dashboard files: 59
#          From investigations files: 0
# [NK] Show&Tell - ITP Dashboards  subtotal Signals 60
# dashboardCount:5 investigationCount 2 metricCount 12
# ../data/From_API/Solutions Demo Workspace/[SIGPIA-2936] Dashboard_PTP_Ariba/metrics/metrics.json
# Number of Metrics Signals: 12 in: [SIGPIA-2936] Dashboard_PTP_Ariba
# W: Solutions Demo Workspace  M ../data/From_API/Solutions Demo Workspace/[SIGPIA-2936] Dashboard_PTP_Ariba/metrics/metrics.json 12
#         From metric file: 12
# Number of metrics Metrics in Dashboards/Investigations Signals: 1 in: [SIGPIA-2936] Dashboard_PTP_Ariba
#  Number of dashboard Signals: 20 in: [SIGPIA-2936] Dashboard_PTP_Ariba
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/[SIGPIA-2936] Dashboard_PTP_Ariba/dashboards/Automation Dashboard_2024-02-01.json 21
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: [SIGPIA-2936] Dashboard_PTP_Ariba
#  Number of dashboard Signals: 22 in: [SIGPIA-2936] Dashboard_PTP_Ariba
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/[SIGPIA-2936] Dashboard_PTP_Ariba/dashboards/Cycle Time Dashboard_2024-02-01.json 22
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: [SIGPIA-2936] Dashboard_PTP_Ariba
#  Number of dashboard Signals: 36 in: [SIGPIA-2936] Dashboard_PTP_Ariba
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/[SIGPIA-2936] Dashboard_PTP_Ariba/dashboards/00_Overview Dashboard_2024-02-01.json 36
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: [SIGPIA-2936] Dashboard_PTP_Ariba
#  Number of dashboard Signals: 38 in: [SIGPIA-2936] Dashboard_PTP_Ariba
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/[SIGPIA-2936] Dashboard_PTP_Ariba/dashboards/Payment Behaviour_2024-02-01.json 38
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: [SIGPIA-2936] Dashboard_PTP_Ariba
#  Number of dashboard Signals: 38 in: [SIGPIA-2936] Dashboard_PTP_Ariba
# W: Solutions Demo Workspace D ../data/From_API/Solutions Demo Workspace/[SIGPIA-2936] Dashboard_PTP_Ariba/dashboards/Spend Analysis_2024-02-01.json 38
#          From dashboard files: 155
# I ../data/From_API/Solutions Demo Workspace/[SIGPIA-2936] Dashboard_PTP_Ariba/investigations/Test_2024-02-01.json
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: [SIGPIA-2936] Dashboard_PTP_Ariba
#  Number of investigation Signals: 0 in: [SIGPIA-2936] Dashboard_PTP_Ariba
# W: Solutions Demo Workspace  I ../data/From_API/Solutions Demo Workspace/[SIGPIA-2936] Dashboard_PTP_Ariba/investigations/Test_2024-02-01.json 0
# I ../data/From_API/Solutions Demo Workspace/[SIGPIA-2936] Dashboard_PTP_Ariba/investigations/SAP_ARIBA_PTP_2024-02-01.json
# Number of metrics Metrics in Dashboards/Investigations Signals: 10 in: [SIGPIA-2936] Dashboard_PTP_Ariba
#  Number of investigation Signals: 112 in: [SIGPIA-2936] Dashboard_PTP_Ariba
# W: Solutions Demo Workspace  I ../data/From_API/Solutions Demo Workspace/[SIGPIA-2936] Dashboard_PTP_Ariba/investigations/SAP_ARIBA_PTP_2024-02-01.json 122
#          From investigations files: 122
# [SIGPIA-2936] Dashboard_PTP_Ariba  subtotal Signals 289
# Total Signals 4689
# dashboardCount:2 investigationCount 2 metricCount 5
# ../data/From_API/Process AI/demo01/metrics/metrics.json
# Number of Metrics Signals: 5 in: demo01
# W: Process AI  M ../data/From_API/Process AI/demo01/metrics/metrics.json 5
#         From metric file: 5
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: demo01
#  Number of dashboard Signals: 1 in: demo01
# W: Process AI D ../data/From_API/Process AI/demo01/dashboards/workingdashboard_2024-02-01.json 1
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: demo01
#  Number of dashboard Signals: 0 in: demo01
# W: Process AI D ../data/From_API/Process AI/demo01/dashboards/qqqq_2024-02-01.json 0
#          From dashboard files: 1
# I ../data/From_API/Process AI/demo01/investigations/AskData POC_2024-02-01.json
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: demo01
#  Number of investigation Signals: 14 in: demo01
# W: Process AI  I ../data/From_API/Process AI/demo01/investigations/AskData POC_2024-02-01.json 14
# I ../data/From_API/Process AI/demo01/investigations/AskData POC (Copy)_2024-02-01.json
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: demo01
#  Number of investigation Signals: 14 in: demo01
# W: Process AI  I ../data/From_API/Process AI/demo01/investigations/AskData POC (Copy)_2024-02-01.json 14
#          From investigations files: 28
# demo01  subtotal Signals 34
# dashboardCount:0 investigationCount 0 metricCount 0
# ../data/From_API/Process AI/dv_test/metrics/metrics.json
# Number of Metrics Signals: 0 in: dv_test
# W: Process AI  M ../data/From_API/Process AI/dv_test/metrics/metrics.json 0
#         From metric file: 0
#          From dashboard files: 0
#          From investigations files: 0
# dv_test  subtotal Signals 0
# dashboardCount:0 investigationCount 0 metricCount 1
# ../data/From_API/Process AI/sfdsdf/metrics/metrics.json
# Number of Metrics Signals: 1 in: sfdsdf
# W: Process AI  M ../data/From_API/Process AI/sfdsdf/metrics/metrics.json 1
#         From metric file: 1
#          From dashboard files: 0
#          From investigations files: 0
# sfdsdf  subtotal Signals 1
# dashboardCount:0 investigationCount 0 metricCount 0
# ../data/From_API/Process AI/Test/metrics/metrics.json
# Number of Metrics Signals: 0 in: Test
# W: Process AI  M ../data/From_API/Process AI/Test/metrics/metrics.json 0
#         From metric file: 0
#          From dashboard files: 0
#          From investigations files: 0
# Test  subtotal Signals 0
# dashboardCount:1 investigationCount 2 metricCount 177
# ../data/From_API/Process AI/test00/metrics/metrics.json
# Number of Metrics Signals: 177 in: test00
# W: Process AI  M ../data/From_API/Process AI/test00/metrics/metrics.json 177
#         From metric file: 177
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: test00
#  Number of dashboard Signals: 0 in: test00
# W: Process AI D ../data/From_API/Process AI/test00/dashboards/testdashboard_2024-02-01.json 0
#          From dashboard files: 0
# I ../data/From_API/Process AI/test00/investigations/AskData POC_2024-02-01.json
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: test00
#  Number of investigation Signals: 14 in: test00
# W: Process AI  I ../data/From_API/Process AI/test00/investigations/AskData POC_2024-02-01.json 14
# I ../data/From_API/Process AI/test00/investigations/q1_2024-02-01.json
# Number of metrics Metrics in Dashboards/Investigations Signals: 2 in: test00
#  Number of investigation Signals: 0 in: test00
# W: Process AI  I ../data/From_API/Process AI/test00/investigations/q1_2024-02-01.json 2
#          From investigations files: 16
# test00  subtotal Signals 193
# dashboardCount:0 investigationCount 1 metricCount 2
# ../data/From_API/Process AI/test001/metrics/metrics.json
# Number of Metrics Signals: 2 in: test001
# W: Process AI  M ../data/From_API/Process AI/test001/metrics/metrics.json 2
#         From metric file: 2
#          From dashboard files: 0
# I ../data/From_API/Process AI/test001/investigations/AskData POC_2024-02-01.json
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: test001
#  Number of investigation Signals: 14 in: test001
# W: Process AI  I ../data/From_API/Process AI/test001/investigations/AskData POC_2024-02-01.json 14
#          From investigations files: 14
# test001  subtotal Signals 16
# dashboardCount:0 investigationCount 1 metricCount 1
# ../data/From_API/Process AI/test002/metrics/metrics.json
# Number of Metrics Signals: 1 in: test002
# W: Process AI  M ../data/From_API/Process AI/test002/metrics/metrics.json 1
#         From metric file: 1
#          From dashboard files: 0
# I ../data/From_API/Process AI/test002/investigations/AskData POC_2024-02-01.json
# Number of metrics Metrics in Dashboards/Investigations Signals: 0 in: test002
#  Number of investigation Signals: 14 in: test002
# W: Process AI  I ../data/From_API/Process AI/test002/investigations/AskData POC_2024-02-01.json 14
#          From investigations files: 14
# test002  subtotal Signals 15
# Total Signals 259
# Total Signals to save 4948

# %%
print("Total Signals to save",len(signals_all))
# Out:
# Total Signals to save 4948

# %%
# save signals to FS ../data/
date_str = datetime.datetime.now().strftime("%Y-%m-%dT%H_%M_%S")
fl=f"all_extracted_signals_{date_str}.json"
filename_all_extracted_signal=os.path.join("../data/From_API",fl)

with open(filename_all_extracted_signal, 'w') as f:
    json.dump( signals_all,f)
    print(f"Dumping {len(signals_all)} extracted signals  to {filename_all_extracted_signal}")
# Out:
# Dumping 4948 extracted signals  to ../data/From_API/all_extracted_signals_2024-02-01T08_21_30.json

# %%
### here Load API-extracted signals_all from JSON-file saved in the above step
filename_all_extracted_signal= "../data/From_API/all_extracted_signals_2024-02-01T08_21_30.json"

with open(filename_all_extracted_signal, 'r') as f:
    signals_all = json.load(f)
    print(f"Loading {len(signals_all)} extracted Signal from {filename_all_extracted_signal}")
# Out:
# Loading 4948 extracted Signal from ../data/From_API/all_extracted_signals_2024-02-01T08_21_30.json

# %% [markdown]
# ## 6. Load Signals from Stored locations: can do both - the created above and external, i.e., provided by other colleagues
#
# Here we can extract Signals from files metrics, dashboards, investigations JSON-files stored on your filesystem.
#
# Problem here is that we have specify view variable - needed to run API calls against real log DB, typically we need this to
# validate Signals, human or LLM-generated.
#
# ```js
# data/
# ├── ContentPackage_November2023
# │   ├── KFFI000960\ -\ Supplier\ payment\ without\ purchasing
# │   ├── KFFI001060\ -\ Cash\ collection\ for\ non-sales\ (invoices)
# │   ├── KPLE000360\ -\ Delivery\ processing\ for\ subcontracting\ wit
# ...
# ── NLP\ POC\ (JustAsk)
# │   ├── 01\ Introduction
# │   ├── 02\ OTC\ Data\ Set
# │   ├── 03\ Mining\ Questions\ and\ SIGNAL\ Queries
# │   ├── 04\ PI\ Investigation
# │   └── JustAsk\ -\ Signavio\ Widget\ Builder.pptx
# ├── OPAL
# │   ├── DRAFT_1.json
# │   └── DRAFT_2.json
# data/From_API/
# ├── Process\ AI
# │   ├── Test
# │   ├── demo01
# ...
# ├── Solutions\ Demo\ Workspace
# │   ├── 000_DEMO�\234�\ -\ Dashboards\ ITC\ ECC\ &\ S4H\ (DO\ NOT\ CHANGE)
# │   ├── 000_DEMO�\234�\ -\ Dashboards\ ITP\ ECC\ &\ S4H\ (DO\ NOT\ CHANGE
# ...
# ├── all_extracted_signals_2023-12-01T09_59_45.json
# ├── all_json_Process_AI_2023-12-01T09_53_37.json
# └── all_json_Solutions_Demo_Workspace_2023-12-01T09_53_24.json
# ...
# ```

# %%
#%%script echo skipping
import glob
import json

def signals_from_locals(p, workspacename, viewid):
    """
    """
    signals_i=[]
    signals_d=[]
    signals_m=[]
    filenames=glob.glob(str(p)+"/**/*.json",recursive=True)

    print(f"Number of detected JSON files: {len(filenames)}")
    for filename in filenames:
        js_type=filename.split("/")[-2] # metrics  investigation dashboard   
        with open(filename, 'r') as f:
            fromjson = json.load(f)
            path=filename
            print(filename, fromjson)

        if not isinstance(fromjson,dict):
            print(f'JSON File: {filename} is not of Signavio Metric, Dashboard or Investigation type ')
            continue
        
        if 'investigation' in fromjson.keys():
            i = docs_from_investigations_dashboard_json(path,from_json=fromjson, sourcekeys=["investigation","metrics"],view=viewid)[path]
            [s.update(origin=path,workspace_name=workspacename) for s in i]
            signals_i+=i
        if 'dashboard' in fromjson.keys():
            d = docs_from_investigations_dashboard_json(path,from_json=fromjson, sourcekeys=["dashboard","metrics"],view=viewid)[path]
            [s.update(origin=path,workspace_name=workspacename) for s in d]
            signals_d+=d
        if 'metrics' in fromjson.keys() and 'investigation' not in fromjson.keys() and 'dashboard' not in fromjson.keys():
            m = docs_from_metric_json(path, from_json=fromjson, view=viewid)[path] #"strview-1") #[path][0]['metric_vars']['sla_closure_events']
            [s.update(origin=path,workspace_name=workspacename) for s in m]
            signals_m+=m
    
    signals_all_local=signals_i + signals_d + signals_m
    print(f" \n You have extracted form DIR: {p}. \n Workspace: {workspacename} \n View: {viewid} \n Signals: {len(signals_all_local)} ")
        
    return signals_all_local

# %%
# Here we read the files from provided dirs and extract all Signals
p = "../data/From_API/Solutions Demo Workspace/" #.replace(" ", "\\ ")             # Signals: 4266 (filtered 1399) 
                                                                          #                                Validated: 1246   when 'Solutions Demo Workspace' with proper 31 views
                                                                          #                                
                                                                          #                                Validated: "strview-1" - 388 
                                                                          #                                Validated: "defaultview-545" - 430 
p0 = "../data/NLP POC (JustAsk)"                                          # Signals: 14                   Validated: "strview-1" - 14   "defaultview-545" - 11

# external_gits$ git clone https://github.com/signavio/pex-metric-library.git
# cp -rf pex-metric-library/metric_definitions ../../data/.
# fix bug in manage_transportation.json '$) - remove $
p1 = "../data/metric_definitions"                                         # Signals: 488  (filtered 481)  Validated: "strview-1" - 173  "defaultview-545" - 183

# external_gits$ git clone https://github.tools.sap/SAP-Signavio-PIA/pia-dashboards.git
# external_gits$ cp -rf pia-dashboards ../../data/. 
p2 = "../data/pia-dashboards"                                             # Signals: 942  (filtered 785)  Validated: "strview-1" - 230  "defaultview-545" - 248

# files shared by Maximillian 
p3 = "../data/OPAL"                                                       # Signals: 69   (filtered 67)   Validated: "strview-1" - 3    "defaultview-545" - 1
                                                                          # Signals: 1513 (filtered 1164) Validated: 372
                                                                          # 
                                                                          # Signals: 4266+1513 = 5779  (filtered 1741 ) Validated: 879 when 'Solutions Demo Workspace' with proper 31 views
                                                                          #                                             Validated: 519 when read "Solutions Demo Workspace/" with fixed "defaultview-545"
# external_gits git clone https://github.tools.sap/business-process-insights/bpi-python-tools.git
# external_gits$ cp -rf bpi-python-tools/content/ContentPackage_December2023 ../../data/.
p4="../data/ContentPackage_December2023"


ws0='Process AI'
ws1='Solutions Demo Workspace'

v0="strview-1" 
v1="defaultview-545"

#p, ws, view = p, 'Solutions Demo Workspace', "defaultview-545"
#signals_all_local_p=signals_from_locals(p, ws, view)

### p, ws, view = p0, 'Process AI', "strview-1" 
### signals_all_local_p0=signals_from_locals(p, ws, view)
### "../data/metric_definitions"   
p, ws, view = p1, 'Solutions Demo Workspace', "defaultview-545"
signals_all_local_p1=signals_from_locals(p, ws, view)

### "../data/pia-dashboards"  
p, ws, view = p2, 'Solutions Demo Workspace', "defaultview-545"
signals_all_local_p2=signals_from_locals(p, ws, view)

### "../data/OPAL"    
p, ws, view = p3, 'Solutions Demo Workspace', "defaultview-545"
signals_all_local_p3=signals_from_locals(p, ws, view)

### "../../data/SignavioText2Signal/ContentPackage_November2023"
p, ws, view = p4, 'Solutions Demo Workspace', "defaultview-545"
signals_all_local_p4=signals_from_locals(p, ws, view)

#signals_all_local=signals_all_local_p0+signals_all_local_p1+signals_all_local_p2+signals_all_local_p3+signals_all_local_p4  #+ signals_all_local_p

# Signals: 5396 
signals_all_local= signals_all_local_p1+signals_all_local_p2+signals_all_local_p3+signals_all_local_p4 
#signals_all_local=signals_all_local_p4


print(f" >>>>>>>>>>>>< Signals: {len(signals_all_local)} ")
# Out:
# Number of detected JSON files: 35
# ../data/metric_definitions/__source_systems.json [{'id': 'SAP_SALES_CLOUD', 'name': 'SAP Sales Cloud'}, {'id': 'SAP_SERVICE_CLOUD', 'name': 'SAP Service Cloud'}, {'id': 'SERVICENOW', 'name': 'ServiceNow'}, {'id': 'SFSF', 'name': 'SAP SuccessFactors'}, {'id': 'SAP_ECC', 'name': 'SAP ECC'}, {'id': 'SAP_S4HANA', 'name': 'SAP S/4HANA'}, {'id': 'SAP_S4HANACLOUD', 'name': 'SAP S/4HANA Cloud'}, {'id': 'SAP_ISU', 'name': 'SAP for Utilities (IS-U)'}, {'id': 'SALESFORCE', 'name': 'Salesforce'}, {'id': 'ARIBA', 'name': 'SAP Ariba'}, {'id': 'JIRA', 'name': 'Jira'}, {'id': 'SAP_IBP', 'name': 'SAP Integrated Business Planning (IBP)'}, {'id': 'CROSS_SAP_ARIBA_SAP_ERP', 'name': 'Cross System: SAP Ariba and SAP ERP (ECC, S/4HANA)'}, {'id': 'SAP_DIGITAL_MANUFACTURING', 'name': 'SAP Digital Manufacturing (DM)'}, {'id': 'SAP_EWM', 'name': 'SAP Extended Warehouse Management (EWM)'}, {'id': 'SAP_OPENTEXT', 'name': 'SAP OpenText'}, {'id': 'SAP_TM', 'name': 'SAP Transportation Management'}]
# JSON File: ../data/metric_definitions/__source_systems.json is not of Signavio Metric, Dashboard or Investigation type
# ../data/metric_definitions/incident_to_resolution.json {'metrics': [{'id': 'total_incident_number', 'name': 'Total number of created incidents', 'description': 'Total number of created incidents', 'signalFragment': 'COUNT(case_id)', 'aggregationType': 'CASE', 'processTypes': ['INCIDENT_TO_RESOLUTION'], 'unit': {'type': 'SUFFIX', 'suffix': '%'}, 'version': '1.0.0'}, {'id': 'open_incident_number', 'name': 'Total number of open incidents', 'description': 'Total number of open incidents', 'signalFragment': 'COUNT(case_id) FILTER (WHERE \n\t(SELECT BOOL_AND(\n NOT event_name IN (${incident_closure_events})))\n)', 'aggregationType': 'CASE', 'processTypes': ['INCIDENT_TO_RESOLUTION'], 'version': '1.0.0'}, {'id': 'resolved_incident_number', 'name': 'Total number of resolved incidents', 'description': 'Total number of resolved incidents', 'signalFragment': 'COUNT(case_id) FILTER (WHERE \n\t(SELECT BOOL_OR(\n event_name IN (${incident_closure_events})))\n)', 'aggregationType': 'CASE', 'processTypes': ['INCIDENT_TO_RESOLUTION'], 'version': '1.0.0'}, {'id': 'avg_response_time', 'name': 'Average response time', 'description': 'Average time from incident creation to first response', 'signalFragment': 'AVG(\n\t(SELECT LAST(end_time)\n\t\tWHERE event_name IN (${response_events}))\n\t-(SELECT FIRST(end_time)\n\t\tWHERE event_name IN (${incident_creation_events}))\n)', 'aggregationType': 'CASE', 'processTypes': ['INCIDENT_TO_RESOLUTION'], 'version': '1.0.0'}, {'id': 'avg_resolution_time', 'name': 'Average resolution time', 'description': 'Average time from incident creation to its resolution', 'signalFragment': 'AVG(\n\t(SELECT LAST(end_time)\n\t\tWHERE event_name IN (${resolution_events}))\n\t-(SELECT FIRST(end_time)\n\t\tWHERE event_name IN (${incident_creation_events}))\n)', 'aggregationType': 'CASE', 'processTypes': ['INCIDENT_TO_RESOLUTION'], 'version': '1.0.0'}, {'id': 'first_call_resolution_rate', 'name': 'First call resolution rate', 'description': 'Percentage of incidents that are resolved without any rework. Rework is defined here as any case that contains the same event name more than once.', 'signalFragment': 'COUNT(case_id) FILTER(\n\tWHERE (SELECT COUNT(DISTINCT event_name)) = (SELECT COUNT(event_name))\n\t)', 'aggregationType': 'CASE', 'processTypes': ['INCIDENT_TO_RESOLUTION'], 'version': '1.0.0'}, {'id': 'itr_sla_breach_ratio', 'name': 'SLA breach ratio', 'description': 'Percentage of cases that have breached the SLAs', 'signalFragment': 'COUNT(case_id) FILTER (WHERE \n\t (SELECT BOOL_OR(\n event_name IN (${itr_sla_breach_events})))\n)/ COUNT(case_id)\n* 100', 'aggregationType': 'CASE', 'processTypes': ['INCIDENT_TO_RESOLUTION'], 'version': '1.0.0'}, {'id': 'avg_ticket_reassignment_rate', 'name': 'Average ticket reassignment rate', 'description': 'Average number of reassignments per case', 'signalFragment': '(SUM(${incident_reassignments})\n/ COUNT(case_id))', 'aggregationType': 'CASE', 'processTypes': ['INCIDENT_TO_RESOLUTION'], 'version': '1.0.0'}, {'id': 'avg_rework_rate', 'name': 'Average rework rate', 'description': 'Percentage of cases with rework', 'signalFragment': '(COUNT(case_id) FILTER (\n\tWHERE (${rework_condition}))\n/ COUNT(case_id))\n* 100', 'aggregationType': 'CASE', 'processTypes': ['INCIDENT_TO_RESOLUTION'], 'version': '1.0.0'}, {'id': 'high_priority_incident_ratio', 'name': 'High priority incident ratio', 'description': 'Percentage of cases with high priority', 'signalFragment': '(COUNT(case_id) FILTER (\n\tWHERE (${high_priority})) \n/ COUNT(case_id))\n* 100', 'aggregationType': 'CASE', 'processTypes': ['INCIDENT_TO_RESOLUTION'], 'version': '1.0.0'}], 'variables': [{'name': 'incident_closure_events', 'description': "Events defining the closing events of a case, for example 'Close Incident'", 'defaultValues': [{'defaultValue': "'Close Incident'", 'sourceSystems': ['SERVICENOW']}]}, {'name': 'incident_creation_events', 'description': "Events defining the start events of a case, for example 'Create Problem', ' ...
# Number of Metrics Signals: 10 in: ../data/metric_definitions/incident_to_resolution.json
# ../data/metric_definitions/invoice_to_cash_s4h_cloud.json {'metrics': [{'id': 'i2c_s4hc_avg_ar_creation_to_clearing_time', 'name': 'Average accounts receivable documents creation to clearing time', 'description': 'Average time from accounts receivable documents creation to clearing', 'signalFragment': 'SUM("AR_AVGClearingDays" * "AR_CountClearedDocuments")\n/\nSUM("AR_CountClearedDocuments")', 'aggregationType': 'CASE', 'processTypes': ['INVOICE_TO_CASH'], 'version': '1.0.0'}, {'id': 'i2c_s4hc_avg_net_payment_terms', 'name': 'Average net payment terms', 'description': 'Average net payment terms in days', 'signalFragment': 'SUM("AR_AVGNetDueDateDays" * "AR_CountDocuments")\n/\nSUM("AR_CountDocuments")', 'aggregationType': 'CASE', 'processTypes': ['INVOICE_TO_CASH'], 'version': '1.0.0'}, {'id': 'i2c_s4hc_avg_payment_delay', 'name': 'Average payment delay', 'description': 'Average delay of payments in days', 'signalFragment': 'SUM("AR_AVGClearingAfterNetDueDays" * "AR_CountClearedDocuments")\n/\nSUM("AR_CountClearedDocuments")', 'aggregationType': 'CASE', 'processTypes': ['INVOICE_TO_CASH'], 'version': '1.0.0'}, {'id': 'i2c_s4hc_billing_request_rejection_rate', 'name': 'Billing request (DMR) rejection rate', 'description': 'Percentage of billing requests (debit memo requests) that were rejected', 'signalFragment': '(\nSUM("BillingRequest_RejectedCount")\n/\nSUM("BillingRequest_TotalCount")\n)\n * 100', 'aggregationType': 'CASE', 'processTypes': ['INVOICE_TO_CASH'], 'version': '1.0.0'}, {'id': 'i2c_s4hc_automation_rate_inv_clearing', 'name': 'Automation rate for invoice clearing', 'description': 'Percentage of automated invoice clearing events', 'signalFragment': 'SUM(\n\t(SELECT COUNT(event_name) FILTER (\n\t\tWHERE (event_name IN (${i2c_s4hc_clear_invoice_events})\n\t\t\tAND (${i2c_s4hc_automation_condition})))\n\t)\n)\n/ SUM(\n\t(SELECT COUNT(event_name) FILTER (\n\tWHERE (event_name IN (${i2c_s4hc_clear_invoice_events})))\n\t)\n)\n * 100', 'aggregationType': 'CASE', 'processTypes': ['INVOICE_TO_CASH'], 'version': '1.0.0'}, {'id': 'i2c_s4hc_lead_time', 'name': 'Average time from invoice creation to its clearing within a certain time frame', 'description': 'Average time from invoice creation to invoice clearing within a reference period', 'signalFragment': 'AVG(\n\t(SELECT LAST(${i2c_s4hc_clearing_date}) \n\t\tWHERE ((NOW() - LAST(end_time)) < DURATION ${i2c_s4hc_invoice_clearing_period}))\n\t-(SELECT LAST(${i2c_s4hc_posting_date})\n\t\tWHERE ((NOW() - LAST(end_time)) < DURATION ${i2c_s4hc_invoice_posting_period}))\n\t)', 'aggregationType': 'CASE', 'processTypes': ['INVOICE_TO_CASH'], 'version': '1.0.0'}, {'id': 'i2c_s4hc_days_sales_outstanding', 'name': 'Days sales outstanding (DSO)', 'description': 'Average number of days to collect revenue, weighted by the invoice value', 'signalFragment': 'AVG((\n\t(SELECT LAST(${i2c_s4hc_clearing_date})) \n\t\t- (SELECT FIRST(${i2c_s4hc_posting_date})))\n\t* (SELECT LAST(${i2c_s4hc_amount_conv}))\n)', 'aggregationType': 'CASE', 'processTypes': ['INVOICE_TO_CASH'], 'version': '1.0.0'}, {'id': 'i2c_s4hc_early_payment_rate', 'name': 'Early payment rate', 'description': 'Percentage of invoices that were cleared more than 5 days before their due dates', 'signalFragment': 'COUNT(case_id) FILTER (\n\tWHERE (${i2c_s4hc_due_date} - ${i2c_s4hc_clearing_date} \n\t\t> DURATION ${i2c_s4hc_early_payment_condition})\n)\n/ COUNT(case_id) FILTER (\n\tWHERE (${i2c_s4hc_clearing_date} IS NOT NULL)\n) * 100', 'aggregationType': 'CASE', 'processTypes': ['INVOICE_TO_CASH'], 'version': '1.0.0'}, {'id': 'i2c_s4hc_late_payment_rate', 'name': 'Late payment rate', 'description': 'Percentage of invoices that were cleared one or more days after their due dates', 'signalFragment': 'COUNT(case_id) FILTER (\n\tWHERE (${i2c_s4hc_clearing_date} - ${i2c_s4hc_due_date} \n\t\t> DURATION ${i2c_s4hc_late_payment_condition})\n)\n/ COUNT(case_id) FILTER (\n\tWHERE (${i2c_s4hc_clearing_date} IS NOT NULL)\n) * 100', 'aggregationType ...
# Number of Metrics Signals: 30 in: ../data/metric_definitions/invoice_to_cash_s4h_cloud.json
# ../data/metric_definitions/ewm_basic_outbound.json {'metrics': [{'id': 'ewm_outb_percentage_odoi_fully_shipped', 'name': '% of ODO Items fully shipped', 'description': 'Percentage of Outbound Delivery Order Items where ODO quantity was fully shipped (GI quantity)', 'signalFragment': 'COUNT (DISTINCT (CASE \nWHEN "ODO Item Quantity"="Total GI Quantity" THEN "case_id" \nELSE NULL\nEND)) \n/\nCOUNT (distinct "case_id")\n*100', 'aggregationType': 'CASE', 'sourceSystems': ['SAP_EWM'], 'processTypes': ['EWM_BASIC_OUTBOUND'], 'version': '1.0.0'}, {'id': 'ewm_outb_percentage_odoi_not_fully_shipped', 'name': '% of ODO items not fully shipped', 'description': 'Percentage of Outbound Delivery Order Items where ODO quantity matches GI quantity - ODO Item is fully shipped', 'signalFragment': 'COUNT (DISTINCT (CASE \nWHEN "ODO Item Quantity"="Total GI Quantity" THEN NULL \nWHEN "ODO Item Quantity"<"Total GI Quantity" THEN NULL \nELSE "case_id" \nEND)) \n/\nCOUNT (distinct "case_id")\n*100', 'aggregationType': 'CASE', 'sourceSystems': ['SAP_EWM'], 'processTypes': ['EWM_BASIC_OUTBOUND'], 'version': '1.0.0'}, {'id': 'ewm_outb_percentage_odoi_overdelivered', 'name': '% of ODO items overdelivered', 'description': 'Percentage of Outbound Delivery Order Items where a higher quantity was delivered than ordered', 'signalFragment': 'COUNT (DISTINCT (CASE \nWHEN "ODO Item Quantity"="Total GI Quantity" THEN NULL \nWHEN "ODO Item Quantity">"Total GI Quantity" THEN NULL \nELSE "case_id" \nEND)) \n/\nCOUNT (distinct "case_id")\n*100', 'aggregationType': 'CASE', 'sourceSystems': ['SAP_EWM'], 'processTypes': ['EWM_BASIC_OUTBOUND'], 'version': '1.0.0'}, {'id': 'ewm_outb_percentage_odoi_wo_picking_wts', 'name': '% of ODO Items w/o Picking WTs', 'description': 'Percentage of Outbound Delivery Order Items without the Warehouse Task "Picking"', 'signalFragment': 'COUNT(\nCASE WHEN\n(SELECT COUNT(event_name)\nWHERE (event_name = \'Create Warehouse Task\' \nAND "WT Activity Type" = \'PICK\')) = 0 \nTHEN Null\nELSE case_id\nEND)\n/\nCOUNT(case_id)\n*100', 'aggregationType': 'CASE', 'sourceSystems': ['SAP_EWM'], 'processTypes': ['EWM_BASIC_OUTBOUND'], 'version': '1.0.0'}, {'id': 'ewm_outb_percentage_odoi_wo_wts', 'name': '% of ODO Items w/o WTs', 'description': "Percentage of Outbound Delivery Order Items that don't have any Warehouse Tasks created", 'signalFragment': "COUNT(\nCASE WHEN event_name MATCHES('Create Warehouse Task') THEN null\nELSE case_id\nEND)\n/\nCOUNT(case_id)\n*100", 'aggregationType': 'CASE', 'sourceSystems': ['SAP_EWM'], 'processTypes': ['EWM_BASIC_OUTBOUND'], 'version': '1.0.0'}, {'id': 'ewm_outb_percentage_odoi_completed_wts', 'name': '% of ODO Items with completed WTs', 'description': 'Percentage of Outbound Delivery Order Items where all WTs are confirmed', 'signalFragment': "COUNT(\nCASE WHEN\n(SELECT COUNT(event_name)\nWHERE (event_name = 'Create Warehouse Task')) > 0\nAND\n(SELECT COUNT(event_name)\nWHERE (event_name = 'Create Warehouse Task' )) =\n(SELECT COUNT(event_name)\nWHERE (event_name = 'Confirm Warehouse Task')) \nTHEN case_id\nELSE Null\nEND)\n/\nCOUNT(case_id)\n*100", 'aggregationType': 'CASE', 'sourceSystems': ['SAP_EWM'], 'processTypes': ['EWM_BASIC_OUTBOUND'], 'version': '1.0.0'}, {'id': 'ewm_outb_percentage_odoi_w_partially_completed_wts', 'name': '% of ODO Items with partially completed WTs', 'description': 'Percentage of Outbound Delivery Order Items where not all WTs are confirmed', 'signalFragment': "COUNT(\nCASE WHEN\n(SELECT COUNT(event_name)\nWHERE (event_name = 'Create Warehouse Task' )) >\n(SELECT COUNT(event_name)\nWHERE (event_name = 'Confirm Warehouse Task')) \nTHEN case_id\nELSE Null\nEND)\n/\nCOUNT(case_id)\n*100", 'aggregationType': 'CASE', 'sourceSystems': ['SAP_EWM'], 'processTypes': ['EWM_BASIC_OUTBOUND'], 'version': '1.0.0'}, {'id': 'ewm_outb_percentage_w_picking_wts_completed', 'name': '% of ODO Items with Picking WTs completed', 'description': 'Percentage of Outbound Delivery Items where all "Picking" W ...
# Number of Metrics Signals: 16 in: ../data/metric_definitions/ewm_basic_outbound.json
# ../data/metric_definitions/ariba_strategic_sourcing.json {'metrics': [{'id': 'ass_rfp_savings_baseline', 'name': 'RFP savings vs baseline spend', 'description': 'RFP (Request for Proposal) awarded value compared to the baseline spend. Indicates how much money your organization allocated (or expected to spend, baseline) versus how much they actually spent within RFP events.', 'signalFragment': 'SUM(\n\t(SELECT MAX("Baseline Spend of Sourcing Project") FILTER (\n\t\tWHERE (event_name IN (${rfp_creation_events})) \n        AND "Awarded Total Cost" > 0\n        AND "Baseline Spend of Sourcing Project" > 0))\n\t-(SELECT SUM("Awarded Total Cost") FILTER (\n\t\tWHERE (event_name IN (${rfp_creation_events})) \n        AND "Awarded Total Cost" > 0\n        AND "Baseline Spend of Sourcing Project" > 0))\n)', 'aggregationType': 'CASE', 'processTypes': ['ARIBA_STRATEGIC_SOURCING'], 'version': '1.0.0'}, {'id': 'ass_auction_savings_baseline', 'name': 'Auction savings vs baseline spend', 'description': 'Auction awarded value compared to the baseline spend. Indicates how much money your organization allocated (or expected to spend, baseline) versus how much they actually spent within Auction events.', 'signalFragment': 'SUM(\n\t(SELECT MAX("Baseline Spend of Sourcing Project") FILTER (\n\t\tWHERE (event_name IN (${auction_creation_events})) \n        AND "Awarded Total Cost" > 0\n        AND "Baseline Spend of Sourcing Project"  > 0))\n\t-(SELECT SUM("Awarded Total Cost") FILTER (\n\t\tWHERE (event_name IN (${auction_creation_events})) \n        AND "Awarded Total Cost" > 0\n        AND "Baseline Spend of Sourcing Project" > 0))\n)', 'aggregationType': 'CASE', 'processTypes': ['ARIBA_STRATEGIC_SOURCING'], 'version': '1.0.0'}, {'id': 'ass_rfp_savings_historic', 'name': 'RFP savings vs historic spend', 'description': 'RFP (Request for Proposal) savings compared to historic spend. Indicates how much money your organization used to spend for this product/service (historic) versus how much they actually spent within RFP events.', 'signalFragment': 'SUM(\n\t(SELECT SUM("Historic Total Cost") FILTER (\n\t\tWHERE (event_name IN (${rfp_creation_events})) \n        AND "Awarded Total Cost" > 0\n        AND "Historic Total Cost" > 0))\n\t-(SELECT SUM("Awarded Total Cost") FILTER (\n\t\tWHERE (event_name IN (${rfp_creation_events})) \n        AND "Awarded Total Cost" > 0\n        AND "Historic Total Cost" > 0))\n)', 'aggregationType': 'CASE', 'processTypes': ['ARIBA_STRATEGIC_SOURCING'], 'version': '1.0.0'}, {'id': 'ass_auction_savings_historic', 'name': 'Auction savings vs historic spend', 'description': 'Auction savings compared to historic spend. Indicates how much money your organization used to spend for this product/service (historic) versus how much they actually spent within Auction events.', 'signalFragment': 'SUM(\n\t(SELECT SUM("Historic Total Cost") FILTER (\n\t\tWHERE (event_name IN (${auction_creation_events})) \n        AND "Awarded Total Cost" > 0\n        AND "Historic Total Cost" > 0))\n\t-(SELECT SUM("Awarded Total Cost") FILTER (\n\t\tWHERE (event_name IN (${auction_creation_events})) \n        AND "Awarded Total Cost" > 0\n        AND "Historic Total Cost" > 0))\n)', 'aggregationType': 'CASE', 'processTypes': ['ARIBA_STRATEGIC_SOURCING'], 'version': '1.0.0'}, {'id': 'ass_awarded_events_1_supplier', 'name': 'Single participant awarded events', 'description': 'Number of awarded sourcing events with a single participant', 'signalFragment': 'SUM((\n\tSELECT COUNT("Event Id") FILTER (\n\t\tWHERE "Participating Suppliers" = 1 and "Awarded Total Cost" > 0\n\t)\n))', 'aggregationType': 'CASE', 'processTypes': ['ARIBA_STRATEGIC_SOURCING'], 'version': '1.0.0'}, {'id': 'ass_avg_supplier_participation', 'name': 'Average supplier participation', 'description': 'Average supplier participation in sourcing events', 'signalFragment': 'AVG(\n\t(SELECT SUM("Participating Suppliers") FILTER (\n\t\tWHERE (event_name IN (${sourcing_event_creation_events}) ...
# Number of Metrics Signals: 9 in: ../data/metric_definitions/ariba_strategic_sourcing.json
# ../data/metric_definitions/lead-to-opportunity-sap-sales-cloud.json {'metrics': [{'id': 'lto_sapsalescloud_total_opp_expected_revenue_amount', 'name': 'Total amount of opportunity expected revenue', 'description': 'Total amount of the expected revenue considering all opportunities', 'signalFragment': 'SUM(${lto_sapsalescloud_opportunity_expected_revenue})\n', 'aggregationType': 'CASE', 'processTypes': ['LEAD_TO_OPPORTUNITY'], 'version': '1.0.0'}, {'id': 'lto_sapsalescloud_total_opp_lost_expected_revenue_amount', 'name': 'Total amount of opportunity expected revenue lost', 'description': 'Total amount of the expected revenue considering only opportunity lost', 'signalFragment': 'SUM(${lto_sapsalescloud_opportunity_expected_revenue}) FILTER (\n\tWHERE ${lto_sapsalescloud_opp_lost_condition})\n', 'aggregationType': 'CASE', 'processTypes': ['LEAD_TO_OPPORTUNITY'], 'version': '1.0.0'}, {'id': 'lto_sapsalescloud_total_opp_won_expected_revenue_amount', 'name': 'Total amount of opportunity expected revenue won', 'description': 'Total amount of the expected revenue considering only opportunity won', 'signalFragment': 'SUM(${lto_sapsalescloud_opportunity_expected_revenue}) FILTER (\n\tWHERE ${lto_sapsalescloud_opp_won_condition})\n', 'aggregationType': 'CASE', 'processTypes': ['LEAD_TO_OPPORTUNITY'], 'version': '1.0.0'}, {'id': 'lto_sapsalescloud_lead_conversion_rate', 'name': 'Lead Conversion Rate', 'description': 'Percentage of converted lead: ((number of leads converted to opportunities) / (number of leads processed)) X 100', 'signalFragment': 'COUNT(case_id)\nFILTER(WHERE event_name MATCHES (${lto_sapsalescloud_lead_converted_events}))/count(case_id) * 100', 'aggregationType': 'CASE', 'processTypes': ['LEAD_TO_OPPORTUNITY'], 'version': '1.0.0'}, {'id': 'lto_sapsalescloud_avg_opp_lost_time', 'name': 'Average opportunity lost time', 'description': 'Average time from creating the opportunity to loosing the opportunity', 'signalFragment': 'AVG(\n\t(SELECT LAST(end_time) \n\tWHERE event_name IN (${lto_sapsalescloud_opp_lost_events})) \n\t-\n\t(SELECT FIRST(end_time) \n\tWHERE event_name IN (${lto_sapsalescloud_opp_created_events}))\n)', 'aggregationType': 'CASE', 'processTypes': ['LEAD_TO_OPPORTUNITY'], 'version': '1.0.0'}, {'id': 'lto_sapsalescloud_avg_lead_response_time', 'name': 'Average lead response time', 'description': 'Average time from lead creation to working on lead', 'signalFragment': 'AVG(\n\t(SELECT FIRST(end_time) FILTER (\n\t\tWHERE NOT event_name IN (${lto_sapsalescloud_lead_created_events})))\n\t-(SELECT FIRST(end_time) FILTER (\n\t\tWHERE event_name IN (${lto_sapsalescloud_lead_created_events})))\n)', 'aggregationType': 'CASE', 'processTypes': ['LEAD_TO_OPPORTUNITY'], 'version': '1.0.0'}, {'id': 'lto_sapsalescloud_total_nr_won_opp', 'name': 'Total number of won opportunities', 'description': 'Total number of won opportunities', 'signalFragment': 'COUNT(case_id) FILTER (\n\tWHERE (${lto_sapsalescloud_opp_won_condition})\n\t)', 'aggregationType': 'CASE', 'processTypes': ['LEAD_TO_OPPORTUNITY'], 'version': '1.0.0'}, {'id': 'lto_sapsalescloud_opp_wo_lead', 'name': 'Opportunities without lead', 'description': 'Total number of opportunities without lead', 'signalFragment': 'COUNT(case_id) FILTER (\n\tWHERE ${lto_sapsalescloud_lead_identifier} IS NULL\n\t)', 'aggregationType': 'CASE', 'processTypes': ['LEAD_TO_OPPORTUNITY'], 'version': '1.0.0'}, {'id': 'lto_sapsalescloud_total_nr_open_opp', 'name': 'Total number of open opportunities', 'description': 'Total number of currently open opportunities', 'signalFragment': 'COUNT(case_id) FILTER (\n\tWHERE (SELECT BOOL_AND( NOT event_name IN (${lto_sapsalescloud_close_opp_events})))\n\t)', 'aggregationType': 'CASE', 'processTypes': ['LEAD_TO_OPPORTUNITY'], 'version': '1.0.0'}, {'id': 'lto_sapsalescloud_lead_converted_w_qualification', 'name': 'Leads Converted with Qualification', 'description': 'Number of leads converted with qualification', 'signalFragment': 'count(case_id)\nfilter( ...
# Number of Metrics Signals: 25 in: ../data/metric_definitions/lead-to-opportunity-sap-sales-cloud.json
# ../data/metric_definitions/request-to-service.json {'metrics': [{'id': 'rts_contract_attach_rate', 'name': 'Contract attach rate', 'description': 'Service tickets with attached customer contract', 'signalFragment': 'COUNT(case_id) FILTER (WHERE "Ticket Contract" IS NOT NULL)\n/\nCOUNT(case_id)*100', 'aggregationType': 'CASE', 'processTypes': ['REQUEST_TO_SERVICE'], 'sourceSystems': ['SAP_SERVICE_CLOUD'], 'unit': {'type': 'SUFFIX', 'suffix': '%'}, 'direction': 'UP', 'version': '1.0.0'}, {'id': 'rts_first_time_fix_rate', 'name': 'First time fix rate', 'description': 'Rate of first time fixes for tickets', 'signalFragment': "(COUNT (case_id) FILTER(WHERE ((SELECT COUNT (event_name) FILTER (WHERE event_name IN ('Technically Completed')) < 2) ))\n/ \nCOUNT (case_id) )*100", 'aggregationType': 'CASE', 'processTypes': ['REQUEST_TO_SERVICE'], 'sourceSystems': ['SAP_SERVICE_CLOUD'], 'unit': {'type': 'SUFFIX', 'suffix': '%'}, 'direction': 'UP', 'version': '1.0.0'}, {'id': 'rts_avg_tickets_per_customer', 'name': 'Average number of tickets per customer', 'description': 'Average number of tickets per customer', 'signalFragment': 'COUNT(case_id) / COUNT(DISTINCT "Ticket Account ID")', 'aggregationType': 'CASE', 'processTypes': ['REQUEST_TO_SERVICE'], 'sourceSystems': ['SAP_SERVICE_CLOUD'], 'direction': 'DOWN', 'version': '1.0.0'}, {'id': 'rts_ratio_escalated_tickets', 'name': 'Ratio of escalated tickets', 'description': 'Rate of tickets that were escalated', 'signalFragment': 'COUNT ("case_id") \nFILTER (WHERE (EVENT_NAME MATCHES (\'Escalated\')))\n/\nCOUNT ("case_id") * 100', 'aggregationType': 'CASE', 'processTypes': ['REQUEST_TO_SERVICE'], 'sourceSystems': ['SAP_SERVICE_CLOUD'], 'unit': {'type': 'SUFFIX', 'suffix': '%'}, 'direction': 'DOWN', 'version': '1.0.0'}, {'id': 'rts_avg_response_time', 'name': 'Average response time', 'description': 'Average time from ticket creation to first response', 'signalFragment': 'AVG(\n\t(SELECT LAST(end_time)\n\t\tWHERE event_name IN (${rts_response_events}))\n\t-(SELECT FIRST(end_time)\n\t\tWHERE event_name IN (${ticket_creation_events}))\n   )', 'aggregationType': 'CASE', 'processTypes': ['REQUEST_TO_SERVICE'], 'sourceSystems': ['SAP_SERVICE_CLOUD'], 'direction': 'DOWN', 'version': '1.0.0'}], 'variables': [{'name': 'rts_response_events', 'description': "Events defining the response to a recently opened case, for example 'In Progress - Accepted', 'In Progress - Approved'", 'defaultValues': [{'defaultValue': "'In Process - Accepted', 'In Process - Approved'", 'sourceSystems': ['SAP_SERVICE_CLOUD']}]}, {'name': 'ticket_creation_events', 'description': "Events defining the start events of a case, for example 'Open'", 'defaultValues': [{'defaultValue': "'Open'", 'sourceSystems': ['SAP_SERVICE_CLOUD']}]}]}
# Number of Metrics Signals: 5 in: ../data/metric_definitions/request-to-service.json
# ../data/metric_definitions/manage_personal_employee_information.json {'metrics': [{'id': 'average_time_completed_prior_to_effective_date', 'name': 'Average Time Completed Prior To Effective Date', 'description': 'Determines how long before the effective date the record was created. A negative value means that the record was created retroactively.', 'signalFragment': 'AVG(\n(SELECT FIRST("Effective Date")) \n- \n(SELECT LAST("Created Date"))\n)', 'aggregationType': 'CASE', 'processTypes': ['MANAGE_PERSONAL_EMPLOYEE_INFORMATION'], 'version': '1.0.0'}, {'id': 'average_time_resubmit_workflow_request', 'name': 'Average Time for Employee to Resubmit Workflow Request', 'description': 'Counts the average time from when a workflow was rejected by HR until the employee resubmits a workflow request', 'signalFragment': "AVG ((SELECT LAST (END_TIME) FILTER (\n WHERE EVENT_NAME IN ('Personal Data Change WF Resubmitted'))) \n- (SELECT FIRST (END_TIME) FILTER (\n WHERE EVENT_NAME IN ('Personal Data Change WF Rejected'))))", 'aggregationType': 'CASE', 'processTypes': ['MANAGE_PERSONAL_EMPLOYEE_INFORMATION'], 'version': '1.0.0'}, {'id': 'average_time_to_approve_workflow_request', 'name': 'Average Time to Approve Workflow Request', 'description': 'Counts the average time from the initiation of a workflow to change personal data by the employee to the approval of the workflow request by the HR department', 'signalFragment': "AVG ((SELECT LAST (END_TIME) FILTER (\n WHERE EVENT_NAME IN ('Personal Data Change WF Approved'))) \n- (SELECT FIRST (END_TIME) FILTER (\n WHERE EVENT_NAME IN ('Personal Data Change WF Initiated'))))", 'aggregationType': 'CASE', 'processTypes': ['MANAGE_PERSONAL_EMPLOYEE_INFORMATION'], 'version': '1.0.0'}, {'id': 'average_time_to_reject_workflow_request', 'name': 'Average Time to Reject Workflow Request', 'description': 'Counts the average time from the initiation of a workflow to change personal data by the employee to the rejection of the workflow request by the HR department', 'signalFragment': "AVG ((SELECT LAST (END_TIME) FILTER (\n WHERE EVENT_NAME IN ('Personal Data Change WF Rejected'))) \n- (SELECT FIRST (END_TIME) FILTER (\n WHERE EVENT_NAME IN ('Personal Data Change WF Initiated'))))", 'aggregationType': 'CASE', 'processTypes': ['MANAGE_PERSONAL_EMPLOYEE_INFORMATION'], 'version': '1.0.0'}, {'id': 'average_time_workflow_initiated_prior_to_effective_date', 'name': 'Average Time Workflow Initiated Prior to Effective Date', 'description': 'Determines how long before the effective date the workflow request was initiated. A negative value means that the record was created retroactively.', 'signalFragment': 'AVG("Effective Date" - "Workflow Created Date")', 'aggregationType': 'CASE', 'processTypes': ['MANAGE_PERSONAL_EMPLOYEE_INFORMATION'], 'version': '1.0.0'}, {'id': 'rate_of_personal_data_changes_initiated_by_employee', 'name': 'Rate of Personal Data Changes Initiated by Employee', 'description': 'Determines the rate of cases with personal data changes initiated by the employee.', 'signalFragment': "SUM(\n\t(SELECT COUNT(CASE_ID) FILTER (\n \tWHERE (EVENT_NAME IN ('Personal Data Change WF Initiated'))))) \n/ COUNT (CASE_ID) \n*100", 'aggregationType': 'CASE', 'processTypes': ['MANAGE_PERSONAL_EMPLOYEE_INFORMATION'], 'version': '1.0.0'}], 'variables': []}
# Number of Metrics Signals: 6 in: ../data/metric_definitions/manage_personal_employee_information.json
# ../data/metric_definitions/meter_to_cash.json {'metrics': [{'id': 'conformance_level', 'name': 'Conformance level', 'description': 'Percentage of cases without conformance issues', 'signalFragment': 'COUNT(case_id) FILTER (\n\tWHERE NOT event_name MATCHES ((${no_happy_path_events}))\n\t)\n/ COUNT(case_id)\n* 100', 'aggregationType': 'CASE', 'processTypes': ['METER_TO_CASH'], 'version': '1.0.0'}, {'id': 'customer_self_readings', 'name': 'Number of meter readings performed by customer', 'description': 'Number of meter readings performed by customer (self-reading)', 'signalFragment': 'COUNT(case_id) FILTER (\n\tWHERE (\n\t\tSELECT BOOL_OR(event_name IN (${obtain_readings_events})\n\t\tAND ${self_reading_condition}))\n\t)', 'aggregationType': 'CASE', 'processTypes': ['METER_TO_CASH'], 'version': '1.0.0'}, {'id': 'onsite_readings', 'name': 'Number of meter readings performed on-site', 'description': 'Number of meter readings performed on-site by utility', 'signalFragment': 'COUNT(case_id) FILTER (\n\tWHERE (\n\t\tSELECT BOOL_OR(event_name IN (${obtain_readings_events})\n\t\tAND ${utility_reading_condition}))\n\t)', 'aggregationType': 'CASE', 'processTypes': ['METER_TO_CASH'], 'version': '1.0.0'}, {'id': 'readings_after_invoicing', 'name': 'Number of meter reading data obtained after invoicing', 'description': 'Number of meter reading data obtained after invoicing period', 'signalFragment': 'COUNT(case_id) FILTER (\n\tWHERE (\n\t\t(SELECT BOOL_OR(event_name IN (${obtain_readings_events})))\n\t\tAND ${after_invoicing_condition}\n\t)\n)', 'aggregationType': 'CASE', 'processTypes': ['METER_TO_CASH'], 'version': '1.0.0'}, {'id': 'non_reachable_smart_meters', 'name': 'Number of non-reachable smart meters', 'description': 'Number of smart meter devices for which no data was transmitted for 10+ days', 'signalFragment': 'COUNT(case_id) FILTER (WHERE (\n\tSELECT LAST(end_time) FILTER (WHERE event_name IN (${obtain_readings_events}))\n\t-\n\tFIRST(end_time) FILTER (WHERE event_name IN (${create_reading_orders_events}))\n\t) > DURATION ${non_reachable_smart_meters_period}\n)', 'aggregationType': 'CASE', 'processTypes': ['METER_TO_CASH'], 'version': '1.0.0'}, {'id': 'missing_meter_readings', 'name': 'Number of missing meter readings', 'description': 'Number of meter readings for which the scheduled reading date is passed, but no data was obtained', 'signalFragment': 'COUNT (case_id) FILTER (\n\t\tWHERE ${overdue_reading_date_condition}\n\t\tAND (SELECT BOOL_AND(NOT event_name IN (${obtain_readings_events})))\n\t)', 'aggregationType': 'CASE', 'processTypes': ['METER_TO_CASH'], 'version': '1.0.0'}, {'id': 'ratio_timely_late_readings', 'name': 'Ratio between timely and late meter readings', 'description': 'Ratio between timely and late meter readings', 'signalFragment': '(COUNT(case_id) FILTER (\n\tWHERE (\n\t\t(SELECT BOOL_OR(event_name IN (${obtain_readings_events})))\n\t\tAND ${timely_meter_reading_condition})\n\t)\n/\nCOUNT(case_id) FILTER (\n\tWHERE (\n\t\t(SELECT BOOL_OR(event_name IN (${obtain_readings_events})))\n\t\tAND ${late_meter_reading_condition})\n\t)\n)*100', 'aggregationType': 'CASE', 'processTypes': ['METER_TO_CASH'], 'version': '1.0.0'}, {'id': 'timely_readings_percent', 'name': 'Percentage of timely meter readings', 'description': 'Percentage of total meter readings completed on-time', 'signalFragment': 'COUNT(case_id) FILTER (\n\tWHERE (\n\t\t(SELECT BOOL_OR(event_name IN (${obtain_readings_events})))\n\t\tAND ${timely_meter_reading_condition})\n\t)\n/\nCOUNT(case_id) *100', 'aggregationType': 'CASE', 'processTypes': ['METER_TO_CASH'], 'version': '1.0.0'}, {'id': 'late_readings_percent', 'name': 'Percentage of late meter readings', 'description': 'Percentage of total meter readings completed late', 'signalFragment': 'COUNT(case_id) FILTER (\n\tWHERE (\n\t\t(SELECT BOOL_OR(event_name IN (${obtain_readings_events})))\n\t\tAND ${late_meter_reading_condition})\n\t)\n/\nCOUNT(case_id) *100', 'aggregationType': 'CASE', 'processTypes ...
# Number of Metrics Signals: 18 in: ../data/metric_definitions/meter_to_cash.json
# ../data/metric_definitions/__process_types.json [{'id': 'ARIBA_CONTRACTING', 'name': 'Manage Procurement'}, {'id': 'ARIBA_STRATEGIC_SOURCING', 'name': 'Source Products and Services'}, {'id': 'ATTRACT_TO_ACQUIRE_TALENT', 'name': 'Attract-to-Acquire Talent'}, {'id': 'INCIDENT_TO_RESOLUTION', 'name': 'Incident-to-Resolution'}, {'id': 'INVOICE_TO_CASH', 'name': 'Invoice-to-Cash'}, {'id': 'INVOICE_TO_PAY', 'name': 'Invoice-to-Pay'}, {'id': 'ISSUE_TO_RESOLUTION', 'name': 'Issue-to-Resolution'}, {'id': 'LEAD_TO_OPPORTUNITY', 'name': 'Lead-to-Opportunity'}, {'id': 'LEAD_TO_QUOTE', 'name': 'Lead-to-Quote'}, {'id': 'MAKE_TO_ORDER_STOCK', 'name': 'Make-to-Order-Stock'}, {'id': 'MAKE_TO_STOCK', 'name': 'Make-to-Stock'}, {'id': 'MANAGE_PERSONAL_EMPLOYEE_INFORMATION', 'name': 'Manage Personal Employee Information'}, {'id': 'METER_TO_CASH', 'name': 'Meter-to-Cash'}, {'id': 'ORDER_TO_CASH', 'name': 'Order-to-Cash'}, {'id': 'PROCURE_TO_PAY', 'name': 'Procure-to-Pay'}, {'id': 'PROJECT_TO_CASH_SAP_S4H_CLOUD', 'name': 'Project-to-Cash'}, {'id': 'REQUEST_TO_SERVICE', 'name': 'Request-to-Service'}, {'id': 'SALES_AND_OPERATIONS', 'name': 'Sales and Operations'}, {'id': 'ACQUIRE_TO_ONBOARD', 'name': 'Acquire-to-Onboard'}, {'id': 'OPERATE_MANUFACTURING', 'name': 'Operate Manufacturing'}, {'id': 'INSPECT_TO_QUALITY', 'name': 'Inspect-to-Quality'}, {'id': 'EWM_BASIC_OUTBOUND', 'name': 'Manage Warehouse and Inventory (Outbound)'}, {'id': 'VENDOR_INVOICE_MANAGEMENT', 'name': 'Vendor Invoice Management'}, {'id': 'MANAGE_TRANSPORTATION', 'name': 'Manage Transportation Execution'}]
# JSON File: ../data/metric_definitions/__process_types.json is not of Signavio Metric, Dashboard or Investigation type
# ../data/metric_definitions/invoice_to_cash.json {'metrics': [{'id': 'itc_ecc_s4h_total_overdue_invoice_amount', 'name': 'Total overdue invoice amounts', 'description': 'Sum of all invoice amounts that are overdue (converted in USD)', 'signalFragment': "SUM(${itc_ecc_s4h_amount_conv}) FILTER(\n\t WHERE (${itc_ecc_s4h_clearing_date} IS NULL)\n\t\tAND ${itc_ecc_s4h_due_date} < DATE_TRUNC('day', NOW())\n\t)", 'aggregationType': 'CASE', 'processTypes': ['INVOICE_TO_CASH'], 'version': '1.0.0'}, {'id': 'itc_ecc_s4h_open_overdue_invoices', 'name': 'Number of open overdue invoices', 'description': 'Number of invoices that are currently open and overdue', 'signalFragment': "COUNT(case_id) FILTER (\n\tWHERE (${itc_ecc_s4h_clearing_date} IS NULL)\n\t\tAND ${itc_ecc_s4h_due_date} < DATE_TRUNC('day', NOW())\n)", 'aggregationType': 'CASE', 'processTypes': ['INVOICE_TO_CASH'], 'version': '1.0.0'}, {'id': 'itc_ecc_s4h_lead_time', 'name': 'Average time invoice creation to invoice clearing', 'description': 'Average time from invoice creation to invoice clearing within a reference period', 'signalFragment': 'AVG(\n\t(SELECT LAST(${itc_ecc_s4h_clearing_date}) \n\t\tWHERE ((NOW() - LAST(end_time)) < DURATION ${itc_ecc_s4h_invoice_clearing_period}))\n\t-(SELECT LAST(${itc_ecc_s4h_posting_date})\n\t\tWHERE ((NOW() - LAST(end_time)) < DURATION ${itc_ecc_s4h_invoice_posting_period}))\n\t)', 'aggregationType': 'CASE', 'processTypes': ['INVOICE_TO_CASH'], 'version': '1.0.0'}, {'id': 'itc_ecc_s4h_avg_creation_pgi_invoice', 'name': 'Average time post goods issue to invoice creation', 'description': 'Average time from posting goods issue to invoice creation', 'signalFragment': 'AVG(\n\t(SELECT LAST(end_time) \n\tWHERE event_name IN (${itc_ecc_s4h_invoice_creation_events})) \n\t-\n\t(SELECT FIRST(end_time) \n\tWHERE event_name IN (${itc_ecc_s4h_shipping_events}))\n)', 'aggregationType': 'CASE', 'processTypes': ['INVOICE_TO_CASH'], 'version': '1.0.0'}, {'id': 'itc_ecc_s4h_no_payment_rate', 'name': 'No payment rate', 'description': 'Percentage of overdue invoices from all open invoices', 'signalFragment': "COUNT (case_id) FILTER (\n\tWHERE (${itc_ecc_s4h_clearing_date} IS NULL AND ${itc_ecc_s4h_due_date} < DATE_TRUNC('day', NOW()))\n\t)\n/ COUNT (case_id) FILTER(\n\tWHERE (${itc_ecc_s4h_clearing_date} IS NULL)) * 100", 'aggregationType': 'CASE', 'processTypes': ['INVOICE_TO_CASH'], 'version': '1.0.0'}, {'id': 'itc_ecc_s4h_dunning_rate', 'name': 'Dunning rate', 'description': 'Percentage of invoices that were dunned', 'signalFragment': 'COUNT (case_id) FILTER (\n\tWHERE (${itc_ecc_s4h_dunning_condition})\n\t) / COUNT (case_id) * 100', 'aggregationType': 'CASE', 'processTypes': ['INVOICE_TO_CASH'], 'version': '1.0.0'}, {'id': 'itc_ecc_s4h_automation_rate_inv_clearing', 'name': 'Automation rate for invoice clearing', 'description': 'Percentage of automated invoice clearing events', 'signalFragment': 'SUM(\n\t(SELECT COUNT(event_name) FILTER (\n\t\tWHERE (event_name IN (${itc_ecc_s4h_clear_invoice_events})\n\t\t\tAND (${itc_ecc_s4h_automation_condition})))\n\t)\n)\n/ SUM(\n\t(SELECT COUNT(event_name) FILTER (\n\tWHERE (event_name IN (${itc_ecc_s4h_clear_invoice_events})))\n\t)\n)\n* 100', 'aggregationType': 'CASE', 'processTypes': ['INVOICE_TO_CASH'], 'version': '1.0.0'}, {'id': 'itc_ecc_s4h_duration_of_dunning_blocks', 'name': 'Duration of dunning blocks', 'description': 'Average lead time from setting a dunning block to removing the last dunning block', 'signalFragment': 'AVG(\n\t(SELECT LAST(end_time) FILTER \n\t\t(WHERE event_name IN (${itc_ecc_s4h_remove_dunning_block_events})))\n\t-\n\t(SELECT FIRST(end_time) FILTER\n\t\t(WHERE event_name IN (${itc_ecc_s4h_set_dunning_block_events})))\n)', 'aggregationType': 'CASE', 'processTypes': ['INVOICE_TO_CASH'], 'version': '1.0.0'}, {'id': 'itc_ecc_s4h_days_sales_outstanding', 'name': 'Days Sales Outstanding (DSO)', 'description': 'Average number of days to collect revenue, weighted by the invoice value', 'signalFragm ...
# Number of Metrics Signals: 16 in: ../data/metric_definitions/invoice_to_cash.json
# ../data/metric_definitions/ariba_procure_to_pay.json {'metrics': [{'id': 'ptp_ariba_avg_pr_confirmation_time', 'name': 'Average confirmation time for purchase requisitions', 'description': 'Average time needed to confirm a purchase requisition by creating a purchase order', 'signalFragment': 'AVG(\n\t(SELECT LAST(end_time)\n\t\tWHERE event_name IN (${ptp_ariba_po_creation_events}))\n\t-(SELECT FIRST(end_time)\n\t\tWHERE event_name IN (${ptp_ariba_pr_creation_events}))\n   )', 'aggregationType': 'CASE', 'processTypes': ['PROCURE_TO_PAY'], 'version': '1.0.0'}, {'id': 'ptp_ariba_avg_invoice_payment_time', 'name': 'Average invoice payment time', 'description': 'Average time to clear invoices', 'signalFragment': 'AVG(\n\t(SELECT LAST(end_time)\n\t\tWHERE event_name IN (${ptp_ariba_invoice_clearing_events}))\n\t-(SELECT FIRST(end_time)\n\t\tWHERE event_name IN (${ptp_ariba_invoice_receipt_events}))\n   )', 'aggregationType': 'CASE', 'processTypes': ['PROCURE_TO_PAY'], 'version': '1.0.0'}, {'id': 'ptp_ariba_avg_po_to_delivery_time', 'name': 'Average time from purchase order to delivery', 'description': 'Average time from purchase order to goods receipt', 'signalFragment': 'AVG(\n\t(SELECT LAST(end_time)\n\t\tWHERE event_name IN (${ptp_ariba_goods_receipt_events}))\n\t-(SELECT FIRST(end_time)\n\t\tWHERE event_name IN (${ptp_ariba_po_creation_events}))\n   )', 'aggregationType': 'CASE', 'processTypes': ['PROCURE_TO_PAY'], 'version': '1.0.0'}, {'id': 'ptp_ariba_late_payment_rate', 'name': 'Late payment rate', 'description': 'Percentage of cases with late payments. Only cases that are paid are considered.', 'signalFragment': 'COUNT(case_id) FILTER (\n\tWHERE (${ptp_ariba_late_payment_condition})\n\t)\n/ COUNT(case_id) FILTER (\n\tWHERE (${ptp_ariba_invoice_clearing_date} IS NOT NULL)\n\t)\n* 100', 'aggregationType': 'CASE', 'processTypes': ['PROCURE_TO_PAY'], 'version': '1.0.0'}, {'id': 'ptp_ariba_overdue_payment_rate', 'name': 'Overdue payment rate', 'description': 'Percentage of cases with overdue payments. Only cases that have not been paid yet are considered.', 'signalFragment': 'COUNT(case_id) FILTER (\n\tWHERE (${ptp_ariba_overdue_payment_condition})\n\t)\n/ COUNT(case_id) FILTER (\n\tWHERE (${ptp_ariba_invoice_clearing_date} IS NULL)\n\t)\n* 100', 'aggregationType': 'CASE', 'processTypes': ['PROCURE_TO_PAY'], 'version': '1.0.0'}, {'id': 'ptp_ariba_process_compliance', 'name': 'Process compliance', 'description': 'Percentage of compliant Procure-to-Pay cases', 'signalFragment': 'COUNT(case_id) FILTER (\n\tWHERE event_name MATCHES(${ptp_ariba_compliant_event_sequence})\n\t)\n/ COUNT(case_id)\n* 100', 'aggregationType': 'CASE', 'processTypes': ['PROCURE_TO_PAY'], 'version': '1.0.0'}, {'id': 'ptp_ariba_two_way_match_rate', 'name': 'Two-way match rate', 'description': 'Percentage of purchase orders with a two-way match', 'signalFragment': 'COUNT(case_id) FILTER (\n\tWHERE (${ptp_ariba_two_way_match_condition})\n\t)\n/ COUNT(case_id)\n* 100', 'aggregationType': 'CASE', 'processTypes': ['PROCURE_TO_PAY'], 'version': '1.0.0'}, {'id': 'ptp_ariba_late_deliveries', 'name': 'Late deliveries cases', 'description': 'Number of cases with late deliveries. Only cases that have been completely delivered are considered.', 'signalFragment': 'COUNT(case_id) FILTER (\n\tWHERE ${ptp_ariba_late_delivery_condition}\n\t\tAND ${ptp_ariba_delivery_completed_condition}\n\t)', 'aggregationType': 'CASE', 'processTypes': ['PROCURE_TO_PAY'], 'version': '1.0.0'}, {'id': 'ptp_ariba_late_deliveries_rate', 'name': 'Late deliveries rate', 'description': 'Percentage of cases with late deliveries. Only cases that have been completely delivered are considered.', 'signalFragment': 'COUNT(case_id) FILTER (\n\tWHERE ${ptp_ariba_late_delivery_condition}\n\t\tAND ${ptp_ariba_delivery_completed_condition}\n\t)\n/\nCOUNT(case_id) FILTER (\n\tWHERE ${ptp_ariba_delivery_completed_condition}\n\t)\n* 100', 'aggregationType': 'CASE', 'processTypes': ['PROCURE_TO_PAY'], 'version': '1 ...
# Number of Metrics Signals: 16 in: ../data/metric_definitions/ariba_procure_to_pay.json
# ../data/metric_definitions/invoice_to_pay.json {'metrics': [{'id': 'total_overdue_invoice_amount', 'name': 'Total overdue invoice amounts', 'description': 'Sum of all invoice amounts that are open and overdue (converted to USD)', 'signalFragment': "SUM(${itp_amount_conv}) FILTER(\n\t WHERE (${itp_clearing_date} IS NULL)\n\t\tAND ${itp_due_date} < DATE_TRUNC('day', NOW()))", 'aggregationType': 'CASE', 'processTypes': ['INVOICE_TO_PAY'], 'version': '1.0.0'}, {'id': 'open_overdue_invoices', 'name': 'Number of open overdue invoices', 'description': 'Number of invoices that are currently open and overdue', 'signalFragment': "COUNT(case_id) FILTER (\n\tWHERE (${itp_clearing_date} IS NULL)\n\t\tAND ${itp_due_date} < DATE_TRUNC('day', NOW()))", 'aggregationType': 'CASE', 'processTypes': ['INVOICE_TO_PAY'], 'version': '1.0.0'}, {'id': 'overdue_ratio', 'name': 'Ratio of overdue invoices', 'description': 'Percentage of overdue invoices from all open invoices', 'signalFragment': "COUNT (case_id) FILTER (\n\tWHERE (${itp_clearing_date} IS NULL AND ${itp_due_date} < DATE_TRUNC('day', NOW()))\n\t)\n/ COUNT (case_id) FILTER(\n\tWHERE (${itp_clearing_date} IS NULL)) * 100", 'aggregationType': 'CASE', 'processTypes': ['INVOICE_TO_PAY'], 'version': '1.0.0'}, {'id': 'dpo', 'name': 'Days Payables Outstanding', 'description': 'Days Payables Outstanding - Average time from invoice posting to invoice clearing within a reference period', 'signalFragment': 'AVG(\n\t(SELECT LAST(${itp_clearing_date}) \n\t\tWHERE ((NOW() - LAST(end_time)) < DURATION ${itp_invoice_clearing_period}))\n\t-(SELECT LAST(${itp_posting_date})\n\t\tWHERE ((NOW() - LAST(end_time)) < DURATION ${itp_invoice_posting_period})))', 'aggregationType': 'CASE', 'processTypes': ['INVOICE_TO_PAY'], 'version': '1.0.0'}, {'id': 'automation_rate_inv_clearing', 'name': 'Automation rate for invoice clearing', 'description': "Percentage of automated invoice clearing events. For example 'Clear Invoice' events that are not performed by a Dialog user", 'signalFragment': 'SUM(\n\t(SELECT COUNT(event_name) FILTER (\n\t\tWHERE (event_name IN (${itp_clear_invoice_events})\n\t\t\tAND (${itp_automation_condition})))\n\t)\n)\n/ SUM(\n\t(SELECT COUNT(event_name) FILTER (\n\tWHERE (event_name IN (${itp_clear_invoice_events})))\n\t)\n)\n* 100', 'aggregationType': 'CASE', 'processTypes': ['INVOICE_TO_PAY'], 'version': '1.0.0'}, {'id': 'late_payment_rate', 'name': 'Late payment rate', 'description': 'Percentage of invoices that were cleared more than 1 day after their due dates', 'signalFragment': 'COUNT(case_id) FILTER (\n\tWHERE (${itp_clearing_date} - ${itp_due_date} \n\t\t> DURATION ${itp_late_payment_condition})\n)\n/COUNT(case_id) FILTER (\n\tWHERE (${itp_clearing_date} IS NOT NULL)\n) * 100', 'aggregationType': 'CASE', 'processTypes': ['INVOICE_TO_PAY'], 'version': '1.0.0'}, {'id': 'early_payment_rate', 'name': 'Early payment rate', 'description': 'Percentage of invoices that were cleared more than 5 days before their due dates', 'signalFragment': 'COUNT(case_id) FILTER (\n\tWHERE (${itp_due_date} - ${itp_clearing_date} \n\t\t> DURATION ${itp_early_payment_condition})\n)\n/COUNT(case_id) FILTER (\n\tWHERE (${itp_clearing_date} IS NOT NULL)\n)* 100', 'aggregationType': 'CASE', 'processTypes': ['INVOICE_TO_PAY'], 'version': '1.0.0'}, {'id': 'on_time_payment_rate', 'name': 'On-time payment rate', 'description': 'Percentage of invoices that were cleared less than 5 days before and no later than 1 day after their due dates', 'signalFragment': 'COUNT(case_id) FILTER (\n\tWHERE (${itp_clearing_date} - ${itp_due_date} \n\t\t< DURATION ${itp_late_payment_condition}\n\tAND ${itp_due_date} - ${itp_clearing_date}\n\t\t< DURATION ${itp_early_payment_condition}\n\t)\n)\n/\nCOUNT(case_id) FILTER (\n\tWHERE (${itp_clearing_date}IS NOT NULL)\n)\n* 100', 'aggregationType': 'CASE', 'processTypes': ['INVOICE_TO_PAY'], 'version': '1.0.0'}, {'id': 'reversed_invoices', 'name': 'Percentage of reversed invoices', 'description':  ...
# Number of Metrics Signals: 28 in: ../data/metric_definitions/invoice_to_pay.json
# ...
# Number of Metrics Signals: 16 in: ../data/metric_definitions/make_to_order_stock.json
# ../data/metric_definitions/conformance.json {'metrics': [{'id': 'conformance_level', 'name': 'Conformance level', 'description': 'Percentage of cases without conformance issues', 'signalFragment': 'COUNT(case_id) FILTER (\n\tWHERE event_name MATCHES(${conformance_condition})) \n/ COUNT(case_id) \n* 100', 'aggregationType': 'CASE', 'category': 'Conformance', 'version': '1.0.0'}, {'id': 'non_conformant_cases', 'name': 'Non-conformant cases', 'description': 'Total number of non-conformant cases', 'signalFragment': 'COUNT(case_id) FILTER (\n\tWHERE NOT (event_name MATCHES(${conformance_condition})))', 'aggregationType': 'CASE', 'category': 'Conformance', 'version': '1.0.0'}, {'id': 'cases_compliance_risk', 'name': 'Cases at compliance risk', 'description': 'Number of cases that might face penalty due to compliance violation', 'signalFragment': 'COUNT(case_id) FILTER (\n\tWHERE (NOT event_name MATCHES(${conformance_condition})\n\tAND (SELECT BOOL_OR( event_name IN (${compliance_milestone_events})))\n\tAND (SELECT\n\t\tLAST(end_time) FILTER (WHERE event_name IN (${compliance_end_events}))\n\t\t-\n\t\tFIRST(end_time) FILTER (WHERE event_name IN (${compliance_start_events}))\n\t) < DURATION ${compliance_threshold_time}\n\t)\n)', 'aggregationType': 'CASE', 'category': 'Conformance', 'version': '1.0.0'}], 'variables': [{'name': 'conformance_condition', 'description': 'Sequence of events that describes the "to-be" process, for example, using the MATCHES function syntax ^ \'Create Sales Order Item\' ~> \'Create Outbound Delivery Item\' ~> \'Clear Invoice\' $', 'defaultValues': [{'defaultValue': "^ 'Create Sales Order Item'\n\t~> 'Create Outbound Delivery Item'\n\t~> 'Post Goods Issue'\n\t~> 'Create Invoice Item'\n\t~> 'Clear Invoice'", 'sourceSystems': ['SAP_ECC', 'SAP_S4HANA'], 'processTypes': ['ORDER_TO_CASH']}, {'defaultValue': "^ 'Create PR Item'\n\t~> 'Release PR Item'\n\t~> 'Create PO Item'\n\t~> 'Release PO'\n\t~> 'Create Goods Receipt'\n\t~> ('Record Invoice Receipt'|'Create FI Invoice')\n\t~> 'Clear Invoice'", 'sourceSystems': ['SAP_ECC', 'SAP_S4HANA'], 'processTypes': ['PROCURE_TO_PAY']}, {'defaultValue': "^ 'Create Invoice'\n\t~> 'Post Invoice'\n\t~> 'Clear Invoice'\n\t~> 'Due Date passed'", 'sourceSystems': ['SAP_ECC', 'SAP_S4HANA'], 'processTypes': ['INVOICE_TO_CASH']}, {'defaultValue': "^ 'Vendor Creates Invoice'\\n\\t~> 'Post Invoice'\\n\\t~> 'Clear Invoice'\\n\\t~> 'Due Date passed'", 'sourceSystems': ['SAP_ECC', 'SAP_S4HANA'], 'processTypes': ['INVOICE_TO_PAY']}, {'defaultValue': "^ 'Create PR Item'\n\t~> 'Create PO Item'\n\t~> 'Create Goods Receipt'\n\t~> 'Create Asset Item'\n\t~> 'Capitalize Asset Item''\n\t~> 'Create FI Invoice'", 'sourceSystems': ['SAP_ECC', 'SAP_S4HANA'], 'processTypes': ['ACQUIRE_TO_ONBOARD']}, {'defaultValue': "^ 'Create Inspection Lot'\n\t~> 'Begin Result Recording'\n\t~> 'Complete Result Recording'\n\t~> 'Create Usage Decision'~> ('Material Movement Free'|'Material Movement Restricted')", 'sourceSystems': ['SAP_ECC', 'SAP_S4HANA'], 'processTypes': ['INSPECT_TO_QUALITY']}, {'defaultValue': "^ 'Create Process Order'\n\t~> 'Released'\n\t~> 'Confirmed'\n\t~> 'Technically completed'", 'sourceSystems': ['SAP_ECC', 'SAP_S4HANA'], 'processTypes': ['MAKE_TO_STOCK']}, {'defaultValue': "^ 'Create Incident'\n\t~> ('Assign Incident to User'|'Assign Incident to Network Group'|'Assign Incident to Service Desk Group')\n\t~> 'Incident in Progress'\n\t~> 'Incident Resolved'\n\t~> 'Close Incident'", 'sourceSystems': ['SERVICENOW'], 'processTypes': ['INCIDENT_TO_RESOLUTION']}, {'defaultValue': "^ 'Create Lead'\n\t~> 'Assign Lead Owner'\n\t~> 'Create Opportunity'\n\t~> ('Update Opportunity Stage to: Closed Won'\n\t\t|'Update Opportunity Stage to: 06 Closed Won (Onboarding)'\n\t\t|'Update Opportunity Stage to: Closed Lost'\n\t\t|'Update Opportunity Stage to: Dead'\n\t\t|'Update Opportunity Stage to: Dead - No Opportunity'\n\t\t|'Update Opportunity Stage to: Dead - No Decision'\n\t\t|'Update Opportunity Stage to: Dead  ...
# Number of Metrics Signals: 3 in: ../data/metric_definitions/conformance.json
# ../data/metric_definitions/make_to_stock.json {'metrics': [{'id': 'mts_production_qty_accuracy', 'name': 'Production quantity accuracy', 'description': 'Rate between total process order quantities and total goods receipt quantities', 'signalFragment': 'AVG(\n\t"Produced Delivered Quantity"/"Total Order Quantity")\n\tFILTER(WHERE "Delivery Completed" IS NOT NULL)\n*100', 'aggregationType': 'CASE', 'processTypes': ['MAKE_TO_STOCK'], 'version': '1.0.0'}, {'id': 'mts_po_specific_status', 'name': 'Process orders specific status', 'description': 'Total process orders with a specific status', 'signalFragment': 'COUNT(event_name)\n\tFILTER(WHERE event_name MATCHES(${mts_po_status_event_name}))', 'aggregationType': 'CASE', 'processTypes': ['MAKE_TO_STOCK'], 'version': '1.0.0'}, {'id': 'mts_po_without_plo', 'name': 'Process orders without planned orders', 'description': 'Total process orders created without planned order reference', 'signalFragment': 'COUNT(case_id)\n\tFILTER(WHERE "Planned Order Number" IS NULL)', 'aggregationType': 'CASE', 'processTypes': ['MAKE_TO_STOCK'], 'version': '1.0.0'}, {'id': 'mts_planning_rate', 'name': 'Planning rate', 'description': 'Process orders with planned order reference and total process orders', 'signalFragment': 'COUNT(case_id)\n\tFILTER(WHERE "Planned Order Number" IS NOT NULL)\n/ \nCOUNT(case_id)\n*100', 'aggregationType': 'CASE', 'processTypes': ['MAKE_TO_STOCK'], 'version': '1.0.0'}, {'id': 'mts_num_goods_receipts', 'name': 'Number of goods receipts', 'description': 'Total number of single goods receipt postings', 'signalFragment': "SUM((\n\tSELECT COUNT(event_name)\n\tFILTER(WHERE event_name LIKE 'GR%')))", 'aggregationType': 'CASE', 'processTypes': ['MAKE_TO_STOCK'], 'version': '1.0.0'}, {'id': 'mts_automation_rate_specific_event', 'name': 'Automation rate specific event', 'description': 'Automation rate for a specific event', 'signalFragment': 'SUM(\n\t(SELECT COUNT(event_name)\n\tFILTER (\n\t\tWHERE ((${mts_automation_condition})\n\t\tAND event_name IN (${mts_automation_event_name})))))\n/ SUM(\n\t(SELECT COUNT(event_name)\n\tFILTER (\n\t\tWHERE (event_name IN (${mts_automation_event_name})))))\n*100', 'aggregationType': 'CASE', 'processTypes': ['MAKE_TO_STOCK'], 'version': '1.0.0'}, {'id': 'mts_po_release_overdue', 'name': 'Process orders overdue for release', 'description': 'Process orders where the scheduled release date is in the past and the actual release date is pending', 'signalFragment': 'COUNT(case_id)\n\tFILTER (WHERE "Scheduled Release Date" < NOW()\n\tAND "Actual Release Date" IS NULL)', 'aggregationType': 'CASE', 'processTypes': ['MAKE_TO_STOCK'], 'version': '1.0.0'}, {'id': 'mts_po_delivery_overdue', 'name': 'Process orders overdue for delivery', 'description': 'Process orders where the scheduled finish date is in the past and the actual delivery date is pending', 'signalFragment': 'COUNT(case_id)\n\tFILTER (WHERE "Scheduled Finish Date" < NOW()\n\tAND "Actual Delivery Date" IS NULL)', 'aggregationType': 'CASE', 'processTypes': ['MAKE_TO_STOCK'], 'version': '1.0.0'}, {'id': 'mts_start_date_diff', 'name': 'Start date: difference scheduled and actual date', 'description': 'Average difference of the scheduled start date minus the actual start date', 'signalFragment': 'AVG(\n"Scheduled Start Date" - "Actual Start Date")', 'aggregationType': 'CASE', 'processTypes': ['MAKE_TO_STOCK'], 'version': '1.0.0'}, {'id': 'mts_end_date_diff', 'name': 'Finish date: difference scheduled and actual date', 'description': 'Average difference of the scheduled finish date minus the actual finish date', 'signalFragment': 'AVG(\n"Scheduled Finish Date" - "Actual Finish Date")', 'aggregationType': 'CASE', 'processTypes': ['MAKE_TO_STOCK'], 'version': '1.0.0'}, {'id': 'mts_release_date_diff', 'name': 'Release date: difference scheduled and actual date', 'description': 'Average difference of the scheduled release date minus the actual release date', 'signalFragment': 'AVG(\n"Scheduled Release Date" - " ...
# Number of Metrics Signals: 17 in: ../data/metric_definitions/make_to_stock.json
# ../data/metric_definitions/manage_transportation.json {'metrics': [{'id': 'carrier_change_rate', 'name': 'Carrier Change Rate', 'description': 'Rate of Freight Orders that have a carrier change', 'signalFragment': "COUNT(case_id) \n\tFILTER (WHERE event_name MATCHES ('Change Carrier')\n\t)\n/\nCOUNT(case_id) \n*100 ", 'aggregationType': 'CASE', 'sourceSystems': ['SAP_TM'], 'processTypes': ['MANAGE_TRANSPORTATION'], 'version': '1.0.0'}, {'id': 'carrier_rejection_rate', 'name': 'Carrier Rejection Rate', 'description': 'Rate of Freight Orders that were rejected by Carrier', 'signalFragment': "COUNT(case_id) \n\tFILTER (WHERE event_name MATCHES ('Freight Order Rejected by Vendor')\n\t)\n/\nCOUNT(case_id) \n*100 ", 'aggregationType': 'CASE', 'sourceSystems': ['SAP_TM'], 'processTypes': ['MANAGE_TRANSPORTATION'], 'version': '1.0.0'}, {'id': 'fsd_cancellation_rate', 'name': 'Freight Settlement Cancellation Rate', 'description': 'Rate of Freight Settlements that were cancelled', 'signalFragment': "COUNT(case_id) \n\tFILTER (WHERE event_name MATCHES ('Cancel Settlement')\n\t)\n/\nCOUNT(case_id) \n*100 ", 'aggregationType': 'CASE', 'sourceSystems': ['SAP_TM'], 'processTypes': ['MANAGE_TRANSPORTATION'], 'version': '1.0.0'}, {'id': 'late_delivery_rate', 'name': 'Late Delivery Rate', 'description': 'Rate of Freight Order that were executed a defined period of time after the defined delivery date', 'signalFragment': 'COUNT(case_id) FILTER(WHERE\n\t(SELECT LAST(end_time) FILTER\n    (WHERE event_name IN (\'Confirm Execution Done\')))\n\t- "FRO Delivery Date"\n\t> DURATION ${late_delivery_duration}\n    AND "FRO Delivery Status" = \'03\')\n/ \nCOUNT(case_id) FILTER (WHERE "FRO Delivery Status" = \'03\')', 'aggregationType': 'CASE', 'sourceSystems': ['SAP_TM'], 'processTypes': ['MANAGE_TRANSPORTATION'], 'version': '1.0.0'}, {'id': 'confirmation_cycle_time', 'name': 'Med. Cycle Time FRO Confirmation by Vendor', 'description': 'Median Cycle Time from Send Freight Order to Vendor to Freight Order Confirmed by Vendor', 'signalFragment': "MEDIAN(\n\t(SELECT LAST (end_time) FILTER (\n     WHERE event_name IN ('Freight Order Confirmed by Vendor'))\n\t) \n- \t(SELECT FIRST (end_time) FILTER (\n     WHERE event_name IN ('Send Freight Order to Vendor'))\n\t)\n)    ", 'aggregationType': 'CASE', 'sourceSystems': ['SAP_TM'], 'processTypes': ['MANAGE_TRANSPORTATION'], 'version': '1.0.0'}, {'id': 'execution_cancel_cycle_time', 'name': 'Med. Cycle Time FRO Creation to Execution Cancellation', 'description': 'Median Cycle Time Freight Order Creation to Cancel Execution', 'signalFragment': "MEDIAN(\n\t(SELECT LAST (end_time) FILTER (\n     WHERE event_name IN ('Cancel Execution'))\n\t) \n- \t(SELECT FIRST (end_time) FILTER (\n     WHERE event_name IN ('Create Freight Order'))\n\t)\n)    ", 'aggregationType': 'CASE', 'sourceSystems': ['SAP_TM'], 'processTypes': ['MANAGE_TRANSPORTATION'], 'version': '1.0.0'}, {'id': 'fro_to_fsd_cycle_time', 'name': 'Med. Cycle Time FRO Creation to FSD Creation', 'description': 'Median Cycle Time Freight Order Creation to Freight Settlement Document Creation', 'signalFragment': "MEDIAN(\n\t(SELECT LAST (end_time) FILTER (\n     WHERE event_name IN ('Create Freight Settlement Document'))\n\t) \n- \t(SELECT FIRST (end_time) FILTER (\n     WHERE event_name IN ('Create Freight Order'))\n\t)\n)    ", 'aggregationType': 'CASE', 'sourceSystems': ['SAP_TM'], 'processTypes': ['MANAGE_TRANSPORTATION'], 'version': '1.0.0'}, {'id': 'fsd_cancel_cycle_time', 'name': 'Med. Cycle Time FSD Creation to Cancel Settlement', 'description': 'Median Cycle Time Freight Settlement Document Creation to Cancel Settlement', 'signalFragment': "MEDIAN(\n\t(SELECT LAST (end_time) FILTER (\n     WHERE event_name IN ('Cancel Settlement'))\n\t) \n- \t(SELECT FIRST (end_time) FILTER (\n     WHERE event_name IN ('Create Freight Settlement Document'))\n\t)\n)    ", 'aggregationType': 'CASE', 'sourceSystems': ['SAP_TM'], 'processTypes': ['MANAGE_TRANSPORTATION'], 'ver ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 41
#      34 #p, ws, view = p, 'Solutions Demo Workspace', "defaultview-545"
#      35 #signals_all_local_p=signals_from_locals(p, ws, view)
#      36
#      37 ### p, ws, view = p0, 'Process AI', "strview-1"
#      38 ### signals_all_local_p0=signals_from_locals(p, ws, view)
#      39 ### "../data/metric_definitions"
#      40 p, ws, view = p1, 'Solutions Demo Workspace', "defaultview-545"
# ---> 41 signals_all_local_p1=signals_from_locals(p, ws, view)
#      43 ### "../data/pia-dashboards"
#      44 p, ws, view = p2, 'Solutions Demo Workspace', "defaultview-545"
#
# Cell In[24], line 34, in signals_from_locals(p, workspacename, viewid)
#      32     signals_d+=d
#      33 if 'metrics' in fromjson.keys() and 'investigation' not in fromjson.keys() and 'dashboard' not in fromjson.keys():
# ---> 34     m = docs_from_metric_json(path, from_json=fromjson, view=viewid)[path] #"strview-1") #[path][0]['metric_vars']['sla_closure_events']
#      35     [s.update(origin=path,workspace_name=workspacename) for s in m]
#      36     signals_m+=m
#
# Cell In[30], line 58, in docs_from_metric_json(path, from_json, view)
#      55                 metrics= json.load(stream)
#      57         for i in range(len(metrics['metrics'])):
# ---> 58                 signal, s, mapm, metric, metric_vars = vars_substitution(mindex=i,m=metrics)
#      59                 string_to_prompt="""
#      60 SELECT
#      61 {signal}
#      62 FROM "{THIS_PROCESS}"
#      63                 """.format(signal=signal,THIS_PROCESS=view)
#      64                 name=metric['name']
#
# Cell In[30], line 40, in vars_substitution(mindex, m)
#      36     mapm.update(bug_vars)
#      37 #print("STR DDBG mapm",mapm)
#      38 #print("STR DDBG s, m['metrics'][mindex],metric_vars:",s, m['metrics'][mindex],metric_vars )
#      39 #s.format(**mapm) # produces extra $
# ---> 40 return temp.substitute(**mapm) , s,  mapm, m['metrics'][mindex] , metric_vars
#
# File ~/.pyenv/versions/3.11.6/lib/python3.11/string.py:121, in Template.substitute(self, mapping, **kws)
#     118         self._invalid(mo)
#     119     raise ValueError('Unrecognized named group in pattern',
#     120                      self.pattern)
# --> 121 return self.pattern.sub(convert, self.template)
#
# File ~/.pyenv/versions/3.11.6/lib/python3.11/string.py:118, in Template.substitute.<locals>.convert(mo)
#     116     return self.delimiter
#     117 if mo.group('invalid') is not None:
# --> 118     self._invalid(mo)
#     119 raise ValueError('Unrecognized named group in pattern',
#     120                  self.pattern)
#
# File ~/.pyenv/versions/3.11.6/lib/python3.11/string.py:101, in Template._invalid(self, mo)
#      99     colno = i - len(''.join(lines[:-1]))
#     100     lineno = len(lines)
# --> 101 raise ValueError('Invalid placeholder in string: line %d, col %d' %
#     102                  (lineno, colno))
#
# ValueError: Invalid placeholder in string: line 3, col 63

# %%
print(f" >>>>>>>>>>>>< Signals: {len(signals_all_local)} ")
# Out:
#  >>>>>>>>>>>>< Signals: 5396

# %% [markdown]
# # Pandas and data Analysis
#
# Here we:
# - *vdf* - Load view column names for each involved view: from all_json and all_json1
# - *df* -  Combine Signals from different sources into Pandas for Statistical analysis.

# %% [markdown]
# ## Schemas to Data Frames

# %%
# Load all column names from all available views to DF vf
#p=list(all_json.keys())[17]
import pandas as pd


def get_column_names_from_aal_json(all_json):
    """_summary_

    Args:
        all_json (_type_): _description_
    """
    col_names=[]
    for p in  list(all_json.keys()):
        if "views" in all_json[p].keys() and len( all_json[p]["views"]) > 0:
            #print(p, all_json[p]["views"])
            view=list(all_json[p]["views"].keys())[0]
            print(p,view)
            j = all_json[p]["views"][view]['data']['subjectView']['columns']
            for el in j:
                el["view"]=view
                el["process"]=p
                col_names.append(el)
    return col_names

# %%
# Here we create a ne DataFrame and load schemas from all views from given: all_json or all_json_1 JSONs 
import pandas as pd

col_names = get_column_names_from_aal_json(all_json) 
col_names+= get_column_names_from_aal_json(all_json_1) 
#col_names= get_column_names_from_aal_json(all_json_2) 
vdf = pd.DataFrame(col_names)
#vf["view"]=view

#vf[["name"]].describe()
vdf[["name","view"]].describe() #.value_counts
# Out:
# 000_DEMO✨ - Dashboards ITC ECC & S4H (DO NOT CHANGE) defaultview-529
# 000_DEMO✨ - Dashboards ITP ECC & S4H (DO NOT CHANGE/DELETE) defaultview-320
# 000_DEMO✨ - Dashboards OTC ECC & S4H (DO NOT CHANGE)  defaultview-383
# 000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE/DELETE) defaultview-124
# 00_DEMO - Acquire-to-Onboard for  SAP ECC & S/4 HANA (DO NOT CHANGE/DELETE) defaultview-459
# 00_DEMO - Attract-to-Acquire-Talent for SuccessFactors defaultview-462
# 00_DEMO - Inspect-to-Quality for SAP S/4 HANA (DO NOT CHANGE/DELETE) defaultview-525
# 00_DEMO - Invoice-to-Cash for SAP S/4 HANA (DO NOT CHANGE/DELETE) defaultview-59
# 00_DEMO - Invoice-to-Pay for SAP S/4 HANA (DO NOT CHANGE/DELETE) defaultview-133
# 00_DEMO Issue-to-Resolution for Jira defaultview-370
# 00_DEMO - Make-to-Stock for SAP S/4 HANA (DO NOT CHANGE/DELETE) defaultview-183
# 00_DEMO - Manage-Personal-Employee-Information for SAP SuccessFactors Employee Central (DO NOT CHANGE/DELETE) defaultview-299
# 00_DEMO - Manage Warehouse and Inventory (Outbound) in SAP EWM (DO NOT CHANGE/DELETE) defaultview-528
# 00_DEMO - Meter-to-Cash for SAP IS-U and S/4HANA (DO NOT CHANGE/DELETE) defaultview-50
# 00_DEMO_Operate Manufacturing in SAP Digital Manufacturing (DO NOT CHANGE/DELETE) defaultview-538
# 00_DEMO - Operate-to-Maintain/Plant_Maintenance for SAP ECC defaultview-95
# 00_DEMO - OTC SAP ECC V2 (DO NOT CHANGE/DELETE) defaultview-290
# 00_DEMO - OTC SAP S/4 HANA (DO NOT CHANGE/DELETE) defaultview-43
# 00_DEMO - OTC SAP S/4 HANA V2 (DO NOT CHANGE/DELETE) defaultview-291
# 00_DEMO PTP Cross System SAP Ariba + SAP ERP (DO NOT CHANGE / DELETE) defaultview-471
# 00_DEMO PTP in Ariba (DO NOT CHANGE / DELETE) defaultview-431
# 00_DEMO - PTP SAP S4H (DO NOT CHANGE/DELETE) defaultview-57
# 00_DEMO - SAP IBP S&OP (DO NOT CHANGE/DELETE) defaultview-404
# 00_DEMO - SAP S/4HANA Cloud - Invoice-to-Cash defaultview-222
# 00_DEMO - SAP S/4HANA Cloud - Project-to-Cash defaultview-197
# 00_DMC_Showcase [DO NOT CHANGE / DELETE] defaultview-270
# [00]_PIA Jira Process defaultview-217
# [0]_Dashboards_ITP Process defaultview-225
# 0_demo_accelerators_generic (PTP S4H, changes allowed) defaultview-288
# [NK] Show&Tell - ITP Dashboards defaultview-362
# [SIGPIA-2936] Dashboard_PTP_Ariba defaultview-545
# demo01 defaultview-9
# test00 defaultview-2
# test001 defaultview-4
# test002 defaultview-3
#           name             view
# count     4003             4003
# unique    1501               35
# top     CaseId  defaultview-197
# freq        35              248

# %% [markdown]
# ## Transfer Signals read from local files from signals_all_local and extracted from workspaces signals_all to DF

# %%
import pandas as pd
dfA = pd.DataFrame(signals_all_local) 
print("Number of Signals A:",dfA.shape)
dfB = pd.DataFrame(signals_all)
print("Number of Signals B:",dfB.shape)
#df = pd.DataFrame(signals_all)
#df = pd.DataFrame(signals_all_local)
df=pd.concat([dfA,dfB])
print("Number of Signals:",df.shape)
df.head(3)
# Out:
# Number of Signals A: (5396, 10)
# Number of Signals B: (4599, 10)
# Number of Signals: (9995, 10)
#                                  name  \
# 0   Total number of created incidents
# 1      Total number of open incidents
# 2  Total number of resolved incidents
#
#                                                query  \
# 0  \nSELECT\nCOUNT(case_id)\nFROM "defaultview-54...
# 1  \nSELECT\nCOUNT(case_id) FILTER (WHERE \n\t(SE...
# 2  \nSELECT\nCOUNT(case_id) FILTER (WHERE \n\t(SE...
#
#                           description    meta  \
# 0   Total number of created incidents  metric
# 1      Total number of open incidents  metric
# 2  Total number of resolved incidents  metric
#
#                                          metric_vars             view  \
# 0                                                 {}  defaultview-545
# 1  {'incident_closure_events': {'name': 'incident...  defaultview-545
# 2  {'incident_closure_events': {'name': 'incident...  defaultview-545
#
#                                       signalFragment  \
# 0            SELECT COUNT(case_id) FROM THIS_PROCESS
# 1  SELECT COUNT(case_id) FILTER (WHERE \n\t(SELEC...
# 2  SELECT COUNT(case_id) FILTER (WHERE \n\t(SELEC...
#
#                                              process  \
# 0  ../data/metric_definitions/incident_to_resolut...
# 1  ../data/metric_definitions/incident_to_resolut...
# 2  ../data/metric_definitions/incident_to_resolut...
#
#                                               origin            workspace_name
# 0  ../data/metric_definitions/incident_to_resolut...  Solutions Demo Workspace
# 1  ../data/metric_definitions/incident_to_resolut...  Solutions Demo Workspace
# 2  ../data/metric_definitions/incident_to_resolut...  Solutions Demo Workspace

# %%
df[["workspace_name"]].value_counts()
# Out:
# workspace_name
# Solutions Demo Workspace    9736
# Process AI                   259
# Name: count, dtype: int64

# %%
#%%script echo skipping
# Here we save the above schemas and signals DF to CSV files:
from pathlib import Path  

date_str = datetime.datetime.now().strftime("%Y-%m-%dT%H_%M_%S")
filename=f"all_extracted_signals_{date_str}.json"

filepath = Path(f'schemas_from_views_{date_str}.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
vdf.to_csv(filepath)  
print(f"CSV files with Schemas for Signals: {filepath}")

filepath = Path(f'signals_{date_str}.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  

df.to_csv(filepath)  

print(f"CSV files with Signals: {filepath}")
# Out:
# CSV files with Schemas for Signals: schemas_from_views_2023-12-04T14_22_21.csv
# CSV files with Signals: signals_2023-12-04T14_22_21.csv

# %%
print("Number of unfiltered Signals:",df.shape)
print("Number of vars/views:",vdf.shape)
vdf[["name","view"]].describe() #.value_counts
# Out:
# Number of unfiltered Signals: (9995, 10)
# Number of vars/views: (4003, 8)
#           name             view
# count     4003             4003
# unique    1501               35
# top     CaseId  defaultview-197
# freq        35              248

# %% [markdown]
# # >>>>>>>>>>>>>>>> Data in CSV format have been saved <<<<<<<<<<<<<<<<<<<<<<<
# #----------------------->>>>> DBG
# ## From here Open another Notebook to operate with data

# %%
pd.set_option('display.max_colwidth', None)
#df[df['APIvalidated'].str.contains("Syntax error at")][["query","APIvalidated","validationDataResponse"]]
#df[df['query'].str.contains('""')]['meta'].describe()
df[df['query'].str.contains('""')]['process'].describe()
df[df['query'].str.contains('""')][['process',"query"]]
#df[df['query'].str.contains('""')]['process'].drop_duplicates(keep="first")  # .describe()
#df['meta'].describe()
#df[["query","origin"]]
# Out:
# Empty DataFrame
# Columns: [process, query]
# Index: []

# %%
s="""SELECT \n\t"6 - Other - Transaction (TCODE)" AS "Transaction code",\n\tCOUNT("case_id") AS "# Cases",\n\tAVG(\n\t\t\t(SELECT LAST(end_time))\n\t\t\t-\n\t\t\t(SELECT FIRST(end_time)))\n\t\tAS "AVG cycle time",\n AVG("3 - Info - Purchase order items without purchase requisition reference")*100 AS "Items without purchase requisition reference (%)",\n AVG("2 - Blocker - Purchase order items without agreement or purchasing info record")*100 AS "Items without agreement or purchasing info record (%)",\n --AVG("")*100 AS " (%)",\n\tCOUNT(DISTINCT "6 - Other - Created By (ERNAM)" ) AS "# Users"\nFROM "defaultview-545"\nWHERE "6 - Other - Created on (Header) (AEDAT_H)" IS NOT NULL\n"""
s="""SELECT \nSUM((SELECT COUNT ("Request Type")\n\tFILTER (\n \tWHERE (EVENT_NAME IN (\n \t'Personal Data Updated'))))) \nAS "",\n"Request Type"\nFROM "defaultview-299" \nWHERE "Request Type" IS NOT NULL\nGROUP BY 2\n"""
print(s)
# Out:
# SELECT
# SUM((SELECT COUNT ("Request Type")
# 	FILTER (
#  	WHERE (EVENT_NAME IN (
#  	'Personal Data Updated')))))
# AS "",
# "Request Type"
# FROM "defaultview-299"
# WHERE "Request Type" IS NOT NULL
# GROUP BY 2

# %% [markdown]
# ### Plot duplicates

# %%
# number of unique records
df[['name','signalFragment','query','description']].describe().loc[['count','unique']].plot(kind='bar', title="All data",figsize=(10,3))
df[['name','signalFragment','query','description']].describe().loc[['count','unique']]
# Out:
#         name signalFragment query description
# count   9948           9948  9948        9942
# unique  3152           3867  5783        1255

# %% [markdown]
# ### Add columns with length of the signalFragments and WordCount to characterize complexity of the queries

# %%
# add  columns with length of the signalFragments
import numpy as np
import string
def words_count(text):
    t=text.replace("("," ").replace(")"," ").replace("["," ").replace("]"," ").replace("{"," ").replace("}"," ")
    return len(''.join([x for x in " ".join(t.split()) if x in string.ascii_letters + '_'+ ' ' or x.isdigit()]).split())
df['description'].replace(np.nan, "", inplace=True) # None in descriptions

df['FragmentWordCount'] = df['signalFragment'].apply(lambda x: words_count(x))
df['descriptionWordCount'] = df['description'].apply(lambda x: words_count(x))
df['nameWordCount'] = df['name'].apply(lambda x: words_count(x))

df['FragmentLength'] = df['signalFragment'].apply(lambda x: len(x))
df['descriptionLength'] = df['description'].apply(lambda x: len(x))
df['nameLength'] = df['name'].apply(lambda x: len(x)) 

df.shape
#df.head(n=3)
# Out:
# (9948, 16)

# %%
#mask = df['FragmentLength'] > 1000 
#df[mask]

# %%
# get an element
indx=10 #4193
df.loc[[indx]]['signalFragment']
df.loc[[indx]][['name','query','signalFragment']]
#df[['query',"signalFragment","view","origin"]][indx:indx+1].values.tolist()[0]
# Out:
#                                                   name  \
# 10  FI-AP items released for payment (total lead time)
#
#                                                                                                                      query  \
# 10  \nSELECT\nAVG ("4 - Lead time from start - FI-AP items released for payment")\nFROM "defaultview-32"\n
#
#                                                                                   signalFragment
# 10  SELECT AVG ("4 - Lead time from start - FI-AP items released for payment") FROM THIS_PROCESS

# %% [markdown]
# ### Filter out Signals without descriptions and with None descriptions - new data frame:  DF1

# %%
# Filter out Signals without descriptions and with None descriptios
pd.set_option('display.max_colwidth', None)  
new_df = df[~df['description'].isnull()]
print("Without None descriptions", new_df.shape)

df1=new_df[new_df['description'] != "" ]
#df1=new_df
print("Signals with Non-empty description",df1.shape)
figsize=(10,3)
df1[['name','signalFragment','query','description']].describe().loc[['count','unique']].plot(kind='bar',title="Siganls with non-empty descriptions",figsize=figsize)
df1[['name','signalFragment','query','description','view']].describe().loc[['count','unique']]
# Out:
# Without None descriptions (9948, 16)
# Signals with Non-empty description (4708, 16)
#         name signalFragment query description  view
# count   4708           4708  4708        4708  4708
# unique  1298           1655  3184        1254    35

# %% [markdown]
# ### Drop duplicates in DF1

# %%
# Drop duplicates
print(df1.shape)
columns=['name','description','signalFragment'] # 1702
#columns=['name','description']                  # 1409 
#columns=['name','signalFragment']               # 1620
df1.drop_duplicates(columns, keep='first',inplace=True)
print(df1.shape)
df1[['name','description','signalFragment','view']].describe().loc[['count','unique']]
# Out:
# (4708, 16)
# (1946, 16)
# /var/folders/hb/_ptqrx710ljb_2f6664d20bh0000gn/T/ipykernel_35105/959564203.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop_duplicates(columns, keep='first',inplace=True)
#         name description signalFragment  view
# count   1946        1946           1946  1946
# unique  1298        1254           1655    28

# %%
df1.head(n=3)
# Out:
#                                  name  \
# 0   Total number of created incidents
# 1      Total number of open incidents
# 2  Total number of resolved incidents
#
#                                                                                                                                                 query  \
# 0                                                                                  \nSELECT\nCOUNT(case_id)\nFROM "defaultview-545"\n
# 1  \nSELECT\nCOUNT(case_id) FILTER (WHERE \n\t(SELECT BOOL_AND(\n NOT event_name IN ('Close Incident')))\n)\nFROM "defaultview-545"\n
# 2       \nSELECT\nCOUNT(case_id) FILTER (WHERE \n\t(SELECT BOOL_OR(\n event_name IN ('Close Incident')))\n)\nFROM "defaultview-545"\n
#
#                           description    meta  \
# 0   Total number of created incidents  metric
# 1      Total number of open incidents  metric
# 2  Total number of resolved incidents  metric
#
#                                                                                                                                                                                                                                                                             metric_vars  \
# 0                                                                                                                                                                                                                                                                                    {}
# 1  {'incident_closure_events': {'name': 'incident_closure_events', 'description': 'Events defining the closing events of a case, for example 'Close Incident'', 'defaultValues': [{'defaultValue': "'Close Incident'", 'sourceSystems': ['SERVICENOW']}], 'value': ''Close Incident''}}
# 2  {'incident_closure_events': {'name': 'incident_closure_events', 'description': 'Events defining the closing events of a case, for example 'Close Incident'', 'defaultValues': [{'defaultValue': "'Close Incident'", 'sourceSystems': ['SERVICENOW']}], 'value': ''Close Incident''}}
#
#               view  \
# 0  defaultview-545
# 1  defaultview-545
# 2  defaultview-545
#
#                                                                                                                       signalFragment  \
# 0                                                                                            SELECT COUNT(case_id) FROM THIS_PROCESS
# 1  SELECT COUNT(case_id) FILTER (WHERE \n\t(SELECT BOOL_AND(\n NOT event_name IN (${incident_closure_events})))\n) FROM THIS_PROCESS
# 2       SELECT COUNT(case_id) FILTER (WHERE \n\t(SELECT BOOL_OR(\n event_name IN (${incident_closure_events})))\n) FROM THIS_PROCESS
#
#                                                   process  \
# 0  ../data/metric_definitions/incident_to_resolution.json
# 1  ../data/metric_definitions/incident_to_resolution.json
# 2  ../data/metric_definitions/incident_to_resolution.json
#
#                                                    origin  \
# 0  ../data/metric_definitions/incident_to_resolution.json
# 1  ../data/metric_definitions/incident_to_resolution.json
# 2  ../data/metric_definitions/incident_to_resolution.json
#
#              workspace_name  FragmentWordCount  descriptionWordCount  \
# 0  Solutions Demo Workspace                  5                     5
# 1  Solutions Demo Workspace                 13                     5
# 2  Solutions Demo Workspace                 12                     5
#
#    nameWordCount  FragmentLength  descriptionLength  nameLength
# 0              5              39                 33          33
# 1              5             125                 30          30
# 2              5             120                 34          34

# %% [markdown]
# ## Validate pandas col with signals against log on dataFrame DF1
#
# **11mins** :API validation for 1702 took: 0.38511105219709885 per signal call

# %%
#>>>>>>>>>>>> olD<<<<<<<<<<<

# %% [markdown]
# ### Check various option to get signals

# %%
# Signals from metric file
path="../data/metric_definitions/SLAs.json"
#path="experiment00/test001/metrics/metrics.json"
docs_from_metric_json(path, from_json=None, view="strview-1") #[path][0]['metric_vars']
# Out:
# Number of Metrics Signals: 4 in: ../data/metric_definitions/SLAs.json
# {'../data/metric_definitions/SLAs.json': [{'name': 'SLA breach ratio on process level, based on SLA events',
#    'query': '\nSELECT\nCOUNT(case_id) FILTER (\n\tWHERE (SELECT FIRST(event_name)\n\t\t\tWHERE event_name IN (\'Incident Resolution SLA Breached\',\'Incident Response SLA Breached\')) IS NOT NULL)\n/ COUNT(case_id)\n* 100\nFROM "strview-1"\n                ',
#    'description': 'Percentage of cases where the SLA was breached, based on events related to SLA breaches',
#    'meta': 'metric',
#    'metric_vars': {'sla_breach_events': {'name': 'sla_breach_events',
#      'description': "Events indicating the breach of an SLA, for example 'Incident Resolution SLA Breached'",
#      'defaultValues': [{'defaultValue': "'Incident Resolution SLA Breached','Incident Response SLA Breached'",
#        'sourceSystems': ['SERVICENOW'],
#        'processTypes': ['INCIDENT_TO_RESOLUTION']}],
#      'value': "'Incident Resolution SLA Breached','Incident Response SLA Breached'"}},
#    'view': 'strview-1',
#    'signalFragment': 'SELECT COUNT(case_id) FILTER (\n\tWHERE (SELECT FIRST(event_name)\n\t\t\tWHERE event_name IN (${sla_breach_events})) IS NOT NULL)\n/ COUNT(case_id)\n* 100 FROM THIS_PROCESS',
#    'process': '../data/metric_definitions/SLAs.json'},
#   {'name': 'Number of SLA breaches based on SLA events',
#    'query': '\nSELECT\nCOUNT(case_id) FILTER (\n\tWHERE (SELECT FIRST(event_name) \n\t\t\tWHERE event_name IN (\'Incident Resolution SLA Breached\',\'Incident Response SLA Breached\')) IS NOT NULL)\nFROM "strview-1"\n                ',
#    'description': 'Number of cases where the SLA was breached, based on events related to SLA breaches',
#    'meta': 'metric',
#    'metric_vars': {'sla_breach_events': {'name': 'sla_breach_events',
#      'description': "Events indicating the breach of an SLA, for example 'Incident Resolution SLA Breached'",
#      'defaultValues': [{'defaultValue': "'Incident Resolution SLA Breached','Incident Response SLA Breached'",
#        'sourceSystems': ['SERVICENOW'],
#        'processTypes': ['INCIDENT_TO_RESOLUTION']}],
#      'value': "'Incident Resolution SLA Breached','Incident Response SLA Breached'"}},
#    'view': 'strview-1',
#    'signalFragment': 'SELECT COUNT(case_id) FILTER (\n\tWHERE (SELECT FIRST(event_name) \n\t\t\tWHERE event_name IN (${sla_breach_events})) IS NOT NULL) FROM THIS_PROCESS',
#    'process': '../data/metric_definitions/SLAs.json'},
#   {'name': 'Average actual to target SLA ratio',
#    'query': '\nSELECT\nAVG(\n\t((SELECT LAST(end_time) WHERE event_name IN (\'Close Incident\'))\n\t-(SELECT FIRST(end_time) WHERE event_name IN (\'Create Incident\')))\n) / (DURATION \'15days\')\n*100\nFROM "strview-1"\n                ',
#    'description': 'Ratio between the average incident resolution duration to target SLA duration',
#    'meta': 'metric',
#    'metric_vars': {'sla_closure_events': {'name': 'sla_closure_events',
#      'description': "Events defining the closing events of a case, for example 'Close Incident'",
#      'defaultValues': [{'defaultValue': "'Close Incident'",
#        'sourceSystems': ['SERVICENOW'],
#        'processTypes': ['INCIDENT_TO_RESOLUTION']}],
#      'value': "'Close Incident'"},
#     'sla_creation_events': {'name': 'sla_creation_events',
#      'description': "Events defining the start events of a case, for example 'Create Incident'",
#      'defaultValues': [{'defaultValue': "'Create Incident'",
#        'sourceSystems': ['SERVICENOW'],
#        'processTypes': ['INCIDENT_TO_RESOLUTION']}],
#      'value': "'Create Incident'"},
#     'target_sla_time': {'name': 'target_sla_time',
#      'description': "SLA time expectation, for example '15 days'",
#      'defaultValues': [{'defaultValue': "'15days'",
#        'sourceSystems': ['SERVICENOW'],
#        'processTypes': ['INCIDENT_TO_RESOLUTION']}],
#      'value': "'15days'"}},
#    'view': 'strview-1',
#    'signalFragment': 'SELECT AVG(\n\t((SELECT LAST(end_time) WHERE event_name IN (${sla_closure_events}))\n\t-(SELECT FIRST(end_time) WHERE event_name IN (${sla_creation_events})))\n) / (DURATION ${target_sla_time})\n*100 FROM THIS_PROCESS',
#    'process': '../data/metric_definitions/SLAs.json'},
#   {'name': 'Percentage of incident resolutions that meet SLA expectations',
#    'query': '\nSELECT\nCOUNT(case_id) FILTER (WHERE (\n\tSELECT LAST(end_time) FILTER (WHERE event_name IN (\'Close Incident\'))\n\t-\n\tFIRST(end_time) FILTER (WHERE event_name IN (\'Create Incident\'))\n\t) < DURATION \'15days\'\n)\n/count(case_id) *100\nFROM "strview-1"\n                ',
#    'description': 'Percentage of incident resolutions that met their target',
#    'meta': 'metric',
#    'metric_vars': {'sla_closure_events': {'name': 'sla_closure_events',
#      'description': "Events defining the closing events of a case, for example 'Close Incident'",
#      'defaultValues': [{'defaultValue': "'Close Incident'",
#        'sourceSystems': ['SERVICENOW'],
#        'processTypes': ['INCIDENT_TO_RESOLUTION']}],
#      'value': "'Close Incident'"},
#     'sla_creation_events': {'name': 'sla_creation_events',
#      'description': "Events defining the start events of a case, for example 'Create Incident'",
#      'defaultValues': [{'defaultValue': "'Create Incident'",
#        'sourceSystems': ['SERVICENOW'],
#        'processTypes': ['INCIDENT_TO_RESOLUTION']}],
#      'value': "'Create Incident'"},
#     'target_sla_time': {'name': 'target_sla_time',
#      'description': "SLA time expectation, for example '15 days'",
#      'defaultValues': [{'defaultValue': "'15days'",
#        'sourceSystems': ['SERVICENOW'],
#        'processTypes': ['INCIDENT_TO_RESOLUTION']}],
#      'value': "'15days'"}},
#    'view': 'strview-1',
#    'signalFragment': 'SELECT COUNT(case_id) FILTER (WHERE (\n\tSELECT LAST(end_time) FILTER (WHERE event_name IN (${sla_closure_events}))\n\t-\n\tFIRST(end_time) FILTER (WHERE event_name IN (${sla_creation_events}))\n\t) < DURATION ${target_sla_time}\n)\n/count(case_id) *100 FROM THIS_PROCESS',
#    'process': '../data/metric_definitions/SLAs.json'}]}

# %%
# Signals from metric query json
path='test001' # 'test001-1'
q_list_metrics['variables']['subjectId']=path
j = POST_Signavio(query=q_list_metrics,auth=auth)['data']
j = all_json[path]['list_metrics']
docs_from_metric_json(path, from_json=j, view="strview-1") #[path][0]['metric_vars']['sla_closure_events']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/d071932/PycharmProjects/foundationmodel-benchmark-1/SignavioText2Signal/notebooks/GetSignalsFromSignavio.ipynb Cell 67 line 4
#       <a href='vscode-notebook-cell:/Users/d071932/PycharmProjects/foundationmodel-benchmark-1/SignavioText2Signal/notebooks/GetSignalsFromSignavio.ipynb#Y155sZmlsZQ%3D%3D?line=1'>2</a> path='test001' # 'test001-1'
#       <a href='vscode-notebook-cell:/Users/d071932/PycharmProjects/foundationmodel-benchmark-1/SignavioText2Signal/notebooks/GetSignalsFromSignavio.ipynb#Y155sZmlsZQ%3D%3D?line=2'>3</a> q_list_metrics['variables']['subjectId']=path
# ----> <a href='vscode-notebook-cell:/Users/d071932/PycharmProjects/foundationmodel-benchmark-1/SignavioText2Signal/notebooks/GetSignalsFromSignavio.ipynb#Y155sZmlsZQ%3D%3D?line=3'>4</a> j = POST_Signavio(query=q_list_metrics,auth=auth)['data']
#       <a href='vscode-notebook-cell:/Users/d071932/PycharmProjects/foundationmodel-benchmark-1/SignavioText2Signal/notebooks/GetSignalsFromSignavio.ipynb#Y155sZmlsZQ%3D%3D?line=4'>5</a> j = all_json[path]['list_metrics']
#       <a href='vscode-notebook-cell:/Users/d071932/PycharmProjects/foundationmodel-benchmark-1/SignavioText2Signal/notebooks/GetSignalsFromSignavio.ipynb#Y155sZmlsZQ%3D%3D?line=5'>6</a> docs_from_metric_json(path, from_json=j, view="strview-1") #[path][0]['metric_vars']['sla_closure_events']
#
# /Users/d071932/PycharmProjects/foundationmodel-benchmark-1/SignavioText2Signal/notebooks/GetSignalsFromSignavio.ipynb Cell 67 line 1
#       <a href='vscode-notebook-cell:/Users/d071932/PycharmProjects/foundationmodel-benchmark-1/SignavioText2Signal/notebooks/GetSignalsFromSignavio.ipynb#Y155sZmlsZQ%3D%3D?line=6'>7</a> timeout=50
#       <a href='vscode-notebook-cell:/Users/d071932/PycharmProjects/foundationmodel-benchmark-1/SignavioText2Signal/notebooks/GetSignalsFromSignavio.ipynb#Y155sZmlsZQ%3D%3D?line=7'>8</a> try:
#       <a href='vscode-notebook-cell:/Users/d071932/PycharmProjects/foundationmodel-benchmark-1/SignavioText2Signal/notebooks/GetSignalsFromSignavio.ipynb#Y155sZmlsZQ%3D%3D?line=8'>9</a>     query_request = requests.post(
#      <a href='vscode-notebook-cell:/Users/d071932/PycharmProjects/foundationmodel-benchmark-1/SignavioText2Signal/notebooks/GetSignalsFromSignavio.ipynb#Y155sZmlsZQ%3D%3D?line=9'>10</a>         signal_endpoint,
# ---> <a href='vscode-notebook-cell:/Users/d071932/PycharmProjects/foundationmodel-benchmark-1/SignavioText2Signal/notebooks/GetSignalsFromSignavio.ipynb#Y155sZmlsZQ%3D%3D?line=10'>11</a>         cookies=auth[workspace_name]["cookies"],
#      <a href='vscode-notebook-cell:/Users/d071932/PycharmProjects/foundationmodel-benchmark-1/SignavioText2Signal/notebooks/GetSignalsFromSignavio.ipynb#Y155sZmlsZQ%3D%3D?line=11'>12</a>         headers=auth[workspace_name]["headers"],
#      <a href='vscode-notebook-cell:/Users/d071932/PycharmProjects/foundationmodel-benchmark-1/SignavioText2Signal/notebooks/GetSignalsFromSignavio.ipynb#Y155sZmlsZQ%3D%3D?line=12'>13</a>         timeout=timeout,
#      <a href='vscode-notebook-cell:/Users/d071932/PycharmProjects/foundationmodel-benchmark-1/SignavioText2Signal/notebooks/GetSignalsFromSignavio.ipynb#Y155sZmlsZQ%3D%3D?line=13'>14</a>         json=query)
#      <a href='vscode-notebook-cell:/Users/d071932/PycharmProjects/foundationmodel-benchmark-1/SignavioText2Signal/notebooks/GetSignalsFromSignavio.ipynb#Y155sZmlsZQ%3D%3D?line=14'>15</a>     query_request.raise_for_status()
#      <a href='vscode-notebook-cell:/Users/d071932/PycharmProjects/foundationmodel-benchmark-1/SignavioText2Signal/notebooks/GetSignalsFromSignavio.ipynb#Y155sZmlsZQ%3D%3D?line=15'>16</a> except requests.HTTPError as ex:
#      <a href='vscode-notebook-cell:/Users/d071932/PycharmProjects/foundationmodel-benchmark-1/SignavioText2Signal/notebooks/GetSignalsFromSignavio.ipynb#Y155sZmlsZQ%3D%3D?line=16'>17</a>     # possibly check response for a message
#
# KeyError: ''

# %%
# From Dashboard file
path="../../data/SignavioText2Signal/dashboards/pia-dashboards/source-to-pay/Procure to Pay for ECC & S4H/Late Payments.json"
path="experiment00/demo01/dashboards/workingdashboard_2023-11-16.json"
print(path)
docs_from_investigations_dashboard_json(path,from_json=None, sourcekeys=["dashboard","metrics"],view="strview-1")
# Out:
# experiment00/demo01/dashboards/workingdashboard_2023-11-16.json
# Number of metrics Metrics Signals: 0 in: experiment00/demo01/dashboards/workingdashboard_2023-11-16.json
#  Number of dashboard Signals: 1 in: experiment00/demo01/dashboards/workingdashboard_2023-11-16.json
# {'experiment00/demo01/dashboards/workingdashboard_2023-11-16.json': [{'name': 'w1',
#    'query': 'SELECT count(case_id) FROM "strview-1"',
#    'description': '',
#    'meta': 'dashboard',
#    'metric_vars': '',
#    'view': 'strview-1',
#    'signalFragment': 'SELECT count(case_id) FROM THIS_PROCESS',
#    'process': 'experiment00/demo01/dashboards/workingdashboard_2023-11-16.json'}]}

# %%
# From Investigation file
path="../../data/SignavioText2Signal/NLP POC (JustAsk)/04 PI Investigation/JustAsk SIGNAL POC - PI Investigation.json"
#path="experiment00/demo01/investigations/AskData POC_2023-11-15.json"
print(path)
i=docs_from_investigations_dashboard_json(path,from_json=None, sourcekeys=["investigation","metrics"],view="strview-1")[path]
len(i)
# Out:
# ../../data/SignavioText2Signal/NLP POC (JustAsk)/04 PI Investigation/JustAsk SIGNAL POC - PI Investigation.json
# Number of metrics Metrics Signals: 0 in: ../../data/SignavioText2Signal/NLP POC (JustAsk)/04 PI Investigation/JustAsk SIGNAL POC - PI Investigation.json
#  Number of investigation Signals: 14 in: ../../data/SignavioText2Signal/NLP POC (JustAsk)/04 PI Investigation/JustAsk SIGNAL POC - PI Investigation.json
# 14
