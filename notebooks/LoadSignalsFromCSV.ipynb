# %% [markdown]
# # Load Signals from CSV
#
# You would need Signavio credentials - check if you can access:
#
# https://editor.signavio.com/g/statics/pi/areas
#
# Create *.env* file
# ```js
# MY_SIGNAVIO_PASSWORD=*****
# MY_SIGNAVIO_NAME=alexey.streltsov@sap.com
#
# This notebook provides a collection of cells where we load signals from CSV files.
# CSV files have been created by extracting Signals from several workspaces by means of Signavio API backend calls.
#
# Here we can run API call to validate Signals against Signavio workspace view. - this step can take 25 mins.
#
# ```bash
# ls -ltr schemas_from_views_2023-11-28T07_35_58.csv signals_2023-11-28T07_35_58.csv LoadSignalsFromCSV.ipynb
# -rw-r--r--@ 1 d071932  staff   573K Nov 28 07:35 schemas_from_views_2023-11-28T07_35_58.csv
# -rw-r--r--@ 1 d071932  staff    10M Nov 28 07:35 signals_2023-11-28T07_35_58.csv
# -rw-r--r--  1 d071932  staff   1.1M Nov 29 12:31 LoadSignalsFromCSV.ipynb
#
# ```

# %%
! ls -ltrah schemas_from_views_*.csv signals_*.csv LoadSignalsFromCSV.ipynb
# Out:
# -rw-r--r--  1 d071932  staff   577K Feb  1 10:44 schemas_from_views_2024-02-01T10_44_03.csv
# -rw-r--r--  1 d071932  staff    11M Feb  1 10:44 signals_2024-02-01T10_44_03.csv
# -rw-r--r--  1 d071932  staff   1.1M Feb  1 10:49 LoadSignalsFromCSV.ipynb

# %%
# Define your access to Signavio UI here or in bash env
#%env MY_SIGNAVIO_PASSWORD=*****
#%env MY_SIGNAVIO_NAME=alexey.streltsov@sap.com

# Or via .env file
#! pip install python-dotenv
from dotenv import load_dotenv
from pathlib import Path  # Python 3.6+ only
import sys
import os
sys.path.append("./")
env_path = Path('..') / '.env'
load_dotenv(dotenv_path=env_path)

! echo $MY_SIGNAVIO_NAME
# Out:
# alexey.streltsov@sap.com

# %%
import sys
import json
import pathlib
import logging
import requests
import os
import time

logging.getLogger("urllib3").setLevel(logging.WARNING)
sys.path.append("./")

# Class coped and modified  from https://github.com/signavio/bpmn2constraints/blob/main/tutorial/SignavioAuthenticator.py
class SignavioAuthenticatorCoE:
    def __init__(self, system_instance, tenant_id, email, pw):
        self.system_instance = system_instance
        self.tenant_id = tenant_id
        self.email = email
        self.pw = pw

    """
    Takes care of authentication against Signavio systems
    """

    def authenticate(self):
        """
        Authenticates user at Signavio system instance and initiates session.
        Returns:
            dictionary: Session information
        """
        login_url = self.system_instance + "/p/login"
        data = {"name": self.email, "password": self.pw, "tokenonly": "true"}
        #if "tenant_id" in locals():
        #    data["tenant"] = self.tenant_id
        data["tenant"] = self.tenant_id
        # authenticate
        login_request = requests.post(login_url, data)

        # retrieve token and session ID
        auth_token = login_request.content.decode("utf-8")
        jsesssion_ID = login_request.cookies["JSESSIONID"]

        # The cookie is named 'LBROUTEID' for base_url 'editor.signavio.com'
        # and 'editor.signavio.com', and 'AWSELB' for base_url
        # 'app-au.signavio.com' and 'app-us.signavio.com'
        lb_route_ID = login_request.cookies["LBROUTEID"]

        # return credentials
        return {
            "jsesssion_ID": jsesssion_ID,
            "lb_route_ID": lb_route_ID,
            "auth_token": auth_token,
        }
def credentials_actualization(system_instance, workspace_id, user_name, pw, auth={}):
    # get credentials for current session. They are valid for 24 hours 
    authenticator = SignavioAuthenticatorCoE(system_instance, workspace_id, user_name, pw)
    auth_data = authenticator.authenticate()
    cookies = {'JSESSIONID': auth_data['jsesssion_ID'], 'LBROUTEID': auth_data['lb_route_ID']}
    headers = {'Accept': 'application/json', 'x-signavio-id':  auth_data['auth_token']}
    print(auth_data['jsesssion_ID'],auth_data['lb_route_ID'])
    print(auth_data['auth_token'])
    auth[workspace_name]={"cookies":cookies,"headers":headers}
    return auth

# POST - need to re-run to inject the above generated credentials
#q=q_list_processes #

#def POST_Signavio(query={},cookies=cookies,headers=headers):
def POST_Signavio(query={},workspace_name="",auth={}):
        signal_endpoint = system_instance + '/g/api/pi-graphql/graphql'
        timeout=30
        try:
            query_request = requests.post(
                signal_endpoint,
                cookies=auth[workspace_name]["cookies"],
                headers=auth[workspace_name]["headers"],
                timeout=timeout,
                json=query)
            query_request.raise_for_status()
        except requests.HTTPError as ex:
            # possibly check response for a message
            raise ex  # let the caller handle it
        except requests.Timeout:
            print("request took too long")


        return query_request.json()
    


## REST API endpoint

def API_validation(query,workspacename,auth={}):
    """
    """
    #print(query)
    signal_endpoint = system_instance + '/g/api/pi-graphql/signal'
    cookies=auth[workspacename]["cookies"]
    headers=auth[workspacename]["headers"]
    
    
    try:
        query_request = requests.post(
        signal_endpoint,
        cookies=cookies,
        headers=headers,
        json={"query":query})
        #print("JS",query_request.json().keys())
        query_request.raise_for_status()
        if "data" in query_request.json().keys():            
            d = query_request.json()["data"]
            #print("data type", type(d), d)
            #print("data type np:", type(d), len(np.asarray(d)), np.asarray(d))
            #print("data type", type(d), len(d), json.dumps(d))
            #d=np.asarray(d)
            l = len(d) 
            d=json.dumps(d)[:100]
            message="ok" # 'errorType': 'ColumnNotFound', 'message': "ColumnNotFound: 'Risk Class'"}
        #else:
        #    message=query_request.json()['message']        
    except requests.HTTPError as ex:
         print("requests.HTTPError", ex,query_request.json()['message'] )
         d=f"Error {ex}"
         l=0
         message=query_request.json()['message'] 
    except Exception as e:
        print("API error:", e)
        raise e
    
    return [message,d,l]

# %% [markdown]
# # Credentials / API  initialization

# %%
# select workspace here fro credentials needed if API calls are planned
auth={}
 
user_name = os.environ.get('MY_SIGNAVIO_NAME','alexey.streltsov@sap.com') # username
pw = os.environ.get('MY_SIGNAVIO_PASSWORD', None) # Signavio password
print("Your are:",user_name)
system_instance = 'https://editor.signavio.com'
workspace_id = 'b0f07deabd3140aea5344baa686e0d84' # workspace Process AI 
workspace_name="Process AI"
credentials_actualization(system_instance, workspace_id, user_name, pw, auth=auth) 
workspace_id = 'ccf98b692d1d4e0aa895df3aab8cd905' # workspace Solutions Demo Workspace access by alexandra.dang@sap.com
workspace_name="Solutions Demo Workspace"
credentials_actualization(system_instance, workspace_id, user_name, pw, auth=auth)
auth
# Out:
# Your are: alexey.streltsov@sap.com
# 7FC15A8DB7062F2085921FE05F66AC29 "b0bef9bd73f538ca"
# df1f9cdbdd01483ea868618bf34ab628
# D25B1A81404DBCFDC7834F642726AD24 "038ac76d96abd5c3"
# e39aa6ccb9b849cca08b1c57200190d6
# {'Process AI': {'cookies': {'JSESSIONID': '7FC15A8DB7062F2085921FE05F66AC29',
#    'LBROUTEID': '"b0bef9bd73f538ca"'},
#   'headers': {'Accept': 'application/json',
#    'x-signavio-id': 'df1f9cdbdd01483ea868618bf34ab628'}},
#  'Solutions Demo Workspace': {'cookies': {'JSESSIONID': 'D25B1A81404DBCFDC7834F642726AD24',
#    'LBROUTEID': '"038ac76d96abd5c3"'},
#   'headers': {'Accept': 'application/json',
#    'x-signavio-id': 'e39aa6ccb9b849cca08b1c57200190d6'}}}

# %% [markdown]
# ## Example how to run manually -constructed SIGNALS against workspace DB:

# %%
# Run manually -constructed SIGNALS need for VIEW 
def signal_template(signal,view):
    return f'SELECT {signal} FROM "{view}"'
signal_endpoint = system_instance + '/g/api/pi-graphql/signal'

workspace_name="Solutions Demo Workspace"
workspace_name="Process AI"

# https://editor.signavio.com/g/statics/pi/areas/ba-3/processes/test00-1/views/defaultview-2
# https://editor.signavio.com/g/statics/pi/areas/etl-403/processes/sl-itc-dashboard-test-1/views/defaultview-529
view="defaultview-529" # for workspace_name="Solutions Demo Workspace"
view="strview-1" 
signal='AVG( (SELECT LAST(end_time) - FIRST(end_time)))'
q = {'query': signal_template(signal=signal,view=view)}
q = {'query': 'SELECT count(1) \nFROM FLATTEN("defaultview-1")'}
query_request = requests.post(
        signal_endpoint,
        cookies=auth[workspace_name]["cookies"],
        headers=auth[workspace_name]["headers"] ,
        json={'query': signal_template(signal=signal,view=view)})
query_request.json()
# Out:
# {'header': [{'columnName': 'AVG((SELECT LAST(end_time) - FIRST(end_time)))',
#    'columnAlias': 'AVG((SELECT LAST(end_time) - FIRST(end_time)))',
#    'columnRole': 'MEASURE',
#    'dataType': 'DURATION'}],
#  'data': [[2061973225.072404]]}

# %% [markdown]
# # Load CSV Pandas and data Analysis
#
# Here we:
# - Load view variables
# - Statistical analysis.

# %%
# Here we save the above schemas and signals DF to CSV files:
from pathlib import Path  
import pandas as pd

# Latest
#CSV files with Schemas for Signals: schemas_from_views_2024-02-01T10_44_03.csv
#CSV files with Signals: signals_2024-02-01T10_44_03.csv

filename_schemas="schemas_from_views_2024-02-01T10_44_03.csv"
vdf = pd.read_csv(filename_schemas) 
print(f"CSV files with Schemas for Signals: {filename_schemas}")

filename_signals="signals_2024-02-01T10_44_03.csv"
df = pd.read_csv(filename_signals)  
print(f"CSV files with Signals: {filename_signals}")

print("Number of unfiltered Signals:",df.shape)
print("Number of vars/views:",vdf.shape)
# Out:
# CSV files with Schemas for Signals: schemas_from_views_2024-02-01T10_44_03.csv
# CSV files with Signals: signals_2024-02-01T10_44_03.csv
# Number of unfiltered Signals: (11042, 11)
# Number of vars/views: (3906, 9)
# /var/folders/hb/_ptqrx710ljb_2f6664d20bh0000gn/T/ipykernel_17721/1121547076.py:3: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# ## Schemas to Data Frames

# %%
#vf[["name"]].describe()
vdf[["name","view"]].describe() #.value_counts
# Out:
#           name             view
# count     3906             3906
# unique    1500               34
# top     CaseId  defaultview-197
# freq        34              248

# %%
vdf
# Out:
#       Unnamed: 0                                               name  \
# 0              0                                             CaseId
# 1              1                                           Activity
# 2              2                                           End time
# 3              3            Accounting Document Segment Primary Key
# 4              4  Amount Eligible for Cash Discount in Document ...
# ...          ...                                                ...
# 3901        3901                                          Net Sales
# 3902        3902                                 Overdue receivable
# 3903        3903                                         Receivable
# 3904        3904                                           Rejected
# 3905        3905                                         Risk Class
#
#       isVisible    dataType                 processVariableId  filter  \
# 0          True     CASE_ID                               NaN     NaN
# 1          True  EVENT_NAME                               NaN     NaN
# 2          True    END_TIME                               NaN     NaN
# 3          True      CHOICE  accounting-document-segment-p-39     NaN
# 4          True      NUMBER  amount-eligible-for-cash-disc-33     NaN
# ...         ...         ...                               ...     ...
# 3901       True      NUMBER                       net-sales-2     NaN
# 3902       True      NUMBER              overdue-receivable-2     NaN
# 3903       True      NUMBER                      receivable-2     NaN
# 3904       True      NUMBER                        rejected-2     NaN
# 3905       True      CHOICE                      risk-class-2     NaN
#
#              __typename             view  \
# 0     SubjectViewColumn  defaultview-529
# 1     SubjectViewColumn  defaultview-529
# 2     SubjectViewColumn  defaultview-529
# 3     SubjectViewColumn  defaultview-529
# 4     SubjectViewColumn  defaultview-529
# ...                 ...              ...
# 3901  SubjectViewColumn    defaultview-3
# 3902  SubjectViewColumn    defaultview-3
# 3903  SubjectViewColumn    defaultview-3
# 3904  SubjectViewColumn    defaultview-3
# 3905  SubjectViewColumn    defaultview-3
#
#                                                 process
# 0     000_DEMO✨ - Dashboards ITC ECC & S4H (DO NOT C...
# 1     000_DEMO✨ - Dashboards ITC ECC & S4H (DO NOT C...
# 2     000_DEMO✨ - Dashboards ITC ECC & S4H (DO NOT C...
# 3     000_DEMO✨ - Dashboards ITC ECC & S4H (DO NOT C...
# 4     000_DEMO✨ - Dashboards ITC ECC & S4H (DO NOT C...
# ...                                                 ...
# 3901                                            test002
# 3902                                            test002
# 3903                                            test002
# 3904                                            test002
# 3905                                            test002
#
# [3906 rows x 9 columns]

# %%
# Select columns for given view/TableName
vdf[vdf["view"] == "defaultview-3"]
# Out:
#       Unnamed: 0                               name  isVisible    dataType  \
# 3884        3884                             CaseId       True     CASE_ID
# 3885        3885                           Activity       True  EVENT_NAME
# 3886        3886                           End time       True    END_TIME
# 3887        3887  Accounts Receivable Turnover Rate       True      NUMBER
# 3888        3888                    Automation Rate       True      NUMBER
# 3889        3889            Average Days Delinquent       True      NUMBER
# 3890        3890     Collection Effectiveness Index       True      NUMBER
# 3891        3891                Cost per 1k Revenue       True      NUMBER
# 3892        3892      Credit Reviews per Credit FTE       True      NUMBER
# 3893        3893                       Credit Score       True      NUMBER
# 3894        3894                           Data Set       True      CHOICE
# 3895        3895             Days Sales Outstanding       True      NUMBER
# 3896        3896                  Delivered on Time       True      CHOICE
# 3897        3897                       Dispute Case       True      CHOICE
# 3898        3898              FTEs per 1Bil Revenue       True      NUMBER
# 3899        3899                        Gross Sales       True      NUMBER
# 3900        3900                   Invoice Due Date       True   DATE_TIME
# 3901        3901                          Net Sales       True      NUMBER
# 3902        3902                 Overdue receivable       True      NUMBER
# 3903        3903                         Receivable       True      NUMBER
# 3904        3904                           Rejected       True      NUMBER
# 3905        3905                         Risk Class       True      CHOICE
#
#                     processVariableId  filter         __typename  \
# 3884                              NaN     NaN  SubjectViewColumn
# 3885                              NaN     NaN  SubjectViewColumn
# 3886                              NaN     NaN  SubjectViewColumn
# 3887  accounts-receivable-turnover--2     NaN  SubjectViewColumn
# 3888                automation-rate-2     NaN  SubjectViewColumn
# 3889        average-days-delinquent-2     NaN  SubjectViewColumn
# 3890  collection-effectiveness-inde-2     NaN  SubjectViewColumn
# 3891            cost-per-1k-revenue-2     NaN  SubjectViewColumn
# 3892  credit-reviews-per-credit-fte-2     NaN  SubjectViewColumn
# 3893                   credit-score-2     NaN  SubjectViewColumn
# 3894                       data-set-2     NaN  SubjectViewColumn
# 3895         days-sales-outstanding-2     NaN  SubjectViewColumn
# 3896              delivered-on-time-2     NaN  SubjectViewColumn
# 3897                   dispute-case-2     NaN  SubjectViewColumn
# 3898          ftes-per-1bil-revenue-2     NaN  SubjectViewColumn
# 3899                    gross-sales-2     NaN  SubjectViewColumn
# 3900               invoice-due-date-2     NaN  SubjectViewColumn
# 3901                      net-sales-2     NaN  SubjectViewColumn
# 3902             overdue-receivable-2     NaN  SubjectViewColumn
# 3903                     receivable-2     NaN  SubjectViewColumn
# 3904                       rejected-2     NaN  SubjectViewColumn
# 3905                     risk-class-2     NaN  SubjectViewColumn
#
#                view  process
# 3884  defaultview-3  test002
# 3885  defaultview-3  test002
# 3886  defaultview-3  test002
# 3887  defaultview-3  test002
# 3888  defaultview-3  test002
# 3889  defaultview-3  test002
# 3890  defaultview-3  test002
# 3891  defaultview-3  test002
# 3892  defaultview-3  test002
# 3893  defaultview-3  test002
# 3894  defaultview-3  test002
# 3895  defaultview-3  test002
# 3896  defaultview-3  test002
# 3897  defaultview-3  test002
# 3898  defaultview-3  test002
# 3899  defaultview-3  test002
# 3900  defaultview-3  test002
# 3901  defaultview-3  test002
# 3902  defaultview-3  test002
# 3903  defaultview-3  test002
# 3904  defaultview-3  test002
# 3905  defaultview-3  test002

# %% [markdown]
# ## Transfer Signals read from local files from signals_all_local and extracted from workspaces signals_all to DF

# %%
print("Number of Signals:",df.shape)
df.head(3)
# Out:
# Number of Signals: (11042, 11)
#    Unnamed: 0                                name  \
# 0           0   Total number of created incidents
# 1           1      Total number of open incidents
# 2           2  Total number of resolved incidents
#
#                                                query  \
# 0  \nSELECT\nCOUNT(case_id)\nFROM "defaultview-54...
# 1  \nSELECT\nCOUNT(case_id) FILTER (WHERE \n\t(SE...
# 2  \nSELECT\nCOUNT(case_id) FILTER (WHERE \n\t(SE...
#
#                           description    meta  \
# 0   Total number of created incidents  metric
# 1      Total number of open incidents  metric
# 2  Total number of resolved incidents  metric
#
#                                          metric_vars             view  \
# 0                                                 {}  defaultview-545
# 1  {'incident_closure_events': {'name': 'incident...  defaultview-545
# 2  {'incident_closure_events': {'name': 'incident...  defaultview-545
#
#                                       signalFragment  \
# 0            SELECT COUNT(case_id) FROM THIS_PROCESS
# 1  SELECT COUNT(case_id) FILTER (WHERE \n\t(SELEC...
# 2  SELECT COUNT(case_id) FILTER (WHERE \n\t(SELEC...
#
#                                              process  \
# 0  ../data/metric_definitions/incident_to_resolut...
# 1  ../data/metric_definitions/incident_to_resolut...
# 2  ../data/metric_definitions/incident_to_resolut...
#
#                                               origin            workspace_name
# 0  ../data/metric_definitions/incident_to_resolut...  Solutions Demo Workspace
# 1  ../data/metric_definitions/incident_to_resolut...  Solutions Demo Workspace
# 2  ../data/metric_definitions/incident_to_resolut...  Solutions Demo Workspace

# %%
# DBG
# Check for possible substitution error: ""THIS_PROCESS"" instead "THIS_PROCESS"
df[df['query'].str.contains('""')][['query',"signalFragment"]]
# Out:
#                                                   query  \
# 2084  SELECT \n\t"6 - Other - Transaction (TCODE)" A...
# 2890  SELECT \n\t"6 - Other - Transaction (TCODE)" A...
# 8166  SELECT \nSUM((SELECT COUNT ("Request Type")\n\...
# 8174  SELECT \nSUM((SELECT COUNT ("Request Type")\n\...
#
#                                          signalFragment
# 2084  SELECT \n\t"6 - Other - Transaction (TCODE)" A...
# 2890  SELECT \n\t"6 - Other - Transaction (TCODE)" A...
# 8166  SELECT \nSUM((SELECT COUNT ("Request Type")\n\...
# 8174  SELECT \nSUM((SELECT COUNT ("Request Type")\n\...

# %% [markdown]
# ### Plot duplicates

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot') 
# Remove duplicates 
columns= df.columns.to_list() #[0:4] # problem with metrics_vars column
#columns=['name', 'query', 'description', 'meta', 'view', 'signalFragment', 'process', 'origin']
#columns.remove('metric_vars')
#columns=['name', 'query'] #, 'description']
#a= df.duplicated(columns).value_counts()
#columns=['name','signalFragment','description'] 
#columns=['signalFragment'] 
#print(columns)
#b= df.duplicated(columns).value_counts()

width = .25   
columns=['name'] 
title1=f'Columns: {columns}'
df.duplicated(columns).value_counts().sort_index().plot(kind='bar', position=1, width = width, title="Duplucates")
columns=['name','signalFragment'] 
columns=['signalFragment'] 
title2=f'Columns: {columns}'
df.duplicated(columns).value_counts().sort_index().plot(kind='bar', position=2, color='skyblue' , width = width)
columns=['name','signalFragment','description'] 
columns=['description'] 
title3=f'Columns: {columns}'
df.duplicated(columns).value_counts().sort_index().plot(kind='bar',  position=3,  color='lime',  width = width, figsize=(7,3))
plt.legend([title1,title2,title3])
plt.show()

#df.drop_duplicates(columns, keep='first',inplace=True)
#print(columns, df.shape)
#df.value_counts
#df.duplicated(columns).describe()

# %%
# number of unique records
df[['name','signalFragment','query','description']].describe().loc[['count','unique']].plot(kind='bar', title="All data",figsize=(10,3))
df[['name','signalFragment','query','description']].describe().loc[['count','unique']]
# Out:
#          name signalFragment  query description
# count   11042          11042  11042        5101
# unique   3634           4450   6444        1372

# %% [markdown]
# ### Add columns with length of the signalFragments and WordCount to characterize complexity of the queries

# %%
# add  columns with length of the signalFragments
import numpy as np
import string
def words_count(text):
    t=text.replace("("," ").replace(")"," ").replace("["," ").replace("]"," ").replace("{"," ").replace("}"," ")
    return len(''.join([x for x in " ".join(t.split()) if x in string.ascii_letters + '_'+ ' ' or x.isdigit()]).split())
df['description'].replace(np.nan, "", inplace=True) # None in descriptions

df['FragmentWordCount'] = df['signalFragment'].apply(lambda x: words_count(x))
df['descriptionWordCount'] = df['description'].apply(lambda x: words_count(x))
df['nameWordCount'] = df['name'].apply(lambda x: words_count(x))

df['FragmentLength'] = df['signalFragment'].apply(lambda x: len(x))
df['descriptionLength'] = df['description'].apply(lambda x: len(x))
df['nameLength'] = df['name'].apply(lambda x: len(x)) 

df.shape
df.head(n=3)
# Out:
# /var/folders/hb/_ptqrx710ljb_2f6664d20bh0000gn/T/ipykernel_17721/3926161789.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['description'].replace(np.nan, "", inplace=True) # None in descriptions
#    Unnamed: 0                                name  \
# 0           0   Total number of created incidents
# 1           1      Total number of open incidents
# 2           2  Total number of resolved incidents
#
#                                                query  \
# 0  \nSELECT\nCOUNT(case_id)\nFROM "defaultview-54...
# 1  \nSELECT\nCOUNT(case_id) FILTER (WHERE \n\t(SE...
# 2  \nSELECT\nCOUNT(case_id) FILTER (WHERE \n\t(SE...
#
#                           description    meta  \
# 0   Total number of created incidents  metric
# 1      Total number of open incidents  metric
# 2  Total number of resolved incidents  metric
#
#                                          metric_vars             view  \
# 0                                                 {}  defaultview-545
# 1  {'incident_closure_events': {'name': 'incident...  defaultview-545
# 2  {'incident_closure_events': {'name': 'incident...  defaultview-545
#
#                                       signalFragment  \
# 0            SELECT COUNT(case_id) FROM THIS_PROCESS
# 1  SELECT COUNT(case_id) FILTER (WHERE \n\t(SELEC...
# 2  SELECT COUNT(case_id) FILTER (WHERE \n\t(SELEC...
#
#                                              process  \
# 0  ../data/metric_definitions/incident_to_resolut...
# 1  ../data/metric_definitions/incident_to_resolut...
# 2  ../data/metric_definitions/incident_to_resolut...
#
#                                               origin  \
# 0  ../data/metric_definitions/incident_to_resolut...
# 1  ../data/metric_definitions/incident_to_resolut...
# 2  ../data/metric_definitions/incident_to_resolut...
#
#              workspace_name  FragmentWordCount  descriptionWordCount  \
# 0  Solutions Demo Workspace                  5                     5
# 1  Solutions Demo Workspace                 13                     5
# 2  Solutions Demo Workspace                 12                     5
#
#    nameWordCount  FragmentLength  descriptionLength  nameLength
# 0              5              39                 33          33
# 1              5             125                 30          30
# 2              5             120                 34          34

# %% [markdown]
# ### Add columns with variables extracted from  from queries/signalFragmemts by means of custom SQL parser (sqlglot) and regexp
# The extracted results are added as new columns:

# %%
### Extract Variables from queries/signalFragmemts by means of custom SQL parser (sqlglot) and regexp
# https://sqlglot.com/sqlglot/dialects.html
import re
from sqlglot import parse_one, exp
from sqlglot import exp
from sqlglot.dialects.dialect import Dialect
from sqlglot.generator import Generator
from sqlglot.tokens import Tokenizer, TokenType


class Signavio(Dialect):
    class Tokenizer(Tokenizer):
        QUOTES = ["'", '"']
        IDENTIFIERS = ["`"]

        KEYWORDS = {
            **Tokenizer.KEYWORDS,
            "INT64": TokenType.BIGINT,
            "FLOAT64": TokenType.DOUBLE,
            "MATCHES": TokenType.LIKE,
            "~>": TokenType.ARROW,
            "BEHAVIOUR": TokenType.COMMAND,
            "FILL": TokenType.SELECT
        }

    class Generator(Generator):
        TRANSFORMS = {exp.Array: lambda self, e: f"[{self.expressions(e)}]"}

        TYPE_MAPPING = {
            exp.DataType.Type.TINYINT: "INT64",
            exp.DataType.Type.SMALLINT: "INT64",
            exp.DataType.Type.INT: "INT64",
            exp.DataType.Type.BIGINT: "INT64",
            exp.DataType.Type.DECIMAL: "NUMERIC",
            exp.DataType.Type.FLOAT: "FLOAT64",
            exp.DataType.Type.DOUBLE: "FLOAT64",
            exp.DataType.Type.BOOLEAN: "BOOL",
            exp.DataType.Type.TEXT: "STRING",
        }
#Tokenizer.KEYWORDS['~>']
#Tokenizer.KEYWORDS['MATCHES']
#Tokenizer.KEYWORDS #['BEHAVIOUR']



def get_column_names_values(query,dialect=Signavio):
    """  
    """
    query=query.replace("\'",'"').replace('\"','"').replace("\n"," ").replace("\t"," ").replace("'",'"')
    #print(query)
    #print(">>>>>>>")
    try:
      out={ "parser_column_names": list(set([column.name for column in parse_one(query,dialect).find_all(exp.Column)])),
      "parser_values":  list(set([column.name for column in parse_one(query,dialect).find_all(exp.Literal)])),
      "parser_error": "",
      "parser":"Signavio"
      }
    except Exception as e:
        print("SQL parsing error:", e)
        v =query.replace('[',' ').replace(']',' ').replace('(',' ').replace(')',' ').replace(',',' ')
        out={ "parser_column_names":list(set([e for e in v.split(" ") if "_" in str(e)])),
            "parser_values":  list(set(re.findall("'([^']*)'", query)+re.findall('"([^"]*)"', query))),
            "parser_error": e,
            "parser":"regexp"
        }
        #raise e
    #print(out)
    return [json.dumps(out["parser_column_names"]) , json.dumps(out["parser_values"]), out["parser_error"],  out["parser"]]

# %% [markdown]
# #### Experiments with custom parser (can skip)

# %%
#### Experiments (can skip)

# Experiments start here

query="""
SELECT
AVG(
	(SELECT LAST(end_time)
		WHERE event_name IN ('Close Incident', 'Mark Incident as Resolved'))
	-(SELECT FIRST(end_time)
		WHERE event_name IN ('Create Incident'))
)
FROM "defaultview-545"
"""

# print all column references (a and b)
for column in parse_one(query).find_all(exp.Column):
    print("column:", column) # name) #, column.alias_or_name, column.catalog )

for select in parse_one(query).find_all(exp.Select):
    print("select",select)
    for projection in select.expressions:
        print("p",projection)
        #for column in parse_one(projection).find_all(exp.Column):
        #    print("column:",column.alias_or_name, column.catalog )

# find all tables (x, y, z)
for table in parse_one(query).find_all(exp.Table):
    print("table:",table.name)

#find all values
for val in parse_one(query).find_all(exp.Literal):
    print("lit:",val ) # val.parent.args)

for val in parse_one(query).find_all(exp.Identifier):
    print("id:",val)

    
for el in parse_one(query).expressions:
    print(el)
#list(parse_one(query).find_all(exp.Var))
Signavio().Tokenizer.KEYWORDS['FILL']


indx=45
df.iloc[indx]["signalFragment"]
#print("column:", column) # name) #, column.alias_or_name, column.catalog )

s="""SELECT COUNT(1) AS "Case Count"
FROM THIS_PROCESS
WHERE "Risk Class" = 'Not evaluated'
AND
BEHAVIOUR
         (event_name = 'Create Invoice') AS create_invoice,
         ("Risk Class" = 'Not evaluated') AS no_risk_evaluation
MATCHES (no_risk_evaluation ~> create_invoice)
AND 
NOT event_name MATCHES ('Create Invoice' ~> 'Receive Payment')
AND
NOT event_name MATCHES ('Create Invoice' ~> 'Cancel Invoice')
"""
sok='SELECT COUNT(1) AS Case_Count FROM "strview-1"'

s1='SELECT AVG(\n\t(SELECT LAST(end_time)\n\t\tWHERE event_name IN (${ato_goods_receipt_events}))\n\t-(SELECT FIRST(end_time)\n\t\tWHERE event_name IN (${ato_po_creation_events}))\n   ) FROM THIS_PROCESS'

#sqlglot.transpile(sql, read='doris', pretty=True)[0]
#sqlglot.transpile(s,read='doris', pretty=True)

s2="""
SELECT (\n\t\tCOUNT(1) FILTER (WHERE event_name MATCHES ('Create Invoice'~> 'Receive Payment'))\n /\n COUNT(1)\n ) * 100 AS "Standard Invoicing Compliance Rate"\n\nFROM THIS_PROCESS
"""
s2="""
SELECT COUNT(1) AS "Case Count"
FROM THIS_PROCESS
WHERE "Risk Class" = 'Not evaluated'
AND
BEHAVIOUR
 (event_name = 'Create Invoice') AS create_invoice,
 ("Risk Class" = 'Not evaluated') AS no_risk_evaluation
MATCHES (no_risk_evaluation ~> create_invoice)
AND 
NOT event_name MATCHES ('Create Invoice' ~> 'Receive Payment')
AND
NOT event_name MATCHES ('Create Invoice' ~> 'Cancel Invoice')
"""

s2="""
 SELECT "Month"
 ,IF(count_started IS NOT NULL, count_started, 0) - IF(LAG(count_finished) OVER () IS NOT NULL, LAG(count_finished) OVER (), 0) AS "Active Cases"
 FROM (SELECT "Month"
 , SUM(count_started) OVER (ORDER BY "Month") AS count_started
 , SUM(count_finished) OVER (ORDER BY "Month") AS count_finished
 FROM (SELECT "Month"
 , COUNT(1) FILTER (WHERE started = 1) AS count_started
 , COUNT(1) FILTER (WHERE started = 0) AS count_finished
 FROM (SELECT date_trunc('month', (SELECT FIRST(end_time))) AS "Month", 
 			 1 AS started
 FROM "defaultview-9"
 UNION ALL
 SELECT date_trunc('month', (SELECT LAST(end_time))) AS "Month", 
 0 AS started
 FROM "defaultview-9") AS sub
 GROUP BY 1
 FILL TIMESERIES('month')
 ) AS sub2
 ) AS sub3
"""

#Signavio=Signavio()
#print(s2)
#sqlglot.parse(s2,dialect=Signavio)
get_column_names_values(s1,dialect=Signavio)
#print(out)

#print(s2)

#s= json.dumps({"query":s})
#json.loads(s)["query"]

#get_column_names_values(repr(s))
#import sqlglot
#sqlglot.transpile(s, read="presto", write="hive")
#dfp.apply(lambda x: API_validation(x.query,x.workspace_name, auth=auth), axis=1 ).to_list()
#dfp[["parser_column_names","parser_values","parser_error","parser"]] = dfp.apply(lambda x: get_column_names_values(x.query,Signavio), axis=1).to_list()
#repr(s)
#dfp
# Out:
# column: end_time
# column: end_time
# column: event_name
# column: event_name
# select SELECT AVG((SELECT LAST(end_time) WHERE event_name IN ('Close Incident', 'Mark Incident as Resolved')) - (SELECT FIRST(end_time) WHERE event_name IN ('Create Incident'))) FROM "defaultview-545"
# p AVG((SELECT LAST(end_time) WHERE event_name IN ('Close Incident', 'Mark Incident as Resolved')) - (SELECT FIRST(end_time) WHERE event_name IN ('Create Incident')))
# select SELECT LAST(end_time) WHERE event_name IN ('Close Incident', 'Mark Incident as Resolved')
# p LAST(end_time)
# select SELECT FIRST(end_time) WHERE event_name IN ('Create Incident')
# p FIRST(end_time)
# table: defaultview-545
# lit: 'Close Incident'
# lit: 'Mark Incident as Resolved'
# lit: 'Create Incident'
# id: "defaultview-545"
# id: end_time
# id: end_time
# id: event_name
# id: event_name
# AVG((SELECT LAST(end_time) WHERE event_name IN ('Close Incident', 'Mark Incident as Resolved')) - (SELECT FIRST(end_time) WHERE event_name IN ('Create Incident')))
# ['["end_time", "event_name", "ato_po_creation_events", "ato_goods_receipt_events"]',
#  '[]',
#  '',
#  'Signavio']

# %% [markdown]
# #### Here apply lambda with variables extraction (tales 25 secs)

# %%
# Here apply lambda with variables extraction (takes 25 secs)
df[["parser_column_names","parser_values","parser_error","parser"]] = df.apply(lambda x: get_column_names_values(x.query,dialect=Signavio), axis=1).to_list()
# Out:
# SQL parsing error: Expecting ). Line 1, Col: 105.
#    SELECT AVG(  (SELECT LAST("AR_LastClearingDate")    WHERE ((NOW() - LAST(end_time)) < DURATION "60weeks"))  -(SELECT LAST("AR_LastCreationDateTime")   WHERE ((NOW() - LAST(end_time)) < DURATION "60weeks")
# SQL parsing error: Expecting ). Line 1, Col: 104.
#    SELECT COUNT(case_id) FILTER (  WHERE ("AR_LastNetDueDate" - "AR_LastClearingDate"    > DURATION "1day") ) / COUNT(case_id) FILTER (  WHERE ("AR_LastClearingDate" IS NOT NULL) ) * 100 FROM "defaultview-5
# SQL parsing error: Expecting ). Line 1, Col: 104.
#    SELECT COUNT(case_id) FILTER (  WHERE ("AR_LastClearingDate" - "AR_LastNetDueDate"    > DURATION "1day") ) / COUNT(case_id) FILTER (  WHERE ("AR_LastClearingDate" IS NOT NULL) ) * 100 FROM "defaultview-5
# SQL parsing error: Expecting ). Line 1, Col: 104.
#    SELECT COUNT(case_id) FILTER (  WHERE ("AR_LastClearingDate" - "AR_LastNetDueDate"    < DURATION "1day"   AND "AR_LastNetDueDate" - "AR_LastClearingDate"   < DURATION "1day"  ) ) / COUNT(case_id) FILTER
# SQL parsing error: Expecting ). Line 1, Col: 177.
#   "Create Accounts Receivable"    AND "ClearingDate" IS NULL    AND (NOW()-"DocumentDate") > DURATION "30days"  ) FROM "defaultview-545"
# SQL parsing error: Expecting ). Line 1, Col: 171.
#   e = "Create Accounts Receivable"   AND "ClearingDate" IS NULL   AND (NOW()-"NetDueDate") > DURATION "30days"  ) FROM "defaultview-545"
# SQL parsing error: Expecting ). Line 1, Col: 171.
#   e = "Create Accounts Receivable"   AND "ClearingDate" IS NULL   AND (NOW()-"NetDueDate") > DURATION "30days"  ) FROM "defaultview-545"
# SQL parsing error: Expecting ). Line 1, Col: 152.
#    (  WHERE event_name = "Clear Accounts Receivable"   AND ("ClearingDate" - "NetDueDate") > DURATION "30days"  ) FROM "defaultview-545"
# SQL parsing error: Expecting ). Line 1, Col: 223.
#   ta"))  -  FIRST(end_time) FILTER (WHERE event_name IN ("Create Meter Reading Order"))  ) > DURATION "10days" ) FROM "defaultview-545"
# SQL parsing error: Expecting ). Line 1, Col: 114.
#   CT AVG(  (SELECT LAST("Last Inv. Item Clearing Date")    WHERE ((NOW() - LAST(end_time)) < DURATION "60weeks"))  -(SELECT LAST("Inv. Posting Document Date")   WHERE ((NOW() - LAST(end_time)) < DURATION "60week
# SQL parsing error: Expecting ). Line 1, Col: 120.
#   (case_id) FILTER (  WHERE ("Last Inv. Item Clearing Date" - "Last Inv. Item Due Date"    > DURATION "1days") ) /COUNT(case_id) FILTER (  WHERE ("Last Inv. Item Clearing Date" IS NOT NULL) ) * 100 FROM "defau
# SQL parsing error: Expecting ). Line 1, Col: 120.
#   (case_id) FILTER (  WHERE ("Last Inv. Item Due Date" - "Last Inv. Item Clearing Date"    > DURATION "5days") ) /COUNT(case_id) FILTER (  WHERE ("Last Inv. Item Clearing Date" IS NOT NULL) )* 100 FROM "defaul
# SQL parsing error: Expecting ). Line 1, Col: 120.
#   (case_id) FILTER (  WHERE ("Last Inv. Item Clearing Date" - "Last Inv. Item Due Date"    < DURATION "1days"  AND "Last Inv. Item Due Date" - "Last Inv. Item Clearing Date"   < DURATION "5days"  ) ) / COUNT(c
# SQL parsing error: Required keyword: 'this' missing for <class 'sqlglot.expressions.BitwiseXor'>. Line 1, Col: 180.
#    "Create PO Item" ~> "Receive PO Item" ~> "Receive Invoice" ~> "Reconcile Invoice" ~> "Pay Invoice" $)  ) / COUNT(case_id) * 100 FROM "defaultview-545"
# SQL parsing error: Expecting ). Line 1, Col: 114.
#   CT AVG(  (SELECT LAST("Last Inv. Item Clearing Date")    WHERE ((NOW() - LAST(end_time)) < DURATION "52weeks"))  -(SELECT LAST("Inv. Posting Document Date")   WHERE ((NOW() - LAST(end_time)) < DURATION "52week
# SQL parsing error: Expecting ). Line 1, Col: 120.
#   (case_id) FILTER (  WHERE ("Last Inv. Item Clearing Date" - "Last Inv. Item Due Date"    > DURATION "1days") ) /COUNT(case_id) FILTER (  WHERE ("Last Inv. Item Clearing Date" IS NOT NULL) ) * 100 FROM "defau
# SQL parsing error: Expecting ). Line 1, Col: 120.
#   (case_id) FILTER (  WHERE ("Last Inv. Item Due Date" - "Last Inv. Item Clearing Date"    > DURATION "5days") ) /COUNT(case_id) FILTER (  WHERE ("Last Inv. Item Clearing Date" IS NOT NULL) )* 100 FROM "defaul
# SQL parsing error: Expecting ). Line 1, Col: 120.
#   (case_id) FILTER (  WHERE ("Last Inv. Item Clearing Date" - "Last Inv. Item Due Date"    < DURATION "1days"  AND "Last Inv. Item Due Date" - "Last Inv. Item Clearing Date"   < DURATION "5days"  ) ) / COUNT(c
# SQL parsing error: Expecting ). Line 1, Col: 227.
#    -"Inv. Converted USD Cash Discount Amount"  ) FILTER(  WHERE EVENT_NAME MATCHES ("Clear Invoice"~>("Cash Discount 1 Due Date passed"|"Cash Discount 2 Due Date passed"))) FROM "defaultview-545"
# SQL parsing error: Expecting ). Line 1, Col: 99.
#    SELECT COUNT(DISTINCT case_id) FILTER (  WHERE NOW() - (SELECT LAST(end_time)) > DURATION "30days"    AND (SELECT FIRST(event_name) FILTER (   WHERE event_name IN ("Clear Accounts Receivable"))) IS
# SQL parsing error: Expecting ). Line 1, Col: 174.
#    = "Create Accounts Receivable"   AND "ClearingDate" IS NULL   AND (NOW()-"DocumentDate")> DURATION "30days"  ) FROM "defaultview-545"
# SQL parsing error: Expecting ). Line 1, Col: 172.
#    = "Create Accounts Receivable"    AND "ClearingDate" IS NULL    AND (NOW()-"NetDueDate")> DURATION "30days"  ) FROM "defaultview-545"
# SQL parsing error: Expecting ). Line 1, Col: 172.
#    = "Create Accounts Receivable"    AND "ClearingDate" IS NULL    AND (NOW()-"NetDueDate")> DURATION "30days"  ) FROM "defaultview-545"
# SQL parsing error: Expecting ). Line 1, Col: 201.
#   "Create Accounts Receivable"     AND "ClearingDate" IS NULL     AND (NOW()-"NetDueDate") > DURATION "30days")  )  FROM "defaultview-545"
# SQL parsing error: Expecting ). Line 1, Col: 151.
#   (  WHERE event_name = "Clear Accounts Receivable"    AND ("ClearingDate" - "NetDueDate") > DURATION "1day"  ) FROM "defaultview-545"
# SQL parsing error: Expecting ). Line 1, Col: 105.
#    SELECT (COUNT(case_id) FILTER (  WHERE event_name MATCHES("Create Quote"  ~> ("Opportunity closed (won)" | "Update Opportunity Stage to: Closed Won" | "Update Opportunity Stage to: 06 Closed Won (Onboardi
# SQL parsing error: Expecting ). Line 1, Col: 26.
#    SELECT (DURATION "4hours")/ AVG(  (   (SELECT LAST(end_time) WHERE event_name    IN ("Post Goods Issue")  )  - (SELECT FIRST(
# SQL parsing error: Expecting ). Line 1, Col: 222.
#   "))   -  FIRST(end_time) FILTER (WHERE event_name    IN ("Create Sales Order Item"))   ) < DURATION "4hours" ) / COUNT(case_id) FILTER (  WHERE (SELECT BOOL_OR(event_name IN ("Post Goods Issue")))  ) * 100 FR
# SQL parsing error: Expecting ). Line 1, Col: 139.
#   time)   WHERE event_name IN ("Create Outbound Delivery") AND   ((NOW() - LAST(end_time)) < DURATION "21days")   )  -(SELECT FIRST(end_time)   WHERE event_name IN ("Create Sales Order Item")   )  ) FROM "defau
# SQL parsing error: Expecting ). Line 1, Col: 114.
#   T AVG(  (SELECT LAST("InvoiceAccountingClearingDate") WHERE    ((NOW() - LAST(end_time)) < DURATION "21days"))  -(SELECT FIRST("InvoiceAccountingDocumentDate")WHERE    ((NOW() - LAST(end_time)) < DURATION "21
# SQL parsing error: Expecting ). Line 1, Col: 154.
#   LECT BOOL_OR(event_name IN ("Create Sales Order Item"))    AND ((NOW() - LAST(end_time)) < DURATION "21days")  )  AND (SELECT BOOL_OR(event_name = "Reject Sales Doc Item")   AND ((NOW() - LAST(end_time)) < DU
# SQL parsing error: Expecting ). Line 1, Col: 154.
#   LECT BOOL_OR(event_name IN ("Create Sales Order Item"))    AND ((NOW() - LAST(end_time)) < DURATION "21days")  )  AND (SELECT BOOL_OR(event_name = "Create Return Sales Order Item")   AND ((NOW() - LAST(end_ti
# SQL parsing error: Expecting ). Line 1, Col: 147.
#   (   SELECT BOOL_OR(event_name IN ("Delete Sales Doc Item"))   AND NOW() - LAST(end_time) < DURATION "21days"  ) ) FROM "defaultview-545"
# SQL parsing error: Expecting ). Line 1, Col: 365.
#   t Item")    AND ("EventCreatedByUserType" != "Dialog"))    AND ((NOW() - LAST(end_time)) < DURATION "21days"))   ) ) / SUM((SELECT COUNT(event_name))) * 100 FROM "defaultview-545"
# SQL parsing error: Expecting ). Line 1, Col: 90.
#    SELECT COUNT(case_id) FILTER (  WHERE NOW() - (SELECT LAST(end_time)) > DURATION "21days"   AND (SELECT FIRST(event_name) FILTER (    WHERE event_name IN ("Update Opportunity Stage to: Clos
# SQL parsing error: Expecting ). Line 1, Col: 185.
#      AND "ProdOrderGRIndicator" = "X"             AND (NOW() - "ProdOrderSchedFinishDate") < DURATION "1days"               ) ) FROM "defaultview-545"
# SQL parsing error: Expecting ). Line 1, Col: 189.
#   "ProdOrderItemStatus" IN ("DLFL")     ) = 0     AND (NOW() - "ProdOrderBasicFinishDate") > DURATION "1days" )  FROM "defaultview-545"
# SQL parsing error: Expecting ). Line 1, Col: 287.
#   dOrderItemStatus" IN ("CLSD","DLFL")     ) = 0  AND (NOW() - "ProdOrderSchedFinishDate") < DURATION "1days" )  FROM "defaultview-545"
# SQL parsing error: Expecting ). Line 1, Col: 138.
#     WHERE ("ProdOrderActRelDate" IS NULL             AND ( NOW() - "ProdOrderSchRelDate" ) > DURATION "1days"     ) ) FROM "defaultview-545"
# SQL parsing error: Expecting ). Line 1, Col: 198.
#   rItemStatus" IN ("TECO","CLSD")     ) = 0     AND ( NOW() - "ProdOrderSchedFinishDate" ) > DURATION "1days" )  FROM "defaultview-545"
# SQL parsing error: Expecting ). Line 1, Col: 99.
#    SELECT COUNT( case_id) FILTER (  WHERE ( ( NOW() - "ProdOrderSchedFinishDate" ) > DURATION "1days"             AND "ProdOrderSchedFinishDate" IS NULL     ) ) FROM "defaultview-545"
# SQL parsing error: Expecting ). Line 1, Col: 322.
#   CT LAST(end_time)     WHERE event_name IN ("Create Production Order Item") )            <= DURATION "180Days") )  FROM "defaultview-545"
# SQL parsing error: Required keyword: 'this' missing for <class 'sqlglot.expressions.BitwiseXor'>. Line 1, Col: 191.
#   "Create Outbound Delivery Item"  ~> "Post Goods Issue"  ~> "Create Invoice Item"  ~> "Clear Invoice"))  / COUNT(case_id)  * 100 FROM "defaultview-545"
# SQL parsing error: Required keyword: 'this' missing for <class 'sqlglot.expressions.BitwiseXor'>. Line 1, Col: 196.
#   "Create Outbound Delivery Item"  ~> "Post Goods Issue"  ~> "Create Invoice Item"  ~> "Clear Invoice"))) FROM "defaultview-545"
# SQL parsing error: Required keyword: 'this' missing for <class 'sqlglot.expressions.BitwiseXor'>. Line 1, Col: 196.
#   "Create Outbound Delivery Item"  ~> "Post Goods Issue"  ~> "Create Invoice Item"  ~> "Clear Invoice")  AND (SELECT BOOL_OR( event_name IN ("Post Goods Issue")))  AND (SELECT   LAST(end_time) FILTER (WH
# SQL parsing error: Expecting ). Line 1, Col: 146.
#   Actual Delivery Date" IS NOT NULL  AND ("Actual Delivery Date" - "Scheduled Finish Date" > DURATION "0days")) / COUNT(case_id) FILTER(  WHERE "Actual Delivery Date" IS NOT NULL) *100 FROM "defaultview-545"
# SQL parsing error: Expecting ). Line 1, Col: 146.
#   Actual Delivery Date" IS NOT NULL  AND ("Actual Delivery Date" - "Scheduled Finish Date" < DURATION "0days")  ) / COUNT(case_id) FILTER(  WHERE"Actual Delivery Date" IS NOT NULL) *100 FROM "defaultview-545"
# SQL parsing error: Expecting ). Line 1, Col: 145.
#   "Actual Delivery Date" IS NOT NULL  AND "Actual Delivery Date" - "Scheduled Finish Date" = DURATION "0days"  ) / COUNT(case_id) FILTER(  WHERE "Actual Delivery Date" IS NOT NULL) *100 FROM "defaultview-545"
# SQL parsing error: Expecting ). Line 1, Col: 163.
#   me) FILTER     (WHERE event_name IN ("Confirm Execution Done")))  - "FRO Delivery Date"  > DURATION "1days"     AND "FRO Delivery Status" = "03") /  COUNT(case_id) FILTER (WHERE "FRO Delivery Status" = "03")
# SQL parsing error: Expecting ). Line 1, Col: 164.
#   e) FILTER      (WHERE event_name IN ("Confirm Execution Done")))   -"FRO Delivery Date" <= DURATION "1days"  AND "FRO Delivery Status" = "03") FROM "defaultview-545"
# SQL parsing error: Expecting ). Line 1, Col: 144.
#   - "Order Scheduled Start")  FILTER (WHERE "Order Actual Start" - "Order Scheduled Start" > DURATION "0minutes") FROM "defaultview-545"
# SQL parsing error: Expecting ). Line 1, Col: 154.
#    Actual Start" IS NOT NULL  AND "Order Actual Completion" - "Order Scheduled Completion" > DURATION "0minutes") FROM "defaultview-545"
# SQL parsing error: Expecting ). Line 1, Col: 143.
#   HERE "Order Actual Start" IS NOT NULL AND "Order Actual Start" - "Order Scheduled Start" > DURATION "0minutes") FROM "defaultview-545"
# SQL parsing error: Expecting ). Line 1, Col: 124.
#   CT COUNT(case_id) FILTER (  WHERE event_name MATCHES("Create PO Item" ~> "Create Goods Receipt" ~> ("Create FI Invoice"|"Record Invoice Receipt") ~> "Clear Invoice" $)  ) / COUNT(case_id) * 100 FROM "defaultview-545"
# SQL parsing error: Expecting ). Line 1, Col: 191.
#        "Contract Status" IN ("Published") AND         ( "Contract Expiration Date" - NOW() < DURATION "90days" )     ) FROM "defaultview-545"
# SQL parsing error: Expecting ). Line 1, Col: 135.
#   R  ( WHERE "Contract Status" IN ("Expired") OR      ( "Contract Expiration Date" - NOW() < DURATION "0days" ) ) FROM "defaultview-545"
# SQL parsing error: Expecting ). Line 1, Col: 140.
#    WHERE "Statistical Fcst Qty Error (%)" > 30  AND (DATE_TRUNC("month", NOW()) - "MONTH") < DURATION "200days"  AND (DATE_TRUNC("month", NOW())) > "MONTH"  ) / COUNT(case_id) FILTER(  WHERE (DATE_TRUNC("month",
# SQL parsing error: Expecting ). Line 1, Col: 227.
#     AND (DATE_TRUNC("month", NOW())) > "MONTH"  AND (DATE_TRUNC("month", NOW()) - "MONTH") < DURATION "200days"  ) / COUNT(case_id) FILTER(  WHERE "Statistical Fcst Qty Bias (%)" <> 0  AND (DATE_TRUNC("month", N
# SQL parsing error: Expecting ). Line 1, Col: 173.
#     AND (DATE_TRUNC("month", NOW())) > "MONTH"  AND (DATE_TRUNC("month", NOW()) - "MONTH") < DURATION "200days"  ) / COUNT(case_id) FILTER(  WHERE "Consensus Demand Plan Qty" <> 0  AND (DATE_TRUNC("month", NOW()
# SQL parsing error: Expecting ). Line 1, Col: 227.
#     AND (DATE_TRUNC("month", NOW())) > "MONTH"  AND (DATE_TRUNC("month", NOW()) - "MONTH") < DURATION "200days"  ) FROM "defaultview-545"
# SQL parsing error: Expecting ). Line 1, Col: 300.
#   ND (DATE_TRUNC("month", NOW())) > "MONTH"     AND (DATE_TRUNC("month", NOW()) - "MONTH") < DURATION "200days"     ) > 0 ) FROM "defaultview-545"
# SQL parsing error: Expecting ). Line 1, Col: 381.
#    AND "MONTH" >= (DATE_TRUNC("month", NOW()))  AND ("MONTH" - DATE_TRUNC("month", NOW())) < DURATION "320days"  ) / COUNT(DISTINCT "Product ID") FILTER(  WHERE "Statistical Fcst Qty" > 0  AND "MONTH" >= (DATE_T
# SQL parsing error: Expecting ). Line 1, Col: 211.
#    AND "MONTH" >= (DATE_TRUNC("month", NOW()))  AND ("MONTH" - DATE_TRUNC("month", NOW())) < DURATION "320days" ) / COUNT(DISTINCT "Product ID") FILTER(  WHERE "MONTH" >= (DATE_TRUNC("month", NOW()))  AND ("MONT
# SQL parsing error: Expecting ). Line 1, Col: 170.
#    AND "MONTH" >= (DATE_TRUNC("month", NOW()))  AND ("MONTH" - DATE_TRUNC("month", NOW())) < DURATION "320days" ) FROM "defaultview-545"
# SQL parsing error: Expecting ). Line 1, Col: 379.
#   HERE "MONTH" >= (DATE_TRUNC("month", NOW()))  AND ("MONTH" - DATE_TRUNC("month", NOW())) < DURATION "320days" ) * 100 FROM "defaultview-545"
# SQL parsing error: Expecting ). Line 1, Col: 175.
#    AND "MONTH" >= (DATE_TRUNC("month", NOW()))  AND ("MONTH" - DATE_TRUNC("month", NOW())) < DURATION "320days" ) FROM "defaultview-545"
# SQL parsing error: Expecting ). Line 1, Col: 242.
#    AND "MONTH" >= (DATE_TRUNC("month", NOW()))  AND ("MONTH" - DATE_TRUNC("month", NOW())) < DURATION "320days" ) / COUNT( DISTINCT "Product ID") FILTER(  WHERE "Consensus Demand" <> 0  AND "MONTH" >= (DATE_TRUN
# SQL parsing error: Expecting ). Line 1, Col: 197.
#   ERE "MONTH" >= (DATE_TRUNC("month", NOW()))   AND ("MONTH" - DATE_TRUNC("month", NOW())) < DURATION "320days"   )   AND (   SELECT SUM("Projected Stock") = 0   WHERE "MONTH" >= (DATE_TRUNC("month", NOW()))   A
# SQL parsing error: Expecting ). Line 1, Col: 230.
#    AND "MONTH" >= (DATE_TRUNC("month", NOW()))  AND ("MONTH" - DATE_TRUNC("month", NOW())) < DURATION "320days" ) FROM "defaultview-545"
# SQL parsing error: Expecting ). Line 1, Col: 422.
#    AND "MONTH" >= (DATE_TRUNC("month", NOW()))  AND ("MONTH" - DATE_TRUNC("month", NOW())) < DURATION "320days" ) * 100 FROM "defaultview-545"
# SQL parsing error: Expecting ). Line 1, Col: 226.
#    AND "MONTH" >= (DATE_TRUNC("month", NOW()))  AND ("MONTH" - DATE_TRUNC("month", NOW())) < DURATION "320days" ) FROM "defaultview-545"
# SQL parsing error: Expecting ). Line 1, Col: 214.
#   ONTH" >= (DATE_TRUNC("month", NOW()))         AND ("MONTH" - DATE_TRUNC("month", NOW())) < DURATION "320days"     AND "Consensus Demand" > 0  ) / COUNT("case_id") FILTER(  WHERE "Consensus Demand" > 0     AND
# SQL parsing error: Expecting ). Line 1, Col: 168.
#   Close Incident"))  -(SELECT FIRST(end_time) WHERE event_name IN ("Create Incident"))) ) / (DURATION "15days") *100 FROM "defaultview-545"
# SQL parsing error: Expecting ). Line 1, Col: 201.
#   lose Incident"))  -  FIRST(end_time) FILTER (WHERE event_name IN ("Create Incident"))  ) < DURATION "15days" ) /count(case_id) *100 FROM "defaultview-545"
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 163.
#   as Week,     count(case_id) AS "No. of ODO Items" FROM "defaultview-545" ORDER BY 1 ASC NULLS FIRST FILL TIMESERIES("QUARTER"), NULL
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 212.
#   (SELECT FIRST(end_time))) AS "Median Cycle Time"  FROM "defaultview-545" ORDER BY 1 ASC NULLS FIRST FILL TIMESERIES("QUARTER"), NULL
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 316.
#   S "Revenue", count(case_id) AS "No. of ODO Items" FROM "defaultview-545" ORDER BY 1 ASC NULLS FIRST FILL TIMESERIES("QUARTER"), NULL
# SQL parsing error: Expecting ). Line 1, Col: 136.
#   R (     WHERE       (         "Last Inv. Item Due Date" - "Last Inv. Item Clearing Date" > DURATION "5days"       ) AND "Last Inv. Item Clearing Date" IS NOT NULL   ) / COUNT(case_id) FILTER (     WHERE
# SQL parsing error: Expecting ). Line 1, Col: 82.
#   SELECT COUNT (DISTINCT CASE_ID) FILTER (  WHERE "Change Type" MATCHES ( "Update" )  -- get all PT "changes"  AND ("Changed Table" MATCHES ("BSEG"))  AND ("Changed Field" MATCHES  ("Z
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 558.
#   ew-545" WHERE   event_name MATCHES ("Post Invoice" ~> "Clear Invoice") ORDER BY   1 ASC NULLS FIRST FILL TIMESERIES("MONTH"),   NULL
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 558.
#   Invoice")   AND EVENT_NAME MATCHES ("Post Invoice" ~> "Clear Invoice") ORDER BY   1 ASC NULLS FIRST FILL TIMESERIES("MONTH"),   NULL
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 497.
#   ew-545" WHERE   event_name MATCHES ("Post Invoice" ~> "Clear Invoice") ORDER BY   1 ASC NULLS FIRST FILL TIMESERIES("MONTH"),   NULL
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 602.
#   ew-545" WHERE   event_name MATCHES ("Post Invoice" ~> "Clear Invoice") ORDER BY   1 ASC NULLS FIRST FILL TIMESERIES("MONTH")
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 460.
#   ultview-545"  WHERE EVENT_NAME MATCHES ("Post Invoice"~>"Clear Invoice") ORDER BY 1 ASC NULLS FIRST FILL timeseries("MONTH")
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 568.
#   FROM   "defaultview-545" WHERE   EVENT_NAME MATCHES ("Create Invoice") ORDER BY   1 ASC NULLS FIRST FILL TIMESERIES("MONTH"),   NULL
# SQL parsing error: Expecting ). Line 1, Col: 229.
#   e"))   - FIRST (END_TIME) FILTER (      WHERE EVENT_NAME IN ("Post Invoice")))           < DURATION "14days")   / COUNT (CASE_ID) * 100      FROM "defaultview-545"
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 464.
#   ultview-545"  WHERE EVENT_NAME MATCHES ("Post Invoice"~>"Clear Invoice") ORDER BY 1 ASC NULLS FIRST FILL timeseries("MONTH")
# SQL parsing error: Expecting ). Line 1, Col: 229.
#   e"))   - FIRST (END_TIME) FILTER (      WHERE EVENT_NAME IN ("Post Invoice")))           < DURATION "14days")   / COUNT (CASE_ID) * 100      FROM "defaultview-545"
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 568.
#   FROM   "defaultview-545" WHERE   EVENT_NAME MATCHES ("Create Invoice") ORDER BY   1 ASC NULLS FIRST FILL TIMESERIES("MONTH"),   NULL
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 533.
#   pany"  FROM "defaultview-545" WHERE "Inv. Company Code Text" IS NOT NULL ORDER BY 1 ASC NULLS FIRST FILL timeseries("MONTH"), NULL
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 599.
#   Type"  FROM "defaultview-545" WHERE "Inv. Company Code Text" IS NOT NULL ORDER BY 1 ASC NULLS FIRST FILL timeseries("MONTH"), NULL
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 153.
#   time))) as Month,     count(case_id) as "# Cases" FROM "defaultview-545" ORDER BY 1 ASC NULLS FIRST FILL TIMESERIES("MONTH"), NULL
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 324.
#   NT(event_name)))  * 100 AS "Automation Rate"      FROM "defaultview-545" ORDER BY 1 ASC NULLS FIRST FILL TIMESERIES("MONTH"), NULL
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 291.
#   ))  / COUNT (CASE_ID) * 100 AS "Change Rate"      FROM "defaultview-545" ORDER BY 1 ASC NULLS FIRST FILL TIMESERIES("MONTH"), NULL
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 308.
#   ))  / COUNT (CASE_ID) * 100 AS "Rework Rate"      FROM "defaultview-545" ORDER BY 1 ASC NULLS FIRST FILL TIMESERIES("MONTH"), NULL
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 206.
#    - FIRST(end_time))) AS "Average Cycle Time"      FROM "defaultview-545" ORDER BY 1 ASC NULLS FIRST FILL TIMESERIES("MONTH"), NULL
# SQL parsing error: Expecting ). Line 1, Col: 183.
#   learing Date" IS NULL)     AND "Last FI Invoice Item Due Date"- DATE_TRUNC("day", NOW()) > DURATION "7DAYS"    ) FROM "defaultview-545"
# SQL parsing error: Expecting ). Line 1, Col: 207.
#   ing Date" IS NULL     AND "Last FI Invoice Item Due Date"- DATE_TRUNC("day", NOW())     >  DURATION "7DAYS"  ) ) FROM "defaultview-545"
# SQL parsing error: Expecting ). Line 1, Col: 186.
#   ring Date" IS NULL)     AND "Last FI Invoice Item Due Date"- DATE_TRUNC("day", NOW())    > DURATION "7DAYS"    ) FROM "defaultview-545"
# SQL parsing error: Expecting ). Line 1, Col: 207.
#   ing Date" IS NULL     AND "Last FI Invoice Item Due Date"- DATE_TRUNC("day", NOW())     >  DURATION "7DAYS"  ) ) FROM "defaultview-545"
# SQL parsing error: Expecting ). Line 1, Col: 183.
#   learing Date" IS NULL)     AND "Last FI Invoice Item Due Date"- DATE_TRUNC("day", NOW()) > DURATION "7DAYS"    ) FROM "defaultview-545"
# SQL parsing error: Expecting ). Line 1, Col: 207.
#   ing Date" IS NULL     AND "Last FI Invoice Item Due Date"- DATE_TRUNC("day", NOW())     >  DURATION "7DAYS"  ) ) FROM "defaultview-545"
# SQL parsing error: Required keyword: 'this' missing for <class 'sqlglot.expressions.ILike'>. Line 1, Col: 1044.
#   "Rework Rate in %"    ,COUNT("Last FI Invoice ID") FILTER(WHERE event_name MATCHES (ILIKE "%update%"))/COUNT("Last FI Invoice ID") * 100 AS "Change Rate in %"    FROM     (SELECT DISTINCT     "PO Compa
# SQL parsing error: Expecting ). Line 1, Col: 183.
#   learing Date" IS NULL)     AND "Last FI Invoice Item Due Date"- DATE_TRUNC("day", NOW()) > DURATION "7DAYS"    ) FROM "defaultview-545"
# SQL parsing error: Expecting ). Line 1, Col: 207.
#   ing Date" IS NULL     AND "Last FI Invoice Item Due Date"- DATE_TRUNC("day", NOW())     >  DURATION "7DAYS"  ) ) FROM "defaultview-545"
# SQL parsing error: Expecting ). Line 1, Col: 177.
#   CHES (      ("Create PO Item"|"Create PR Item")   ~> "Release PO"   ~> "Create Goods Receipt"   ~> ("Record Invoice Receipt"|"Create FI Invoice")   ~> "Clear Invoice"         ))   / COUNT (CASE_ID) FILTER (WHERE EVENT_NAME M
# SQL parsing error: Expecting ). Line 1, Col: 177.
#   CHES (      ("Create PO Item"|"Create PR Item")   ~> "Release PO"   ~> "Create Goods Receipt"   ~> ("Record Invoice Receipt"|"Create FI Invoice")   ~> "Clear Invoice"))   / COUNT (CASE_ID) FILTER (WHERE EVENT_NAME MATCHES ("
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 445.
#   ULL))          * 100 AS "Late Payment Rate"       FROM "defaultview-545" ORDER BY 1 ASC NULLS FIRST FILL TIMESERIES("MONTH"), NULL
# SQL parsing error: Expecting ). Line 1, Col: 303.
#   CHES (      ("Create PO Item"|"Create PR Item")   ~> "Release PO"   ~> "Create Goods Receipt"   ~> ("Record Invoice Receipt"|"Create FI Invoice")   ~> "Clear Invoice"))   / COUNT (CASE_ID)     * 100 AS "Conformance Rate"  FR
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 388.
#   ME))) * 100 AS "Automation rate"                  FROM "defaultview-545" ORDER BY 1 ASC NULLS FIRST FILL TIMESERIES("MONTH"), NULL
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 345.
#   e%")))   / COUNT (CASE_ID) * 100 AS "Change Rate" FROM "defaultview-545" ORDER BY 1 ASC NULLS FIRST FILL timeseries("MONTH"), NULL
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 453.
#   ultview-545" WHERE event_name MATCHES ("Create PR Item" "Clear Invoice") ORDER BY 1 ASC NULLS FIRST FILL TIMESERIES("MONTH"), NULL
# SQL parsing error: Expected END after CASE. Line 1, Col: 217.
#   oice Amount in $" ,"Late Payment Rate in %"  FROM  (SELECT    CASE    WHEN "CYCLE_TIME" <= DURATION "5days"THEN "0 - 5 Days"    WHEN "CYCLE_TIME" > DURATION "5days" AND "CYCLE_TIME" <= DURATION "10days" THEN
# SQL parsing error: Expecting ). Line 1, Col: 234.
#   ipt"))   - FIRST (END_TIME) FILTER (      WHERE EVENT_NAME IN ("Release PO")))           < DURATION "14days")   / COUNT (CASE_ID) * 100      FROM "defaultview-545"
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 469.
#   ew-545"  WHERE EVENT_NAME MATCHES ("Create PO Item" "Create FI Invoice") ORDER BY 1 ASC NULLS FIRST FILL timeseries("MONTH")
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 370.
#   ents" FROM "defaultview-545" WHERE EVENT_NAME MATCHES ("Create PO Item") ORDER BY 1 ASC NULLS FIRST FILL TIMESERIES("MONTH"), NULL
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 292.
#   tomated Events"  ,"PO Company Name" AS "Company"  FROM "defaultview-545" ORDER BY 1 ASC NULLS FIRST FILL timeseries("MONTH"), NULL
# SQL parsing error: Expected END after CASE. Line 1, Col: 261.
#   N "RFQ"     WHEN event_name LIKE "%Auction%" THEN "Auction"     WHEN event_name LIKE "%Event%" THEN "Bidding"  --WHEN event_name LIKE "Create Sourcing Project" THEN "Create Sourcing Project"  --WHEN event_name
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 515.
#   ent_name MATCHES ("Create Sourcing Project" ~> "Close Sourcing Project") ORDER BY 1 ASC NULLS FIRST FILL TIMESERIES("MONTH"), NULL
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 321.
#   rcing Project"))) AS "Open Sourcing Projects"     FROM "defaultview-545" ORDER BY 1 ASC NULLS FIRST FILL TIMESERIES("MONTH"), NULL
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 634.
#   ent_name MATCHES ("Create Sourcing Project" ~> "Close Sourcing Project") ORDER BY 1 ASC NULLS FIRST FILL TIMESERIES("MONTH"), NULL
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 717.
#   ent_name MATCHES ("Create Sourcing Project" ~> "Close Sourcing Project") ORDER BY 1 ASC NULLS FIRST FILL TIMESERIES("MONTH"), NULL
# SQL parsing error: Expecting ). Line 1, Col: 369.
#   efaultview-545" WHERE EVENT_NAME MATCHES ("Create Auction"~>"Auction: Bidding ends; event moves to ""Pending Selection"" state")
# SQL parsing error: Expecting ). Line 1, Col: 429.
#   E MATCHES ("RFP: Publish Event; Invitation for participants" ~> "RFP: Bidding ends; event moves to ""Pending Selection"" state")
# SQL parsing error: Expecting ). Line 1, Col: 430.
#   S         ("RFI: Publish Event; Invitation for participants"~>  "RFI: Bidding ends; event moves to ""Pending Selection"" state")
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 487.
#   ES ("RFP Approved" ~> "RFP: Publish Event; Invitation for participants") ORDER BY 1 ASC NULLS FIRST FILL timeseries("MONTH"), NULL
# SQL parsing error: Expecting ). Line 1, Col: 1371.
#   ltview-545"  WHERE EVENT_NAME MATCHES ("Create Auction" ~>  "Auction: Bidding ends; event moves to ""Pending Selection"" state")  )  AS SUB ORDER BY 1
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 204.
#   SELECT FIRST (END_TIME))) AS "Overall Cycle Time" FROM "defaultview-545" ORDER BY 1 ASC NULLS FIRST FILL timeseries("MONTH"), NULL
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 575.
#     )) )*100) AS "Number of Suppliers Participated" FROM "defaultview-545" ORDER BY 1 ASC NULLS FIRST FILL timeseries("MONTH"), NULL
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 475.
#   RFP"~>"RFP: Awarding; announcement to participant who has been awarded") ORDER BY 1 ASC NULLS FIRST FILL timeseries("MONTH"), NULL
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 392.
#   view-545" WHERE EVENT_NAME MATCHES ("Create RFI" ~>  "RFI: Close Event") ORDER BY 1 ASC NULLS FIRST FILL timeseries("MONTH"), NULL
# SQL parsing error: Expecting ). Line 1, Col: 503.
#   ultview-545" WHERE EVENT_NAME MATCHES ("Create Auction" ~>  "Auction: Bidding ends; event moves to ""Pending Selection"" state") ORDER BY 1 ASC NULLS FIRST --FILL timeseries("MONTH"), NULL
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 582.
#   vent moves to ""Pending Selection"" state" ~>  "Close Sourcing Project") ORDER BY 1 ASC NULLS FIRST FILL timeseries("MONTH"), NULL
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 501.
#   S ("RFI Approved" ~>  "RFI: Publish Event; Invitation for participants") ORDER BY 1 ASC NULLS FIRST FILL timeseries("MONTH"), NULL
# SQL parsing error: Expecting ). Line 1, Col: 553.
#   E MATCHES ("RFI: Publish Event; Invitation for participants" ~> "RFI: Bidding ends; event moves to ""Pending Selection"" state")
# SQL parsing error: Expecting ). Line 1, Col: 511.
#   ultview-545" WHERE EVENT_NAME MATCHES ("Create Auction" ~>  "Auction: Bidding ends; event moves to ""Pending Selection"" state") ORDER BY 1 ASC NULLS FIRST FILL timeseries("MONTH"), NULL
# SQL parsing error: Expecting ). Line 1, Col: 99.
#   SELECT   COUNT (CASE_ID) FILTER (WHERE EVENT_NAME MATCHES (      "Create RFP"   ~> ("RFP Cancelled"|"RFP: Event cancelled")         ))   / COUNT (CASE_ID) FILTER (WHERE EVENT_NAME MATCHES ("Create RF
# SQL parsing error: Expecting ). Line 1, Col: 130.
#   SELECT   COUNT (DISTINCT CASE_ID) FILTER (WHERE EVENT_NAME MATCHES (     "Create RFP"      ~> ("RFP: Event edited and republished"|"RFP: Event resumed"| "RFP: Event reopened")          ))   / COUNT (DISTINCT CASE_ID) FILTER (WHERE
# SQL parsing error: Expecting ). Line 1, Col: 110.
#   SELECT   COUNT (DISTINCT CASE_ID) FILTER (WHERE EVENT_NAME MATCHES (     "Create RFP"      ~> ("RFP Withdrawn")          ))   / COUNT (DISTINCT CASE_ID) FILTER (WHERE EVENT_NAME MATCHES ("Create RFP"))      * 1
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 114.
#   COUNT(case_id)  FILTER  (WHERE EVENT_NAME MATCHES ("Create RFP" ~> "Create Sourcing Project")) as ""Create RFP" ~> "Create Sourcing Project"", COUNT(case_id)  FILTER  (WHERE EVENT_NAME MATCHES ("RFP Approve
# SQL parsing error: Expecting ). Line 1, Col: 187.
#    (         "RFP: Publish Event; Invitation for participants" ~> "RFP: Bidding ends; event moves to ""Pending Selection"" state"       )   ) / COUNT (CASE_ID) FILTER (     WHERE       EVENT_NAME MATCHES ("RFP: Publish Ev
# SQL parsing error: Expecting ). Line 1, Col: 204.
#   proved" ~> "RFP: Publish Event; Invitation for participants" ~> "RFP: Bidding ends; event moves to ""Pending Selection"" state" ~> "RFP: Close Event"       )   ) / COUNT (CASE_ID) FILTER (     WHERE       EVENT_NAME MAT
# SQL parsing error: Expecting ). Line 1, Col: 110.
#   SELECT   COUNT (DISTINCT CASE_ID) FILTER (WHERE EVENT_NAME MATCHES (     "Create RFI"      ~> ("RFI Withdrawn")          ))   / COUNT (DISTINCT CASE_ID) FILTER (WHERE EVENT_NAME MATCHES ("Create RFI"))      * 1
# SQL parsing error: Expecting ). Line 1, Col: 99.
#   SELECT   COUNT (CASE_ID) FILTER (WHERE EVENT_NAME MATCHES (      "Create RFI"   ~> ("RFI Cancelled"|"RFI: Event cancelled")         ))   / COUNT (CASE_ID) FILTER (WHERE EVENT_NAME MATCHES ("Create RF
# SQL parsing error: Expecting ). Line 1, Col: 130.
#   SELECT   COUNT (DISTINCT CASE_ID) FILTER (WHERE EVENT_NAME MATCHES (     "Create RFP"      ~> ("RFI: Event edited and republished"|"RFI: Event resumed"| "RFI: Event reopened")          ))   / COUNT (DISTINCT CASE_ID) FILTER (WHERE
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 114.
#   COUNT(case_id)  FILTER  (WHERE EVENT_NAME MATCHES ("Create RFI" ~> "Create Sourcing Project")) as ""Create RFI" ~> "Create Sourcing Project"", COUNT(case_id)  FILTER  (WHERE EVENT_NAME MATCHES ("RFI Approve
# SQL parsing error: Expecting ). Line 1, Col: 187.
#    (         "RFI: Publish Event; Invitation for participants" ~> "RFI: Bidding ends; event moves to ""Pending Selection"" state"       )   ) / COUNT (CASE_ID) FILTER (     WHERE       EVENT_NAME MATCHES ("RFI: Publish Ev
# SQL parsing error: Expecting ). Line 1, Col: 204.
#   proved" ~> "RFI: Publish Event; Invitation for participants" ~> "RFI: Bidding ends; event moves to ""Pending Selection"" state" ~> "RFI: Close Event"       )   ) / COUNT (CASE_ID) FILTER (     WHERE       EVENT_NAME MAT
# SQL parsing error: Expecting ). Line 1, Col: 195.
#      "Auction: Publish Event; Invitation for participants" ~> "Auction: Bidding ends; event moves to ""Pending Selection"" statee"       )   ) / COUNT (CASE_ID) FILTER (     WHERE       EVENT_NAME MATCHES ("Auction: Publi
# SQL parsing error: Expecting ). Line 1, Col: 195.
#      "Auction: Publish Event; Invitation for participants" ~> "Auction: Bidding ends; event moves to ""Pending Selection"" statee" ~> "RFI: Close Event"       )   ) / COUNT (CASE_ID) FILTER (     WHERE       EVENT_NAME MA
# SQL parsing error: Required keyword: 'this' missing for <class 'sqlglot.expressions.BitwiseXor'>. Line 1, Col: 228.
#   "     ~> "Receive Invoice"     ~> "Reconcile Invoice"     ~> "Approve Invoice"     ~> "Pay Invoice" $         ))   / COUNT (CASE_ID) FILTER (WHERE EVENT_NAME MATCHES ("Pay Invoice"))      * 100 FROM "d
# SQL parsing error: Expecting ). Line 1, Col: 155.
#    EVENT_NAME MATCHES (     "Create PR item" ~>     "Create PO Item" ~>     "Receive PO item" ~>     ("Receive Invoice" ~> "Reconcile Invoice") ~>     "Pay Invoice"))   / COUNT (CASE_ID) FILTER (WHERE EVENT_NAME MATCHES
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 419.
#   ULL))          * 100 AS "Late Payment Rate"       FROM "defaultview-545" ORDER BY 1 ASC NULLS FIRST FILL TIMESERIES("MONTH"), NULL
# SQL parsing error: Expecting ). Line 1, Col: 281.
#    EVENT_NAME MATCHES (     "Create PR item" ~>     "Create PO Item" ~>     "Receive PO item" ~>     ("Receive Invoice" ~> "Reconcile Invoice") ~>     "Pay Invoice"))   / COUNT (CASE_ID)     * 100 AS "Conformance Rate"
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 532.
#   l reconciled invoices Over Time"                  FROM "defaultview-545" ORDER BY 1 ASC NULLS FIRST FILL TIMESERIES("MONTH"), NULL
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 345.
#   e%")))   / COUNT (CASE_ID) * 100 AS "Change Rate" FROM "defaultview-545" ORDER BY 1 ASC NULLS FIRST FILL timeseries("MONTH"), NULL
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 457.
#   tview-545" WHERE event_name MATCHES ("Create PO Item" "Receive Invoice") ORDER BY 1 ASC NULLS FIRST FILL TIMESERIES("MONTH"), NULL
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 295.
#   NC("day", NOW())) AS "Number of Invoices Overdue" FROM "defaultview-545" ORDER BY 1 ASC NULLS FIRST FILL timeseries("MONTH"), NULL
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 300.
#   defaultview-545" WHERE "Last Invoice Reconciliation Status" = "Rejected" ORDER BY 1 ASC NULLS FIRST FILL timeseries("MONTH"), NULL
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 292.
#   m Total Amount") AS "PO Item Amount" FROM "defaultview-545" GROUP BY 1,2 ORDER BY 1 ASC NULLS FIRST FILL timeseries("MONTH"), NULL LIMIT 25
# SQL parsing error: Expected END after CASE. Line 1, Col: 356.
#    ) > DURATION "0day"     AND (       "Last Invoice Payment Date" - "Last Invoice Due Date"     ) <= DURATION "7day" THEN "0-7 days after Due Date"     WHEN (       "Last Invoice Payment Date" - "Last Invoice
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 314.
#   Date" IS NOT NULL)) * 100 AS "Late Payment Rate%" FROM "defaultview-545" ORDER BY 1 ASC NULLS FIRST FILL timeseries("MONTH"), NULL
# SQL parsing error: Expecting ). Line 1, Col: 636.
#   Last Invoice Payment Date"  AND "Last Invoice Due Date" - "Last Invoice Accounting Date" < DURATION "7days"        ) AS "Short Payment Terms",       count("Last Invoice Id") FILTER (         WHERE
# SQL parsing error: Expecting ). Line 1, Col: 859.
#   ENT_NAME = "Pay Invoice"  AND ("Last Invoice Payment Date"   - "Last Invoice Due Date")  > DURATION "1day")   / COUNT (DISTINCT "Last Invoice Id")  FILTER (WHERE EVENT_NAME = "Pay Invoice" )  ) * 100 AS "La
# SQL parsing error: Expected END after CASE. Line 1, Col: 356.
#    ) > DURATION "0day"     AND (       "Last Invoice Payment Date" - "Last Invoice Due Date"     ) <= DURATION "7day" THEN "0-7 days after Due Date"     WHEN (       "Last Invoice Payment Date" - "Last Invoice
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 213.
#   m Total Amount",  "PO Business Unit" FROM "defaultview-545" GROUP BY 1,3 ORDER BY 1 ASC NULLS FIRST FILL timeseries("QUARTER") LIMIT 500
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 214.
#    Total Amount",  "PO Item Line Type" FROM "defaultview-545" GROUP BY 1,3 ORDER BY 1 ASC NULLS FIRST FILL timeseries("QUARTER") LIMIT 500
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 288.
#   ine Type" = "Catalog" OR "PO Item Line Type" = "NonCatalog" GROUP BY 1,3 ORDER BY 1 ASC NULLS FIRST FILL timeseries("MONTH") LIMIT 100
# SQL parsing error: Expecting ). Line 1, Col: 230.
#   )   - FIRST (END_TIME) FILTER (      WHERE EVENT_NAME IN ("Approve Invoice")))           < DURATION "14days")   / COUNT (CASE_ID) * 100      FROM "defaultview-545"
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 489.
#   tview-545"  WHERE EVENT_NAME MATCHES ("Create PR Item" ~> "Pay Invoice") ORDER BY 1 ASC NULLS FIRST FILL timeseries("QUARTER")
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 495.
#   ew-545"  WHERE EVENT_NAME MATCHES ("Create PR Item" ~> "Create PO Item") ORDER BY 1 ASC NULLS FIRST FILL timeseries("MONTH")
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 493.
#   view-545"  WHERE EVENT_NAME MATCHES ("Receive Invoice" ~> "Pay Invoice") ORDER BY 1 ASC NULLS FIRST FILL timeseries("MONTH")
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 206.
#      - "Issue Created Date" ) AS "Resolution Time" FROM "defaultview-545"  ORDER BY 1 ASC NULLS FIRST FILL timeseries("MONTH") LIMIT 500
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 272.
#   nt",     DATE_TRUNC("MONTH", (SELECT FIRST(end_time))) as "Month"   FROM "defaultview-545" ) AS SUB FILL TIMESERIES("MONTH"), NULL
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 204.
#   Date" - "Issue Created Date") AS "Response Time" FROM "defaultview-545"  ORDER BY 1 ASC NULLS FIRST FILL timeseries("MONTH") LIMIT 500
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 210.
#   A Definition Count") * 100 AS "SLA Breach Ratio" FROM "defaultview-545"  ORDER BY 1 ASC NULLS FIRST FILL timeseries("MONTH") LIMIT 500
# SQL parsing error: Required keyword: 'true' missing for <class 'sqlglot.expressions.If'>. Line 1, Col: 158.
#   ,   "Cycle Type",   "Breached",   "Paused",   "Breach Time",   IF ("Breach Time" - NOW() < DURATION "0days", "Breach Time" - NOW(), NULL) as "Remaining Time",   NOW()-"Start Time" as "Elapsed time" FROM FLAT
# SQL parsing error: Required keyword: 'this' missing for <class 'sqlglot.expressions.BitwiseXor'>. Line 1, Col: 298.
#   ely Processed" -> "Post Goods Issue" -> "Create Invoice" -> "Post Invoice" ~> "Clear Invoice"       )   ) / COUNT (CASE_ID) FILTER (     WHERE       EVENT_NAME MATCHES ("Clear Invoice")   ) * 100 FROM
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 688.
#   ew-545" WHERE   event_name MATCHES ("Post Invoice" ~> "Clear Invoice") ORDER BY   1 ASC NULLS FIRST FILL TIMESERIES("MONTH"),   NULL
# SQL parsing error: Required keyword: 'this' missing for <class 'sqlglot.expressions.BitwiseXor'>. Line 1, Col: 403.
#   essed" -> "Post Goods Issue" -> "Create Invoice" -> "Post Invoice" ~> "Clear Invoice"               )   ) / COUNT (CASE_ID) FILTER (     WHERE       EVENT_NAME MATCHES ("Clear Invoice")   ) * 100 AS "C
# SQL parsing error: Required keyword: 'this' missing for <class 'sqlglot.expressions.BitwiseXor'>. Line 1, Col: 518.
#   efaultview-545" WHERE   event_name MATCHES (^"Create Sales Order Item" ~> "Create Outbound Delivery") ORDER BY   1 ASC NULLS FIRST FILL TIMESERIES("MONTH")
# SQL parsing error: Expecting ). Line 1, Col: 184.
#   TER (     WHERE       BEHAVIOUR (         "EventCreatedByUserType" IN ("System", "Service")       ) AS automation MATCHES (automation)   ) / COUNT ("event_name") FILTER (     WHERE       BEHAVIOUR (
# SQL parsing error: Required keyword: 'this' missing for <class 'sqlglot.expressions.BitwiseXor'>. Line 1, Col: 298.
#   ely Processed" -> "Post Goods Issue" -> "Create Invoice" -> "Post Invoice" ~> "Clear Invoice"       )   ) / COUNT (CASE_ID) FILTER (     WHERE       EVENT_NAME MATCHES ("Clear Invoice")   ) * 100 FROM
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 488.
#   NT (CASE_ID) * 100 AS "On-time delivery rate" FROM   "defaultview-545" ORDER BY   1 ASC NULLS FIRST FILL TIMESERIES("MONTH"),   NULL
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 451.
#   vered"   ) / COUNT (CASE_ID) * 100 AS "OTIFc" FROM   "defaultview-545" ORDER BY   1 ASC NULLS FIRST FILL TIMESERIES("Month"),   NULL
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 402.
#    ("Create Invoice")))) AS "AVG Cycle Time"       FROM "defaultview-545"  ORDER BY 1 ASC NULLS FIRST FILL timeseries("MONTH")
# SQL parsing error: Expecting ). Line 1, Col: 393.
#   ME) FILTER (      WHERE EVENT_NAME IN ("Post Goods Issue")) as PGIdate     ,"InvoiceCompanyCode" AS "Company"     --,"SalesDocCustomerCountry" AS "Country" FROM FLATTEN("defaultview-545") ) as sub WHERE Delive
# SQL parsing error: Required keyword: 'this' missing for <class 'sqlglot.expressions.BitwiseXor'>. Line 1, Col: 321.
#   " WHERE event_name MATCHES(^"Create Sales Order Item" ~> "Create Outbound Delivery"~>"Clear Invoice") ORDER BY 2 DESC NULLS LAST LIMIT 10
# SQL parsing error: Expecting ). Line 1, Col: 397.
#   E) FILTER (      WHERE EVENT_NAME IN ("Goods Delivered")) as ClearDate     ,"InvoiceCompanyCode" AS "Company"     --,"SalesDocCustomerCountry" AS "Country" FROM FLATTEN("defaultview-545") ) as sub WHERE Delive
# SQL parsing error: Required keyword: 'this' missing for <class 'sqlglot.expressions.BitwiseXor'>. Line 1, Col: 663.
#   " WHERE event_name MATCHES(^"Create Sales Order Item" ~> "Create Outbound Delivery"~>"Clear Invoice")  AND "Create Sales Order Item" IS NOT NULL  AND "Create Outbound Delivery"IS NOT NULL     AND "Clea
# SQL parsing error: Expecting ). Line 1, Col: 145.
#        LAST("InvoiceAccountingClearingDate")       WHERE         ((NOW() - LAST(end_time)) < DURATION "365days")     ) - (       SELECT         FIRST("InvoiceAccountingDocumentDate")       WHERE         ((NOW()
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 568.
#    / COUNT (CASE_ID) * 100 AS "No payment rate" FROM   "defaultview-545" ORDER BY   1 ASC NULLS FIRST FILL TIMESERIES("MONTH")
# SQL parsing error: Expecting ). Line 1, Col: 167.
#   ("event_name") FILTER (     WHERE       BEHAVIOUR (         EVENT_NAME LIKE "Change%Price%"       ) AS CHANGE MATCHES (CHANGE)   ) AS "# Price Changes" FROM   FLATTEN("defaultview-545") ORDER BY   1 ASC
# SQL parsing error: Expecting ). Line 1, Col: 117.
#   ("event_name") FILTER (     WHERE       BEHAVIOUR (         EVENT_NAME LIKE "Change%Price%"       ) AS created_with_dialog MATCHES (created_with_dialog)   ),   "SalesDocCustomerCompany" AS "Customer" FR
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 333.
#        WHERE       event_name = "Create Invoice Cancellation"   ) AS sub ORDER BY   1 ASC NULLS FIRST FILL TIMESERIES("MONTH"),   NULL
# SQL parsing error: Expecting ). Line 1, Col: 115.
#   T("event_name") FILTER (     WHERE       BEHAVIOR (         event_name LIKE "Reject Sales%"       ) AS rejections MATCHES (rejections)   ) FROM   FLATTEN("defaultview-545")
# SQL parsing error: Expecting ). Line 1, Col: 151.
#   ted") FILTER (     WHERE       BEHAVIOR (         event_name LIKE  "%Invoice%Cancellation%"       ) AS cancelled MATCHES (cancelled)   ) FROM   FLATTEN("defaultview-545")
# SQL parsing error: Expecting ). Line 1, Col: 714.
#   reator = Invoice Clearing Creator") AS "# SDs with Invoice Creator = Invoice Clearer" FROM ( SELECT distinct   --InvoiceCompanyCode,   SalesDocSalesOrganization,   SalesDocCustomerCountry,   SalesDocCustomerC
# SQL parsing error: Expecting ). Line 1, Col: 766.
#   HEN "cleared"     WHEN (       DATE_TRUNC("day", NOW()) - "InvoiceNetPaymentTermsPeriod" > DURATION "0day"     )     AND (       DATE_TRUNC("day", NOW()) - "InvoiceNetPaymentTermsPeriod" <= DURATION "3day"
# SQL parsing error: Expecting ). Line 1, Col: 184.
#   TER (     WHERE       BEHAVIOUR (         "EventCreatedByUserType" IN ("System", "Service")       ) AS automated MATCHES (automated)   ) / COUNT ("event_name") FILTER (           WHERE             "Even
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 745.
#   any" FROM   "defaultview-545" WHERE   "InvoiceCompanyCode" IS NOT NULL ORDER BY   1 ASC NULLS FIRST FILL TIMESERIES("MONTH"),   NULL
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 865.
#   ory" FROM   "defaultview-545" WHERE   "InvoiceCompanyCode" IS NOT NULL ORDER BY   1 ASC NULLS FIRST FILL TIMESERIES("MONTH"),   NULL
# SQL parsing error: Expecting ). Line 1, Col: 734.
#   R event_name LIKE "%Post Invoice%"           OR event_name LIKE "%Clear Invoice%"         )       ) AS automated MATCHES (automated)   ) / COUNT("event_name") FILTER (           WHERE             "Event
# SQL parsing error: Expecting ). Line 1, Col: 188.
#   ByUserType" IN ("System", "Service")         AND (event_name LIKE "Create Quotation Item%")       ) AS automated MATCHES (automated)   ) / COUNT("event_name") FILTER (           WHERE             "Event
# SQL parsing error: Expecting ). Line 1, Col: 172.
#      "EventCreatedByUserType" IN ("System", "Service")         AND (event_name LIKE "Clear%")       ) AS automated MATCHES (automated)   ) / COUNT("event_name") FILTER (           WHERE             "Event
# SQL parsing error: Expecting ). Line 1, Col: 243.
# ...
#   t Percentage1" <> 0 OR "Last Inv. Item Cash Discount Percentage2" <> 0) ORDER BY   1 ASC NULLS LAST FILL TIMESERIES("MONTH")
# SQL parsing error: Required keyword: 'this' missing for <class 'sqlglot.expressions.BitwiseXor'>. Line 1, Col: 202.
#   "Create PO Item" ~> "Receive invoice" ~> "Reconcile invoice" ~>  "Approve Invoice" ~> "Pay Invoice" $)  ) / COUNT(case_id) * 100 FROM "defaultview-545"
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 370.
#   ents" FROM "defaultview-545" WHERE EVENT_NAME MATCHES ("Create PO Item") ORDER BY 1 ASC NULLS FIRST FILL TIMESERIES("MONTH"), NULL
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 292.
#   tomated Events"  ,"PO Company Name" AS "Company"  FROM "defaultview-545" ORDER BY 1 ASC NULLS FIRST FILL timeseries("MONTH"), NULL
# SQL parsing error: Expecting ). Line 1, Col: 230.
#   )   - FIRST (END_TIME) FILTER (      WHERE EVENT_NAME IN ("Approve Invoice")))           < DURATION "14days")   / COUNT (CASE_ID) * 100      FROM "defaultview-545"
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 489.
#   tview-545"  WHERE EVENT_NAME MATCHES ("Create PR Item" ~> "Pay Invoice") ORDER BY 1 ASC NULLS FIRST FILL timeseries("QUARTER")
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 495.
#   ew-545"  WHERE EVENT_NAME MATCHES ("Create PR Item" ~> "Create PO Item") ORDER BY 1 ASC NULLS FIRST FILL timeseries("MONTH")
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 493.
#   view-545"  WHERE EVENT_NAME MATCHES ("Receive Invoice" ~> "Pay Invoice") ORDER BY 1 ASC NULLS FIRST FILL timeseries("MONTH")
# SQL parsing error: Required keyword: 'this' missing for <class 'sqlglot.expressions.BitwiseXor'>. Line 1, Col: 228.
#   "     ~> "Receive Invoice"     ~> "Reconcile Invoice"     ~> "Approve Invoice"     ~> "Pay Invoice" $         ))   / COUNT (CASE_ID) FILTER (WHERE EVENT_NAME MATCHES ("Pay Invoice"))      * 100 FROM "d
# SQL parsing error: Expecting ). Line 1, Col: 155.
#    EVENT_NAME MATCHES (     "Create PR item" ~>     "Create PO Item" ~>     "Receive PO item" ~>     ("Receive Invoice" ~> "Reconcile Invoice") ~>     "Pay Invoice"))   / COUNT (CASE_ID) FILTER (WHERE EVENT_NAME MATCHES
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 419.
#   ULL))          * 100 AS "Late Payment Rate"       FROM "defaultview-545" ORDER BY 1 ASC NULLS FIRST FILL TIMESERIES("MONTH"), NULL
# SQL parsing error: Expecting ). Line 1, Col: 281.
#    EVENT_NAME MATCHES (     "Create PR item" ~>     "Create PO Item" ~>     "Receive PO item" ~>     ("Receive Invoice" ~> "Reconcile Invoice") ~>     "Pay Invoice"))   / COUNT (CASE_ID)     * 100 AS "Conformance Rate"
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 532.
#   l reconciled invoices Over Time"                  FROM "defaultview-545" ORDER BY 1 ASC NULLS FIRST FILL TIMESERIES("MONTH"), NULL
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 345.
#   e%")))   / COUNT (CASE_ID) * 100 AS "Change Rate" FROM "defaultview-545" ORDER BY 1 ASC NULLS FIRST FILL timeseries("MONTH"), NULL
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 457.
#   tview-545" WHERE event_name MATCHES ("Create PO Item" "Receive Invoice") ORDER BY 1 ASC NULLS FIRST FILL TIMESERIES("MONTH"), NULL
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 295.
#   NC("day", NOW())) AS "Number of Invoices Overdue" FROM "defaultview-545" ORDER BY 1 ASC NULLS FIRST FILL timeseries("MONTH"), NULL
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 300.
#   defaultview-545" WHERE "Last Invoice Reconciliation Status" = "Rejected" ORDER BY 1 ASC NULLS FIRST FILL timeseries("MONTH"), NULL
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 292.
#   m Total Amount") AS "PO Item Amount" FROM "defaultview-545" GROUP BY 1,2 ORDER BY 1 ASC NULLS FIRST FILL timeseries("MONTH"), NULL LIMIT 25
# SQL parsing error: Expected END after CASE. Line 1, Col: 356.
#    ) > DURATION "0day"     AND (       "Last Invoice Payment Date" - "Last Invoice Due Date"     ) <= DURATION "7day" THEN "0-7 days after Due Date"     WHEN (       "Last Invoice Payment Date" - "Last Invoice
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 314.
#   Date" IS NOT NULL)) * 100 AS "Late Payment Rate%" FROM "defaultview-545" ORDER BY 1 ASC NULLS FIRST FILL timeseries("MONTH"), NULL
# SQL parsing error: Expecting ). Line 1, Col: 636.
#   Last Invoice Payment Date"  AND "Last Invoice Due Date" - "Last Invoice Accounting Date" < DURATION "7days"        ) AS "Short Payment Terms",       count("Last Invoice Id") FILTER (         WHERE
# SQL parsing error: Expecting ). Line 1, Col: 859.
#   ENT_NAME = "Pay Invoice"  AND ("Last Invoice Payment Date"   - "Last Invoice Due Date")  > DURATION "1day")   / COUNT (DISTINCT "Last Invoice Id")  FILTER (WHERE EVENT_NAME = "Pay Invoice" )  ) * 100 AS "La
# SQL parsing error: Expected END after CASE. Line 1, Col: 356.
#    ) > DURATION "0day"     AND (       "Last Invoice Payment Date" - "Last Invoice Due Date"     ) <= DURATION "7day" THEN "0-7 days after Due Date"     WHEN (       "Last Invoice Payment Date" - "Last Invoice
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 213.
#   m Total Amount",  "PO Business Unit" FROM "defaultview-545" GROUP BY 1,3 ORDER BY 1 ASC NULLS FIRST FILL timeseries("QUARTER") LIMIT 500
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 214.
#    Total Amount",  "PO Item Line Type" FROM "defaultview-545" GROUP BY 1,3 ORDER BY 1 ASC NULLS FIRST FILL timeseries("QUARTER") LIMIT 500
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 288.
#   ine Type" = "Catalog" OR "PO Item Line Type" = "NonCatalog" GROUP BY 1,3 ORDER BY 1 ASC NULLS FIRST FILL timeseries("MONTH") LIMIT 100
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 199.
#   ") AS "PO Item Amount (INR)", "PO Item Line Type" FROM "defaultview-545" ORDER BY 1 ASC NULLS FIRST FILL timeseries("QUARTER") LIMIT 500
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 213.
#   m Amount (INR)",  "PO Business Unit" FROM "defaultview-545" GROUP BY 1,3 ORDER BY 1 ASC NULLS FIRST FILL timeseries("QUARTER") LIMIT 500
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 275.
#   NR)") * 100 AS "% of PO Spend on Catalog", "PO Business Unit" FROM "defaultview-545" ORDER BY 1 ASC FILL timeseries("QUARTER") LIMIT 500
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 278.
#   NR)") * 100 AS "% of PO Spend on Catalog", "PO Business Unit" FROM "defaultview-545" ORDER BY 1 ASC FILL timeseries("QUARTER") LIMIT 500
# SQL parsing error: Expected table name but got None. Line 1, Col: 116.
#   (DISTINCT "CASE_ID") AS "No .of Cases", AVG("Cycle Time") AS "Avg. Cycle Time", "Invoice Item Type" FROM --FLATTEN(  (   SELECT    CASE_ID,   (SELECT LAST (END_TIME)) - (SELECT FIRST (END_TIME)) AS "Cycle
# SQL parsing error: Expected table name but got None. Line 1, Col: 128.
#   ASE_ID") AS "No .of Cases", AVG("Cycle Time") AS "Avg. Cycle Time", "Invoice Reconciliation Status" FROM --FLATTEN(  (   SELECT    CASE_ID,   (SELECT LAST (END_TIME)) - (SELECT FIRST (END_TIME)) AS "Cycle
# SQL parsing error: Expected table name but got None. Line 1, Col: 124.
#   T "CASE_ID") AS "No .of Cases", AVG("Cycle Time") AS "Avg. Cycle Time", "Invoice Submission Method" FROM --FLATTEN(  (   SELECT    CASE_ID,   (SELECT LAST (END_TIME)) - (SELECT FIRST (END_TIME)) AS "Cycle
# SQL parsing error: Expected table name but got None. Line 1, Col: 129.
#   SE_ID") AS "No .of Cases", AVG("Cycle Time") AS "Avg. Cycle Time", "Invoice Reconciliation Outcome" FROM --FLATTEN(  (   SELECT    CASE_ID,   (SELECT LAST (END_TIME)) - (SELECT FIRST (END_TIME)) AS "Cycle
# SQL parsing error: Expecting ). Line 1, Col: 683.
#   S "Invoice Submission Method"   FROM "defaultview-545"   WHERE "PO Item Supplier ID" IS NOT NULL  ) AS SUB1 ) WHERE "Invoice Submission Method" in ("PaperViaICS","Paper Invoice") GROUP BY 1 ORDER BY 2 D
# SQL parsing error: Expecting ). Line 1, Col: 683.
#   S "Invoice Submission Method"   FROM "defaultview-545"   WHERE "PO Item Supplier ID" IS NOT NULL  ) AS SUB1 ) WHERE "Invoice Submission Method" in ("Online") GROUP BY 1 ORDER BY 2 DESC
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 230.
#   ))) AS "Avg. Cycle Time",  "PO Item Line Type" FROM "defaultview-545" ORDER BY 3, 1 ASC NULLS FIRST FILL timeseries("QUARTER"), NULL, GROUP
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 400.
#   D_TIME))) <= DATE "2022-06-30") AND ("PO Item Line Type" IS NOT NULL) ORDER BY 3, 1 ASC NULLS FIRST FILL timeseries("QUARTER"), NULL, GROUP LIMIT 500
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 400.
#   D_TIME))) <= DATE "2022-06-30") AND ("PO Item Line Type" IS NOT NULL) ORDER BY 3, 1 ASC NULLS FIRST FILL timeseries("QUARTER"), NULL, GROUP LIMIT 500
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 400.
#   D_TIME))) <= DATE "2022-06-30") AND ("PO Item Line Type" IS NOT NULL) ORDER BY 3, 1 ASC NULLS FIRST FILL timeseries("QUARTER"), NULL, GROUP LIMIT 500
# SQL parsing error: Required keyword: 'this' missing for <class 'sqlglot.expressions.BitwiseXor'>. Line 1, Col: 202.
#   "Create PO Item" ~> "Receive invoice" ~> "Reconcile invoice" ~>  "Approve Invoice" ~> "Pay Invoice" $)  ) / COUNT(case_id) * 100 FROM "defaultview-545"
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 147.
#   view-9" WHERE "Risk Class" = "Not evaluated" AND BEHAVIOUR          (event_name = "Create Invoice") AS create_invoice,          ("Risk Class" = "Not evaluated") AS no_risk_evaluation MATCHES (no_risk_ev
# SQL parsing error: Expecting ). Line 1, Col: 1075.
#   d                         FROM "defaultview-9") AS sub                  GROUP BY 1                  FILL TIMESERIES("month")                ) AS sub2        ) AS sub3
# SQL parsing error: Expecting ). Line 1, Col: 967.
#   d                         FROM "defaultview-9") AS sub                  GROUP BY 1                  FILL TIMESERIES("month")                ) AS sub2        ) AS sub3
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 147.
#   view-9" WHERE "Risk Class" = "Not evaluated" AND BEHAVIOUR          (event_name = "Create Invoice") AS create_invoice,          ("Risk Class" = "Not evaluated") AS no_risk_evaluation MATCHES (no_risk_ev
# SQL parsing error: Expecting ). Line 1, Col: 1075.
#   d                         FROM "defaultview-9") AS sub                  GROUP BY 1                  FILL TIMESERIES("month")                ) AS sub2        ) AS sub3
# SQL parsing error: Expecting ). Line 1, Col: 967.
#   d                         FROM "defaultview-9") AS sub                  GROUP BY 1                  FILL TIMESERIES("month")                ) AS sub2        ) AS sub3
# SQL parsing error: Expecting ). Line 1, Col: 75.
#    SELECT COUNT(case_id) FILTER (  WHERE (None - None    < DURATION None  AND None - None   < DURATION None  ) ) / COUNT(case_id) FILTER (  WHERE (NoneIS NOT NULL) ) * 100 FROM
# SQL parsing error: Expecting ). Line 1, Col: 72.
#    SELECT AVG(  (SELECT COUNT(event_name) FILTER (   WHERE event_name None)  ) / (SELECT COUNT(event_name))  ) * 100 FROM "defaultview-2"
# SQL parsing error: Expecting ). Line 1, Col: 75.
#    SELECT COUNT(case_id) FILTER (  WHERE (None - None    < DURATION None  AND None - None   < DURATION None  ) ) / COUNT(case_id) FILTER (  WHERE (None IS NOT NULL) ) * 100 FROM
# SQL parsing error: Expecting ). Line 1, Col: 70.
#    SELECT COUNT(case_id) FILTER (  WHERE (SELECT BOOL_OR(event_name None) AND BOOL_OR(None))) / COUNT(case_id) * 100 FROM "defaultview-2"
# SQL parsing error: Expecting ). Line 1, Col: 70.
#    SELECT COUNT(case_id) FILTER (  WHERE (SELECT BOOL_OR(event_name None))) / COUNT(case_id) * 100 FROM "defaultview-2"
# SQL parsing error: Expecting ). Line 1, Col: 71.
#    SELECT COUNT(case_id) FILTER (  WHERE (SELECT BOOL_OR (event_name None)  )) / COUNT(case_id) * 100 FROM "defaultview-2"
# SQL parsing error: Expecting ). Line 1, Col: 70.
#    SELECT COUNT(case_id) FILTER (  WHERE (SELECT BOOL_OR(event_name None))) / COUNT(case_id) FILTER (  WHERE (event_name MATCHES((None)))) * 100 FROM "defaultview-2"
# SQL parsing error: Expecting ). Line 1, Col: 70.
#    SELECT COUNT(case_id) FILTER (  WHERE (SELECT BOOL_OR(event_name None))) / COUNT(case_id) FILTER (  WHERE (event_name MATCHES((None)))) * 100 FROM "defaultview-2"
# SQL parsing error: Expecting ). Line 1, Col: 183.
#   event_name    IN (None))   -  FIRST(end_time) FILTER (WHERE event_name    IN (None))   ) < DURATION None ) / COUNT(case_id) FILTER (  WHERE (SELECT BOOL_OR(event_name IN (None)))  ) * 100 FROM "defaultvie
# SQL parsing error: Expecting ). Line 1, Col: 86.
#    SELECT COUNT(case_id) FILTER (  WHERE NOW() - (SELECT LAST(end_time)) > DURATION None   AND (SELECT FIRST(event_name) FILTER (    WHERE event_name IN (None))) IS NULL    ) FROM "default
# SQL parsing error: Expecting ). Line 1, Col: 112.
#   COUNT(case_id) FILTER (  WHERE (SELECT BOOL_OR(event_name IN (None)   AND None   AND event_name NOT None)  ) )/COUNT(case_id) * 100 FROM "defaultview-2"
# SQL parsing error: Expecting ). Line 1, Col: 72.
#    SELECT AVG(  (SELECT COUNT(event_name) FILTER (   WHERE event_name None))) FROM "defaultview-2"
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 147.
#   view-2" WHERE "Risk Class" = "Not evaluated" AND BEHAVIOUR          (event_name = "Create Invoice") AS create_invoice,          ("Risk Class" = "Not evaluated") AS no_risk_evaluation MATCHES (no_risk_ev
# SQL parsing error: Expecting ). Line 1, Col: 1075.
#   d                         FROM "defaultview-2") AS sub                  GROUP BY 1                  FILL TIMESERIES("month")                ) AS sub2        ) AS sub3
# SQL parsing error: Expecting ). Line 1, Col: 967.
#   d                         FROM "defaultview-2") AS sub                  GROUP BY 1                  FILL TIMESERIES("month")                ) AS sub2        ) AS sub3
# SQL parsing error: Expecting ). Line 1, Col: 168.
#   Close Incident"))  -(SELECT FIRST(end_time) WHERE event_name IN ("Create Incident"))) ) / (DURATION "15days") *100 FROM "defaultview-4"
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 147.
#   view-4" WHERE "Risk Class" = "Not evaluated" AND BEHAVIOUR          (event_name = "Create Invoice") AS create_invoice,          ("Risk Class" = "Not evaluated") AS no_risk_evaluation MATCHES (no_risk_ev
# SQL parsing error: Expecting ). Line 1, Col: 1075.
#   d                         FROM "defaultview-4") AS sub                  GROUP BY 1                  FILL TIMESERIES("month")                ) AS sub2        ) AS sub3
# SQL parsing error: Expecting ). Line 1, Col: 967.
#   d                         FROM "defaultview-4") AS sub                  GROUP BY 1                  FILL TIMESERIES("month")                ) AS sub2        ) AS sub3
# SQL parsing error: Invalid expression / Unexpected token. Line 1, Col: 147.
#   view-3" WHERE "Risk Class" = "Not evaluated" AND BEHAVIOUR          (event_name = "Create Invoice") AS create_invoice,          ("Risk Class" = "Not evaluated") AS no_risk_evaluation MATCHES (no_risk_ev
# SQL parsing error: Expecting ). Line 1, Col: 1075.
#   d                         FROM "defaultview-3") AS sub                  GROUP BY 1                  FILL TIMESERIES("month")                ) AS sub2        ) AS sub3
# SQL parsing error: Expecting ). Line 1, Col: 967.
#   d                         FROM "defaultview-3") AS sub                  GROUP BY 1                  FILL TIMESERIES("month")                ) AS sub2        ) AS sub3

# %%
df[['name','signalFragment','query','description',"parser_column_names","parser_values","parser_error","parser"]].describe().loc[['count','unique']]
# Out:
#          name signalFragment  query description parser_column_names  \
# count   11042          11042  11042       11042               11042
# unique   3634           4450   6444        1373                 262
#
#        parser_values parser_error parser
# count          11042        11042  11042
# unique          4204         1567      2

# %%
df[['parser']].value_counts()
# Out:
# parser
# Signavio    9476
# regexp      1566
# Name: count, dtype: int64

# %%
# get an element
indx=10 #4193
df.loc[[indx]]['signalFragment']
df.loc[[indx]][["workspace_name",'query','parser',"parser_column_names","parser_values"]]
#df[['query',"signalFragment","view","origin"]][indx:indx+1].values.tolist()[0]
# Out:
#               workspace_name  \
# 10  Solutions Demo Workspace
#
#                                                 query    parser  \
# 10  \nSELECT\nSUM("AR_AVGClearingDays" * "AR_Count...  Signavio
#
#    parser_column_names                                      parser_values
# 10                  []  ["AR_AVGClearingDays", "AR_CountClearedDocumen...

# %% [markdown]
# ## Filter out Signals without descriptions and with None descriptions - new data frame:  DF1

# %%
# Filter out Signals without descriptions and with None description
pd.set_option('display.max_colwidth', None)  
new_df = df[~df['description'].isnull()]
print("Without None decriptions", new_df.shape)

df1=new_df[new_df['description'] != "" ] # 4688 - > 1949 
df1=new_df # 4267 
print("Signals wiht Non-empty description",df1.shape)
figsize=(10,3)
df1[['name','signalFragment','query','description']].describe().loc[['count','unique']].plot(kind='bar',title="Siganls with non-empty descriptions",figsize=figsize)
df1[['name','signalFragment','query','description','view']].describe().loc[['count','unique']]
# Out:
# Without None decriptions (11042, 21)
# Signals wiht Non-empty description (11042, 21)
#          name signalFragment  query description   view
# count   11042          11042  11042       11042  11042
# unique   3634           4450   6444        1373     34

# %% [markdown]
# ### Drop duplicates in DF1

# %%
# Drop duplicates
print("Number of Signals before duplicates cleaning:",df1.shape)
columns=['name','description','signalFragment']  # 1949
#columns=['name','description','query']           # 3502
#columns=['name','query']                         # 3341
#columns=['name','description']                  # 1525
#columns=['name','signalFragment']               # 1860
df1.drop_duplicates(columns, keep='first',inplace=True)
print("Number of unique Signals with not-empty descriptions after duplicate cleaning: ",df1.shape)
df1[['name','description','signalFragment','view']].describe().loc[['count','unique']]
# Out:
# Number of Signals before duplicates cleaning: (11042, 21)
# Number of unique Signals with not-empty descriptions after duplicate cleaning:  (4881, 21)
#         name description signalFragment  view
# count   4881        4881           4881  4881
# unique  3634        1373           4450    27

# %%
df1[['meta']].value_counts()
# Out:
# meta
# dashboard        1833
# metric           1832
# investigation    1216
# Name: count, dtype: int64

# %% [markdown]
# ## Validate pandas col with signals against log on dataFrame DF1
#
# **26.44 mins** Number of API calls 4267   duration [mins]: 26.44 mins  0.3760855130297757 per signal call
# **11mins** :API validation for 1702 took: 0.38511105219709885 per signal call

# %%
### q="""SELECT
### SUM(
### 	(SELECT LAST(end_time)) - (SELECT FIRST(end_time))) FILTER (
### 		WHERE (SELECT LAST(event_name) IN (None))
###    )
### FROM "defaultview-9"
### """
### 
### dfp[dfp['process']== "demo01"][["query","APIvalidated","meta"]]

# %% [markdown]
# ### Run API Validation here new data frame DFP is used
#
# Number of API calls 4267   duration [mins]: 26.44 mins  0.3760855130297757 per signal call

# %%
df_test=df1.head(n=10)
print("Number of API calls",df1.shape[0],"  duration [mins]:", 0.38*df1.shape[0]/60," View: ",df1.iloc[0]['view'])
# Out:
# Number of API calls 4881   duration [mins]: 30.913  View:  defaultview-545

# %%
# 33m 37.4s Run Signals API calls 0.3 sec per signal
start = time.time()  
#dfp=df1[df1['process']== "demo01"]
dfp=df1
dfp[['APIvalidated','validationDataResponse','validationDataLength']] = dfp.apply(lambda x: API_validation(x.query,x.workspace_name, auth=auth), axis=1 ).to_list()
delta=time.time()-start
print(f"API validation for {dfp.shape[0]} took: {delta} {(delta)/dfp.shape[0]} per signal call") # 11 mins API validation for 1702 took: 0.38511105219709885 per signal call
# Out:
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'IncidentReassignmentCount'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'IncidentReassignmentCount'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'IncidentPriority'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'AR_AVGClearingDays'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'AR_AVGNetDueDateDays'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'AR_AVGClearingAfterNetDueDays'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'BillingRequest_RejectedCount'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'AutomationFlag'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'AR_LastClearingDate'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'AR_LastClearingDate'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'AR_LastNetDueDate'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'AR_LastClearingDate'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'AR_LastClearingDate'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'AR_LastClearingDate'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'AR_LastClearingDate'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'AR_InvoicedAmountInGlobalCurrency'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'BillingDoc_TotalCancelled'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'AR_CountDocuments'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'AR_PaidLateCount'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'BillingRequest_TotalCount'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'AR_CountClearedDocuments'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'BillingDoc_TotalCancelled'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'BillingDoc_TotalCount'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'AR_CountOpenDocuments'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'ARUniqueKey'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'ARUniqueKey'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'BillingRequest_RejectedCount'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'AR_ClearedAmountInGlobalCurrency'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'AR_InvoicedAmountInGlobalCurrency'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'AR_InvoicedAmountInGlobalCurrency'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'AmountInGlobalCurrency'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'AmountInGlobalCurrency'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'ODO Item Quantity'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'ODO Item Quantity'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'ODO Item Quantity'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'WT Activity Type'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'WT Activity Type'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'WT Activity Type'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'WT Activity Type'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'ODO Document Number'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'ODO Item Quantity'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'SO Item Document Number'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'SO Item Document Number'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Baseline Spend of Sourcing Project'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Baseline Spend of Sourcing Project'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Historic Total Cost'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Historic Total Cost'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Event Id'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Participating Suppliers'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Opportunity Expected Revenue Amount'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Opportunity Expected Revenue Amount'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Opportunity Expected Revenue Amount'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Opportunity Status'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Is Lead'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Opportunity Status'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Number of Tasks'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Opportunity Status'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Opportunity Status'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Is Lead'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Number of Tasks'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Number of Employees Change'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Number of Contacts'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Ticket Contract'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Ticket Account ID'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Effective Date'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Effective Date'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'MeterReadingTypeActual'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'MeterReadingTypeActual'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'LastInvoiceBillingKeyDate'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'MeterReadingScheduledReadingDate'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'MeterReadingScheduledReadingDate'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'MeterReadingScheduledReadingDate'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'MeterReadingScheduledReadingDate'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'EventCreatedByUserType'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'LastInvoiceAmount'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'LastInvoicePaymentDueDate'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Inv. Converted USD Amount'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Last Inv. Item Clearing Date'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Last Inv. Item Clearing Date'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Last Inv. Item Clearing Date'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Last Inv. Item Dunned On'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Event Created By User Type'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Last Inv. Item Clearing Date'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Last Inv. Item Clearing Date'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Last Inv. Item Due Date'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Last Inv. Item Clearing Date'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Inv. Converted USD Amount'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Last Inv. Item Clearing Date'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Last Inv. Item Clearing Date'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Last Inv. Item Clearing Date'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Event Created By User Type'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Last Inv. Item Clearing Date'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Last Inv. Item Due Date'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Last Inv. Item Clearing Date'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Last Inv. Item Dunned On'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Inv. Converted USD Amount'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'PO Item Total Net Order Value'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Event Created By User Type'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Last Inv. Item Net Payment Terms Period'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'PO Item Total Net Order Value'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Event Created By User Type'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Last Inv. Item Cash Discount Days 1'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Inv. Converted USD Amount'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Issue Type'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Satisfaction'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Issue Resolution Date'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'First Response Date'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Current Priority'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Current Status category'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'SLAs Breached'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'SLAs Breached'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'SLAs Completed'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'SLAs Ongoing'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Current Status category'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'SLAs Paused'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Resolution'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'SLAs Started'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'UD Code'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal InvalidArguments: Invalid arguments IN: [TypeCtx { data_type: DictionaryUtf8, type_level: Event }, TypeCtx { data_type: DictionaryUtf8, type_level: Scalar }] for function IN with arguments [TypeCtx { data_type: DictionaryUtf8, type_level: Event }, TypeCtx { data_type: DictionaryUtf8, type_level: Scalar }]
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'UD Code'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal InvalidArguments: Invalid arguments IN: [TypeCtx { data_type: DictionaryUtf8, type_level: Event }, TypeCtx { data_type: DictionaryUtf8, type_level: Scalar }] for function IN with arguments [TypeCtx { data_type: DictionaryUtf8, type_level: Event }, TypeCtx { data_type: DictionaryUtf8, type_level: Scalar }]
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Event Created By User Type'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Event Created By User Type'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Planned Inspection End Date'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Planned Inspection End Date'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Planned Inspection End Date'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'AR_AVGClearingDays'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'AR_AVGNetDueDateDays'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Project_CreateToEndTime'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Project_CreateToStartTime'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Project_PlannedToActualClosingTime'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Project_StartToEndTime'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'TSR_AVGCreationTillApprovalTime'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'BillingRequest_RejectedCount'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'BillingDoc_TotalCancelled'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'BillingDoc_TotalCancelled'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'AR_PaidLateCount'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'AR_CountDocuments'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'TSR_ApprovedDocsNumber'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'TSR_Count'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'TSR_CancelledDocsNumber'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Project_StageText'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'ARUniqueKey'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'TSR_Count'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'TSR_Count'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'AR_CountClearedDocuments'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Project_StageText'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Project_StageText'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Project_StageText'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Project_StageText'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Project_CreationAfterStartFlag'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Project_CreationAfterStartFlag'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Project_StageText'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Project_StageText'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Project_StageText'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Project_StageText'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Project_StageText'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Project_StageText'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Project_StageText'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Project_StageText'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'CostDoc_EnterDocAfterProjectClosingCount'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'CostDoc_EnterDocAfterProjectClosingCount'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'TSR_HoursApproved'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'TSR_HoursCancelled'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'AR_ClearedAmountInGlobalCurrency'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'TSR_HoursChangedAfterApproval'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'TSR_HoursInProcess'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'TSR_HoursReleased'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'AR_InvoicedAmountInGlobalCurrency'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'AR_InvoicedAmountInGlobalCurrency'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'AmountInGlobalCurrency'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'ARUniqueKey'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'ClearingDate'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'AmountInGlobalCurrency'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'TSR_HoursApprovalRejected'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'PO Item Net Order Value'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'PO Item Last Requested Delivery Date'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'PO Item Last Requested Delivery Date'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'PO Item Last Requested Delivery Date'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'PO Item Last Requested Delivery Date'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'PO Item Last Requested Delivery Date'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'PO Item Last Requested Delivery Date'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Event Created By User Type'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Event Created By User Type'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Event Created By User Type'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'OppIsWon'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'OppIsWon'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'LeadConvertedDate'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'OppCloseDate'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'OppCloseDate'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'LeadId'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'OppAmount'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'OppAmount'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Job Requisition ID'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'DeliveryGoodsMovementOnTime'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'InvoiceAccountingClearingDate'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'InvoiceDueDate'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'InvoiceLastDunnedOn'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'InvoiceAccountingClearingDate'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'EventCreatedByUserType'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'InvoiceAccountingClearingDate'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'SalesDocId'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'DeliveryGoodsMovementOnTime'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'EventCreatedByUserType'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'EventCreatedByUserType'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'EventCreatedByUserType'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'EventCreatedByUserType'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'ProdOrderDelivCompleted'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'ProdOrderItemStatus'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'EventCreatedByUserType'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'ProdOrderItemStatus'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'ProdOrderItemStatus'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'ProdOrderBackflushCreationTime'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'ProdOrderVersionUsage'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'ProdOrderUnprocessedPPCPosting'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'ProdOrderActRelDate'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'ProdOrderActTechClosureDate'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'ProdOrderRoutingUsage'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'ProdOrderItemStatus'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'ProdOrderSchedFinishDate'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'ProdOrderItemStatus'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'ProdOrderPlanOrder'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Produced Delivered Quantity'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Planned Order Number'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Planned Order Number'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Event Created By User Type'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Scheduled Release Date'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Scheduled Finish Date'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Scheduled Start Date'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Scheduled Finish Date'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Scheduled Release Date'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Actual Delivery Date'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Actual Delivery Date'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Actual Delivery Date'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'FRO Delivery Date'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'FRO Delivery Date'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Order Actual Start'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Order Execution Status'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Order Actual Start'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Order Actual Start'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Order Actual Start'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Routing Step'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'SFC Build Quantity'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Order Execution Status'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Last FI Invoice Item Due Date'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Last FI Invoice Item Clearing Date'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'PO Item Net Order Value'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'PO Item Last Requested Delivery Date'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'PO Item Last Requested Delivery Date'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'PO Item Net Order Value in USD'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'PO Item Last Requested Delivery Date'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'PO Item Last Requested Delivery Date'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'PO Item Last Requested Delivery Date'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'PO Item Last Requested Delivery Date'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'PO Item Net Order Value in USD'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'PO Item Net Order Value in USD'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Last FI Invoice Item Due Date'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Number of Fallback Contract Clauses'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Number of Alternative Contract Clauses'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Number of Empty Contract Clauses'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Number of Preferred Contract Clauses'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Contract Expiration Type'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Contract Status'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Contract Source'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Contract Source'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Number of Preferred Contract Clauses'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Number of Alternative Contract Clauses'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Number of Alternative Contract Clauses'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Number of Alternative Contract Clauses'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Event Created By User Type'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Event Created By User Type'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'VIM Document ID'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'VIM Document ID'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'VIM Document ID'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Statistical Fcst Qty Error (%)'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Statistical Fcst Qty Bias (%)'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Product ID'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Forecast Open Output'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Statistical Fcst Qty Bias (%)'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Product ID'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Product ID'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Product ID'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Inventory Target'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'MONTH'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Inventory Target'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Sales Forecast Qty'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Marketing Forecast Qty'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Inventory Target'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Capacity Utilization'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Product ID'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Product ID'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Product ID'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'MONTH'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'ABC Id'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'ABC Id'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Step Status'
# ...
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'PO Item Amount (INR)'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'PO Item Amount (INR)'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'PO Item Amount (INR)'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'PO Item Amount (INR)'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'PO Item Amount (INR)'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'PO Item Amount (INR)'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'PO Item Amount (INR)'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'PO Item Amount (INR)'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'PO Item Amount (INR)'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'PO Item Amount (INR)'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'PO Item Amount (INR)'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'PO Item Amount (INR)'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'PO Item Amount (INR)'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'PO Item Amount (INR)'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'PO Item Amount (INR)'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'PO Item Amount (INR)'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'PO Item Amount (INR)'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Is Invoice Reconciled?'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Is Invoice Reconciled?'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Invoice Item Type'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal WhereClauseMustReturnBool: Got 'TypeCtx { data_type: Boolean, type_level: Event }', must be 'Boolean' at scalar or case level
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Invoice Submission Method'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Is Invoice Reconciled?'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Invoice Currency'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Invoice Payment Terms'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Invoice Submission Method'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Invoice Submission Method'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Cost Center Id'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'PO Deliver To'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'PO Item Amount (INR)'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Cost Center Id'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Cost Center Id'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'PO Item Amount (INR)'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'PO Item Amount (INR)'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'PO Item Amount (INR)'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Cost Center Id'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'PO Item Amount (INR)'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'PO Item Amount (INR)'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'PO Item Amount (INR)'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'PO Item Amount (INR)'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'PO Item Amount (INR)'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'PO Item Amount (INR)'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Cost Center Id'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'PO Item Amount (INR)'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'PO Item Amount (INR)'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Cost Center Id'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'PO Item Amount (INR)'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Cost Center Id'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'PO Item Amount (INR)'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Cost Center Id'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'PO Item Amount (INR)'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'PO Item Amount (INR)'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'PO Item Amount (INR)'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'PO Item Amount (INR)'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'PO Item Amount (INR)'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'PO Item Amount (INR)'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Cost Center Id'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'PO Item Amount (INR)'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'PO Item Amount (INR)'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Cost Center Id'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'PO Item Amount (INR)'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Cost Center Id'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'PO Item Amount (INR)'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'Cost Center Id'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'PO Item Amount (INR)'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'PO Item Amount (INR)'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'PO Item Amount (INR)'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'PO Item Amount (INR)'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'PO Item Amount (INR)'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'None'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'None'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'None'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'None'
# requests.HTTPError 400 Client Error: Bad Request for url: https://editor.signavio.com/g/api/pi-graphql/signal Syntax error at 4:31 'None'
# requests.HTTPError 400 Client Error: Bad Request for url: https://editor.signavio.com/g/api/pi-graphql/signal Syntax error at 5:23 'None'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'None'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'None'
# requests.HTTPError 400 Client Error: Bad Request for url: https://editor.signavio.com/g/api/pi-graphql/signal Syntax error at 5:4 'DURATION'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'None'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'None'
# requests.HTTPError 400 Client Error: Bad Request for url: https://editor.signavio.com/g/api/pi-graphql/signal Syntax error at 5:23 'None'
# requests.HTTPError 400 Client Error: Bad Request for url: https://editor.signavio.com/g/api/pi-graphql/signal Syntax error at 5:23 'None'
# requests.HTTPError 400 Client Error: Bad Request for url: https://editor.signavio.com/g/api/pi-graphql/signal Syntax error at 4:28 'None'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'None'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'None'
# requests.HTTPError 400 Client Error: Bad Request for url: https://editor.signavio.com/g/api/pi-graphql/signal Syntax error at 5:4 'DURATION'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'None'
# requests.HTTPError 400 Client Error: Bad Request for url: https://editor.signavio.com/g/api/pi-graphql/signal Syntax error at 5:23 'None'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'None'
# requests.HTTPError 400 Client Error: Bad Request for url: https://editor.signavio.com/g/api/pi-graphql/signal Syntax error at 4:31 'None'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'None'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'None'
# requests.HTTPError 400 Client Error: Bad Request for url: https://editor.signavio.com/g/api/pi-graphql/signal Syntax error at 5:24 'None'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'None'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'None'
# requests.HTTPError 400 Client Error: Bad Request for url: https://editor.signavio.com/g/api/pi-graphql/signal Syntax error at 5:23 'None'
# requests.HTTPError 400 Client Error: Bad Request for url: https://editor.signavio.com/g/api/pi-graphql/signal Syntax error at 8:38 'None'
# requests.HTTPError 400 Client Error: Bad Request for url: https://editor.signavio.com/g/api/pi-graphql/signal Syntax error at 4:26 'None'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'None'
# requests.HTTPError 400 Client Error: Bad Request for url: https://editor.signavio.com/g/api/pi-graphql/signal Syntax error at 5:4 'DURATION'
# requests.HTTPError 400 Client Error: Bad Request for url: https://editor.signavio.com/g/api/pi-graphql/signal Syntax error at 4:26 'None'
# requests.HTTPError 400 Client Error: Bad Request for url: https://editor.signavio.com/g/api/pi-graphql/signal Syntax error at 5:23 'None'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'None'
# requests.HTTPError 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal ColumnNotFound: 'None'
# API validation for 4881 took: 2017.4546780586243 0.4133281454740062 per signal call

# %%
dfp.shape #, dfp[['APIvalidated']] .value_counts().nlargest(100) #, dfp[['FragmentWordCount']] .value_counts().nlargest(100) 
#dfp[['APIvalidated']] .value_counts().nlargest(100)
dfp[['APIvalidated','validationDataResponse','validationDataLength',"workspace_name"]].describe()
# Out:
#        APIvalidated  \
# count          4881
# unique          925
# top              ok
# freq           2581
#
#                                                                                            validationDataResponse  \
# count                                                                                                        4881
# unique                                                                                                       1177
# top     Error 422 Client Error: Unprocessable Entity for url: https://editor.signavio.com/g/api/pi-graphql/signal
# freq                                                                                                         2274
#
#         validationDataLength            workspace_name
# count                   4881                      4881
# unique                   125                         2
# top                        0  Solutions Demo Workspace
# freq                    2347                      4827

# %% [markdown]
# ## Here we WRITE/READ data frames with validated queries to CSV

# %%
#%%script echo skipping
# Here we save the above schemas and signals DF to CSV files:
from pathlib import Path
import datetime

valid_pdf = dfp[(dfp['APIvalidated'] == "ok")  & (dfp['validationDataLength'] >= 1) & (dfp['validationDataResponse'] != '[[null]]') & (dfp['validationDataResponse'] != '[[0.0]]')] 

date_str = datetime.datetime.now().strftime("%Y-%m-%dT%H_%M_%S")
filepath_validated = Path(f'subset_validated_{valid_pdf.shape[0]}_signals_{date_str}.csv')  

# WRITE
filepath_validated.parent.mkdir(parents=True, exist_ok=True)  
valid_pdf.to_csv(filepath_validated)  
print(f"WRITE CSV file with Validated Signals: {filepath_validated} shape {valid_pdf.shape}")
# Out:
# WRITE CSV file with Validated Signals: subset_validated_1542_signals_2024-02-01T11_33_27.csv shape (1542, 24)

# %%
# READ
filepath_validated_read="subset_validated_1542_signals_2024-02-01T11_33_27.csv" # shape (1542, 24)
valid_pdf = pd.read_csv(filepath_validated_read)  
print(f"READ CSV files with Validated Signals: {filepath_validated_read}")
print("Number of API-Validated queries with NON-empty data output:", valid_pdf.shape)
# Out:
# READ CSV files with Validated Signals: subset_validated_1542_signals_2024-02-01T11_33_27.csv
# Number of API-Validated queries with NON-empty data output: (1542, 25)

# %% [markdown]
# # >>>>>>>>>>>>>>>>>>>>>>> From here open another notebook

# %% [markdown]
# ## Error Analysis

# %%
print("Total Number of API calls/Signals:",  df1.shape)
print("Number of API calls/Signals with errors:",  dfp[(dfp['APIvalidated'] != "ok") ].shape)
# Number of Validated queries with  reasonable data response
print("Number of API-Validated queries: ",dfp[dfp['APIvalidated'] == "ok" ]['validationDataLength'].shape)

#dfp[(dfp['APIvalidated'] == "ok")  & (dfp['validationDataLength'] == 1) & (dfp['validationDataResponse'] != '[[null]]') ] [['query','meta','validationDataResponse']]
#valid_pdf = dfp[(dfp['APIvalidated'] == "ok")  & (dfp['validationDataLength'] >= 1) & (dfp['validationDataResponse'] != '[[null]]') & (dfp['validationDataResponse'] != '[[0.0]]')] 
#valid_pdf = dfp[(dfp['APIvalidated'] == "ok")  & (dfp['validationDataLength'] >= 1) & (dfp['validationDataResponse'] != '[[null]]') ] 
print("Number of API-Validated queries with NON-empty data output:", valid_pdf.shape)

valid_pdf[['query','meta','validationDataResponse','descriptionWordCount','description','workspace_name',"parser_column_names","parser_values","parser"]]
# Out:
# Total Number of API calls/Signals: (4264, 24)
# Number of API calls/Signals with errors: (2009, 24)
# Number of API-Validated queries:  (2255,)
# Number of API-Validated queries with NON-empty data output: (2042, 24)
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           query  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            \nSELECT\nCOUNT(case_id)\nFROM "defaultview-545"\n
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            \nSELECT\nCOUNT(case_id) FILTER (WHERE \n\t(SELECT BOOL_AND(\n NOT event_name IN ('Close Incident')))\n)\nFROM "defaultview-545"\n
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 \nSELECT\nCOUNT(case_id) FILTER (WHERE \n\t(SELECT BOOL_OR(\n event_name IN ('Close Incident')))\n)\nFROM "defaultview-545"\n
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     \nSELECT\nCOUNT(case_id) FILTER(\n\tWHERE (SELECT COUNT(DISTINCT event_name)) = (SELECT COUNT(event_name))\n\t)\nFROM "defaultview-545"\n
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      \nSELECT\nCOUNT(case_id) FILTER (WHERE \n\t (SELECT BOOL_OR(\n event_name IN ('Incident Response SLA Breached','Incident Resolution SLA Breached')))\n)/ COUNT(case_id)\n* 100\nFROM "defaultview-545"\n
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         ...
# 9752                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        SELECT COUNT(1) AS "Case Count"\nFROM "defaultview-9"\nWHERE "Risk Class" = 'Not evaluated'\nAND\nBEHAVIOUR\n         (event_name = 'Create Invoice') AS create_invoice,\n         ("Risk Class" = 'Not evaluated') AS no_risk_evaluation\nMATCHES (no_risk_evaluation ~> create_invoice)\nAND \nNOT event_name MATCHES ('Create Invoice' ~> 'Receive Payment')\nAND\nNOT event_name MATCHES ('Create Invoice' ~> 'Cancel Invoice')
# 9753                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              SELECT "Risk Class", \n\t   COUNT(1) AS "Case Count"\nFROM "defaultview-9"\nWHERE event_name \nMATCHES ('Create Invoice')\nAND\nNOT event_name \nMATCHES ('Create Invoice'\n\t\t~> 'Receive Payment')\nAND\nNOT event_name \nMATCHES ('Create Invoice'\n\t\t~> 'Cancel Invoice')\nGROUP BY 1\nORDER BY 2 DESC
# 9754  SELECT "Month"\n\t   ,count_started AS "Cases Started During Month"\n       ,count_finished AS "Cases Completed During Month"\n       ,IF(count_started IS NOT NULL, count_started, 0) - IF(LAG(count_finished) OVER () IS NOT NULL, LAG(count_finished) OVER (), 0) AS "Active Cases"\n  FROM (SELECT "Month"\n             , SUM(count_started) OVER (ORDER BY "Month") AS count_started\n             , SUM(count_finished) OVER (ORDER BY "Month") AS count_finished\n          FROM (SELECT "Month"\n                     , COUNT(1) FILTER (WHERE started = 1) AS count_started\n                     , COUNT(1) FILTER (WHERE started = 0) AS count_finished\n                  FROM (SELECT date_trunc('month', (SELECT FIRST(end_time))) AS "Month", \n                  \t\t\t   1 AS started\n                        FROM "defaultview-9"\n                        UNION ALL\n                        SELECT date_trunc('month', (SELECT LAST(end_time))) AS "Month", \n                               0 AS started\n                        FROM "defaultview-9") AS sub\n                 GROUP BY 1\n                 FILL TIMESERIES('month')\n               ) AS sub2\n       ) AS sub3
# 9755                                                                                                                 SELECT "Month"\n       ,IF(count_started IS NOT NULL, count_started, 0) - IF(LAG(count_finished) OVER () IS NOT NULL, LAG(count_finished) OVER (), 0) AS "Active Cases"\n  FROM (SELECT "Month"\n             , SUM(count_started) OVER (ORDER BY "Month") AS count_started\n             , SUM(count_finished) OVER (ORDER BY "Month") AS count_finished\n          FROM (SELECT "Month"\n                     , COUNT(1) FILTER (WHERE started = 1) AS count_started\n                     , COUNT(1) FILTER (WHERE started = 0) AS count_finished\n                  FROM (SELECT date_trunc('month', (SELECT FIRST(end_time))) AS "Month", \n                  \t\t\t   1 AS started\n                        FROM "defaultview-9"\n                        UNION ALL\n                        SELECT date_trunc('month', (SELECT LAST(end_time))) AS "Month", \n                               0 AS started\n                        FROM "defaultview-9") AS sub\n                 GROUP BY 1\n                 FILL TIMESERIES('month')\n               ) AS sub2\n       ) AS sub3
# 9946                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            \nSELECT\nMEDIAN(\n\t\t\t   (SELECT LAST(end_time)\n\t\t\t    WHERE event_name = 'Receive Return')\n\t\t\t    -\n               (SELECT FIRST(end_time)\n                WHERE event_name = 'Create Return Request')\n                )\nFROM "defaultview-2"\n
#
#                meta  \
# 0            metric
# 1            metric
# 2            metric
# 5            metric
# 6            metric
# ...             ...
# 9752  investigation
# 9753  investigation
# 9754  investigation
# 9755  investigation
# 9946         metric
#
#                                                                                     validationDataResponse  \
# 0                                                                                              [[87812.0]]
# 1                                                                                              [[87812.0]]
# 2                                                                                                  [[0.0]]
# 5                                                                                              [[80161.0]]
# 6                                                                                                  [[0.0]]
# ...                                                                                                    ...
# 9752                                                                                             [[102.0]]
# 9753                           [["Not evaluated", 102.0], ["High", 44.0], ["Medium", 34.0], ["Low", 16.0]]
# 9754  [[1546300800000.0, 804.0, 395.0, 804.0], [1548979200000.0, 1110.0, 825.0, 715.0], [1551398400000.0,
# 9755  [[1546300800000.0, 804.0], [1548979200000.0, 715.0], [1551398400000.0, 545.0], [1554076800000.0, 430
# 9946                                                                                       [[592882500.0]]
#
#       descriptionWordCount  \
# 0                        5
# 1                        5
# 2                        5
# 5                       25
# 6                        8
# ...                    ...
# 9752                     0
# 9753                     0
# 9754                     0
# 9755                     0
# 9946                    55
#
#                                                                                                                                                                                                                                                                                                                                           description  \
# 0                                                                                                                                                                                                                                                                                                                   Total number of created incidents
# 1                                                                                                                                                                                                                                                                                                                      Total number of open incidents
# 2                                                                                                                                                                                                                                                                                                                  Total number of resolved incidents
# 5                                                                                                                                                                                                  Percentage of incidents that are resolved without any rework. Rework is defined here as any case that contains the same event name more than once.
# 6                                                                                                                                                                                                                                                                                                     Percentage of cases that have breached the SLAs
# ...                                                                                                                                                                                                                                                                                                                                               ...
# 9752
# 9753
# 9754
# 9755
# 9946  Median cycle time for a returns processing, ie the median cycle time between creating a return request and receiving the return. Cycle time is the time between two recorded events, in this case the first recorded instance of the 'Create Return Request' event, and last recorded instance of the 'Return Received' event across all cases.
#
#                 workspace_name  \
# 0     Solutions Demo Workspace
# 1     Solutions Demo Workspace
# 2     Solutions Demo Workspace
# 5     Solutions Demo Workspace
# 6     Solutions Demo Workspace
# ...                        ...
# 9752                Process AI
# 9753                Process AI
# 9754                Process AI
# 9755                Process AI
# 9946                Process AI
#
#                                                 parser_column_names  \
# 0                                                       ["case_id"]
# 1                                         ["case_id", "event_name"]
# 2                                         ["case_id", "event_name"]
# 5                                         ["case_id", "event_name"]
# 6                                         ["case_id", "event_name"]
# ...                                                             ...
# 9752         ["no_risk_evaluation", "event_name", "create_invoice"]
# 9753                                                 ["event_name"]
# 9754  ["end_time", "count_started", "count_finished", "date_trunc"]
# 9755  ["end_time", "count_started", "count_finished", "date_trunc"]
# 9946                                     ["event_name", "end_time"]
#
#                                                                                                               parser_values  \
# 0                                                                                                                        []
# 1                                                                                                        ["Close Incident"]
# 2                                                                                                        ["Close Incident"]
# 5                                                                                                                        []
# 6                                             ["100", "Incident Response SLA Breached", "Incident Resolution SLA Breached"]
# ...                                                                                                                     ...
# 9752  ["Not evaluated", "Case Count", "Cancel Invoice", "defaultview-9", "Receive Payment", "Create Invoice", "Risk Class"]
# 9753                                        ["Cancel Invoice", "Receive Payment", "Create Invoice", "Risk Class", "1", "2"]
# 9754      ["month", "Month", "defaultview-9", "Cases Started During Month", "Active Cases", "Cases Completed During Month"]
# 9755                                                                    ["Active Cases", "month", "defaultview-9", "Month"]
# 9946                                                                            ["Receive Return", "Create Return Request"]
#
#         parser
# 0     Signavio
# 1     Signavio
# 2     Signavio
# 5     Signavio
# 6     Signavio
# ...        ...
# 9752    regexp
# 9753  Signavio
# 9754    regexp
# 9755    regexp
# 9946  Signavio
#
# [2042 rows x 9 columns]

# %%
valid_pdf['parser'].value_counts() , valid_pdf[['meta']].value_counts() 
#valid_pdf[['workspace_name']].value_counts() 
#valid_pdf[['process']].value_counts()
# Out:
# (parser
#  Signavio    1671
#  regexp       371
#  Name: count, dtype: int64,
#  meta
#  dashboard        742
#  metric           676
#  investigation    624
#  Name: count, dtype: int64)

# %%
# Error analysis:
# requests.HTTPError 400 
#  df1=new_df[new_df['description'] != "" ]
#dfp["requests.HTTPError 400" in dfp['validationDataResponse'] ]
#dfp[dfp['validationDataResponse'].str.contains("requests.HTTPError 400")]
#dfp['APIvalidated'] 
#dfp[dfp['APIvalidated'] != "ok" ] [["query","APIvalidated","validationDataResponse"]] # ok

error_string="MissingDataSourceError"
error_string="MissingDataSourceError: Data source"
dbg = dfp[dfp['APIvalidated'].str.contains(error_string)] # 41 
#dbg = dfp[dfp['APIvalidated'].str.contains("ColumnNotFound")] # 1934
# dbg = dfp[dfp['APIvalidated'].str.contains("Syntax error at")]
print(dbg['APIvalidated'].describe()) #value_counts())
dbg[["query","APIvalidated","signalFragment","origin","meta"]]

#print(dbg['APIvalidated'].value_counts())
# Out:
# count                                                                3
# unique                                                               2
# top       MissingDataSourceError: Data source 'This_Process' not found
# freq                                                                 2
# Name: APIvalidated, dtype: object
#                                                                                                                                                                                                                                                                                query  \
# 499                                                                                                                                                                                     SELECT\nAVG(\n\t(SELECT LAST(end_time)) - (SELECT FIRST(end_time))\n    )\nFROM This_Process
# 6072  SELECT "PO Vendor Name", "PO Vendor Number", "PO Vendor Master Cash Discount Days 1", "PO Vendor Master Cash Discount Days 2", "PO Vendor Master Net Payment Days", "PO Vendor Master Terms of Payment Key"\nFROM "This_Process"\nWHERE "PO Vendor Name" IS not NULL\nLIMIT 25
# 6352                                                           SELECT \nCOUNT ("CASE_ID") AS "No. of Cases", \n"PR Plant" AS "PR Plant",\n"PR Type"\nFROM "defaultview-4"\n--WHERE (EVENT_NAME MATCHES ('Clear Invoice') AND EVENT_NAME MATCHES ('Create PR Item'))\nORDER BY 1 DESC
#
#                                                        APIvalidated  \
# 499    MissingDataSourceError: Data source 'This_Process' not found
# 6072   MissingDataSourceError: Data source 'This_Process' not found
# 6352  MissingDataSourceError: Data source 'defaultview-4' not found
#
#                                                                                                                                                                                                                                                                       signalFragment  \
# 499                                                                                                                                                                                     SELECT\nAVG(\n\t(SELECT LAST(end_time)) - (SELECT FIRST(end_time))\n    )\nFROM This_Process
# 6072  SELECT "PO Vendor Name", "PO Vendor Number", "PO Vendor Master Cash Discount Days 1", "PO Vendor Master Cash Discount Days 2", "PO Vendor Master Net Payment Days", "PO Vendor Master Terms of Payment Key"\nFROM "This_Process"\nWHERE "PO Vendor Name" IS not NULL\nLIMIT 25
# 6352                                                           SELECT \nCOUNT ("CASE_ID") AS "No. of Cases", \n"PR Plant" AS "PR Plant",\n"PR Type"\nFROM "defaultview-4"\n--WHERE (EVENT_NAME MATCHES ('Clear Invoice') AND EVENT_NAME MATCHES ('Create PR Item'))\nORDER BY 1 DESC
#
#                                                                                                                                                                          origin  \
# 499                                                                               ../data/pia-dashboards/ewm-outbound/Manage Warehouse and Inventory (Outbound) in SAP EWM.json
# 6072                  ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE/DELETE)/dashboards/zz - PO Vendor Dashboard_2023-12-04.json
# 6352  ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE/DELETE)/investigations/Presales Template - HZL POV_Insights_2023-12-04.json
#
#                meta
# 499       dashboard
# 6072      dashboard
# 6352  investigation

# %%
col='IncidentPriority'
vdf[vdf["name"] ==  col]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, name, isVisible, dataType, processVariableId, filter, __typename, view, process]
# Index: []

# %%
indx=5976
#df[['query',"signalFragment","view","origin","workspace_name"]][indx]
df.loc[[indx]][['query',"signalFragment","view","origin","workspace_name",'parser',"parser_column_names","parser_values"]]
# Out:
#                                                                                                                                                                                                               query  \
# 5976  \nSELECT\nCOUNT("Last FI Invoice ID") FILTER(\n\tWHERE "Last FI Invoice Item Cash Discount Days 1" IS NULL\n\t\tOR "Last FI Invoice Item Cash Discount Days 1" = 0)\nFROM "defaultview-124"\n
#
#                                                                                                                                         signalFragment  \
# 5976  SELECT COUNT("Last FI Invoice ID") FILTER(\n\tWHERE ${itp_cash_discount_terms} IS NULL\n\t\tOR ${itp_cash_discount_terms} = 0) FROM THIS_PROCESS
#
#                  view  \
# 5976  defaultview-124
#
#                                                                                                                           origin  \
# 5976  ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE/DELETE)/metrics/metrics.json
#
#      workspace_name    parser parser_column_names  \
# 5976     Process AI  Signavio                  []
#
#                                                                  parser_values
# 5976  ["Last FI Invoice Item Cash Discount Days 1", "0", "Last FI Invoice ID"]

# %%
s = df['query'].loc[[indx]].to_list()[0] #, df.loc[[indx]]['workspace_name']
f =  df['signalFragment'].loc[[indx]].to_list()[0] 
print(s)
f
# Out:
# SELECT
# COUNT("Last FI Invoice ID") FILTER(
# 	WHERE "Last FI Invoice Item Cash Discount Days 1" IS NULL
# 		OR "Last FI Invoice Item Cash Discount Days 1" = 0)
# FROM "defaultview-124"
# 'SELECT COUNT("Last FI Invoice ID") FILTER(\n\tWHERE ${itp_cash_discount_terms} IS NULL\n\t\tOR ${itp_cash_discount_terms} = 0) FROM THIS_PROCESS'

# %% [markdown]
# ### Validate SINGLE signal against log DB

# %%
indx=5976
signal,signalFragment, view, origin, workspacename = df[['query',"signalFragment","view","origin","workspace_name"]][indx:indx+1].values.tolist()[0]
print(signal,signalFragment, view,workspace_name)
#API_validation(query,workspace_name, auth=auth)
# Out:
# SELECT
# COUNT("Last FI Invoice ID") FILTER(
# 	WHERE "Last FI Invoice Item Cash Discount Days 1" IS NULL
# 		OR "Last FI Invoice Item Cash Discount Days 1" = 0)
# FROM "defaultview-124"
#                  SELECT COUNT("Last FI Invoice ID") FILTER(
# 	WHERE ${itp_cash_discount_terms} IS NULL
# 		OR ${itp_cash_discount_terms} = 0) FROM THIS_PROCESS defaultview-124 Process AI

# %%
indx=1113 # query	description	meta	metric_vars	view	signalFragment	process	
indx=5976
signal,signalFragment, view, origin, workspacename = df[['query',"signalFragment","view","origin","workspace_name"]][indx:indx+1].values.tolist()[0]
print(signal,signalFragment, view,workspace_name)
def sfromt(signal,view):
    return f'{signal}'.replace("THIS_PROCESS",f'"{view}"')
signal_endpoint = system_instance + '/g/api/pi-graphql/signal'
view1="defaultview-01"
view1=view
signalFragment=""" SELECT
   COUNT(distinct case_id) AS OnTimeManufacturing
FROM
   THIS_PROCESS
"""
q = {'query': sfromt(signal=signalFragment,view=view1)}
q = {'query': s}
print(origin, "EXEC:",q['query'])


workspacename="Solutions Demo Workspace"
#workspacename="Process AI"

cookies=auth[workspacename]["cookies"]
headers=auth[workspacename]["headers"]

query_request = requests.post(
        signal_endpoint,
        cookies=cookies,
        headers=headers,
        json=q)
print(query_request.json().keys())
print(query_request.json())
#d = query_request.json()["data"]
if "data" in query_request.json().keys():
    d = query_request.json()["data"]
    print("data type", type(d), len(d), json.dumps(d))
else:
    print(query_request.json()['message'])

#print("data type np:", type(d), len(np.asarray(d)), np.asarray(d))
#np.asarray(d)

#print(d,len(d))
# Out:
# ../data/From_API/Solutions Demo Workspace/000_DEMO✨ - Dashboards PTP ECC & S4H (DO NOT CHANGE/DELETE)/metrics/metrics.json EXEC:
# SELECT
# COUNT("Last FI Invoice ID") FILTER(
# 	WHERE "Last FI Invoice Item Cash Discount Days 1" IS NULL
# 		OR "Last FI Invoice Item Cash Discount Days 1" = 0)
# FROM "defaultview-124"
#
# dict_keys(['header', 'data'])
# {'header': [{'columnName': 'COUNT(Last FI Invoice ID)', 'columnAlias': 'COUNT(Last FI Invoice ID)', 'columnRole': 'MEASURE', 'dataType': 'NUMBER'}], 'data': [[139.0]]}
# data type <class 'list'> 1 [[139.0]]

# %% [markdown]
# ## Investigation and plots of the  Complexity of the Signals DF1

# %%
dfp[["name","query","description","meta","metric_vars","view","signalFragment"]].head(n=5)
# Out:
#                                  name  \
# 0   Total number of created incidents
# 1      Total number of open incidents
# 2  Total number of resolved incidents
# 3               Average response time
# 4             Average resolution time
#
#                                                                                                                                                                                                                                        query  \
# 0                                                                                                                                                                         \nSELECT\nCOUNT(case_id)\nFROM "defaultview-545"\n
# 1                                                                                         \nSELECT\nCOUNT(case_id) FILTER (WHERE \n\t(SELECT BOOL_AND(\n NOT event_name IN ('Close Incident')))\n)\nFROM "defaultview-545"\n
# 2                                                                                              \nSELECT\nCOUNT(case_id) FILTER (WHERE \n\t(SELECT BOOL_OR(\n event_name IN ('Close Incident')))\n)\nFROM "defaultview-545"\n
# 3                      \nSELECT\nAVG(\n\t(SELECT LAST(end_time)\n\t\tWHERE event_name IN ('Assign Incident to User'))\n\t-(SELECT FIRST(end_time)\n\t\tWHERE event_name IN ('Create Incident'))\n)\nFROM "defaultview-545"\n
# 4  \nSELECT\nAVG(\n\t(SELECT LAST(end_time)\n\t\tWHERE event_name IN ('Close Incident', 'Mark Incident as Resolved'))\n\t-(SELECT FIRST(end_time)\n\t\tWHERE event_name IN ('Create Incident'))\n)\nFROM "defaultview-545"\n
#
#                                              description    meta  \
# 0                      Total number of created incidents  metric
# 1                         Total number of open incidents  metric
# 2                     Total number of resolved incidents  metric
# 3  Average time from incident creation to first response  metric
# 4  Average time from incident creation to its resolution  metric
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             metric_vars  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    {}
# 1                                                                                                                                                                                                                                                                                                                                                                                  {'incident_closure_events': {'name': 'incident_closure_events', 'description': "Events defining the closing events of a case, for example 'Close Incident'", 'defaultValues': [{'defaultValue': "'Close Incident'", 'sourceSystems': ['SERVICENOW']}], 'value': "'Close Incident'"}}
# 2                                                                                                                                                                                                                                                                                                                                                                                  {'incident_closure_events': {'name': 'incident_closure_events', 'description': "Events defining the closing events of a case, for example 'Close Incident'", 'defaultValues': [{'defaultValue': "'Close Incident'", 'sourceSystems': ['SERVICENOW']}], 'value': "'Close Incident'"}}
# 3                                             {'response_events': {'name': 'response_events', 'description': "Events defining the response to a recently opened case, for example 'Assign ticket', 'Create ticket'", 'defaultValues': [{'defaultValue': "'Assign Incident to User'", 'sourceSystems': ['SERVICENOW']}], 'value': "'Assign Incident to User'"}, 'incident_creation_events': {'name': 'incident_creation_events', 'description': "Events defining the start events of a case, for example 'Create Problem', 'Create Incident'", 'defaultValues': [{'defaultValue': "'Create Incident'", 'sourceSystems': ['SERVICENOW']}], 'value': "'Create Incident'"}}
# 4  {'resolution_events': {'name': 'resolution_events', 'description': "Events defining the resolution of a case, for example 'Close Incident', 'Mark Incident as Resolved'", 'defaultValues': [{'defaultValue': "'Close Incident', 'Mark Incident as Resolved'", 'sourceSystems': ['SERVICENOW']}], 'value': "'Close Incident', 'Mark Incident as Resolved'"}, 'incident_creation_events': {'name': 'incident_creation_events', 'description': "Events defining the start events of a case, for example 'Create Problem', 'Create Incident'", 'defaultValues': [{'defaultValue': "'Create Incident'", 'sourceSystems': ['SERVICENOW']}], 'value': "'Create Incident'"}}
#
#               view  \
# 0  defaultview-545
# 1  defaultview-545
# 2  defaultview-545
# 3  defaultview-545
# 4  defaultview-545
#
#                                                                                                                                                                                     signalFragment
# 0                                                                                                                                                          SELECT COUNT(case_id) FROM THIS_PROCESS
# 1                                                                SELECT COUNT(case_id) FILTER (WHERE \n\t(SELECT BOOL_AND(\n NOT event_name IN (${incident_closure_events})))\n) FROM THIS_PROCESS
# 2                                                                     SELECT COUNT(case_id) FILTER (WHERE \n\t(SELECT BOOL_OR(\n event_name IN (${incident_closure_events})))\n) FROM THIS_PROCESS
# 3    SELECT AVG(\n\t(SELECT LAST(end_time)\n\t\tWHERE event_name IN (${response_events}))\n\t-(SELECT FIRST(end_time)\n\t\tWHERE event_name IN (${incident_creation_events}))\n) FROM THIS_PROCESS
# 4  SELECT AVG(\n\t(SELECT LAST(end_time)\n\t\tWHERE event_name IN (${resolution_events}))\n\t-(SELECT FIRST(end_time)\n\t\tWHERE event_name IN (${incident_creation_events}))\n) FROM THIS_PROCESS

# %%
### Investigation and plots of the  Complexity of the Signals DF1
# plot distr
col='FragmentLength'
#col="descriptionLength"
#col="nameLength"
col="FragmentWordCount"

#col='validationDataLength'
col="descriptionWordCount"
#bins=df[col].quantile([0,.05,0.1,0.15,0.20,0.25,0.3,0.35,0.40,0.45,0.5,0.55,0.6,0.65,0.70,0.75,0.80,0.85,0.90,0.95,1]).to_list()
#bins=[50,100,150,200,250,300,350,400,450,500,550, 600, 700, 800,1000] #,2000,8000]

binwidth=1
rmax=200
rmin=0

#rmax=10000
#rmin=1000
#banwidth=10
dfplot=dfp[dfp['APIvalidated'] == "ok" ]
data_binned = dfplot[(dfplot[col]>rmin)&(dfplot[col]<rmax)]

plt.figure().set_figwidth(15)
bins=range(min(data_binned[col]), max(data_binned[col]) + binwidth, binwidth)
data_binned[col].plot(kind='hist', edgecolor='white', linewidth=1, bins=bins, alpha=0.3, histtype='barstacked', color='steelblue', title=f'Word Count distribution for {col}')
plt.xlabel("length")
plt.ylabel("Samples count")

data_binned[col].describe() #.loc[['count','min','max']]



#plt.rcParams['figure.figsize'] = [25, 5]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/d071932/PycharmProjects/foundationmodel-benchmark-1/SignavioText2Signal/notebooks/LoadSignalsFromCSV.ipynb Cell 54 line 2
#      <a href='vscode-notebook-cell:/Users/d071932/PycharmProjects/foundationmodel-benchmark-1/SignavioText2Signal/notebooks/LoadSignalsFromCSV.ipynb#Y104sZmlsZQ%3D%3D?line=14'>15</a> rmin=0
#      <a href='vscode-notebook-cell:/Users/d071932/PycharmProjects/foundationmodel-benchmark-1/SignavioText2Signal/notebooks/LoadSignalsFromCSV.ipynb#Y104sZmlsZQ%3D%3D?line=16'>17</a> #rmax=10000
#      <a href='vscode-notebook-cell:/Users/d071932/PycharmProjects/foundationmodel-benchmark-1/SignavioText2Signal/notebooks/LoadSignalsFromCSV.ipynb#Y104sZmlsZQ%3D%3D?line=17'>18</a> #rmin=1000
#      <a href='vscode-notebook-cell:/Users/d071932/PycharmProjects/foundationmodel-benchmark-1/SignavioText2Signal/notebooks/LoadSignalsFromCSV.ipynb#Y104sZmlsZQ%3D%3D?line=18'>19</a> #banwidth=10
# ---> <a href='vscode-notebook-cell:/Users/d071932/PycharmProjects/foundationmodel-benchmark-1/SignavioText2Signal/notebooks/LoadSignalsFromCSV.ipynb#Y104sZmlsZQ%3D%3D?line=19'>20</a> dfplot=dfp[dfp['APIvalidated'] == "ok" ]
#      <a href='vscode-notebook-cell:/Users/d071932/PycharmProjects/foundationmodel-benchmark-1/SignavioText2Signal/notebooks/LoadSignalsFromCSV.ipynb#Y104sZmlsZQ%3D%3D?line=20'>21</a> data_binned = dfplot[(dfplot[col]>rmin)&(dfplot[col]<rmax)]
#      <a href='vscode-notebook-cell:/Users/d071932/PycharmProjects/foundationmodel-benchmark-1/SignavioText2Signal/notebooks/LoadSignalsFromCSV.ipynb#Y104sZmlsZQ%3D%3D?line=22'>23</a> plt.figure().set_figwidth(15)
#
# NameError: name 'dfp' is not defined

# %%
col1="FragmentLength"
col2='descriptionLength'
col1="FragmentWordCount"
col2="descriptionWordCount"
#col2="nameWordCount"
dfplot=dfp[dfp['APIvalidated'] == "ok" ]
datapd=dfplot[[col1,col2]]
datapd.describe()
bin_x = np.arange(0, 300, 5)
bin_y = np.arange(0, 40, 1)

bin_x = np.arange(0, 150, 1)
bin_y = np.arange(0, 50, 1)
plt.figure().set_figwidth(13)
title=f"Statistics on Complexity: {col1}/{col2}"
plt.title(title)
plt.hist2d(data=datapd, x=col1, y=col2, cmin=0.3, cmap='turbo',bins=[bin_x, bin_y])
plt.xlabel(col1)
plt.ylabel(col2)

plt.colorbar()

# %%
#df2=df1[df1['APIvalidated'] == "ok" ]
#df2.shape
#df1[df1['APIvalidated'] != "ok" ]
#df2

# %% [markdown]
# # Export for Training

# %%
from hashlib import blake2b
def get_unique_file_name_hashlib(x,filename_from=['name',"description","signalFragment","query"]):
    string=str(("+").join([x[col] for col in filename_from]))
    out = blake2b(string.encode("utf-8"),digest_size=5).hexdigest()
    return out

def writejson(row, path="training_data", columns=[]):
  filename = pathlib.Path(os.path.join( path, row["filename"]+'.json'))
  pathlib.Path(filename.parent).mkdir(parents=True, exist_ok=True)
  if len(columns) >0:
    js=json.loads(row[columns].to_json())
  else:
    js=json.loads(row.to_json())
  #print (filename, row[columns].to_json())
  if "view_columns" in js.keys():
  #  print(js["view_columns"])
     js["view_columns"]=json.loads(js["view_columns"])
  try:
    with open(filename, "w") as outfile:
      json.dump(js, outfile, indent=2)
      #outfile.write(row.to_json())
      return "saved"
  except Exception as e:
    print(e)
    return "saving failed"
def get_view_columns(x):
  """_summary_
  Insert column names as stringified json to output table element
  Args:
      x (_type_): _description_

  Returns:
      _type_: _description_
  """
  out = json.dumps(vdf[vdf["view"] ==  str(x["view"]) ]["name"].to_list())
  return out

# %% [markdown]
# ## Actual export - per each row as JSON happens here
# for 4267 records takes 11 sec - fast from scratch remove previous attempts

# %%
#dfp[(dfp['name'] == N)].describe()
dfp.columns
# Out:
# Index(['Unnamed: 0', 'name', 'query', 'description', 'meta', 'metric_vars',
#        'view', 'signalFragment', 'process', 'origin', 'workspace_name',
#        'FragmentWordCount', 'descriptionWordCount', 'nameWordCount',
#        'FragmentLength', 'descriptionLength', 'nameLength',
#        'parser_column_names', 'parser_values', 'parser_error', 'parser',
#        'APIvalidated', 'validationDataResponse', 'validationDataLength',
#        'view_columns', 'filename', 'json_filename_saved'],
#       dtype='object')

# %%
# what to save?
#df_export=dfp.head(n=3)
df_export = dfp[(dfp['APIvalidated'] == "ok")  
                & (dfp['FragmentWordCount'] > 30)  
                & (dfp['validationDataResponse'] != '[[null]]') 
                & (dfp['validationDataResponse'] != "[[0.0]]") 
                & (dfp['validationDataResponse'] !="[]")
                ] 
#df_export=dfp
print("Number of Signals:", df_export.shape)
df_export[['name','description','view','query',"meta","signalFragment",'validationDataResponse','parser', 'parser_column_names', 'parser_values']]
# Out:
# Number of Signals: (647, 27)
#                                                                          name  \
# 483                      Fraction of total average cycle time spent on rework
# 505                                               Median Cycle Time over Time
# 512                                                   Overview of WTs Status
# 624                              Average Number of Changes per Case Over Time
# 625                                    Percent of Cases with Rework Over Time
# ...                                                                       ...
# 9636  Case Count & Cycle Time (Approve to Pay Invoice) by Bill to Location Id
# 9644   Case Count & Cycle Time (Create PR to PR Approval) by PO Business Unit
# 9646   Case Count & Cycle Time (PR Approval to Create PO) by PO Business Unit
# 9648        Case Count & Cycle Time (Create PR to PR Approval) by PO Supplier
# 9650        Case Count & Cycle Time (PR Approval to Create PO) by PO Supplier
#
#                                                                                                                      description  \
# 483                                            Ratio between net average cycle time spent on rework and total average cycle time
# 505
# 512   Overview of different completion Status for Warehouse Task. Only Cases with Event 'Create Warehouse Task'  are considered.
# 624
# 625
# ...                                                                                                                          ...
# 9636
# 9644
# 9646
# 9648
# 9650
#
#                  view  \
# 483   defaultview-545
# 505   defaultview-545
# 512   defaultview-545
# 624   defaultview-545
# 625   defaultview-545
# ...               ...
# 9636  defaultview-545
# 9644  defaultview-545
# 9646  defaultview-545
# 9648  defaultview-545
# 9650  defaultview-545
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 query  \
# 483                                                                                                                                                                                                                                                                                                                                 \nSELECT\n((AVG(\n\t(SELECT LAST(end_time) - FIRST(end_time))\n\t)\n\tFILTER (WHERE (SELECT BOOL_OR (occurrence > 1)\n\t\tFROM (SELECT OCCURRENCE(event_name) AS occurrence) AS sub)\n\t\t))\n-\n(AVG(\n\t(SELECT LAST(end_time) - FIRST(end_time))\n\t))\n)\n/(AVG(\n\t(SELECT LAST(end_time) - FIRST(end_time))\n\t))\nFROM "defaultview-545"\n
# 505                                                                                                                                                                                                                                                                                                                                                                                                                                           SELECT\n    DATE_TRUNC('quarter', (SELECT FIRST(end_time))) as Quarter,\n   \nMEDIAN((SELECT LAST(end_time)) - (SELECT FIRST(end_time))) AS "Median Cycle Time"\n\nFROM "defaultview-545"\nORDER BY 1 ASC NULLS FIRST\nFILL TIMESERIES('QUARTER'), NULL
# 512   SELECT \n\nCASE \nWHEN (\n(SELECT COUNT(event_name)\nWHERE event_name = 'Create Warehouse Task') > 0\nAND\n(SELECT COUNT(event_name)\nWHERE (event_name = 'Create Warehouse Task' )) =\n (SELECT COUNT(event_name)\nWHERE (event_name = 'Confirm Warehouse Task'))) \nTHEN  'WTs completed'\n\nWHEN (SELECT COUNT(event_name)\nWHERE (event_name = 'Create Warehouse Task' )) >\n(SELECT COUNT(event_name)\nWHERE (event_name = 'Confirm Warehouse Task')) \nTHEN 'WTs partially completed'\n\nWHEN (SELECT COUNT(event_name)\nWHERE (event_name = 'Create Warehouse Task' )) = 0\nTHEN 'W/o WTs'\n\nELSE NULL\nEND AS "WTs Status",\ncount (case_id) AS "No. of Cases"\nFROM "defaultview-545"
# 624                                                                                                                                                                                                                                                                                                                                                        SELECT\n    DATE_TRUNC('month', (SELECT FIRST(end_time))) as Month,\n    \n    COUNT (CASE_ID) \n\tFILTER (WHERE (SELECT BOOL_OR (EVENT_NAME ILIKE '%Update%' \n\t\tOR EVENT_NAME ILIKE '%Change%'))) \n/ COUNT (CASE_ID) * 100 AS "Change Rate"\n    \nFROM "defaultview-545"\nORDER BY 1 ASC NULLS FIRST\nFILL TIMESERIES('MONTH'), NULL
# 625                                                                                                                                                                                                                                                                                                                                        SELECT\n    DATE_TRUNC('month', (SELECT FIRST(end_time))) as Month,\n    \n    COUNT (CASE_ID) \n\tFILTER (WHERE (SELECT BOOL_OR (occurrence > 1) \n    \tFROM (SELECT OCCURRENCE(EVENT_NAME) AS occurrence) AS sub)) \n/ COUNT (CASE_ID) * 100 AS "Rework Rate"\n    \nFROM "defaultview-545"\nORDER BY 1 ASC NULLS FIRST\nFILL TIMESERIES('MONTH'), NULL
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# 9636                                                                                                                                                                                                                                                                                                                                                                          SELECT \nCOUNT(CASE_ID) AS "No. of Cases",\nAVG ((SELECT LAST (END_TIME) FILTER (WHERE EVENT_NAME = 'Pay Invoice')) - (SELECT FIRST (END_TIME) FILTER (WHERE EVENT_NAME = 'Approve Invoice'))) AS "Avg. Cycle Time (Approve to Pay Invoice)",\n"Bill to Location Id"\nFROM "defaultview-545"\nORDER BY 1 DESC\nLIMIT 10
# 9644                                                                                                                                                                                                                                                                                                                                                                           SELECT \nCOUNT(CASE_ID) AS "No. of Cases",\nAVG ((SELECT LAST (END_TIME) FILTER (WHERE EVENT_NAME = 'Approve PR item')) - (SELECT FIRST (END_TIME) FILTER (WHERE EVENT_NAME = 'Create PR item'))) AS "Avg. Cycle Time (Crt PR to PR Apprvl)", \n"PO Business Unit"\nFROM "defaultview-545"\nORDER BY 1 DESC\nLIMIT 100
# 9646                                                                                                                                                                                                                                                                                                                                                                           SELECT \nCOUNT(CASE_ID) AS "No. of Cases",\nAVG ((SELECT LAST (END_TIME) FILTER (WHERE EVENT_NAME = 'Create PO Item')) - (SELECT FIRST (END_TIME) FILTER (WHERE EVENT_NAME = 'Approve PR item'))) AS "Avg. Cycle Time (PR Apprvl to Crt PO)", \n"PO Business Unit"\nFROM "defaultview-545"\nORDER BY 1 DESC\nLIMIT 100
# 9648                                                                                                                                                                                                                                                                                                                                                        SELECT \nCOUNT(CASE_ID) AS "No. of Cases",\nAVG ((SELECT LAST (END_TIME) FILTER (WHERE EVENT_NAME = 'Approve PR item')) - (SELECT FIRST (END_TIME) FILTER (WHERE EVENT_NAME = 'Create PR item'))) AS "Avg. Cycle Time (Crt PR to PR Apprvl)", \n"PO Item Supplier Id" AS "PO Supplier"\nFROM "defaultview-545"\nORDER BY 1 DESC\nLIMIT 10
# 9650                                                                                                                                                                                                                                                                                                                                                       SELECT \nCOUNT(CASE_ID) AS "No. of Cases",\nAVG ((SELECT LAST (END_TIME) FILTER (WHERE EVENT_NAME = 'Create PO Item')) - (SELECT FIRST (END_TIME) FILTER (WHERE EVENT_NAME = 'Approve PR item'))) AS "Avg. Cycle Time (PR Apprvl to Crt PO)", \n"PO Item Supplier Id" AS "PO Supplier"\nFROM "defaultview-545"\nORDER BY 1 DESC\nLIMIT 100
#
#                meta  \
# 483          metric
# 505       dashboard
# 512       dashboard
# 624       dashboard
# 625       dashboard
# ...             ...
# 9636  investigation
# 9644  investigation
# 9646  investigation
# 9648  investigation
# 9650  investigation
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   signalFragment  \
# 483                                                                                                                                                                                                                                                                                                                                           SELECT ((AVG(\n\t(SELECT LAST(end_time) - FIRST(end_time))\n\t)\n\tFILTER (WHERE (SELECT BOOL_OR (${minimum_loops_condition})\n\t\tFROM (SELECT OCCURRENCE(event_name) AS occurrence) AS sub)\n\t\t))\n-\n(AVG(\n\t(SELECT LAST(end_time) - FIRST(end_time))\n\t))\n)\n/(AVG(\n\t(SELECT LAST(end_time) - FIRST(end_time))\n\t)) FROM THIS_PROCESS
# 505                                                                                                                                                                                                                                                                                                                                                                                                                                           SELECT\n    DATE_TRUNC('quarter', (SELECT FIRST(end_time))) as Quarter,\n   \nMEDIAN((SELECT LAST(end_time)) - (SELECT FIRST(end_time))) AS "Median Cycle Time"\n\nFROM THIS_PROCESS\nORDER BY 1 ASC NULLS FIRST\nFILL TIMESERIES('QUARTER'), NULL
# 512   SELECT \n\nCASE \nWHEN (\n(SELECT COUNT(event_name)\nWHERE event_name = 'Create Warehouse Task') > 0\nAND\n(SELECT COUNT(event_name)\nWHERE (event_name = 'Create Warehouse Task' )) =\n (SELECT COUNT(event_name)\nWHERE (event_name = 'Confirm Warehouse Task'))) \nTHEN  'WTs completed'\n\nWHEN (SELECT COUNT(event_name)\nWHERE (event_name = 'Create Warehouse Task' )) >\n(SELECT COUNT(event_name)\nWHERE (event_name = 'Confirm Warehouse Task')) \nTHEN 'WTs partially completed'\n\nWHEN (SELECT COUNT(event_name)\nWHERE (event_name = 'Create Warehouse Task' )) = 0\nTHEN 'W/o WTs'\n\nELSE NULL\nEND AS "WTs Status",\ncount (case_id) AS "No. of Cases"\nFROM THIS_PROCESS
# 624                                                                                                                                                                                                                                                                                                                                                        SELECT\n    DATE_TRUNC('month', (SELECT FIRST(end_time))) as Month,\n    \n    COUNT (CASE_ID) \n\tFILTER (WHERE (SELECT BOOL_OR (EVENT_NAME ILIKE '%Update%' \n\t\tOR EVENT_NAME ILIKE '%Change%'))) \n/ COUNT (CASE_ID) * 100 AS "Change Rate"\n    \nFROM THIS_PROCESS\nORDER BY 1 ASC NULLS FIRST\nFILL TIMESERIES('MONTH'), NULL
# 625                                                                                                                                                                                                                                                                                                                                        SELECT\n    DATE_TRUNC('month', (SELECT FIRST(end_time))) as Month,\n    \n    COUNT (CASE_ID) \n\tFILTER (WHERE (SELECT BOOL_OR (occurrence > 1) \n    \tFROM (SELECT OCCURRENCE(EVENT_NAME) AS occurrence) AS sub)) \n/ COUNT (CASE_ID) * 100 AS "Rework Rate"\n    \nFROM THIS_PROCESS\nORDER BY 1 ASC NULLS FIRST\nFILL TIMESERIES('MONTH'), NULL
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ...
# 9636                                                                                                                                                                                                                                                                                                                                                                        SELECT \nCOUNT(CASE_ID) AS "No. of Cases",\nAVG ((SELECT LAST (END_TIME) FILTER (WHERE EVENT_NAME = 'Pay Invoice')) - (SELECT FIRST (END_TIME) FILTER (WHERE EVENT_NAME = 'Approve Invoice'))) AS "Avg. Cycle Time (Approve to Pay Invoice)",\n"Bill to Location Id"\nFROM "THIS_PROCESS"\nORDER BY 1 DESC\nLIMIT 10
# 9644                                                                                                                                                                                                                                                                                                                                                                         SELECT \nCOUNT(CASE_ID) AS "No. of Cases",\nAVG ((SELECT LAST (END_TIME) FILTER (WHERE EVENT_NAME = 'Approve PR item')) - (SELECT FIRST (END_TIME) FILTER (WHERE EVENT_NAME = 'Create PR item'))) AS "Avg. Cycle Time (Crt PR to PR Apprvl)", \n"PO Business Unit"\nFROM "THIS_PROCESS"\nORDER BY 1 DESC\nLIMIT 100
# 9646                                                                                                                                                                                                                                                                                                                                                                         SELECT \nCOUNT(CASE_ID) AS "No. of Cases",\nAVG ((SELECT LAST (END_TIME) FILTER (WHERE EVENT_NAME = 'Create PO Item')) - (SELECT FIRST (END_TIME) FILTER (WHERE EVENT_NAME = 'Approve PR item'))) AS "Avg. Cycle Time (PR Apprvl to Crt PO)", \n"PO Business Unit"\nFROM "THIS_PROCESS"\nORDER BY 1 DESC\nLIMIT 100
# 9648                                                                                                                                                                                                                                                                                                                                                      SELECT \nCOUNT(CASE_ID) AS "No. of Cases",\nAVG ((SELECT LAST (END_TIME) FILTER (WHERE EVENT_NAME = 'Approve PR item')) - (SELECT FIRST (END_TIME) FILTER (WHERE EVENT_NAME = 'Create PR item'))) AS "Avg. Cycle Time (Crt PR to PR Apprvl)", \n"PO Item Supplier Id" AS "PO Supplier"\nFROM "THIS_PROCESS"\nORDER BY 1 DESC\nLIMIT 10
# 9650                                                                                                                                                                                                                                                                                                                                                     SELECT \nCOUNT(CASE_ID) AS "No. of Cases",\nAVG ((SELECT LAST (END_TIME) FILTER (WHERE EVENT_NAME = 'Create PO Item')) - (SELECT FIRST (END_TIME) FILTER (WHERE EVENT_NAME = 'Approve PR item'))) AS "Avg. Cycle Time (PR Apprvl to Crt PO)", \n"PO Item Supplier Id" AS "PO Supplier"\nFROM "THIS_PROCESS"\nORDER BY 1 DESC\nLIMIT 100
#
#                                                                                     validationDataResponse  \
# 483                                                                                  [[8.356719518634584]]
# 505   [[1443657600000.0, 111067202000.0], [1451606400000.0, 2000.0], [1459468800000.0, 2000.0], [146733120
# 512                                                                                 [["W/o WTs", 87812.0]]
# 624   [[1446336000000.0, 0.0], [1448928000000.0, 0.0], [1451606400000.0, 0.0], [1454284800000.0, 0.0], [14
# 625   [[1446336000000.0, 66.66666666666666], [1448928000000.0, 100.0], [1451606400000.0, 55.76923076923077
# ...                                                                                                    ...
# 9636  [[42542.0, 881107202.3121387, null], [26520.0, 3480953724.137931, "3000"], [9889.0, 7771202000.0, "3
# 9644  [[42542.0, null, null], [36751.0, null, "3000"], [2841.0, null, "1710"], [1957.0, null, "2"], [710.0
# 9646  [[42542.0, null, null], [36751.0, null, "3000"], [2841.0, null, "1710"], [1957.0, null, "2"], [710.0
# 9648  [[42542.0, null, null], [12350.0, null, "STRATUSSAFETY"], [9665.0, null, "STRATUSRETAIL"], [3324.0,
# 9650  [[42542.0, null, null], [12350.0, null, "STRATUSSAFETY"], [9665.0, null, "STRATUSRETAIL"], [3324.0,
#
#         parser  \
# 483   Signavio
# 505     regexp
# 512   Signavio
# 624     regexp
# 625     regexp
# ...        ...
# 9636  Signavio
# 9644  Signavio
# 9646  Signavio
# 9648  Signavio
# 9650  Signavio
#
#                                                  parser_column_names  \
# 483                         ["event_name", "end_time", "occurrence"]
# 505                                       ["DATE_TRUNC", "end_time"]
# 512                                        ["event_name", "case_id"]
# 624   ["EVENT_NAME", "BOOL_OR", "CASE_ID", "DATE_TRUNC", "end_time"]
# 625   ["EVENT_NAME", "BOOL_OR", "CASE_ID", "DATE_TRUNC", "end_time"]
# ...                                                              ...
# 9636                           ["CASE_ID", "EVENT_NAME", "END_TIME"]
# 9644                           ["CASE_ID", "EVENT_NAME", "END_TIME"]
# 9646                           ["CASE_ID", "EVENT_NAME", "END_TIME"]
# 9648                           ["CASE_ID", "EVENT_NAME", "END_TIME"]
# 9650                           ["CASE_ID", "EVENT_NAME", "END_TIME"]
#
#                                                                                                         parser_values
# 483                                                                                                             ["1"]
# 505                                                    ["QUARTER", "defaultview-545", "quarter", "Median Cycle Time"]
# 512   ["Create Warehouse Task", "WTs partially completed", "0", "Confirm Warehouse Task", "WTs completed", "W/o WTs"]
# 624                                      ["MONTH", "month", "Change Rate", "%Change%", "%Update%", "defaultview-545"]
# 625                                                              ["MONTH", "Rework Rate", "defaultview-545", "month"]
# ...                                                                                                               ...
# 9636                                             ["Bill to Location Id", "Approve Invoice", "Pay Invoice", "1", "10"]
# 9644                                            ["Approve PR item", "PO Business Unit", "100", "1", "Create PR item"]
# 9646                                            ["Approve PR item", "Create PO Item", "PO Business Unit", "100", "1"]
# 9648                                          ["Approve PR item", "Create PR item", "1", "PO Item Supplier Id", "10"]
# 9650                                         ["Approve PR item", "Create PO Item", "100", "1", "PO Item Supplier Id"]
#
# [647 rows x 10 columns]

# %%
# for 4267 records takes 14 sec - fast from scratch remove previous attempts 
# where to save ?
pathtosave="training_data_with_non_empty_description"
# Here we add to each row a new column with Original Data Base column names
df_export["view_columns"] =df_export.apply(lambda x: get_view_columns(x), axis=1)
# Here we add a md5 hash for each row and use it as json file name: 00a3ba06c5.json
df_export["filename"] = df_export.apply(lambda x: get_unique_file_name_hashlib(x,filename_from=['name',"description","signalFragment","query"]),  axis=1)
# Here we save each row to separate json file in dir: path
#df_export["json_filename_saved"]= df_export.apply(lambda row: writejson(row,path="training_data",columns=["filename","name","description","query","signalFragment","view_columns"] ), axis=1) # selected columns only
df_export["json_filename_saved"]= df_export.apply(lambda row: writejson(row,path=pathtosave), axis=1)
# Out:
# /var/folders/hb/_ptqrx710ljb_2f6664d20bh0000gn/T/ipykernel_55965/2213704140.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_export["view_columns"] =df_export.apply(lambda x: get_view_columns(x), axis=1)
# /var/folders/hb/_ptqrx710ljb_2f6664d20bh0000gn/T/ipykernel_55965/2213704140.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_export["filename"] = df_export.apply(lambda x: get_unique_file_name_hashlib(x,filename_from=['name',"description","signalFragment","query"]),  axis=1)
# /var/folders/hb/_ptqrx710ljb_2f6664d20bh0000gn/T/ipykernel_55965/2213704140.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_export["json_filename_saved"]= df_export.apply(lambda row: writejson(row,path=pathtosave), axis=1)

# %%
filename=os.path.join(pathtosave+".json") 
with open(filename, "w") as outfile:
      #json.dump(js, outfile, indent=2)
      outfile.write(df_export.to_json(orient="records"))

# %%
# check number of saved json files
! ls -l  $pathtosave/*.json | wc -l

df_export["json_filename_saved"].describe()
# Out:
#      755
# count       755
# unique        1
# top       saved
# freq        755
# Name: json_filename_saved, dtype: object

# %%
# dbg
# check if col with name is in total name in all views
col='2 - Blocker - FI-AR items previously dunned are cleared'
vdf[vdf["name"] ==  col]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, name, isVisible, dataType, processVariableId, filter, __typename, view, process]
# Index: []

# %% [markdown]
# #### Experiments (can skip)

# %%
# Experiments start here

query="""
SELECT
AVG(
	(SELECT LAST(end_time)
		WHERE event_name IN ('Close Incident', 'Mark Incident as Resolved'))
	-(SELECT FIRST(end_time)
		WHERE event_name IN ('Create Incident'))
)
FROM "defaultview-545"
"""

# print all column references (a and b)
for column in parse_one(query).find_all(exp.Column):
    print("column:", column) # name) #, column.alias_or_name, column.catalog )

for select in parse_one(query).find_all(exp.Select):
    print("select",select)
    for projection in select.expressions:
        print("p",projection)
        #for column in parse_one(projection).find_all(exp.Column):
        #    print("column:",column.alias_or_name, column.catalog )

# find all tables (x, y, z)
for table in parse_one(query).find_all(exp.Table):
    print("table:",table.name)

#find all values
for val in parse_one(query).find_all(exp.Literal):
    print("lit:",val ) # val.parent.args)

for val in parse_one(query).find_all(exp.Identifier):
    print("id:",val)

    
for el in parse_one(query).expressions:
    print(el)
#list(parse_one(query).find_all(exp.Var))
Signavio().Tokenizer.KEYWORDS['FILL']
indx=45
df1.iloc[indx]["signalFragment"]
#print("column:", column) # name) #, column.alias_or_name, column.catalog )

s="""SELECT COUNT(1) AS "Case Count"
FROM THIS_PROCESS
WHERE "Risk Class" = 'Not evaluated'
AND
BEHAVIOUR
         (event_name = 'Create Invoice') AS create_invoice,
         ("Risk Class" = 'Not evaluated') AS no_risk_evaluation
MATCHES (no_risk_evaluation ~> create_invoice)
AND 
NOT event_name MATCHES ('Create Invoice' ~> 'Receive Payment')
AND
NOT event_name MATCHES ('Create Invoice' ~> 'Cancel Invoice')
"""
sok='SELECT COUNT(1) AS Case_Count FROM "strview-1"'

s1='SELECT AVG(\n\t(SELECT LAST(end_time)\n\t\tWHERE event_name IN (${ato_goods_receipt_events}))\n\t-(SELECT FIRST(end_time)\n\t\tWHERE event_name IN (${ato_po_creation_events}))\n   ) FROM THIS_PROCESS'

#sqlglot.transpile(sql, read='doris', pretty=True)[0]
#sqlglot.transpile(s,read='doris', pretty=True)

s2="""
SELECT (\n\t\tCOUNT(1) FILTER (WHERE event_name MATCHES ('Create Invoice'~> 'Receive Payment'))\n /\n COUNT(1)\n ) * 100 AS "Standard Invoicing Compliance Rate"\n\nFROM THIS_PROCESS
"""
s2="""
SELECT COUNT(1) AS "Case Count"
FROM THIS_PROCESS
WHERE "Risk Class" = 'Not evaluated'
AND
BEHAVIOUR
 (event_name = 'Create Invoice') AS create_invoice,
 ("Risk Class" = 'Not evaluated') AS no_risk_evaluation
MATCHES (no_risk_evaluation ~> create_invoice)
AND 
NOT event_name MATCHES ('Create Invoice' ~> 'Receive Payment')
AND
NOT event_name MATCHES ('Create Invoice' ~> 'Cancel Invoice')
"""

s2="""
 SELECT "Month"
 ,IF(count_started IS NOT NULL, count_started, 0) - IF(LAG(count_finished) OVER () IS NOT NULL, LAG(count_finished) OVER (), 0) AS "Active Cases"
 FROM (SELECT "Month"
 , SUM(count_started) OVER (ORDER BY "Month") AS count_started
 , SUM(count_finished) OVER (ORDER BY "Month") AS count_finished
 FROM (SELECT "Month"
 , COUNT(1) FILTER (WHERE started = 1) AS count_started
 , COUNT(1) FILTER (WHERE started = 0) AS count_finished
 FROM (SELECT date_trunc('month', (SELECT FIRST(end_time))) AS "Month", 
 			 1 AS started
 FROM "defaultview-9"
 UNION ALL
 SELECT date_trunc('month', (SELECT LAST(end_time))) AS "Month", 
 0 AS started
 FROM "defaultview-9") AS sub
 GROUP BY 1
 FILL TIMESERIES('month')
 ) AS sub2
 ) AS sub3
"""

#Signavio=Signavio()
#print(s2)
#sqlglot.parse(s2,dialect=Signavio)
get_column_names_values(s1,dialect=Signavio)
#print(out)

#print(s2)

#s= json.dumps({"query":s})
#json.loads(s)["query"]

#get_column_names_values(repr(s))
#import sqlglot
#sqlglot.transpile(s, read="presto", write="hive")
#dfp.apply(lambda x: API_validation(x.query,x.workspace_name, auth=auth), axis=1 ).to_list()
#dfp[["parser_column_names","parser_values","parser_error","parser"]] = dfp.apply(lambda x: get_column_names_values(x.query,Signavio), axis=1).to_list()
#repr(s)
#dfp
# Out:
# column: end_time
# column: end_time
# column: event_name
# column: event_name
# select SELECT AVG((SELECT LAST(end_time) WHERE event_name IN ('Close Incident', 'Mark Incident as Resolved')) - (SELECT FIRST(end_time) WHERE event_name IN ('Create Incident'))) FROM "defaultview-545"
# p AVG((SELECT LAST(end_time) WHERE event_name IN ('Close Incident', 'Mark Incident as Resolved')) - (SELECT FIRST(end_time) WHERE event_name IN ('Create Incident')))
# select SELECT LAST(end_time) WHERE event_name IN ('Close Incident', 'Mark Incident as Resolved')
# p LAST(end_time)
# select SELECT FIRST(end_time) WHERE event_name IN ('Create Incident')
# p FIRST(end_time)
# table: defaultview-545
# lit: 'Close Incident'
# lit: 'Mark Incident as Resolved'
# lit: 'Create Incident'
# id: "defaultview-545"
# id: end_time
# id: end_time
# id: event_name
# id: event_name
# AVG((SELECT LAST(end_time) WHERE event_name IN ('Close Incident', 'Mark Incident as Resolved')) - (SELECT FIRST(end_time) WHERE event_name IN ('Create Incident')))
# ['["ato_goods_receipt_events", "event_name", "end_time", "ato_po_creation_events"]',
#  '[]',
#  '',
#  'Signavio']
